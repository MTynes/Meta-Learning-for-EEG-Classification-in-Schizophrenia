# %%
import pandas as pd
import numpy as np
import gdown
import os


# To improve the speed of setting up, retrieve only the files for the two groups used in training
# Swap with the line below to get the entire dataset as a zip file
# gdown.download('https://drive.google.com/uc?id=1-QTtycxsVNeym17zrMBSZCAAtEZEs05p', '/content/miniimagenet.zip', quiet=False)
gdown.download('https://drive.google.com/uc?id=1CZeMPRt4OZGJL_xQNfgi5evJW1PpA77l', '/content/miniimagenet.zip', quiet=False) # selected groups only
images_directory = '/content/miniimagenet/images/'
if not os.path.exists(images_directory):
  os.makedirs(images_directory) 
# !unzip -qq /content/miniimagenet.zip -d {images_directory}


# get the CSV with the list of all file names
mini_imagenet_file_list_csv = '/content/all_imagenet_file_names.csv'
gdown.download('https://drive.google.com/uc?id=1-1JiyyEC6JlnEi0H0x-JKIGEKjdI_Nea', mini_imagenet_file_list_csv, quiet=False)
file_list = pd.read_csv(mini_imagenet_file_list_csv)

selected_groups = ['n01532829', 'n01558993']
samples_miniimagenet = file_list[file_list['label'].isin(selected_groups)].groupby('label').first()

# Other options for group pairs
# n01532829, n01558993
# n02108551, n02108915
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CZeMPRt4OZGJL_xQNfgi5evJW1PpA77l
# To: /content/miniimagenet.zip
# 59.8MB [00:00, 76.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-1JiyyEC6JlnEi0H0x-JKIGEKjdI_Nea
# To: /content/all_imagenet_file_names.csv
# 2.27MB [00:00, 111MB/s]

# %% [markdown]
# <br>
# <br>
# For this analysis, the first two groups above are used n01532829 and n01558993. These are two similar-looking bird species. The goal is to train the classifier to detect minor details that distinguish the two groups.

# %%
# show a sample from the two selected classes

from PIL import Image
from importlib import reload 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

for image_path in samples_miniimagenet['filename'].unique():
    print('Sample for group ID ', image_path[:9])
    print(images_directory +  image_path)
    reload(plt)
    
    img=mpimg.imread(images_directory + image_path)
    #plt.close('all')
    imgplot = plt.imshow(img)
    plt.show()
# Out:
# Sample for group ID  n01532829
# /content/miniimagenet/images/n0153282900000006.jpg
# Sample for group ID  n01558993
# /content/miniimagenet/images/n0155899300000838.jpg

# %%
# Since the imagenet files are all in the same directory, they can be used as-is 
# with the maml-pytorch setup and do not need to be processed further at this point.
# However, the directory does need to be added to the Python training file

file_list[file_list['label'].isin(selected_groups)].to_csv(images_directory + '/train.csv')

# %%
#Get the EEG spectrograms zip file and unzip it
eeg_image_directory = '/content/eeg_sz_spectrograms'
gdown.download('https://drive.google.com/uc?id=1WZ1yIFE2bng0McnY_4UBJHqTttsXTTNX', '{}.zip'.format(eeg_image_directory), quiet=False) 
# !unzip -qq {eeg_image_directory}.zip -d {eeg_image_directory}
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1WZ1yIFE2bng0McnY_4UBJHqTttsXTTNX
# To: /content/eeg_sz_spectrograms.zip
# 44.2MB [00:00, 105MB/s]

# %%
# rename 
dl_link = '/content/eeg_sz_spectrograms/gen_data_20s_70pct_overlap_-_high_nfft_all_channels_sml/'
# !mv "{dl_link}/hc" {eeg_image_directory}
# !mv "{dl_link}/sz" {eeg_image_directory}

# %%
# Use EEG of Sz for validation and testing
# Extract files from an eeg_sz spectrogram directory where files are saved by subject

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split


rand_seed = 1
# List of raw patient file IDs that should be skipped based on categorization as outliers
ignore_list = ['h09', 'h10', 's10', 's11', 's12']
hc_subject_ids = ['hc' + str(i) for i in range(14) if "h{:02}".format(i) not in ignore_list] 
sz_subject_ids = ['sz' + str(i) for i in range(14) if "s{:02}".format(i) not in ignore_list] 
all_subject_ids = np.concatenate([hc_subject_ids, sz_subject_ids], axis=0)
validate_hc, test_hc = train_test_split(hc_subject_ids, test_size=0.5, random_state=rand_seed)
validate_sz, test_sz = train_test_split(sz_subject_ids, test_size=0.5, random_state=rand_seed)

validation_ids = np.concatenate([validate_hc, validate_sz])  
test_ids = np.concatenate([test_hc, test_sz]) 


print('\nSubjects assigned to groups using sklearn.model_selection.train_test_split')
print('Test group: ', ", ".join(test_ids), "\n")
print('Validation group: ', ", ".join(validation_ids), "\n")

  

from shutil import copyfile
import pandas as pd
import os 


test_images_output_directory = 'all_test_images'
validation_images_output_directory = 'all_validation_images'

if not os.path.exists(test_images_output_directory):
    os.mkdir(test_images_output_directory)
if not os.path.exists(validation_images_output_directory):
    os.mkdir(validation_images_output_directory)



# Note: CSV is only used for MAML and Prototypical networks
def gen_csv_and_copy_sz_files(image_dir, img_output_dir, participant_ids, output_name, split_with_csv=False):
    subdir_data = []
    for group in ['hc', 'sz']: #['Healthy_Control', 'Sz_Patient']:
        for pid in os.listdir(image_dir + '/' + group): # by participant IDs
            if pid in participant_ids:
              for file in os.listdir(image_dir + '/' + group + '/' + pid):
                file_data = {'filename': file, 'label': group}
                subdir_data.append(file_data)
                destination = img_output_dir + '/' + file if split_with_csv else  '{}/{}/{}'.format(img_output_dir, group, file)
                if not os.path.exists('{}/{}'.format(img_output_dir, group)):
                  os.makedirs('{}/{}'.format(img_output_dir, group))
                copyfile(image_dir + '/' + group + '/' + pid + '/' + file,  destination )
    if split_with_csv:
      pd.DataFrame(subdir_data).to_csv(img_output_dir + '/' + output_name)
    return pd.DataFrame(subdir_data)


df = gen_csv_and_copy_sz_files(image_dir=eeg_image_directory, 
                                img_output_dir=test_images_output_directory,
                                participant_ids=test_ids,
                               split_with_csv=True,
                                output_name= 'test.csv')
df = gen_csv_and_copy_sz_files(image_dir=eeg_image_directory, 
                                img_output_dir=validation_images_output_directory,
                                participant_ids=validation_ids, 
                               split_with_csv=True,
                                output_name= 'test.csv') #file must be name test.csv
print(df.head())
# Out:
# Subjects assigned to groups using sklearn.model_selection.train_test_split
# Test group:  hc2, hc3, hc4, hc12, hc1, hc6, sz2, sz3, sz4, sz9, sz1, sz6
#
# Validation group:  hc0, hc7, hc13, hc11, hc8, hc5, sz0, sz7, sz13, sz8, sz5
#
#      filename label
# 0  hc7_48.png    hc
# 1  hc7_70.png    hc
# 2  hc7_39.png    hc
# 3  hc7_50.png    hc
# 4   hc7_1.png    hc

# %%
# Get the project files from github
# !git clone https://github.com/MTynes/MAML-Pytorch.git maml_pytorch
# Out:
# Cloning into 'maml_pytorch'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 226 (delta 8), reused 7 (delta 3), pack-reused 209
# Receiving objects: 100% (226/226), 672.94 KiB | 1.97 MiB/s, done.
# Resolving deltas: 100% (129/129), done.

# %%
# !python /content/maml_pytorch/train_custom_dataset.py --help
# Out:
# usage: train_custom_dataset.py [-h] [--train_dir TRAIN_DIR]
#                                [--further_training_dir FURTHER_TRAINING_DIR]
#                                [--validation_dir VALIDATION_DIR]
#                                [--test_dir TEST_DIR]
#                                [--run_further_training RUN_FURTHER_TRAINING]
#                                [--epochs EPOCHS]
#                                [--further_training_epochs FURTHER_TRAINING_EPOCHS]
#                                [--n_way N_WAY] [--k_spt K_SPT] [--k_qry K_QRY]
#                                [--imgsz IMGSZ] [--imgc IMGC]
#                                [--task_num TASK_NUM] [--meta_lr META_LR]
#                                [--update_lr UPDATE_LR]
#                                [--update_step UPDATE_STEP]
#                                [--update_step_test UPDATE_STEP_TEST]
#                                [--accuracy_log_file ACCURACY_LOG_FILE]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --train_dir TRAIN_DIR
#                         train data directory
#   --further_training_dir FURTHER_TRAINING_DIR
#                         further training data directory
#   --validation_dir VALIDATION_DIR
#                         validation data directory
#   --test_dir TEST_DIR   test data directory
#   --run_further_training RUN_FURTHER_TRAINING
#                         Boolean for adding a second dataset for further
#                         training. Set as string. Case insensitive.
#   --epochs EPOCHS       Number of epochs
#   --further_training_epochs FURTHER_TRAINING_EPOCHS
#                         Number of epochs for further training cycle
#   --n_way N_WAY         n way
#   --k_spt K_SPT         k shot for support set
#   --k_qry K_QRY         k shot for query set
#   --imgsz IMGSZ         imgsz
#   --imgc IMGC           imgc
#   --task_num TASK_NUM   meta batch size, namely task num
#   --meta_lr META_LR     meta-level outer learning rate
#   --update_lr UPDATE_LR
#                         task-level inner update learning rate
#   --update_step UPDATE_STEP
#                         task-level inner update steps
#   --update_step_test UPDATE_STEP_TEST
#                         update steps for fine-tuning
#   --accuracy_log_file ACCURACY_LOG_FILE
#                         Output file for mean test accuracy

# %%
# run the training file

import timeit

start = timeit.default_timer()

n_epochs = 400 * 10000 # must be a multiple of 10000

train_dir = '/content/miniimagenet/images'
# !python /content/maml_pytorch/train_custom_dataset.py  --epochs {n_epochs} --run_further_training 'false'



stop = timeit.default_timer()
print('MAML execution time: {} hrs'.format((stop - start)/60/60) )
# Out:
# Namespace(accuracy_log_file='/content/mean_test_accuracy.txt', epochs=4000000, fine_tune_dir='/content/all_fine_tuning_images', fine_tuning_epochs=2000000, imgc=3, imgsz=84, k_qry=5, k_spt=1, meta_lr=0.001, n_way=2, run_fine_tuning=False, task_num=4, test_dir='/content/all_test_images', train_dir='/content/miniimagenet/images', update_lr=0.01, update_step=5, update_step_test=10, validation_dir='/content/all_validation_images')
# Meta(
#   (net): Learner(
#     conv2d:(ch_in:3, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:2, padding:0)
#     conv2d:(ch_in:32, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:2, padding:0)
#     conv2d:(ch_in:32, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:2, padding:0)
#     conv2d:(ch_in:32, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:1, padding:0)
#     flatten:()
#     linear:(in:800, out:2)
#
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 32x3x3x3 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 32x32x3x3 (GPU 0)]
#         (5): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (6): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (7): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (8): Parameter containing: [torch.cuda.FloatTensor of size 32x32x3x3 (GPU 0)]
#         (9): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (10): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (11): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (12): Parameter containing: [torch.cuda.FloatTensor of size 32x32x3x3 (GPU 0)]
#         (13): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (14): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (15): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (16): Parameter containing: [torch.cuda.FloatTensor of size 2x800 (GPU 0)]
#         (17): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#     )
#     (vars_bn): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (5): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (6): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (7): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#     )
#   )
# )
# Total trainable tensors: 30498
# shuffle DB :train, b:50, 2-way, 1-shot, 5-query, resize:84
# shuffle DB :test, b:50, 2-way, 1-shot, 5-query, resize:84
# shuffle DB :test, b:50, 2-way, 1-shot, 5-query, resize:84
#
#
#
# Epoch  0
# Training accuracies: 	 [0.625 0.425 0.425 0.425 0.425 0.425]
# Test accuracies: 	 [0.782 0.348 0.574 0.512 0.56  0.526 0.536 0.534 0.538 0.54  0.538]
# Mean test acc: 0.54443359375  Mean support loss:  0.156494140625   Mean query loss: 2.2734375
#
# Epoch  1
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [0.998 0.79  0.58  0.648 0.59  0.6   0.602 0.598 0.598 0.594 0.594]
# Mean test acc: 0.65380859375  Mean support loss:  0.09466552734375   Mean query loss: 1.5830078125
#
# Epoch  2
# Training accuracies: 	 [1.    1.    0.975 0.975 0.975 0.975]
# Test accuracies: 	 [1.    0.858 0.592 0.606 0.6   0.608 0.586 0.598 0.592 0.592 0.59 ]
# Mean test acc: 0.65625  Mean support loss:  0.1470947265625   Mean query loss: 1.8583984375
#
# Epoch  3
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.874 0.606 0.654 0.62  0.632 0.614 0.626 0.626 0.624 0.622]
# Mean test acc: 0.681640625  Mean support loss:  0.163818359375   Mean query loss: 1.5908203125
#
# Epoch  4
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.872 0.66  0.632 0.606 0.63  0.62  0.62  0.62  0.62  0.62 ]
# Mean test acc: 0.681640625  Mean support loss:  0.1600341796875   Mean query loss: 1.6630859375
#
# Epoch  5
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.878 0.682 0.628 0.644 0.628 0.62  0.61  0.61  0.61  0.608]
# Mean test acc: 0.68359375  Mean support loss:  0.211669921875   Mean query loss: 1.697265625
#
# Epoch  6
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.894 0.636 0.65  0.638 0.61  0.638 0.614 0.626 0.612 0.616]
# Mean test acc: 0.68505859375  Mean support loss:  0.1912841796875   Mean query loss: 1.375
#
# Epoch  7
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.936 0.622 0.612 0.59  0.612 0.594 0.61  0.608 0.608 0.608]
# Mean test acc: 0.6728515625  Mean support loss:  0.1639404296875   Mean query loss: 1.5947265625
#
# Epoch  8
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.934 0.674 0.656 0.64  0.65  0.626 0.636 0.636 0.636 0.634]
# Mean test acc: 0.7021484375  Mean support loss:  0.2376708984375   Mean query loss: 1.6865234375
#
# Epoch  9
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.91  0.63  0.624 0.638 0.63  0.614 0.624 0.624 0.624 0.624]
# Mean test acc: 0.685546875  Mean support loss:  0.1798095703125   Mean query loss: 1.5302734375
#
# Epoch  10
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.938 0.602 0.626 0.596 0.608 0.596 0.596 0.598 0.598 0.6  ]
# Mean test acc: 0.6689453125  Mean support loss:  0.22607421875   Mean query loss: 1.796875
#
# Epoch  11
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.942 0.614 0.624 0.606 0.614 0.612 0.612 0.612 0.612 0.612]
# Mean test acc: 0.67822265625  Mean support loss:  0.2020263671875   Mean query loss: 1.7509765625
#
# Epoch  12
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.93  0.634 0.612 0.61  0.614 0.614 0.614 0.614 0.614 0.61 ]
# Mean test acc: 0.6787109375  Mean support loss:  0.212158203125   Mean query loss: 1.94140625
#
# Epoch  13
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.918 0.602 0.632 0.606 0.608 0.614 0.612 0.612 0.612 0.612]
# Mean test acc: 0.67529296875  Mean support loss:  0.220947265625   Mean query loss: 1.7353515625
#
# Epoch  14
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.934 0.584 0.592 0.57  0.58  0.572 0.572 0.574 0.574 0.574]
# Mean test acc: 0.64794921875  Mean support loss:  0.2357177734375   Mean query loss: 1.9892578125
#
# Epoch  15
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.938 0.616 0.62  0.636 0.604 0.606 0.606 0.606 0.604 0.604]
# Mean test acc: 0.67626953125  Mean support loss:  0.2470703125   Mean query loss: 1.94140625
#
# Epoch  16
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.958 0.646 0.598 0.596 0.598 0.588 0.59  0.592 0.592 0.592]
# Mean test acc: 0.66796875  Mean support loss:  0.27734375   Mean query loss: 2.0625
#
# Epoch  17
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.952 0.624 0.606 0.61  0.6   0.606 0.602 0.606 0.606 0.606]
# Mean test acc: 0.67431640625  Mean support loss:  0.280517578125   Mean query loss: 1.96875
#
# Epoch  18
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.942 0.632 0.636 0.646 0.634 0.634 0.63  0.63  0.63  0.63 ]
# Mean test acc: 0.69482421875  Mean support loss:  0.24169921875   Mean query loss: 1.4375
#
# Epoch  19
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.948 0.632 0.626 0.638 0.622 0.626 0.624 0.624 0.624 0.624]
# Mean test acc: 0.68994140625  Mean support loss:  0.2298583984375   Mean query loss: 1.61328125
#
# Epoch  20
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.95  0.634 0.624 0.62  0.628 0.632 0.622 0.63  0.62  0.624]
# Mean test acc: 0.689453125  Mean support loss:  0.272705078125   Mean query loss: 1.6044921875
#
# Epoch  21
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.95  0.616 0.6   0.6   0.6   0.6   0.6   0.6   0.6   0.6  ]
# Mean test acc: 0.669921875  Mean support loss:  0.280029296875   Mean query loss: 1.9150390625
#
# Epoch  22
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.942 0.642 0.646 0.642 0.642 0.642 0.642 0.642 0.642 0.64 ]
# Mean test acc: 0.7021484375  Mean support loss:  0.264404296875   Mean query loss: 1.6630859375
#
# Epoch  23
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.954 0.644 0.61  0.626 0.6   0.62  0.6   0.612 0.602 0.602]
# Mean test acc: 0.67919921875  Mean support loss:  0.27001953125   Mean query loss: 1.84375
#
# Epoch  24
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.96  0.638 0.624 0.61  0.624 0.612 0.612 0.612 0.612 0.612]
# Mean test acc: 0.68310546875  Mean support loss:  0.298583984375   Mean query loss: 1.9072265625
#
# Epoch  25
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.976 0.61  0.612 0.588 0.588 0.588 0.588 0.588 0.588 0.588]
# Mean test acc: 0.6650390625  Mean support loss:  0.33837890625   Mean query loss: 1.873046875
#
# Epoch  26
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.976 0.664 0.632 0.644 0.63  0.626 0.63  0.616 0.62  0.62 ]
# Mean test acc: 0.6962890625  Mean support loss:  0.314453125   Mean query loss: 1.7685546875
#
# Epoch  27
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.958 0.682 0.656 0.656 0.672 0.656 0.654 0.654 0.654 0.654]
# Mean test acc: 0.7177734375  Mean support loss:  0.263427734375   Mean query loss: 1.4833984375
#
# Epoch  28
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.962 0.636 0.58  0.604 0.58  0.59  0.58  0.582 0.582 0.582]
# Mean test acc: 0.66162109375  Mean support loss:  0.3408203125   Mean query loss: 2.021484375
#
# Epoch  29
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.98  0.622 0.628 0.614 0.62  0.622 0.622 0.622 0.62  0.62 ]
# Mean test acc: 0.68798828125  Mean support loss:  0.3134765625   Mean query loss: 1.974609375
#
# Epoch  30
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.97  0.68  0.668 0.662 0.652 0.668 0.652 0.65  0.65  0.65 ]
# Mean test acc: 0.71826171875  Mean support loss:  0.32421875   Mean query loss: 1.7275390625
#
# Epoch  31
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.974 0.634 0.564 0.608 0.578 0.578 0.578 0.578 0.578 0.574]
# Mean test acc: 0.65869140625  Mean support loss:  0.32958984375   Mean query loss: 2.19140625
#
# Epoch  32
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.976 0.68  0.638 0.62  0.622 0.624 0.624 0.624 0.624 0.624]
# Mean test acc: 0.6962890625  Mean support loss:  0.319580078125   Mean query loss: 1.537109375
#
# Epoch  33
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.966 0.69  0.59  0.628 0.602 0.618 0.6   0.6   0.6   0.6  ]
# Mean test acc: 0.68115234375  Mean support loss:  0.400390625   Mean query loss: 1.8642578125
#
# Epoch  34
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.98  0.7   0.648 0.624 0.652 0.632 0.636 0.634 0.634 0.634]
# Mean test acc: 0.70654296875  Mean support loss:  0.34765625   Mean query loss: 1.634765625
#
# Epoch  35
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.966 0.69  0.62  0.62  0.624 0.622 0.618 0.618 0.616 0.614]
# Mean test acc: 0.69189453125  Mean support loss:  0.369384765625   Mean query loss: 1.6328125
#
# Epoch  36
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.976 0.71  0.646 0.654 0.654 0.654 0.654 0.654 0.654 0.654]
# Mean test acc: 0.71875  Mean support loss:  0.343017578125   Mean query loss: 1.525390625
#
# Epoch  37
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.984 0.662 0.63  0.63  0.632 0.634 0.63  0.628 0.626 0.626]
# Mean test acc: 0.6982421875  Mean support loss:  0.344482421875   Mean query loss: 1.7724609375
#
# Epoch  38
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.712 0.638 0.682 0.636 0.642 0.642 0.642 0.642 0.642]
# Mean test acc: 0.71533203125  Mean support loss:  0.429931640625   Mean query loss: 1.6845703125
#
# Epoch  39
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.986 0.734 0.628 0.662 0.63  0.656 0.64  0.64  0.64  0.64 ]
# Mean test acc: 0.71435546875  Mean support loss:  0.426513671875   Mean query loss: 1.6474609375
#
# Epoch  40
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.98  0.674 0.596 0.634 0.606 0.624 0.61  0.622 0.618 0.616]
# Mean test acc: 0.68896484375  Mean support loss:  0.38525390625   Mean query loss: 1.7890625
#
# Epoch  41
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.986 0.692 0.6   0.626 0.612 0.614 0.614 0.612 0.612 0.612]
# Mean test acc: 0.68896484375  Mean support loss:  0.41796875   Mean query loss: 1.75
#
# Epoch  42
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.984 0.74  0.654 0.694 0.654 0.682 0.652 0.664 0.654 0.654]
# Mean test acc: 0.72998046875  Mean support loss:  0.486328125   Mean query loss: 1.447265625
#
# Epoch  43
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.984 0.696 0.646 0.666 0.658 0.666 0.648 0.666 0.658 0.666]
# Mean test acc: 0.72314453125  Mean support loss:  0.4111328125   Mean query loss: 1.5546875
#
# Epoch  44
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.988 0.702 0.594 0.602 0.592 0.592 0.59  0.59  0.59  0.59 ]
# Mean test acc: 0.67529296875  Mean support loss:  0.437255859375   Mean query loss: 1.904296875
#
# Epoch  45
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.984 0.734 0.616 0.65  0.62  0.646 0.634 0.634 0.634 0.634]
# Mean test acc: 0.70751953125  Mean support loss:  0.51806640625   Mean query loss: 1.65234375
#
# Epoch  46
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.764 0.632 0.686 0.66  0.666 0.666 0.666 0.666 0.666]
# Mean test acc: 0.73291015625  Mean support loss:  0.52001953125   Mean query loss: 1.533203125
#
# Epoch  47
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.984 0.708 0.636 0.636 0.63  0.628 0.626 0.624 0.624 0.622]
# Mean test acc: 0.70166015625  Mean support loss:  0.478271484375   Mean query loss: 1.447265625
#
# Epoch  48
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.734 0.668 0.686 0.664 0.67  0.672 0.672 0.672 0.672]
# Mean test acc: 0.736328125  Mean support loss:  0.4697265625   Mean query loss: 1.4716796875
#
# Epoch  49
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.98  0.77  0.664 0.66  0.658 0.658 0.658 0.658 0.658 0.658]
# Mean test acc: 0.7294921875  Mean support loss:  0.50927734375   Mean query loss: 1.4873046875
#
# Epoch  50
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.968 0.758 0.678 0.688 0.682 0.69  0.672 0.688 0.672 0.682]
# Mean test acc: 0.74365234375  Mean support loss:  0.544921875   Mean query loss: 1.533203125
#
# Epoch  51
# Training accuracies: 	 [1.    1.    0.975 0.975 0.975 0.975]
# Test accuracies: 	 [1.    0.994 0.758 0.648 0.662 0.634 0.634 0.626 0.622 0.622 0.622]
# Mean test acc: 0.7109375  Mean support loss:  0.63427734375   Mean query loss: 1.6123046875
#
# Epoch  52
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.978 0.736 0.628 0.644 0.626 0.648 0.622 0.638 0.622 0.634]
# Mean test acc: 0.70703125  Mean support loss:  0.658203125   Mean query loss: 1.724609375
#
# Epoch  53
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.776 0.67  0.676 0.664 0.664 0.664 0.664 0.664 0.664]
# Mean test acc: 0.736328125  Mean support loss:  0.58447265625   Mean query loss: 1.61328125
#
# Epoch  54
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.782 0.638 0.662 0.65  0.65  0.65  0.65  0.65  0.65 ]
# Mean test acc: 0.7255859375  Mean support loss:  0.64892578125   Mean query loss: 1.6044921875
#
# Epoch  55
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.752 0.654 0.668 0.658 0.668 0.666 0.666 0.666 0.666]
# Mean test acc: 0.73291015625  Mean support loss:  0.650390625   Mean query loss: 1.4423828125
#
# Epoch  56
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.774 0.656 0.658 0.646 0.646 0.646 0.646 0.646 0.646]
# Mean test acc: 0.7236328125  Mean support loss:  0.771484375   Mean query loss: 1.8212890625
#
# Epoch  57
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.8   0.67  0.658 0.646 0.646 0.646 0.646 0.646 0.646]
# Mean test acc: 0.72705078125  Mean support loss:  0.7734375   Mean query loss: 1.7490234375
#
# Epoch  58
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.844 0.704 0.704 0.692 0.698 0.698 0.698 0.696 0.696]
# Mean test acc: 0.76611328125  Mean support loss:  0.82080078125   Mean query loss: 1.4736328125
#
# Epoch  59
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.812 0.652 0.654 0.636 0.654 0.64  0.644 0.646 0.646]
# Mean test acc: 0.7255859375  Mean support loss:  0.82275390625   Mean query loss: 1.6064453125
#
# Epoch  60
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.826 0.656 0.664 0.64  0.658 0.636 0.642 0.642 0.642]
# Mean test acc: 0.7275390625  Mean support loss:  0.84912109375   Mean query loss: 1.650390625
#
# Epoch  61
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.838 0.68  0.656 0.662 0.654 0.654 0.652 0.652 0.652]
# Mean test acc: 0.736328125  Mean support loss:  0.9169921875   Mean query loss: 1.751953125
#
# Epoch  62
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.778 0.682 0.662 0.668 0.662 0.66  0.658 0.658 0.65 ]
# Mean test acc: 0.734375  Mean support loss:  0.82763671875   Mean query loss: 1.3583984375
#
# Epoch  63
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.854 0.676 0.666 0.666 0.654 0.662 0.652 0.656 0.656]
# Mean test acc: 0.73974609375  Mean support loss:  0.83984375   Mean query loss: 1.4423828125
#
# Epoch  64
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.812 0.678 0.664 0.654 0.654 0.654 0.654 0.654 0.654]
# Mean test acc: 0.73388671875  Mean support loss:  0.80517578125   Mean query loss: 1.3857421875
#
# Epoch  65
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.802 0.616 0.646 0.61  0.624 0.62  0.62  0.62  0.62 ]
# Mean test acc: 0.70654296875  Mean support loss:  0.84716796875   Mean query loss: 1.69140625
#
# Epoch  66
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.828 0.66  0.678 0.656 0.656 0.66  0.66  0.66  0.66 ]
# Mean test acc: 0.73779296875  Mean support loss:  0.921875   Mean query loss: 1.734375
#
# Epoch  67
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.82  0.68  0.674 0.676 0.678 0.668 0.676 0.672 0.672]
# Mean test acc: 0.74658203125  Mean support loss:  0.97314453125   Mean query loss: 1.4521484375
#
# Epoch  68
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.862 0.658 0.674 0.67  0.658 0.668 0.662 0.66  0.66 ]
# Mean test acc: 0.7431640625  Mean support loss:  0.89208984375   Mean query loss: 1.41796875
#
# Epoch  69
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.812 0.646 0.66  0.644 0.66  0.642 0.656 0.642 0.656]
# Mean test acc: 0.72900390625  Mean support loss:  0.94775390625   Mean query loss: 1.6025390625
#
# Epoch  70
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.832 0.686 0.658 0.668 0.656 0.656 0.656 0.656 0.656]
# Mean test acc: 0.73828125  Mean support loss:  0.91064453125   Mean query loss: 1.4521484375
#
# Epoch  71
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.8   0.664 0.672 0.654 0.668 0.658 0.66  0.66  0.66 ]
# Mean test acc: 0.73583984375  Mean support loss:  0.91748046875   Mean query loss: 1.2939453125
#
# Epoch  72
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.86  0.66  0.684 0.656 0.656 0.656 0.656 0.656 0.654]
# Mean test acc: 0.73974609375  Mean support loss:  0.873046875   Mean query loss: 1.521484375
#
# Epoch  73
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.816 0.654 0.668 0.644 0.662 0.64  0.652 0.648 0.648]
# Mean test acc: 0.72998046875  Mean support loss:  0.89404296875   Mean query loss: 1.3720703125
#
# Epoch  74
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.852 0.686 0.674 0.682 0.682 0.672 0.67  0.67  0.67 ]
# Mean test acc: 0.75048828125  Mean support loss:  0.89892578125   Mean query loss: 1.4423828125
#
# Epoch  75
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.844 0.654 0.666 0.648 0.662 0.658 0.658 0.652 0.652]
# Mean test acc: 0.73583984375  Mean support loss:  0.9697265625   Mean query loss: 1.50390625
#
# Epoch  76
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.854 0.676 0.65  0.636 0.638 0.64  0.64  0.64  0.64 ]
# Mean test acc: 0.728515625  Mean support loss:  1.0595703125   Mean query loss: 1.505859375
#
# Epoch  77
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.87  0.708 0.696 0.69  0.698 0.684 0.686 0.686 0.686]
# Mean test acc: 0.763671875  Mean support loss:  1.0341796875   Mean query loss: 1.419921875
#
# Epoch  78
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.85  0.674 0.698 0.682 0.662 0.676 0.662 0.664 0.666]
# Mean test acc: 0.74853515625  Mean support loss:  1.021484375   Mean query loss: 1.548828125
#
# Epoch  79
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.876 0.728 0.69  0.708 0.704 0.704 0.704 0.702 0.702]
# Mean test acc: 0.7744140625  Mean support loss:  1.017578125   Mean query loss: 1.1884765625
#
# Epoch  80
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.858 0.698 0.648 0.666 0.654 0.658 0.652 0.652 0.652]
# Mean test acc: 0.73974609375  Mean support loss:  0.91064453125   Mean query loss: 1.6455078125
#
# Epoch  81
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.818 0.68  0.664 0.67  0.67  0.668 0.666 0.666 0.666]
# Mean test acc: 0.7421875  Mean support loss:  0.94482421875   Mean query loss: 1.3486328125
#
# Epoch  82
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.792 0.662 0.668 0.66  0.642 0.658 0.644 0.642 0.646]
# Mean test acc: 0.728515625  Mean support loss:  0.9306640625   Mean query loss: 1.4580078125
#
# Epoch  83
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.844 0.676 0.62  0.642 0.63  0.634 0.634 0.634 0.634]
# Mean test acc: 0.72265625  Mean support loss:  1.1162109375   Mean query loss: 1.5380859375
#
# Epoch  84
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.872 0.66  0.64  0.63  0.63  0.63  0.63  0.63  0.63 ]
# Mean test acc: 0.72216796875  Mean support loss:  1.1552734375   Mean query loss: 1.7841796875
#
# Epoch  85
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.876 0.708 0.69  0.67  0.678 0.678 0.678 0.678 0.678]
# Mean test acc: 0.75732421875  Mean support loss:  1.1220703125   Mean query loss: 1.4169921875
#
# Epoch  86
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.884 0.71  0.672 0.672 0.672 0.666 0.678 0.662 0.676]
# Mean test acc: 0.75341796875  Mean support loss:  1.2236328125   Mean query loss: 1.384765625
#
# Epoch  87
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.882 0.708 0.682 0.656 0.662 0.656 0.646 0.662 0.652]
# Mean test acc: 0.74609375  Mean support loss:  1.3994140625   Mean query loss: 1.3408203125
#
# Epoch  88
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.894 0.73  0.704 0.696 0.71  0.696 0.706 0.694 0.694]
# Mean test acc: 0.77490234375  Mean support loss:  1.1337890625   Mean query loss: 1.306640625
#
# Epoch  89
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.86  0.71  0.688 0.694 0.686 0.682 0.678 0.676 0.676]
# Mean test acc: 0.75927734375  Mean support loss:  1.263671875   Mean query loss: 1.3818359375
#
# Epoch  90
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.884 0.676 0.646 0.642 0.642 0.64  0.64  0.638 0.638]
# Mean test acc: 0.7314453125  Mean support loss:  1.1240234375   Mean query loss: 1.630859375
#
# Epoch  91
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.882 0.706 0.682 0.656 0.666 0.656 0.656 0.656 0.656]
# Mean test acc: 0.74658203125  Mean support loss:  1.259765625   Mean query loss: 1.521484375
#
# Epoch  92
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.916 0.694 0.66  0.67  0.666 0.646 0.662 0.646 0.658]
# Mean test acc: 0.7470703125  Mean support loss:  1.216796875   Mean query loss: 1.5380859375
#
# Epoch  93
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.898 0.728 0.696 0.706 0.698 0.694 0.694 0.692 0.69 ]
# Mean test acc: 0.77197265625  Mean support loss:  1.2900390625   Mean query loss: 1.1591796875
#
# Epoch  94
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.86  0.714 0.678 0.664 0.674 0.666 0.666 0.666 0.666]
# Mean test acc: 0.75048828125  Mean support loss:  1.1533203125   Mean query loss: 1.33203125
#
# Epoch  95
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.888 0.694 0.624 0.644 0.63  0.63  0.63  0.63  0.63 ]
# Mean test acc: 0.72705078125  Mean support loss:  1.1708984375   Mean query loss: 1.5478515625
#
# Epoch  96
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.89  0.738 0.668 0.674 0.674 0.674 0.672 0.668 0.666]
# Mean test acc: 0.7568359375  Mean support loss:  1.2109375   Mean query loss: 1.427734375
#
# Epoch  97
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.878 0.67  0.628 0.638 0.62  0.616 0.618 0.618 0.616]
# Mean test acc: 0.71826171875  Mean support loss:  1.232421875   Mean query loss: 1.537109375
#
# Epoch  98
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.898 0.742 0.696 0.678 0.694 0.69  0.69  0.688 0.688]
# Mean test acc: 0.76904296875  Mean support loss:  1.171875   Mean query loss: 1.23046875
#
# Epoch  99
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.868 0.746 0.708 0.684 0.712 0.688 0.702 0.696 0.696]
# Mean test acc: 0.77294921875  Mean support loss:  1.287109375   Mean query loss: 1.0224609375
#
# Epoch  100
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.884 0.69  0.646 0.64  0.628 0.642 0.63  0.64  0.62 ]
# Mean test acc: 0.72900390625  Mean support loss:  1.291015625   Mean query loss: 1.41796875
#
# Epoch  101
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.904 0.722 0.67  0.662 0.66  0.642 0.658 0.644 0.646]
# Mean test acc: 0.74609375  Mean support loss:  1.2373046875   Mean query loss: 1.40234375
#
# Epoch  102
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.882 0.714 0.694 0.672 0.69  0.684 0.684 0.682 0.68 ]
# Mean test acc: 0.76220703125  Mean support loss:  1.2451171875   Mean query loss: 1.421875
#
# Epoch  103
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.876 0.694 0.676 0.666 0.662 0.664 0.664 0.662 0.662]
# Mean test acc: 0.748046875  Mean support loss:  1.3359375   Mean query loss: 1.533203125
#
# Epoch  104
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.912 0.72  0.676 0.678 0.67  0.672 0.666 0.652 0.658]
# Mean test acc: 0.7548828125  Mean support loss:  1.287109375   Mean query loss: 1.4013671875
#
# Epoch  105
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.866 0.696 0.688 0.678 0.694 0.68  0.672 0.68  0.668]
# Mean test acc: 0.75634765625  Mean support loss:  1.244140625   Mean query loss: 1.33203125
#
# Epoch  106
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.872 0.718 0.648 0.674 0.656 0.658 0.65  0.666 0.652]
# Mean test acc: 0.74462890625  Mean support loss:  1.24609375   Mean query loss: 1.26953125
#
# Epoch  107
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.854 0.7   0.646 0.676 0.66  0.658 0.656 0.656 0.654]
# Mean test acc: 0.74169921875  Mean support loss:  1.1787109375   Mean query loss: 1.4697265625
#
# Epoch  108
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.816 0.728 0.698 0.712 0.704 0.704 0.702 0.702 0.702]
# Mean test acc: 0.76953125  Mean support loss:  1.03125   Mean query loss: 1.234375
#
# Epoch  109
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.782 0.68  0.67  0.668 0.668 0.65  0.666 0.66  0.664]
# Mean test acc: 0.73681640625  Mean support loss:  0.962890625   Mean query loss: 1.7109375
#
# Epoch  110
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.832 0.718 0.686 0.706 0.698 0.692 0.692 0.692 0.692]
# Mean test acc: 0.76416015625  Mean support loss:  1.0009765625   Mean query loss: 1.53125
#
# Epoch  111
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.828 0.712 0.702 0.704 0.702 0.7   0.7   0.7   0.7  ]
# Mean test acc: 0.767578125  Mean support loss:  0.9951171875   Mean query loss: 1.61328125
#
# Epoch  112
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.844 0.714 0.69  0.702 0.692 0.7   0.7   0.698 0.698]
# Mean test acc: 0.76708984375  Mean support loss:  1.0009765625   Mean query loss: 1.5546875
#
# Epoch  113
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.82  0.712 0.67  0.708 0.688 0.7   0.688 0.686 0.686]
# Mean test acc: 0.759765625  Mean support loss:  1.0126953125   Mean query loss: 1.3818359375
#
# Epoch  114
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.812 0.688 0.654 0.668 0.654 0.664 0.654 0.662 0.658]
# Mean test acc: 0.7373046875  Mean support loss:  1.013671875   Mean query loss: 1.7041015625
#
# Epoch  115
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.832 0.716 0.7   0.694 0.698 0.698 0.698 0.698 0.698]
# Mean test acc: 0.7666015625  Mean support loss:  0.97509765625   Mean query loss: 1.509765625
#
# Epoch  116
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.82  0.694 0.638 0.656 0.642 0.656 0.648 0.648 0.648]
# Mean test acc: 0.7314453125  Mean support loss:  0.99169921875   Mean query loss: 1.8505859375
#
# Epoch  117
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.824 0.692 0.642 0.666 0.654 0.65  0.65  0.65  0.65 ]
# Mean test acc: 0.73388671875  Mean support loss:  1.0185546875   Mean query loss: 1.80859375
#
# Epoch  118
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.818 0.726 0.682 0.698 0.698 0.696 0.696 0.694 0.692]
# Mean test acc: 0.763671875  Mean support loss:  0.9384765625   Mean query loss: 1.5087890625
#
# Epoch  119
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.828 0.68  0.674 0.65  0.666 0.652 0.666 0.652 0.666]
# Mean test acc: 0.7392578125  Mean support loss:  0.96875   Mean query loss: 1.8427734375
#
# Epoch  120
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.806 0.71  0.686 0.702 0.69  0.7   0.7   0.7   0.7  ]
# Mean test acc: 0.76318359375  Mean support loss:  1.0126953125   Mean query loss: 1.4384765625
#
# Epoch  121
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.824 0.686 0.68  0.668 0.676 0.668 0.67  0.668 0.666]
# Mean test acc: 0.74560546875  Mean support loss:  1.0751953125   Mean query loss: 1.4892578125
#
# Epoch  122
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.838 0.724 0.696 0.686 0.692 0.678 0.684 0.684 0.686]
# Mean test acc: 0.76025390625  Mean support loss:  1.1650390625   Mean query loss: 1.544921875
#
# Epoch  123
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.856 0.732 0.7   0.706 0.706 0.704 0.704 0.704 0.704]
# Mean test acc: 0.77392578125  Mean support loss:  1.0263671875   Mean query loss: 1.4736328125
#
# Epoch  124
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.784 0.702 0.682 0.672 0.672 0.672 0.672 0.672 0.672]
# Mean test acc: 0.7451171875  Mean support loss:  1.005859375   Mean query loss: 1.6689453125
#
# Epoch  125
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.8   0.682 0.666 0.672 0.666 0.666 0.666 0.666 0.666]
# Mean test acc: 0.740234375  Mean support loss:  1.00390625   Mean query loss: 1.541015625
#
# Epoch  126
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.818 0.708 0.686 0.702 0.694 0.69  0.692 0.69  0.69 ]
# Mean test acc: 0.76025390625  Mean support loss:  0.9462890625   Mean query loss: 1.4443359375
#
# Epoch  127
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.856 0.732 0.722 0.722 0.722 0.72  0.72  0.72  0.718]
# Mean test acc: 0.78466796875  Mean support loss:  0.94970703125   Mean query loss: 1.306640625
#
# Epoch  128
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.854 0.702 0.674 0.688 0.676 0.672 0.672 0.672 0.672]
# Mean test acc: 0.75244140625  Mean support loss:  1.0986328125   Mean query loss: 1.5380859375
#
# Epoch  129
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.988 0.828 0.692 0.674 0.688 0.68  0.68  0.68  0.678 0.678]
# Mean test acc: 0.75146484375  Mean support loss:  0.9248046875   Mean query loss: 1.7421875
#
# Epoch  130
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.828 0.678 0.642 0.642 0.642 0.64  0.64  0.64  0.64 ]
# Mean test acc: 0.72607421875  Mean support loss:  0.99267578125   Mean query loss: 1.7109375
#
# Epoch  131
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.822 0.664 0.67  0.656 0.65  0.666 0.652 0.656 0.656]
# Mean test acc: 0.7353515625  Mean support loss:  1.0341796875   Mean query loss: 1.73828125
#
# Epoch  132
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.846 0.726 0.69  0.704 0.692 0.692 0.692 0.692 0.692]
# Mean test acc: 0.765625  Mean support loss:  0.9482421875   Mean query loss: 1.6259765625
#
# Epoch  133
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.818 0.7   0.662 0.676 0.658 0.67  0.67  0.67  0.67 ]
# Mean test acc: 0.744140625  Mean support loss:  1.00390625   Mean query loss: 1.6943359375
#
# Epoch  134
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.818 0.658 0.65  0.646 0.646 0.646 0.646 0.646 0.646]
# Mean test acc: 0.72705078125  Mean support loss:  1.041015625   Mean query loss: 1.6416015625
#
# Epoch  135
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.82  0.696 0.686 0.678 0.67  0.674 0.668 0.668 0.668]
# Mean test acc: 0.74755859375  Mean support loss:  1.078125   Mean query loss: 1.443359375
#
# Epoch  136
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.826 0.706 0.688 0.7   0.692 0.69  0.69  0.69  0.69 ]
# Mean test acc: 0.7607421875  Mean support loss:  0.93212890625   Mean query loss: 1.458984375
#
# Epoch  137
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.844 0.69  0.656 0.676 0.66  0.674 0.662 0.672 0.664]
# Mean test acc: 0.74462890625  Mean support loss:  1.0419921875   Mean query loss: 1.5791015625
#
# Epoch  138
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.836 0.714 0.666 0.696 0.668 0.686 0.67  0.678 0.678]
# Mean test acc: 0.75341796875  Mean support loss:  0.986328125   Mean query loss: 1.4482421875
#
# Epoch  139
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.844 0.752 0.732 0.724 0.718 0.72  0.718 0.714 0.712]
# Mean test acc: 0.7841796875  Mean support loss:  0.98193359375   Mean query loss: 1.1103515625
#
# Epoch  140
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.806 0.69  0.68  0.678 0.676 0.674 0.674 0.672 0.672]
# Mean test acc: 0.7470703125  Mean support loss:  0.98291015625   Mean query loss: 1.373046875
#
# Epoch  141
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.846 0.724 0.702 0.716 0.706 0.704 0.704 0.704 0.704]
# Mean test acc: 0.7734375  Mean support loss:  1.0283203125   Mean query loss: 1.40234375
#
# Epoch  142
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.848 0.718 0.71  0.71  0.71  0.71  0.712 0.71  0.71 ]
# Mean test acc: 0.77587890625  Mean support loss:  1.0390625   Mean query loss: 1.375
#
# Epoch  143
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.836 0.702 0.702 0.696 0.7   0.698 0.698 0.698 0.694]
# Mean test acc: 0.765625  Mean support loss:  0.9501953125   Mean query loss: 1.431640625
#
# Epoch  144
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.806 0.694 0.658 0.674 0.66  0.662 0.662 0.66  0.66 ]
# Mean test acc: 0.73974609375  Mean support loss:  1.009765625   Mean query loss: 1.578125
#
# Epoch  145
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.864 0.742 0.726 0.728 0.706 0.724 0.71  0.72  0.71 ]
# Mean test acc: 0.7841796875  Mean support loss:  1.1630859375   Mean query loss: 1.330078125
#
# Epoch  146
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.81  0.664 0.646 0.646 0.646 0.646 0.646 0.644 0.654]
# Mean test acc: 0.72705078125  Mean support loss:  0.9208984375   Mean query loss: 1.5732421875
#
# Epoch  147
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.824 0.684 0.678 0.666 0.666 0.664 0.664 0.662 0.66 ]
# Mean test acc: 0.7421875  Mean support loss:  0.98046875   Mean query loss: 1.580078125
#
# Epoch  148
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.814 0.664 0.658 0.65  0.66  0.648 0.664 0.646 0.658]
# Mean test acc: 0.732421875  Mean support loss:  1.041015625   Mean query loss: 1.6015625
#
# Epoch  149
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.818 0.712 0.678 0.682 0.684 0.674 0.688 0.67  0.684]
# Mean test acc: 0.75341796875  Mean support loss:  0.919921875   Mean query loss: 1.560546875
#
# Epoch  150
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.828 0.752 0.72  0.734 0.726 0.728 0.728 0.728 0.728]
# Mean test acc: 0.78759765625  Mean support loss:  1.0625   Mean query loss: 1.23828125
#
# Epoch  151
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.828 0.704 0.68  0.688 0.674 0.674 0.674 0.674 0.674]
# Mean test acc: 0.75146484375  Mean support loss:  1.0693359375   Mean query loss: 1.5068359375
#
# Epoch  152
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.816 0.688 0.66  0.676 0.664 0.672 0.67  0.67  0.67 ]
# Mean test acc: 0.74365234375  Mean support loss:  0.96630859375   Mean query loss: 1.54296875
#
# Epoch  153
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.83  0.7   0.654 0.652 0.644 0.648 0.652 0.652 0.652]
# Mean test acc: 0.734375  Mean support loss:  1.07421875   Mean query loss: 1.7109375
#
# Epoch  154
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.834 0.712 0.684 0.694 0.678 0.688 0.68  0.678 0.678]
# Mean test acc: 0.7568359375  Mean support loss:  1.0361328125   Mean query loss: 1.474609375
#
# Epoch  155
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.832 0.694 0.658 0.676 0.668 0.668 0.666 0.666 0.666]
# Mean test acc: 0.7451171875  Mean support loss:  0.984375   Mean query loss: 1.5283203125
#
# Epoch  156
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.83  0.694 0.676 0.69  0.672 0.67  0.668 0.666 0.666]
# Mean test acc: 0.74755859375  Mean support loss:  1.01953125   Mean query loss: 1.6669921875
#
# Epoch  157
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.872 0.706 0.692 0.676 0.69  0.676 0.686 0.676 0.67 ]
# Mean test acc: 0.7578125  Mean support loss:  0.9755859375   Mean query loss: 1.54296875
#
# Epoch  158
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.836 0.688 0.672 0.67  0.67  0.67  0.67  0.666 0.666]
# Mean test acc: 0.74560546875  Mean support loss:  0.9736328125   Mean query loss: 1.4560546875
#
# Epoch  159
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.834 0.702 0.672 0.676 0.668 0.676 0.666 0.666 0.666]
# Mean test acc: 0.7470703125  Mean support loss:  1.0234375   Mean query loss: 1.640625
#
# Epoch  160
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.846 0.744 0.718 0.708 0.71  0.7   0.714 0.7   0.714]
# Mean test acc: 0.77734375  Mean support loss:  0.95263671875   Mean query loss: 1.4013671875
#
# Epoch  161
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.834 0.704 0.698 0.688 0.692 0.69  0.69  0.69  0.69 ]
# Mean test acc: 0.7607421875  Mean support loss:  1.0146484375   Mean query loss: 1.5419921875
#
# Epoch  162
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.856 0.72  0.718 0.71  0.718 0.708 0.71  0.708 0.708]
# Mean test acc: 0.77783203125  Mean support loss:  0.95849609375   Mean query loss: 1.40234375
#
# Epoch  163
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.842 0.722 0.69  0.694 0.688 0.688 0.684 0.692 0.686]
# Mean test acc: 0.76171875  Mean support loss:  1.0048828125   Mean query loss: 1.44140625
#
# Epoch  164
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.988 0.868 0.738 0.704 0.702 0.712 0.718 0.684 0.708 0.69 ]
# Mean test acc: 0.77392578125  Mean support loss:  1.0380859375   Mean query loss: 1.3583984375
#
# Epoch  165
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.842 0.722 0.69  0.706 0.698 0.688 0.7   0.7   0.7  ]
# Mean test acc: 0.767578125  Mean support loss:  0.93359375   Mean query loss: 1.33984375
#
# Epoch  166
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.814 0.678 0.674 0.654 0.658 0.658 0.656 0.654 0.652]
# Mean test acc: 0.7353515625  Mean support loss:  1.013671875   Mean query loss: 1.517578125
#
# Epoch  167
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.828 0.724 0.702 0.684 0.702 0.69  0.698 0.696 0.696]
# Mean test acc: 0.76513671875  Mean support loss:  0.94580078125   Mean query loss: 1.5234375
#
# Epoch  168
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.816 0.692 0.696 0.678 0.692 0.682 0.682 0.686 0.684]
# Mean test acc: 0.75439453125  Mean support loss:  0.998046875   Mean query loss: 1.6259765625
#
# Epoch  169
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.838 0.726 0.726 0.716 0.714 0.72  0.712 0.71  0.708]
# Mean test acc: 0.7783203125  Mean support loss:  0.96728515625   Mean query loss: 1.4951171875
#
# Epoch  170
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.848 0.724 0.698 0.702 0.696 0.696 0.696 0.696 0.696]
# Mean test acc: 0.76806640625  Mean support loss:  1.05859375   Mean query loss: 1.494140625
#
# Epoch  171
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.808 0.652 0.658 0.654 0.636 0.654 0.638 0.654 0.642]
# Mean test acc: 0.7265625  Mean support loss:  1.015625   Mean query loss: 1.654296875
#
# Epoch  172
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.84  0.674 0.658 0.654 0.654 0.654 0.654 0.654 0.654]
# Mean test acc: 0.7353515625  Mean support loss:  0.96826171875   Mean query loss: 1.6513671875
#
# Epoch  173
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.83  0.67  0.668 0.646 0.652 0.65  0.65  0.65  0.65 ]
# Mean test acc: 0.732421875  Mean support loss:  0.98876953125   Mean query loss: 1.7353515625
#
# Epoch  174
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.85  0.714 0.706 0.708 0.706 0.71  0.692 0.71  0.696]
# Mean test acc: 0.77197265625  Mean support loss:  1.04296875   Mean query loss: 1.607421875
#
# Epoch  175
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.818 0.69  0.67  0.684 0.678 0.678 0.678 0.678 0.68 ]
# Mean test acc: 0.75  Mean support loss:  1.03515625   Mean query loss: 1.685546875
#
# Epoch  176
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.852 0.694 0.672 0.674 0.674 0.674 0.674 0.674 0.676]
# Mean test acc: 0.7509765625  Mean support loss:  1.0478515625   Mean query loss: 1.5537109375
#
# Epoch  177
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.854 0.708 0.696 0.704 0.694 0.692 0.69  0.688 0.688]
# Mean test acc: 0.7646484375  Mean support loss:  0.998046875   Mean query loss: 1.3642578125
#
# Epoch  178
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.858 0.712 0.684 0.688 0.668 0.688 0.682 0.682 0.682]
# Mean test acc: 0.75830078125  Mean support loss:  1.0107421875   Mean query loss: 1.3525390625
#
# Epoch  179
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.858 0.7   0.686 0.67  0.686 0.67  0.684 0.674 0.674]
# Mean test acc: 0.75439453125  Mean support loss:  1.1083984375   Mean query loss: 1.779296875
#
# Epoch  180
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.836 0.682 0.67  0.668 0.658 0.656 0.656 0.656 0.654]
# Mean test acc: 0.7392578125  Mean support loss:  0.9375   Mean query loss: 1.6787109375
#
# Epoch  181
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.818 0.688 0.672 0.68  0.674 0.672 0.672 0.672 0.672]
# Mean test acc: 0.7470703125  Mean support loss:  1.0400390625   Mean query loss: 1.6083984375
#
# Epoch  182
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.832 0.706 0.668 0.68  0.674 0.666 0.666 0.664 0.664]
# Mean test acc: 0.7470703125  Mean support loss:  1.091796875   Mean query loss: 1.5849609375
#
# Epoch  183
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.842 0.718 0.706 0.688 0.704 0.69  0.694 0.694 0.692]
# Mean test acc: 0.765625  Mean support loss:  0.9599609375   Mean query loss: 1.474609375
#
# Epoch  184
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.83  0.706 0.684 0.684 0.668 0.68  0.67  0.67  0.67 ]
# Mean test acc: 0.7509765625  Mean support loss:  1.0087890625   Mean query loss: 1.556640625
#
# Epoch  185
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.834 0.696 0.644 0.662 0.648 0.658 0.648 0.646 0.646]
# Mean test acc: 0.734375  Mean support loss:  1.1337890625   Mean query loss: 1.7548828125
#
# Epoch  186
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.838 0.722 0.69  0.694 0.684 0.686 0.688 0.676 0.692]
# Mean test acc: 0.76025390625  Mean support loss:  1.0361328125   Mean query loss: 1.4052734375
#
# Epoch  187
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.852 0.71  0.676 0.69  0.684 0.684 0.684 0.682 0.682]
# Mean test acc: 0.7578125  Mean support loss:  1.0146484375   Mean query loss: 1.46875
#
# Epoch  188
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.852 0.694 0.672 0.67  0.668 0.668 0.668 0.668 0.668]
# Mean test acc: 0.74755859375  Mean support loss:  1.150390625   Mean query loss: 1.6748046875
#
# Epoch  189
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.84  0.678 0.646 0.66  0.64  0.638 0.636 0.636 0.636]
# Mean test acc: 0.72802734375  Mean support loss:  1.005859375   Mean query loss: 1.6904296875
#
# Epoch  190
# ...
# Test accuracies: 	 [1.    0.996 0.808 0.666 0.652 0.656 0.638 0.638 0.638 0.64  0.64 ]
# Mean test acc: 0.724609375  Mean support loss:  1.099609375   Mean query loss: 1.7275390625
#
# Epoch  333
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.814 0.702 0.668 0.676 0.66  0.674 0.672 0.672 0.67 ]
# Mean test acc: 0.74560546875  Mean support loss:  1.0947265625   Mean query loss: 1.712890625
#
# Epoch  334
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.842 0.696 0.682 0.684 0.678 0.676 0.672 0.672 0.672]
# Mean test acc: 0.751953125  Mean support loss:  1.08203125   Mean query loss: 1.5791015625
#
# Epoch  335
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.822 0.682 0.638 0.646 0.654 0.646 0.65  0.646 0.646]
# Mean test acc: 0.7294921875  Mean support loss:  1.126953125   Mean query loss: 1.7060546875
#
# Epoch  336
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.852 0.664 0.65  0.652 0.65  0.65  0.65  0.65  0.65 ]
# Mean test acc: 0.7333984375  Mean support loss:  1.1396484375   Mean query loss: 1.9228515625
#
# Epoch  337
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.83  0.698 0.672 0.682 0.678 0.678 0.676 0.674 0.67 ]
# Mean test acc: 0.75048828125  Mean support loss:  1.0693359375   Mean query loss: 1.4296875
#
# Epoch  338
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.836 0.66  0.642 0.648 0.644 0.648 0.65  0.65  0.65 ]
# Mean test acc: 0.72998046875  Mean support loss:  1.1328125   Mean query loss: 1.75390625
#
# Epoch  339
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.82  0.658 0.632 0.652 0.636 0.652 0.64  0.642 0.64 ]
# Mean test acc: 0.724609375  Mean support loss:  1.1005859375   Mean query loss: 1.806640625
#
# Epoch  340
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.836 0.672 0.65  0.672 0.658 0.658 0.658 0.658 0.658]
# Mean test acc: 0.73828125  Mean support loss:  1.099609375   Mean query loss: 1.6259765625
#
# Epoch  341
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.806 0.674 0.66  0.656 0.66  0.656 0.656 0.656 0.654]
# Mean test acc: 0.73388671875  Mean support loss:  1.0419921875   Mean query loss: 1.66015625
#
# Epoch  342
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.844 0.706 0.684 0.674 0.678 0.664 0.676 0.668 0.668]
# Mean test acc: 0.7509765625  Mean support loss:  1.17578125   Mean query loss: 1.427734375
#
# Epoch  343
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.872 0.706 0.672 0.67  0.67  0.67  0.67  0.668 0.666]
# Mean test acc: 0.7509765625  Mean support loss:  1.2490234375   Mean query loss: 1.6181640625
#
# Epoch  344
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.838 0.72  0.686 0.672 0.698 0.684 0.698 0.696 0.696]
# Mean test acc: 0.76220703125  Mean support loss:  1.123046875   Mean query loss: 1.615234375
#
# Epoch  345
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.812 0.654 0.638 0.634 0.624 0.626 0.626 0.624 0.624]
# Mean test acc: 0.71435546875  Mean support loss:  1.0654296875   Mean query loss: 1.8955078125
#
# Epoch  346
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.85  0.718 0.67  0.692 0.69  0.676 0.69  0.69  0.688]
# Mean test acc: 0.76025390625  Mean support loss:  1.2041015625   Mean query loss: 1.60546875
#
# Epoch  347
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.822 0.678 0.67  0.658 0.66  0.66  0.66  0.66  0.66 ]
# Mean test acc: 0.73876953125  Mean support loss:  1.0986328125   Mean query loss: 1.6806640625
#
# Epoch  348
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.84  0.7   0.648 0.658 0.65  0.658 0.652 0.654 0.652]
# Mean test acc: 0.7373046875  Mean support loss:  1.1630859375   Mean query loss: 1.76953125
#
# Epoch  349
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.812 0.658 0.636 0.65  0.642 0.642 0.642 0.64  0.64 ]
# Mean test acc: 0.7236328125  Mean support loss:  1.0888671875   Mean query loss: 1.6904296875
#
# Epoch  350
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.96  0.798 0.71  0.692 0.69  0.688 0.688 0.688 0.688 0.688]
# Mean test acc: 0.75341796875  Mean support loss:  0.7685546875   Mean query loss: 1.4951171875
#
# Epoch  351
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.864 0.728 0.708 0.722 0.716 0.722 0.706 0.724 0.708]
# Mean test acc: 0.78125  Mean support loss:  1.220703125   Mean query loss: 1.107421875
#
# Epoch  352
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.914 0.786 0.732 0.732 0.732 0.732 0.732 0.732 0.732]
# Mean test acc: 0.8017578125  Mean support loss:  1.54296875   Mean query loss: 1.171875
#
# Epoch  353
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.974 0.868 0.816 0.796 0.794 0.794 0.792 0.792 0.792]
# Mean test acc: 0.85595703125  Mean support loss:  1.9013671875   Mean query loss: 0.77587890625
#
# Epoch  354
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.972 0.88  0.83  0.824 0.824 0.824 0.824 0.822 0.822]
# Mean test acc: 0.875  Mean support loss:  2.064453125   Mean query loss: 0.6591796875
#
# Epoch  355
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.962 0.842 0.814 0.814 0.814 0.814 0.812 0.81  0.808]
# Mean test acc: 0.86279296875  Mean support loss:  1.9404296875   Mean query loss: 0.759765625
#
# Epoch  356
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.97  0.876 0.824 0.802 0.8   0.8   0.8   0.8   0.8  ]
# Mean test acc: 0.86083984375  Mean support loss:  2.134765625   Mean query loss: 0.798828125
#
# Epoch  357
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.97  0.838 0.794 0.782 0.78  0.774 0.778 0.774 0.774]
# Mean test acc: 0.84228515625  Mean support loss:  2.080078125   Mean query loss: 0.94873046875
#
# Epoch  358
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.984 0.87  0.832 0.822 0.82  0.82  0.82  0.82  0.82 ]
# Mean test acc: 0.87353515625  Mean support loss:  2.119140625   Mean query loss: 0.66455078125
#
# Epoch  359
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.998 0.874 0.828 0.806 0.798 0.8   0.802 0.802 0.8  ]
# Mean test acc: 0.8642578125  Mean support loss:  2.54296875   Mean query loss: 0.68310546875
#
# Epoch  360
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.906 0.87  0.854 0.854 0.854 0.852 0.852 0.852]
# Mean test acc: 0.89892578125  Mean support loss:  2.36328125   Mean query loss: 0.548828125
#
# Epoch  361
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.992 0.896 0.848 0.814 0.808 0.808 0.808 0.808 0.808]
# Mean test acc: 0.8720703125  Mean support loss:  2.5   Mean query loss: 0.6396484375
#
# Epoch  362
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.988 0.89  0.852 0.838 0.838 0.838 0.838 0.838 0.838]
# Mean test acc: 0.88720703125  Mean support loss:  2.4140625   Mean query loss: 0.52783203125
#
# Epoch  363
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.99  0.894 0.86  0.84  0.842 0.842 0.842 0.842 0.842]
# Mean test acc: 0.89013671875  Mean support loss:  2.40625   Mean query loss: 0.4833984375
#
# Epoch  364
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.99  0.892 0.844 0.844 0.816 0.816 0.816 0.816 0.816]
# Mean test acc: 0.87744140625  Mean support loss:  2.31640625   Mean query loss: 0.59130859375
#
# Epoch  365
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.884 0.828 0.814 0.81  0.81  0.81  0.81  0.81 ]
# Mean test acc: 0.8701171875  Mean support loss:  2.4375   Mean query loss: 0.64306640625
#
# Epoch  366
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.9   0.844 0.836 0.834 0.834 0.834 0.834 0.834]
# Mean test acc: 0.88623046875  Mean support loss:  2.583984375   Mean query loss: 0.56982421875
#
# Epoch  367
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.996 0.912 0.842 0.834 0.834 0.834 0.834 0.834 0.832]
# Mean test acc: 0.88671875  Mean support loss:  2.439453125   Mean query loss: 0.56298828125
#
# Epoch  368
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.996 0.894 0.844 0.826 0.818 0.816 0.816 0.816 0.814]
# Mean test acc: 0.87646484375  Mean support loss:  2.5859375   Mean query loss: 0.60986328125
#
# Epoch  369
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.998 0.896 0.85  0.844 0.84  0.84  0.836 0.836 0.836]
# Mean test acc: 0.888671875  Mean support loss:  2.458984375   Mean query loss: 0.56103515625
#
# Epoch  370
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.898 0.856 0.85  0.85  0.848 0.848 0.848 0.846]
# Mean test acc: 0.89453125  Mean support loss:  2.595703125   Mean query loss: 0.430908203125
#
# Epoch  371
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.896 0.84  0.832 0.826 0.826 0.826 0.826 0.826]
# Mean test acc: 0.8818359375  Mean support loss:  2.447265625   Mean query loss: 0.52734375
#
# Epoch  372
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.998 0.902 0.836 0.828 0.828 0.828 0.828 0.828 0.828]
# Mean test acc: 0.88232421875  Mean support loss:  2.375   Mean query loss: 0.5908203125
#
# Epoch  373
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.998 0.904 0.832 0.816 0.814 0.814 0.814 0.814 0.814]
# Mean test acc: 0.87451171875  Mean support loss:  2.283203125   Mean query loss: 0.669921875
#
# Epoch  374
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.996 0.898 0.836 0.828 0.826 0.818 0.818 0.818 0.818]
# Mean test acc: 0.8779296875  Mean support loss:  2.421875   Mean query loss: 0.5078125
#
# Epoch  375
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.998 0.9   0.852 0.818 0.808 0.808 0.808 0.808 0.808]
# Mean test acc: 0.87353515625  Mean support loss:  2.4453125   Mean query loss: 0.673828125
#
# Epoch  376
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.894 0.846 0.83  0.828 0.826 0.826 0.826 0.826]
# Mean test acc: 0.88232421875  Mean support loss:  2.34375   Mean query loss: 0.7138671875
#
# Epoch  377
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.998 0.926 0.882 0.874 0.86  0.856 0.854 0.852 0.852]
# Mean test acc: 0.90478515625  Mean support loss:  2.482421875   Mean query loss: 0.461181640625
#
# Epoch  378
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.996 0.914 0.876 0.866 0.86  0.86  0.86  0.86  0.86 ]
# Mean test acc: 0.90478515625  Mean support loss:  2.474609375   Mean query loss: 0.42724609375
#
# Epoch  379
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.992 0.926 0.868 0.852 0.842 0.842 0.84  0.84  0.84 ]
# Mean test acc: 0.89453125  Mean support loss:  2.6171875   Mean query loss: 0.52197265625
#
# Epoch  380
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.988 0.906 0.854 0.838 0.836 0.828 0.828 0.826 0.826]
# Mean test acc: 0.884765625  Mean support loss:  2.431640625   Mean query loss: 0.654296875
#
# Epoch  381
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.992 0.912 0.842 0.83  0.826 0.826 0.824 0.824 0.824]
# Mean test acc: 0.8818359375  Mean support loss:  2.3984375   Mean query loss: 0.5712890625
#
# Epoch  382
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.892 0.848 0.83  0.83  0.826 0.826 0.824 0.824]
# Mean test acc: 0.88134765625  Mean support loss:  2.427734375   Mean query loss: 0.57763671875
#
# Epoch  383
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.99  0.904 0.842 0.814 0.814 0.814 0.814 0.81  0.81 ]
# Mean test acc: 0.8740234375  Mean support loss:  2.4140625   Mean query loss: 0.5732421875
#
# Epoch  384
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.902 0.868 0.858 0.848 0.848 0.848 0.846 0.846]
# Mean test acc: 0.896484375  Mean support loss:  2.390625   Mean query loss: 0.430908203125
#
# Epoch  385
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.992 0.91  0.84  0.818 0.818 0.818 0.818 0.818 0.818]
# Mean test acc: 0.87744140625  Mean support loss:  2.548828125   Mean query loss: 0.5927734375
#
# Epoch  386
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.906 0.846 0.838 0.838 0.838 0.836 0.836 0.836]
# Mean test acc: 0.88818359375  Mean support loss:  2.498046875   Mean query loss: 0.55712890625
#
# Epoch  387
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.996 0.88  0.832 0.822 0.814 0.814 0.814 0.814 0.814]
# Mean test acc: 0.87255859375  Mean support loss:  2.501953125   Mean query loss: 0.62890625
#
# Epoch  388
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.89  0.85  0.844 0.838 0.836 0.836 0.836 0.834]
# Mean test acc: 0.88720703125  Mean support loss:  2.3046875   Mean query loss: 0.6376953125
#
# Epoch  389
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.996 0.89  0.84  0.836 0.836 0.834 0.832 0.832 0.83 ]
# Mean test acc: 0.88427734375  Mean support loss:  2.42578125   Mean query loss: 0.5693359375
#
# Epoch  390
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.892 0.84  0.822 0.814 0.806 0.808 0.808 0.806]
# Mean test acc: 0.8720703125  Mean support loss:  2.63671875   Mean query loss: 0.71826171875
#
# Epoch  391
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.992 0.914 0.87  0.854 0.854 0.854 0.854 0.854 0.854]
# Mean test acc: 0.89990234375  Mean support loss:  2.47265625   Mean query loss: 0.486572265625
#
# Epoch  392
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.992 0.904 0.856 0.854 0.854 0.852 0.852 0.852 0.852]
# Mean test acc: 0.89697265625  Mean support loss:  2.462890625   Mean query loss: 0.458984375
#
# Epoch  393
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.904 0.862 0.84  0.838 0.834 0.832 0.832 0.83 ]
# Mean test acc: 0.8876953125  Mean support loss:  2.69921875   Mean query loss: 0.57568359375
#
# Epoch  394
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.994 0.926 0.876 0.87  0.866 0.866 0.868 0.868 0.866]
# Mean test acc: 0.9091796875  Mean support loss:  2.51171875   Mean query loss: 0.40673828125
#
# Epoch  395
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.996 0.898 0.824 0.814 0.806 0.804 0.804 0.802 0.802]
# Mean test acc: 0.8681640625  Mean support loss:  2.609375   Mean query loss: 0.6533203125
#
# Epoch  396
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.992 0.902 0.856 0.834 0.824 0.826 0.82  0.826 0.822]
# Mean test acc: 0.8818359375  Mean support loss:  2.685546875   Mean query loss: 0.513671875
#
# Epoch  397
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.998 0.906 0.854 0.834 0.822 0.82  0.82  0.818 0.818]
# Mean test acc: 0.880859375  Mean support loss:  2.78125   Mean query loss: 0.5595703125
#
# Epoch  398
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.996 0.934 0.902 0.87  0.862 0.862 0.862 0.862 0.862]
# Mean test acc: 0.91015625  Mean support loss:  2.662109375   Mean query loss: 0.40625
#
# Epoch  399
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.99  0.912 0.87  0.848 0.842 0.846 0.838 0.846 0.846]
# Mean test acc: 0.89453125  Mean support loss:  2.431640625   Mean query loss: 0.5
#
# Highest mean validation accuracy:  0.91
#
# Assessing test set....
#
# Mean test accuracy: 0.84
# MAML execution time: 0.6549151674191667 hrs

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))


print('Mean Validation Accuracy over Epochs')

text_file = open('/content/mean_test_accuracy.txt', "r")
mean_accs = text_file.read().split('\n')
mean_accs = [(float(ma) * 100) for ma in mean_accs]

axes = plt.gca()
axes.set_ylim([np.int(min(mean_accs)-2), np.int(max(mean_accs)) +2])
        
plt.plot(mean_accs)
plt.xlabel('Epochs')
plt.ylabel('Mean Accuracy')
plt.title('Mean Validation Accuracy over Epochs')
plt.show();
# Out:
# Mean Validation Accuracy over Epochs

# %%
metrics = pd.read_csv('mean_metrics.csv')
metrics.head()


metrics[['train_loss', 'val_loss']].plot(figsize=(10,5), title='Train and Validation Loss over Epochs')

# %%
metrics[['train_accuracy', 'val_accuracy']].plot(figsize=(10,5), title='Train and Validation Accuracy over Epochs')

# %%
import matplotlib.pyplot as plt
import itertools

# modified from main.py https://github.com/zhangrong1722/CheXNet-Pytorch

def plt_roc(test_y, probas_y, plot_micro=False, plot_macro=False):
    assert isinstance(test_y, list) and isinstance(probas_y, list), 'the type of input must be list'
    skplt.metrics.plot_roc(test_y, probas_y, plot_micro=plot_micro, plot_macro=plot_macro)
    plt.savefig('roc_auc_curve.png')
    plt.show()
    plt.close()


###########################################
# Define confusion matrix and ROC visualization functions
# from https://colab.research.google.com/drive/1ISfhxFDntfOos7cOeT7swduSqzLEqyFn#scrollTo=UiKRYOWPfhJs

def plot_confusion_matrix(cm, classes=None,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues,
                          cv=10):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
   
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("\nNormalized confusion matrix")
    else:
        print('\nConfusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    if classes:
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 1.5
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.locator_params(nbins=2)

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# %%
pred_df = pd.read_csv('test_predictions_and_labels.csv')

# %%
from IPython.display import display

# Get the predicted labels for metric calculations.
#
# Since prototypical networks always sets the ground truth to 0,
# infer the predicted class label from true label and the Boolean value for 'correct'
# To do this, set hc to be -1 and sz to 1. This allows the opposite class to be selected
# for rows where correct is False by multiplying the true_label by -1
pred_df['true_label'] = pred_df.apply(lambda x: -1 if x['true_label'] == 0 else 1, axis=1)
pred_df['correct'] = pred_df.apply(lambda x: 1 if x['correct'] == True else 0, axis=1)
pred_df['prediction'] = pred_df.apply(lambda x: x['true_label']
  if x['correct'] == 1 else x['true_label'] * -1, axis=1)
pred_df.replace(-1, 0, inplace=True)
# display(pred_df.head())
# pred_df.tail()

# %%
from sklearn.metrics import confusion_matrix


pred_y = pred_df['prediction'].values
truth_y = pred_df['true_label'].values
#probas_y = [s.replace('[', '').replace(']', '').split(', ') for s in best_model_preds['probas_y'].values]
#probas_y = [[float(t[0]), float(t[1])] for t in probas_y]


confusion = confusion_matrix(pred_y, truth_y)
plot_confusion_matrix(confusion,
                      classes=['hc', 'sz'],
                      title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization

# %%
pd.read_csv('metrics_summary.csv')
# Out:
#    Final Val Support Loss  ...  Test F1 Score Micro
# 0                   2.432  ...                0.842
#
# [1 rows x 9 columns]
