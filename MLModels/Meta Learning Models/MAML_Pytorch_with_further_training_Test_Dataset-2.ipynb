# %%
import pandas as pd
import numpy as np
import gdown
import os
from sklearn.model_selection import train_test_split
import random


# To improve the speed of setting up, retrieve only the files for the two groups used in training
# Swap with the line below to get the entire dataset as a zip file
# gdown.download('https://drive.google.com/uc?id=1-QTtycxsVNeym17zrMBSZCAAtEZEs05p', '/content/miniimagenet.zip', quiet=False)
gdown.download('https://drive.google.com/uc?id=1CZeMPRt4OZGJL_xQNfgi5evJW1PpA77l', '/content/miniimagenet.zip', quiet=False) # selected groups only
images_directory = '/content/miniimagenet/images/'
if not os.path.exists(images_directory):
  os.makedirs(images_directory) 
# !unzip -qq /content/miniimagenet.zip -d {images_directory}


# get the CSV with the list of all file names
mini_imagenet_file_list_csv = '/content/all_imagenet_file_names.csv'
gdown.download('https://drive.google.com/uc?id=1-1JiyyEC6JlnEi0H0x-JKIGEKjdI_Nea', mini_imagenet_file_list_csv, quiet=False)
file_list = pd.read_csv(mini_imagenet_file_list_csv)

selected_groups = ['n01532829', 'n01558993']
samples_miniimagenet = file_list[file_list['label'].isin(selected_groups)].groupby('label').first()

# Other options for group pairs
# n01532829, n01558993
# n02108551, n02108915
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CZeMPRt4OZGJL_xQNfgi5evJW1PpA77l
# To: /content/miniimagenet.zip
# 59.8MB [00:00, 93.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-1JiyyEC6JlnEi0H0x-JKIGEKjdI_Nea
# To: /content/all_imagenet_file_names.csv
# 2.27MB [00:00, 108MB/s]

# %% [markdown]
# <br>
# <br>
# For this analysis, the first two groups above are used n01532829 and n01558993. These are two similar-looking bird species. The goal is to train the classifier to detect minor details that distinguish the two groups.

# %%
# show a sample from the two selected classes

from PIL import Image
from importlib import reload 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

for image_path in samples_miniimagenet['filename'].unique():
    print('Sample for group ID ', image_path[:9])
    print(images_directory +  image_path)
    reload(plt)
    
    img=mpimg.imread(images_directory + image_path)
    #plt.close('all')
    imgplot = plt.imshow(img)
    plt.show()
# Out:
# Sample for group ID  n01532829
# /content/miniimagenet/images/n0153282900000006.jpg
# Sample for group ID  n01558993
# /content/miniimagenet/images/n0155899300000838.jpg

# %%
# Since the imagenet files are all in the same directory, they can be used as-is 
# with the maml-pytorch setup and do not need to be processed further at this point.
# However, the directory does need to be added to the Python training file

file_list[file_list['label'].isin(selected_groups)].to_csv(images_directory + '/train.csv')

# %%
#Get the EEG spectrograms zip file and unzip it
eeg_image_directory = '/content/eeg_sz_spectrograms'
gdown.download('https://drive.google.com/uc?id=1CQwVM0OpOKAhfk6qvgbGHV8OLguYH_qJ', '{}.zip'.format(eeg_image_directory), quiet=False) 
# !unzip -qq {eeg_image_directory}.zip -d {eeg_image_directory}

# rename 
dl_link = '{}/content/drive/My Drive/ML Projects/data/MSU.ru__gen_data_5s_70pct_overlap_-_fractional_noverlap_all_channels_sml_all_participants_v2/'.format(eeg_image_directory)
# !mv "{dl_link}/hc" {eeg_image_directory}
# !mv "{dl_link}/sz" {eeg_image_directory}
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CQwVM0OpOKAhfk6qvgbGHV8OLguYH_qJ
# To: /content/eeg_sz_spectrograms.zip
# 118MB [00:00, 153MB/s]

# %%
# Get the spectrograms zip file for the further step
# For this version of the program, we attempt to use spectrograms from a different EEG dataset to further train the program. The first EEG dataset will still be used for testing

further_training_image_directory = '/content/further_training_eeg_spectrograms'
gdown.download('https://drive.google.com/uc?id=1WZ1yIFE2bng0McnY_4UBJHqTttsXTTNX', '{}.zip'.format(further_training_image_directory), quiet=False) 

# !unzip -qq {further_training_image_directory}.zip -d {further_training_image_directory}

# rename 
ft_dl_link = '{}/gen_data_20s_70pct_overlap_-_high_nfft_all_channels_sml/'.format(further_training_image_directory)
# !mv "{ft_dl_link}/hc" {further_training_image_directory}
# !mv "{ft_dl_link}/sz" {further_training_image_directory}
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1WZ1yIFE2bng0McnY_4UBJHqTttsXTTNX
# To: /content/further_training_eeg_spectrograms.zip
# 44.2MB [00:00, 61.6MB/s]

# %%
# Use EEG of Sz for validation and testing
# Extract files from an eeg_sz spectrogram directory where files are saved by subject

rand_seed = 1
# List of raw patient file IDs that should be skipped based on categorization as outliers
ignore_list = []
hc_subject_ids = ['hc' + str(i) for i in range(38) if "h{:02}".format(i) not in ignore_list] 
#There are 45 Sz participants. Select 38 of those to match with the control group
rand = random.Random(1)
sz_subject_id_range = [i for i in range(45) if "s{:02}".format(i) not in ignore_list]
sz_subject_ids = rand.sample(sz_subject_id_range, k=38) 
sz_subject_ids = ['sz' + str(i) for i in sz_subject_ids]

all_subject_ids = np.concatenate([hc_subject_ids, sz_subject_ids], axis=0)
validate_hc, test_hc = train_test_split(hc_subject_ids, test_size=0.5, random_state=rand_seed)
validate_sz, test_sz = train_test_split(sz_subject_ids, test_size=0.5, random_state=rand_seed)

validation_ids = np.concatenate([validate_hc, validate_sz])  
test_ids = np.concatenate([test_hc, test_sz]) 


print('\nSubjects assigned to groups using sklearn.model_selection.train_test_split')
print('Test group: ', ", ".join(test_ids), "\n")
print('Validation group: ', ", ".join(validation_ids), "\n")

  

from shutil import copyfile
import pandas as pd
import os 


test_images_output_directory = 'all_test_images'
validation_images_output_directory = 'all_validation_images'

if not os.path.exists(test_images_output_directory):
    os.mkdir(test_images_output_directory)
if not os.path.exists(validation_images_output_directory):
    os.mkdir(validation_images_output_directory)



# Note: CSV is only used for MAML and Prototypical networks
def gen_csv_and_copy_sz_files(image_dir, img_output_dir, participant_ids, output_name, split_with_csv=False):
    subdir_data = []
    for group in ['hc', 'sz']: #['Healthy_Control', 'Sz_Patient']:
        for pid in os.listdir(image_dir + '/' + group): # by participant IDs
            if pid in participant_ids:
              for file in os.listdir(image_dir + '/' + group + '/' + pid):
                file_data = {'filename': file, 'label': group}
                subdir_data.append(file_data)
                destination = img_output_dir + '/' + file if split_with_csv else  '{}/{}/{}'.format(img_output_dir, group, file)
                if not os.path.exists('{}/{}'.format(img_output_dir, group)):
                  os.makedirs('{}/{}'.format(img_output_dir, group))
                copyfile(image_dir + '/' + group + '/' + pid + '/' + file,  destination )
    if split_with_csv:
      pd.DataFrame(subdir_data).to_csv(img_output_dir + '/' + output_name)
    return pd.DataFrame(subdir_data)


df = gen_csv_and_copy_sz_files(image_dir=eeg_image_directory, 
                                img_output_dir=test_images_output_directory,
                                participant_ids=test_ids,
                               split_with_csv=True,
                                output_name= 'test.csv')
df = gen_csv_and_copy_sz_files(image_dir=eeg_image_directory, 
                                img_output_dir=validation_images_output_directory,
                                participant_ids=validation_ids, 
                               split_with_csv=True,
                                output_name= 'test.csv') #file must be name test.csv
print(df.head())
# Out:
# Subjects assigned to groups using sklearn.model_selection.train_test_split
# Test group:  hc2, hc29, hc3, hc22, hc25, hc27, hc21, hc35, hc19, hc24, hc30, hc17, hc28, hc34, hc31, hc26, hc4, hc14, hc10, sz4, sz41, sz16, sz40, sz10, sz21, sz44, sz15, sz22, sz3, sz27, sz38, sz17, sz37, sz34, sz26, sz7, sz35, sz6
#
# Validation group:  hc33, hc23, hc32, hc20, hc18, hc6, hc13, hc7, hc36, hc1, hc16, hc0, hc15, hc5, hc11, hc9, hc8, hc12, hc37, sz20, sz18, sz29, sz14, sz0, sz28, sz43, sz30, sz23, sz36, sz33, sz8, sz19, sz31, sz39, sz13, sz24, sz1, sz11
#
#       filename label
# 0   hc33_3.png    hc
# 1  hc33_29.png    hc
# 2   hc33_6.png    hc
# 3  hc33_12.png    hc
# 4  hc33_31.png    hc

# %%
###########################
### Process the further training set

# Use EEG of Sz for testing
# Extract files from an eeg_sz spectrogram directory where files are saved by subject

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split


# List of raw patient file IDs that should be skipped based on categorization as outliers
ft_ignore_list = ['h09', 'h10', 's10', 's11', 's12']

ft_hc_subject_ids = ['hc' + str(i) for i in range(14) if "h{:02}".format(i) not in ft_ignore_list] 
ft_sz_subject_ids = ['sz' + str(i) for i in range(14) if "s{:02}".format(i) not in ft_ignore_list] 
ft_all_subject_ids = np.concatenate([ft_hc_subject_ids, ft_sz_subject_ids], axis=0)

ft_images_output_directory = '/content/all_further_training_images'

if not os.path.exists(ft_images_output_directory):
    os.mkdir(ft_images_output_directory)

print('\nAll subjects assigned to training group for further training')
print(ft_all_subject_ids)

ids = { 'test': test_ids}
  


ft_df = gen_csv_and_copy_sz_files(image_dir=further_training_image_directory, 
                                img_output_dir=ft_images_output_directory,
                                participant_ids=ft_all_subject_ids, 
                                split_with_csv = True,
                                output_name= 'train.csv')
print(ft_df.head())
# Out:
# All subjects assigned to training group for further training
# ['hc0' 'hc1' 'hc2' 'hc3' 'hc4' 'hc5' 'hc6' 'hc7' 'hc8' 'hc11' 'hc12'
#  'hc13' 'sz0' 'sz1' 'sz2' 'sz3' 'sz4' 'sz5' 'sz6' 'sz7' 'sz8' 'sz9' 'sz13']
#      filename label
# 0  hc4_54.png    hc
# 1  hc4_59.png    hc
# 2  hc4_41.png    hc
# 3  hc4_56.png    hc
# 4  hc4_23.png    hc

# %%
# Get the project files from github
# !git clone https://github.com/MTynes/MAML-Pytorch.git maml_pytorch
# Out:
# Cloning into 'maml_pytorch'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 226 (delta 8), reused 7 (delta 3), pack-reused 209
# Receiving objects: 100% (226/226), 672.94 KiB | 22.43 MiB/s, done.
# Resolving deltas: 100% (129/129), done.

# %%
# !python /content/maml_pytorch/train_custom_dataset.py --help
# Out:
# usage: train_custom_dataset.py [-h] [--train_dir TRAIN_DIR]
#                                [--further_training_dir FURTHER_TRAINING_DIR]
#                                [--validation_dir VALIDATION_DIR]
#                                [--test_dir TEST_DIR]
#                                [--run_further_training RUN_FURTHER_TRAINING]
#                                [--epochs EPOCHS]
#                                [--further_training_epochs FURTHER_TRAINING_EPOCHS]
#                                [--n_way N_WAY] [--k_spt K_SPT] [--k_qry K_QRY]
#                                [--imgsz IMGSZ] [--imgc IMGC]
#                                [--task_num TASK_NUM] [--meta_lr META_LR]
#                                [--update_lr UPDATE_LR]
#                                [--update_step UPDATE_STEP]
#                                [--update_step_test UPDATE_STEP_TEST]
#                                [--accuracy_log_file ACCURACY_LOG_FILE]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --train_dir TRAIN_DIR
#                         train data directory
#   --further_training_dir FURTHER_TRAINING_DIR
#                         further training data directory
#   --validation_dir VALIDATION_DIR
#                         validation data directory
#   --test_dir TEST_DIR   test data directory
#   --run_further_training RUN_FURTHER_TRAINING
#                         Boolean for adding a second dataset for further
#                         training. Set as string. Case insensitive.
#   --epochs EPOCHS       Number of epochs
#   --further_training_epochs FURTHER_TRAINING_EPOCHS
#                         Number of epochs for further training cycle
#   --n_way N_WAY         n way
#   --k_spt K_SPT         k shot for support set
#   --k_qry K_QRY         k shot for query set
#   --imgsz IMGSZ         imgsz
#   --imgc IMGC           imgc
#   --task_num TASK_NUM   meta batch size, namely task num
#   --meta_lr META_LR     meta-level outer learning rate
#   --update_lr UPDATE_LR
#                         task-level inner update learning rate
#   --update_step UPDATE_STEP
#                         task-level inner update steps
#   --update_step_test UPDATE_STEP_TEST
#                         update steps for fine-tuning
#   --accuracy_log_file ACCURACY_LOG_FILE
#                         Output file for mean test accuracy

# %%
# run the training file

import timeit

start = timeit.default_timer()

n_epochs = 200 * 10000 # must be multiple of 10000
ft_n_epochs = 200 * 10000
# !python /content/maml_pytorch/train_custom_dataset.py --run_further_training 'true' --epochs {n_epochs} --further_training_epochs {ft_n_epochs}


stop = timeit.default_timer()
print('MAML execution time: {} hrs'.format((stop - start)/60/60) )
# Out:
# Namespace(accuracy_log_file='/content/mean_test_accuracy.txt', epochs=2000000, further_training_dir='/content/all_further_training_images', further_training_epochs=2000000, imgc=3, imgsz=84, k_qry=5, k_spt=1, meta_lr=0.001, n_way=2, run_further_training=True, task_num=4, test_dir='/content/all_test_images', train_dir='/content/miniimagenet/images', update_lr=0.01, update_step=5, update_step_test=10, validation_dir='/content/all_validation_images')
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# Meta(
#   (net): Learner(
#     conv2d:(ch_in:3, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:2, padding:0)
#     conv2d:(ch_in:32, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:2, padding:0)
#     conv2d:(ch_in:32, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:2, padding:0)
#     conv2d:(ch_in:32, ch_out:32, k:3x3, stride:1, padding:0)
#     relu:(True,)
#     bn:(32,)
#     max_pool2d:(k:2, stride:1, padding:0)
#     flatten:()
#     linear:(in:800, out:2)
#
#     (vars): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 32x3x3x3 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 32x32x3x3 (GPU 0)]
#         (5): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (6): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (7): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (8): Parameter containing: [torch.cuda.FloatTensor of size 32x32x3x3 (GPU 0)]
#         (9): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (10): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (11): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (12): Parameter containing: [torch.cuda.FloatTensor of size 32x32x3x3 (GPU 0)]
#         (13): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (14): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (15): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (16): Parameter containing: [torch.cuda.FloatTensor of size 2x800 (GPU 0)]
#         (17): Parameter containing: [torch.cuda.FloatTensor of size 2 (GPU 0)]
#     )
#     (vars_bn): ParameterList(
#         (0): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (1): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (2): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (3): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (4): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (5): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (6): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#         (7): Parameter containing: [torch.cuda.FloatTensor of size 32 (GPU 0)]
#     )
#   )
# )
# Total trainable tensors: 30498
# shuffle DB :train, b:50, 2-way, 1-shot, 5-query, resize:84
# shuffle DB :test, b:50, 2-way, 1-shot, 5-query, resize:84
# shuffle DB :test, b:50, 2-way, 1-shot, 5-query, resize:84
# shuffle DB :train, b:50, 2-way, 1-shot, 5-query, resize:84
#
#  Main training cycle
#
# Epoch  0
# Training accuracies: 	 [0.6 0.6 0.6 0.6 0.6 0.6]
# Test accuracies: 	 [0.686 0.422 0.502 0.5   0.5   0.5   0.498 0.498 0.496 0.496 0.498]
# Mean test acc: 0.5087890625  Mean support loss:  0.0238189697265625   Mean query loss: 2.5390625
#
# Epoch  1
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.786 0.652 0.652 0.652 0.652 0.652 0.652 0.65  0.648 0.648]
# Mean test acc: 0.69482421875  Mean support loss:  0.05316162109375   Mean query loss: 1.380859375
#
# Epoch  2
# Training accuracies: 	 [1.    0.975 0.975 0.975 0.975 0.975]
# Test accuracies: 	 [1.    0.862 0.642 0.638 0.636 0.636 0.634 0.632 0.632 0.632 0.632]
# Mean test acc: 0.6884765625  Mean support loss:  0.1282958984375   Mean query loss: 1.7294921875
#
# Epoch  3
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.908 0.66  0.644 0.646 0.646 0.644 0.644 0.644 0.644 0.642]
# Mean test acc: 0.7021484375  Mean support loss:  0.165283203125   Mean query loss: 1.7646484375
#
# Epoch  4
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.908 0.694 0.682 0.682 0.682 0.682 0.682 0.682 0.682 0.682]
# Mean test acc: 0.732421875  Mean support loss:  0.1881103515625   Mean query loss: 1.353515625
#
# Epoch  5
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.934 0.678 0.658 0.656 0.656 0.654 0.654 0.654 0.654 0.654]
# Mean test acc: 0.7138671875  Mean support loss:  0.2254638671875   Mean query loss: 1.6123046875
#
# Epoch  6
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.924 0.726 0.696 0.696 0.696 0.696 0.694 0.694 0.694 0.694]
# Mean test acc: 0.74609375  Mean support loss:  0.1932373046875   Mean query loss: 1.3427734375
#
# Epoch  7
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.942 0.69  0.668 0.666 0.666 0.666 0.666 0.666 0.666 0.664]
# Mean test acc: 0.7236328125  Mean support loss:  0.1846923828125   Mean query loss: 1.5244140625
#
# Epoch  8
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.942 0.72  0.686 0.684 0.682 0.68  0.676 0.676 0.676 0.672]
# Mean test acc: 0.73583984375  Mean support loss:  0.166259765625   Mean query loss: 1.5234375
#
# Epoch  9
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.932 0.696 0.678 0.674 0.672 0.672 0.672 0.672 0.67  0.668]
# Mean test acc: 0.7275390625  Mean support loss:  0.2178955078125   Mean query loss: 1.546875
#
# Epoch  10
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.93  0.704 0.686 0.684 0.684 0.684 0.684 0.682 0.68  0.68 ]
# Mean test acc: 0.736328125  Mean support loss:  0.1986083984375   Mean query loss: 1.4599609375
#
# Epoch  11
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.924 0.644 0.624 0.622 0.622 0.622 0.622 0.622 0.622 0.622]
# Mean test acc: 0.68603515625  Mean support loss:  0.2498779296875   Mean query loss: 1.76953125
#
# Epoch  12
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.954 0.672 0.634 0.634 0.634 0.634 0.634 0.634 0.634 0.634]
# Mean test acc: 0.69970703125  Mean support loss:  0.267822265625   Mean query loss: 1.625
#
# Epoch  13
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.938 0.696 0.678 0.676 0.676 0.674 0.674 0.674 0.674 0.674]
# Mean test acc: 0.73046875  Mean support loss:  0.209716796875   Mean query loss: 1.513671875
#
# Epoch  14
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.966 0.718 0.686 0.682 0.682 0.682 0.682 0.684 0.684 0.684]
# Mean test acc: 0.74072265625  Mean support loss:  0.244140625   Mean query loss: 1.4189453125
#
# Epoch  15
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.968 0.702 0.676 0.676 0.676 0.676 0.676 0.676 0.674 0.674]
# Mean test acc: 0.73388671875  Mean support loss:  0.2474365234375   Mean query loss: 1.2939453125
#
# Epoch  16
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.974 0.704 0.674 0.672 0.672 0.672 0.672 0.672 0.672 0.67 ]
# Mean test acc: 0.73193359375  Mean support loss:  0.255126953125   Mean query loss: 1.5263671875
#
# Epoch  17
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.958 0.706 0.68  0.676 0.676 0.676 0.676 0.676 0.676 0.676]
# Mean test acc: 0.73388671875  Mean support loss:  0.244873046875   Mean query loss: 1.447265625
#
# Epoch  18
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.976 0.706 0.674 0.674 0.674 0.674 0.674 0.674 0.674 0.674]
# Mean test acc: 0.73388671875  Mean support loss:  0.293212890625   Mean query loss: 1.5673828125
#
# Epoch  19
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.962 0.69  0.682 0.678 0.676 0.676 0.676 0.676 0.674 0.674]
# Mean test acc: 0.73291015625  Mean support loss:  0.265625   Mean query loss: 1.38671875
#
# Epoch  20
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.972 0.706 0.674 0.674 0.672 0.672 0.672 0.67  0.67  0.67 ]
# Mean test acc: 0.73193359375  Mean support loss:  0.28857421875   Mean query loss: 1.4365234375
#
# Epoch  21
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.976 0.71  0.686 0.686 0.686 0.686 0.682 0.682 0.68  0.682]
# Mean test acc: 0.74169921875  Mean support loss:  0.2392578125   Mean query loss: 1.5986328125
#
# Epoch  22
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.972 0.694 0.662 0.662 0.658 0.658 0.658 0.658 0.656 0.652]
# Mean test acc: 0.72119140625  Mean support loss:  0.320068359375   Mean query loss: 1.671875
#
# Epoch  23
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.96  0.728 0.672 0.67  0.67  0.67  0.67  0.668 0.666 0.666]
# Mean test acc: 0.73095703125  Mean support loss:  0.31201171875   Mean query loss: 1.5673828125
#
# Epoch  24
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.982 0.694 0.666 0.66  0.66  0.658 0.658 0.658 0.656 0.656]
# Mean test acc: 0.72265625  Mean support loss:  0.34033203125   Mean query loss: 1.595703125
#
# Epoch  25
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.968 0.678 0.654 0.652 0.652 0.654 0.654 0.654 0.654 0.654]
# Mean test acc: 0.7158203125  Mean support loss:  0.29736328125   Mean query loss: 1.609375
#
# Epoch  26
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.966 0.712 0.668 0.668 0.668 0.668 0.668 0.668 0.668 0.668]
# Mean test acc: 0.72900390625  Mean support loss:  0.2437744140625   Mean query loss: 1.71484375
#
# Epoch  27
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.972 0.674 0.642 0.64  0.64  0.64  0.64  0.64  0.64  0.64 ]
# Mean test acc: 0.7060546875  Mean support loss:  0.338623046875   Mean query loss: 1.62109375
#
# Epoch  28
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.986 0.726 0.696 0.696 0.694 0.694 0.694 0.696 0.696 0.696]
# Mean test acc: 0.751953125  Mean support loss:  0.28369140625   Mean query loss: 1.44921875
#
# Epoch  29
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.964 0.682 0.65  0.646 0.646 0.646 0.646 0.646 0.646 0.646]
# Mean test acc: 0.7109375  Mean support loss:  0.32958984375   Mean query loss: 1.537109375
#
# Epoch  30
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.98  0.714 0.668 0.668 0.67  0.668 0.668 0.668 0.668 0.668]
# Mean test acc: 0.73095703125  Mean support loss:  0.298095703125   Mean query loss: 1.4912109375
#
# Epoch  31
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.97  0.692 0.674 0.668 0.666 0.666 0.666 0.666 0.666 0.666]
# Mean test acc: 0.72705078125  Mean support loss:  0.297607421875   Mean query loss: 1.419921875
#
# Epoch  32
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.958 0.708 0.658 0.656 0.656 0.652 0.652 0.652 0.652 0.652]
# Mean test acc: 0.7177734375  Mean support loss:  0.328857421875   Mean query loss: 1.771484375
#
# Epoch  33
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.964 0.712 0.692 0.69  0.69  0.69  0.686 0.686 0.686 0.684]
# Mean test acc: 0.74365234375  Mean support loss:  0.265625   Mean query loss: 1.328125
#
# Epoch  34
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.978 0.704 0.656 0.65  0.65  0.65  0.65  0.648 0.646 0.644]
# Mean test acc: 0.7158203125  Mean support loss:  0.341796875   Mean query loss: 1.6669921875
#
# Epoch  35
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.974 0.692 0.68  0.68  0.678 0.678 0.678 0.676 0.674 0.674]
# Mean test acc: 0.73486328125  Mean support loss:  0.33740234375   Mean query loss: 1.64453125
#
# Epoch  36
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.982 0.724 0.652 0.652 0.652 0.652 0.65  0.65  0.65  0.65 ]
# Mean test acc: 0.71923828125  Mean support loss:  0.3876953125   Mean query loss: 1.548828125
#
# Epoch  37
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.976 0.686 0.66  0.65  0.65  0.65  0.65  0.65  0.65  0.648]
# Mean test acc: 0.71533203125  Mean support loss:  0.3037109375   Mean query loss: 1.51953125
#
# Epoch  38
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.976 0.702 0.664 0.664 0.662 0.662 0.662 0.662 0.662 0.66 ]
# Mean test acc: 0.72509765625  Mean support loss:  0.3818359375   Mean query loss: 1.5654296875
#
# Epoch  39
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.98  0.71  0.674 0.67  0.67  0.67  0.67  0.67  0.67  0.67 ]
# Mean test acc: 0.73193359375  Mean support loss:  0.390625   Mean query loss: 1.4130859375
#
# Epoch  40
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.978 0.71  0.666 0.666 0.666 0.666 0.666 0.666 0.666 0.666]
# Mean test acc: 0.728515625  Mean support loss:  0.343994140625   Mean query loss: 1.7314453125
#
# Epoch  41
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.728 0.674 0.674 0.67  0.668 0.668 0.668 0.668 0.668]
# Mean test acc: 0.734375  Mean support loss:  0.354736328125   Mean query loss: 1.634765625
#
# Epoch  42
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.984 0.728 0.686 0.686 0.686 0.686 0.686 0.686 0.686 0.686]
# Mean test acc: 0.74560546875  Mean support loss:  0.346435546875   Mean query loss: 1.4169921875
#
# Epoch  43
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.972 0.712 0.632 0.632 0.632 0.632 0.632 0.632 0.632 0.632]
# Mean test acc: 0.70361328125  Mean support loss:  0.374267578125   Mean query loss: 1.8154296875
#
# Epoch  44
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.704 0.67  0.67  0.67  0.67  0.67  0.67  0.67  0.67 ]
# Mean test acc: 0.73193359375  Mean support loss:  0.41748046875   Mean query loss: 1.548828125
#
# Epoch  45
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.976 0.68  0.642 0.64  0.64  0.64  0.64  0.64  0.64  0.64 ]
# Mean test acc: 0.70703125  Mean support loss:  0.358154296875   Mean query loss: 1.673828125
#
# Epoch  46
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.962 0.69  0.642 0.638 0.636 0.636 0.636 0.636 0.636 0.636]
# Mean test acc: 0.70458984375  Mean support loss:  0.4150390625   Mean query loss: 1.705078125
#
# Epoch  47
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.984 0.732 0.654 0.65  0.65  0.65  0.65  0.65  0.65  0.65 ]
# Mean test acc: 0.7197265625  Mean support loss:  0.452392578125   Mean query loss: 1.6689453125
#
# Epoch  48
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.704 0.674 0.674 0.674 0.674 0.676 0.676 0.674 0.674]
# Mean test acc: 0.73583984375  Mean support loss:  0.431884765625   Mean query loss: 1.6240234375
#
# Epoch  49
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.71  0.648 0.638 0.638 0.636 0.636 0.636 0.636 0.636]
# Mean test acc: 0.7099609375  Mean support loss:  0.401123046875   Mean query loss: 1.626953125
#
# Epoch  50
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.974 0.742 0.662 0.658 0.658 0.658 0.658 0.658 0.658 0.658]
# Mean test acc: 0.72607421875  Mean support loss:  0.41650390625   Mean query loss: 1.6513671875
#
# Epoch  51
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.982 0.718 0.666 0.666 0.666 0.666 0.666 0.664 0.664 0.664]
# Mean test acc: 0.7294921875  Mean support loss:  0.387451171875   Mean query loss: 1.69921875
#
# Epoch  52
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.728 0.682 0.67  0.67  0.67  0.67  0.668 0.668 0.668]
# Mean test acc: 0.7353515625  Mean support loss:  0.468017578125   Mean query loss: 1.35546875
#
# Epoch  53
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.728 0.662 0.66  0.66  0.658 0.656 0.656 0.656 0.656]
# Mean test acc: 0.7255859375  Mean support loss:  0.47998046875   Mean query loss: 1.8466796875
#
# Epoch  54
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.77  0.662 0.658 0.656 0.652 0.65  0.65  0.65  0.65 ]
# Mean test acc: 0.72607421875  Mean support loss:  0.495849609375   Mean query loss: 1.6533203125
#
# Epoch  55
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.734 0.676 0.672 0.672 0.672 0.67  0.67  0.67  0.67 ]
# Mean test acc: 0.736328125  Mean support loss:  0.467529296875   Mean query loss: 1.4638671875
#
# Epoch  56
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.762 0.676 0.674 0.674 0.674 0.674 0.674 0.674 0.674]
# Mean test acc: 0.7412109375  Mean support loss:  0.50732421875   Mean query loss: 1.7451171875
#
# Epoch  57
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.744 0.684 0.684 0.686 0.686 0.684 0.684 0.682 0.682]
# Mean test acc: 0.74658203125  Mean support loss:  0.53466796875   Mean query loss: 1.3701171875
#
# Epoch  58
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.746 0.64  0.638 0.638 0.638 0.634 0.634 0.634 0.634]
# Mean test acc: 0.7119140625  Mean support loss:  0.615234375   Mean query loss: 1.7373046875
#
# Epoch  59
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.792 0.67  0.662 0.662 0.662 0.662 0.662 0.662 0.662]
# Mean test acc: 0.73583984375  Mean support loss:  0.59033203125   Mean query loss: 1.541015625
#
# Epoch  60
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.748 0.638 0.64  0.64  0.64  0.64  0.64  0.638 0.638]
# Mean test acc: 0.71484375  Mean support loss:  0.6142578125   Mean query loss: 1.642578125
#
# Epoch  61
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.784 0.678 0.676 0.676 0.676 0.676 0.676 0.676 0.674]
# Mean test acc: 0.74462890625  Mean support loss:  0.60693359375   Mean query loss: 1.484375
#
# Epoch  62
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.794 0.686 0.672 0.666 0.666 0.664 0.664 0.662 0.662]
# Mean test acc: 0.73974609375  Mean support loss:  0.72314453125   Mean query loss: 1.498046875
#
# Epoch  63
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.798 0.692 0.676 0.676 0.674 0.674 0.674 0.674 0.674]
# Mean test acc: 0.74609375  Mean support loss:  0.78515625   Mean query loss: 1.46484375
#
# Epoch  64
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.824 0.69  0.688 0.688 0.688 0.688 0.688 0.688 0.688]
# Mean test acc: 0.7568359375  Mean support loss:  0.75390625   Mean query loss: 1.2646484375
#
# Epoch  65
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.8   0.684 0.66  0.66  0.66  0.66  0.66  0.66  0.66 ]
# Mean test acc: 0.736328125  Mean support loss:  0.89599609375   Mean query loss: 1.5078125
#
# Epoch  66
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.804 0.712 0.67  0.67  0.67  0.67  0.67  0.668 0.668]
# Mean test acc: 0.74560546875  Mean support loss:  0.95751953125   Mean query loss: 1.46875
#
# Epoch  67
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.818 0.686 0.672 0.67  0.67  0.668 0.666 0.666 0.666]
# Mean test acc: 0.74267578125  Mean support loss:  0.86767578125   Mean query loss: 1.587890625
#
# Epoch  68
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.786 0.698 0.672 0.672 0.672 0.672 0.672 0.672 0.672]
# Mean test acc: 0.744140625  Mean support loss:  0.79638671875   Mean query loss: 1.78515625
#
# Epoch  69
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.814 0.712 0.696 0.696 0.696 0.696 0.696 0.694 0.694]
# Mean test acc: 0.76220703125  Mean support loss:  0.84619140625   Mean query loss: 1.4404296875
#
# Epoch  70
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.846 0.756 0.732 0.73  0.73  0.728 0.728 0.728 0.728]
# Mean test acc: 0.79052734375  Mean support loss:  0.85498046875   Mean query loss: 1.3037109375
#
# Epoch  71
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.816 0.724 0.696 0.696 0.696 0.696 0.696 0.696 0.696]
# Mean test acc: 0.763671875  Mean support loss:  0.9189453125   Mean query loss: 1.4013671875
#
# Epoch  72
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.828 0.7   0.672 0.67  0.67  0.67  0.67  0.67  0.67 ]
# Mean test acc: 0.7470703125  Mean support loss:  0.8896484375   Mean query loss: 1.513671875
#
# Epoch  73
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.832 0.736 0.706 0.706 0.706 0.706 0.706 0.706 0.706]
# Mean test acc: 0.77294921875  Mean support loss:  0.873046875   Mean query loss: 1.2783203125
#
# Epoch  74
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.988 0.824 0.72  0.698 0.698 0.698 0.698 0.698 0.698 0.698]
# Mean test acc: 0.765625  Mean support loss:  0.87890625   Mean query loss: 1.521484375
#
# Epoch  75
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.824 0.73  0.696 0.694 0.692 0.692 0.692 0.692 0.692]
# Mean test acc: 0.76318359375  Mean support loss:  0.8837890625   Mean query loss: 1.392578125
#
# Epoch  76
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.832 0.712 0.69  0.686 0.686 0.682 0.68  0.68  0.68 ]
# Mean test acc: 0.75634765625  Mean support loss:  0.8203125   Mean query loss: 1.51953125
#
# Epoch  77
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.8   0.674 0.656 0.654 0.654 0.654 0.654 0.654 0.654]
# Mean test acc: 0.7314453125  Mean support loss:  0.97705078125   Mean query loss: 1.4951171875
#
# Epoch  78
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.83  0.672 0.668 0.67  0.67  0.67  0.668 0.668 0.668]
# Mean test acc: 0.74365234375  Mean support loss:  0.87646484375   Mean query loss: 1.57421875
#
# Epoch  79
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.818 0.692 0.674 0.674 0.674 0.674 0.674 0.674 0.674]
# Mean test acc: 0.74755859375  Mean support loss:  0.97021484375   Mean query loss: 1.5009765625
#
# Epoch  80
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.826 0.722 0.702 0.702 0.698 0.698 0.696 0.696 0.696]
# Mean test acc: 0.7666015625  Mean support loss:  0.861328125   Mean query loss: 1.400390625
#
# Epoch  81
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.818 0.716 0.694 0.692 0.69  0.69  0.69  0.69  0.69 ]
# Mean test acc: 0.76025390625  Mean support loss:  0.88330078125   Mean query loss: 1.37890625
#
# Epoch  82
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.822 0.69  0.658 0.658 0.658 0.658 0.654 0.654 0.654]
# Mean test acc: 0.73583984375  Mean support loss:  0.90966796875   Mean query loss: 1.54296875
#
# Epoch  83
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.83  0.69  0.676 0.666 0.666 0.664 0.664 0.664 0.664]
# Mean test acc: 0.74365234375  Mean support loss:  0.859375   Mean query loss: 1.54296875
#
# Epoch  84
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.818 0.706 0.686 0.682 0.682 0.682 0.682 0.682 0.68 ]
# Mean test acc: 0.75439453125  Mean support loss:  0.8642578125   Mean query loss: 1.4326171875
#
# Epoch  85
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.824 0.696 0.684 0.684 0.684 0.684 0.684 0.682 0.682]
# Mean test acc: 0.75439453125  Mean support loss:  0.89990234375   Mean query loss: 1.3837890625
#
# Epoch  86
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.846 0.744 0.714 0.714 0.714 0.714 0.714 0.714 0.714]
# Mean test acc: 0.7802734375  Mean support loss:  0.9853515625   Mean query loss: 1.3505859375
#
# Epoch  87
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.822 0.694 0.688 0.682 0.682 0.68  0.68  0.68  0.68 ]
# Mean test acc: 0.75341796875  Mean support loss:  0.8759765625   Mean query loss: 1.392578125
#
# Epoch  88
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.832 0.716 0.706 0.704 0.704 0.704 0.704 0.702 0.702]
# Mean test acc: 0.77001953125  Mean support loss:  0.8984375   Mean query loss: 1.2861328125
#
# Epoch  89
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.828 0.708 0.688 0.684 0.682 0.682 0.682 0.682 0.682]
# Mean test acc: 0.755859375  Mean support loss:  0.96142578125   Mean query loss: 1.375
#
# Epoch  90
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.838 0.698 0.664 0.662 0.662 0.66  0.66  0.66  0.66 ]
# Mean test acc: 0.7412109375  Mean support loss:  0.98681640625   Mean query loss: 1.59375
#
# Epoch  91
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.838 0.718 0.692 0.692 0.69  0.69  0.69  0.69  0.69 ]
# Mean test acc: 0.76220703125  Mean support loss:  0.9560546875   Mean query loss: 1.3642578125
#
# Epoch  92
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.84  0.726 0.696 0.698 0.696 0.696 0.696 0.698 0.698]
# Mean test acc: 0.76708984375  Mean support loss:  0.9052734375   Mean query loss: 1.4736328125
#
# Epoch  93
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.834 0.722 0.686 0.684 0.682 0.68  0.68  0.678 0.678]
# Mean test acc: 0.75634765625  Mean support loss:  0.9267578125   Mean query loss: 1.2421875
#
# Epoch  94
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.83  0.708 0.692 0.692 0.692 0.692 0.692 0.692 0.692]
# Mean test acc: 0.76123046875  Mean support loss:  0.830078125   Mean query loss: 1.427734375
#
# Epoch  95
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.82  0.75  0.73  0.726 0.724 0.722 0.722 0.722 0.722]
# Mean test acc: 0.78515625  Mean support loss:  0.92431640625   Mean query loss: 1.1171875
#
# Epoch  96
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.832 0.712 0.682 0.68  0.68  0.68  0.678 0.676 0.676]
# Mean test acc: 0.75390625  Mean support loss:  1.0048828125   Mean query loss: 1.50390625
#
# Epoch  97
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.816 0.688 0.66  0.658 0.658 0.658 0.656 0.658 0.656]
# Mean test acc: 0.73681640625  Mean support loss:  1.0068359375   Mean query loss: 1.580078125
#
# Epoch  98
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.812 0.712 0.682 0.68  0.68  0.68  0.68  0.68  0.68 ]
# Mean test acc: 0.75341796875  Mean support loss:  0.98193359375   Mean query loss: 1.37890625
#
# Epoch  99
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.832 0.738 0.702 0.702 0.702 0.702 0.7   0.7   0.7  ]
# Mean test acc: 0.7705078125  Mean support loss:  0.93212890625   Mean query loss: 1.40234375
#
# Epoch  100
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.832 0.732 0.686 0.686 0.686 0.686 0.686 0.686 0.686]
# Mean test acc: 0.76025390625  Mean support loss:  0.900390625   Mean query loss: 1.5439453125
#
# Epoch  101
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.824 0.708 0.678 0.676 0.676 0.676 0.676 0.676 0.676]
# Mean test acc: 0.7509765625  Mean support loss:  0.9609375   Mean query loss: 1.4384765625
#
# Epoch  102
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.832 0.746 0.706 0.706 0.706 0.706 0.706 0.706 0.706]
# Mean test acc: 0.7744140625  Mean support loss:  0.92919921875   Mean query loss: 1.3857421875
#
# Epoch  103
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.83  0.698 0.674 0.674 0.674 0.674 0.674 0.674 0.674]
# Mean test acc: 0.7490234375  Mean support loss:  0.91455078125   Mean query loss: 1.52734375
#
# Epoch  104
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.824 0.716 0.702 0.698 0.696 0.696 0.696 0.696 0.696]
# Mean test acc: 0.76513671875  Mean support loss:  0.98046875   Mean query loss: 1.4541015625
#
# Epoch  105
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.834 0.722 0.69  0.69  0.69  0.69  0.688 0.688 0.688]
# Mean test acc: 0.76171875  Mean support loss:  0.99267578125   Mean query loss: 1.4560546875
#
# Epoch  106
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.806 0.692 0.668 0.668 0.666 0.666 0.666 0.666 0.666]
# Mean test acc: 0.74169921875  Mean support loss:  0.99560546875   Mean query loss: 1.435546875
#
# Epoch  107
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.82  0.686 0.67  0.67  0.67  0.67  0.67  0.67  0.67 ]
# Mean test acc: 0.74462890625  Mean support loss:  0.916015625   Mean query loss: 1.5732421875
#
# Epoch  108
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.852 0.73  0.698 0.696 0.696 0.696 0.696 0.696 0.696]
# Mean test acc: 0.7685546875  Mean support loss:  1.0673828125   Mean query loss: 1.37109375
#
# Epoch  109
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.83  0.696 0.694 0.692 0.692 0.692 0.692 0.692 0.692]
# Mean test acc: 0.76025390625  Mean support loss:  0.830078125   Mean query loss: 1.3681640625
#
# Epoch  110
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.832 0.732 0.718 0.716 0.716 0.716 0.716 0.716 0.714]
# Mean test acc: 0.77880859375  Mean support loss:  0.966796875   Mean query loss: 1.1982421875
#
# Epoch  111
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.844 0.74  0.698 0.696 0.694 0.694 0.694 0.694 0.694]
# Mean test acc: 0.767578125  Mean support loss:  1.0009765625   Mean query loss: 1.439453125
#
# Epoch  112
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.826 0.706 0.684 0.682 0.682 0.682 0.682 0.682 0.682]
# Mean test acc: 0.75537109375  Mean support loss:  0.89306640625   Mean query loss: 1.4814453125
#
# Epoch  113
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.832 0.702 0.686 0.686 0.686 0.686 0.686 0.686 0.686]
# Mean test acc: 0.7578125  Mean support loss:  1.015625   Mean query loss: 1.3095703125
#
# Epoch  114
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.814 0.704 0.674 0.672 0.668 0.666 0.666 0.666 0.666]
# Mean test acc: 0.7451171875  Mean support loss:  0.98828125   Mean query loss: 1.3544921875
#
# Epoch  115
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.828 0.742 0.7   0.698 0.698 0.698 0.696 0.696 0.696]
# Mean test acc: 0.76806640625  Mean support loss:  0.91650390625   Mean query loss: 1.41015625
#
# Epoch  116
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.844 0.746 0.702 0.7   0.698 0.7   0.7   0.702 0.702]
# Mean test acc: 0.77197265625  Mean support loss:  0.9228515625   Mean query loss: 1.33984375
#
# Epoch  117
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.818 0.7   0.676 0.676 0.676 0.674 0.674 0.674 0.674]
# Mean test acc: 0.74853515625  Mean support loss:  0.9501953125   Mean query loss: 1.5087890625
#
# Epoch  118
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.846 0.728 0.698 0.694 0.694 0.694 0.694 0.694 0.692]
# Mean test acc: 0.7666015625  Mean support loss:  0.90185546875   Mean query loss: 1.28125
#
# Epoch  119
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.988 0.862 0.718 0.702 0.7   0.7   0.7   0.7   0.7   0.7  ]
# Mean test acc: 0.77001953125  Mean support loss:  0.9931640625   Mean query loss: 1.3310546875
#
# Epoch  120
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.792 0.714 0.702 0.702 0.702 0.702 0.702 0.702 0.702]
# Mean test acc: 0.7646484375  Mean support loss:  0.89794921875   Mean query loss: 1.373046875
#
# Epoch  121
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.828 0.706 0.682 0.68  0.678 0.678 0.678 0.676 0.676]
# Mean test acc: 0.7529296875  Mean support loss:  1.025390625   Mean query loss: 1.48828125
#
# Epoch  122
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.832 0.704 0.692 0.692 0.692 0.692 0.692 0.692 0.692]
# Mean test acc: 0.76123046875  Mean support loss:  1.0283203125   Mean query loss: 1.4375
#
# Epoch  123
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.848 0.708 0.686 0.684 0.682 0.682 0.682 0.682 0.682]
# Mean test acc: 0.75732421875  Mean support loss:  1.0205078125   Mean query loss: 1.3125
#
# Epoch  124
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.806 0.708 0.68  0.678 0.678 0.678 0.678 0.678 0.678]
# Mean test acc: 0.75048828125  Mean support loss:  0.896484375   Mean query loss: 1.4541015625
#
# Epoch  125
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.99  0.832 0.734 0.704 0.7   0.7   0.7   0.7   0.7   0.7  ]
# Mean test acc: 0.76904296875  Mean support loss:  0.97900390625   Mean query loss: 1.31640625
#
# Epoch  126
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.816 0.7   0.684 0.684 0.684 0.684 0.684 0.68  0.68 ]
# Mean test acc: 0.75390625  Mean support loss:  0.99755859375   Mean query loss: 1.4208984375
#
# Epoch  127
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.828 0.716 0.71  0.702 0.702 0.7   0.7   0.7   0.7  ]
# Mean test acc: 0.76904296875  Mean support loss:  0.8974609375   Mean query loss: 1.3818359375
#
# Epoch  128
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.818 0.698 0.674 0.674 0.674 0.674 0.674 0.674 0.674]
# Mean test acc: 0.748046875  Mean support loss:  0.9912109375   Mean query loss: 1.4765625
#
# Epoch  129
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.832 0.692 0.67  0.668 0.666 0.666 0.666 0.666 0.666]
# Mean test acc: 0.744140625  Mean support loss:  1.0   Mean query loss: 1.560546875
#
# Epoch  130
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.816 0.706 0.69  0.688 0.688 0.688 0.686 0.688 0.686]
# Mean test acc: 0.7578125  Mean support loss:  0.88134765625   Mean query loss: 1.4130859375
#
# Epoch  131
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.848 0.724 0.714 0.714 0.714 0.714 0.714 0.714 0.714]
# Mean test acc: 0.77880859375  Mean support loss:  0.830078125   Mean query loss: 1.244140625
#
# Epoch  132
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.818 0.718 0.696 0.692 0.692 0.692 0.692 0.692 0.69 ]
# Mean test acc: 0.76171875  Mean support loss:  0.89990234375   Mean query loss: 1.3408203125
#
# Epoch  133
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.836 0.692 0.642 0.64  0.64  0.64  0.64  0.64  0.638]
# Mean test acc: 0.7275390625  Mean support loss:  0.97216796875   Mean query loss: 1.748046875
#
# Epoch  134
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.84  0.708 0.696 0.692 0.692 0.688 0.688 0.688 0.688]
# Mean test acc: 0.76123046875  Mean support loss:  0.990234375   Mean query loss: 1.341796875
#
# Epoch  135
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.872 0.744 0.726 0.722 0.72  0.72  0.72  0.72  0.72 ]
# Mean test acc: 0.78759765625  Mean support loss:  0.92333984375   Mean query loss: 1.228515625
#
# Epoch  136
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.854 0.742 0.714 0.712 0.71  0.708 0.708 0.708 0.708]
# Mean test acc: 0.7783203125  Mean support loss:  0.97216796875   Mean query loss: 1.294921875
#
# Epoch  137
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.816 0.706 0.694 0.694 0.702 0.694 0.694 0.692 0.692]
# Mean test acc: 0.76220703125  Mean support loss:  0.97509765625   Mean query loss: 1.24609375
#
# Epoch  138
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.826 0.686 0.674 0.668 0.668 0.668 0.668 0.668 0.668]
# Mean test acc: 0.74462890625  Mean support loss:  1.0107421875   Mean query loss: 1.46484375
#
# Epoch  139
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.832 0.706 0.698 0.692 0.692 0.692 0.692 0.692 0.692]
# Mean test acc: 0.76220703125  Mean support loss:  0.94921875   Mean query loss: 1.236328125
#
# Epoch  140
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.82  0.698 0.684 0.682 0.682 0.682 0.682 0.682 0.682]
# Mean test acc: 0.75390625  Mean support loss:  1.021484375   Mean query loss: 1.3759765625
#
# Epoch  141
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.83  0.732 0.702 0.692 0.692 0.692 0.692 0.692 0.692]
# Mean test acc: 0.7646484375  Mean support loss:  1.005859375   Mean query loss: 1.482421875
#
# Epoch  142
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.834 0.702 0.684 0.678 0.678 0.678 0.678 0.678 0.678]
# Mean test acc: 0.75341796875  Mean support loss:  0.8603515625   Mean query loss: 1.3974609375
#
# Epoch  143
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.834 0.69  0.686 0.686 0.686 0.686 0.684 0.684 0.684]
# Mean test acc: 0.755859375  Mean support loss:  0.99365234375   Mean query loss: 1.326171875
#
# Epoch  144
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.992 0.822 0.69  0.676 0.68  0.678 0.676 0.676 0.676 0.676]
# Mean test acc: 0.7490234375  Mean support loss:  0.89892578125   Mean query loss: 1.431640625
#
# Epoch  145
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.832 0.684 0.666 0.66  0.66  0.66  0.66  0.66  0.66 ]
# Mean test acc: 0.73974609375  Mean support loss:  1.0078125   Mean query loss: 1.4384765625
#
# Epoch  146
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.824 0.726 0.702 0.702 0.702 0.702 0.702 0.702 0.702]
# Mean test acc: 0.76953125  Mean support loss:  0.83056640625   Mean query loss: 1.212890625
#
# Epoch  147
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.816 0.736 0.718 0.714 0.712 0.712 0.71  0.71  0.71 ]
# Mean test acc: 0.77587890625  Mean support loss:  0.91845703125   Mean query loss: 1.24609375
#
# Epoch  148
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.852 0.728 0.698 0.698 0.698 0.696 0.696 0.696 0.696]
# Mean test acc: 0.7685546875  Mean support loss:  0.90380859375   Mean query loss: 1.2392578125
#
# Epoch  149
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.826 0.722 0.698 0.694 0.694 0.694 0.694 0.694 0.694]
# Mean test acc: 0.76416015625  Mean support loss:  0.93701171875   Mean query loss: 1.2998046875
#
# Epoch  150
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.994 0.858 0.72  0.682 0.682 0.68  0.68  0.68  0.68  0.68 ]
# Mean test acc: 0.7578125  Mean support loss:  0.927734375   Mean query loss: 1.484375
#
# Epoch  151
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.838 0.724 0.692 0.692 0.692 0.692 0.692 0.69  0.69 ]
# Mean test acc: 0.76318359375  Mean support loss:  1.01171875   Mean query loss: 1.416015625
#
# Epoch  152
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.85  0.712 0.7   0.7   0.698 0.698 0.698 0.696 0.696]
# Mean test acc: 0.767578125  Mean support loss:  0.8876953125   Mean query loss: 1.4306640625
#
# Epoch  153
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.842 0.71  0.702 0.698 0.696 0.696 0.696 0.696 0.694]
# Mean test acc: 0.76611328125  Mean support loss:  0.880859375   Mean query loss: 1.2958984375
#
# Epoch  154
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.816 0.694 0.678 0.678 0.678 0.678 0.676 0.676 0.676]
# Mean test acc: 0.75  Mean support loss:  0.93603515625   Mean query loss: 1.3798828125
#
# Epoch  155
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.834 0.706 0.696 0.692 0.692 0.692 0.692 0.692 0.692]
# Mean test acc: 0.76220703125  Mean support loss:  0.923828125   Mean query loss: 1.466796875
#
# Epoch  156
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.844 0.714 0.694 0.692 0.692 0.692 0.692 0.692 0.692]
# Mean test acc: 0.763671875  Mean support loss:  1.068359375   Mean query loss: 1.248046875
#
# Epoch  157
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.822 0.698 0.676 0.676 0.676 0.676 0.676 0.678 0.678]
# Mean test acc: 0.75  Mean support loss:  0.94677734375   Mean query loss: 1.3779296875
#
# Epoch  158
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.824 0.692 0.676 0.676 0.676 0.674 0.674 0.674 0.674]
# Mean test acc: 0.74853515625  Mean support loss:  0.9248046875   Mean query loss: 1.34765625
#
# Epoch  159
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.824 0.708 0.678 0.676 0.676 0.676 0.676 0.676 0.676]
# Mean test acc: 0.7509765625  Mean support loss:  1.02734375   Mean query loss: 1.501953125
#
# Epoch  160
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.832 0.73  0.688 0.686 0.682 0.682 0.682 0.682 0.682]
# Mean test acc: 0.7587890625  Mean support loss:  0.95947265625   Mean query loss: 1.408203125
#
# Epoch  161
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.834 0.714 0.696 0.688 0.688 0.69  0.69  0.69  0.69 ]
# Mean test acc: 0.76171875  Mean support loss:  0.88916015625   Mean query loss: 1.466796875
#
# Epoch  162
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.832 0.702 0.688 0.682 0.682 0.682 0.682 0.682 0.68 ]
# Mean test acc: 0.75537109375  Mean support loss:  1.015625   Mean query loss: 1.345703125
#
# Epoch  163
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.996 0.81  0.688 0.676 0.678 0.676 0.676 0.676 0.676 0.676]
# Mean test acc: 0.748046875  Mean support loss:  0.9462890625   Mean query loss: 1.4794921875
#
# Epoch  164
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.844 0.718 0.7   0.7   0.7   0.7   0.7   0.7   0.698]
# Mean test acc: 0.76904296875  Mean support loss:  0.98583984375   Mean query loss: 1.46875
#
# Epoch  165
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.83  0.692 0.686 0.686 0.686 0.686 0.686 0.686 0.686]
# Mean test acc: 0.7568359375  Mean support loss:  1.04296875   Mean query loss: 1.330078125
#
# Epoch  166
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.84  0.71  0.684 0.686 0.686 0.684 0.684 0.684 0.684]
# Mean test acc: 0.75830078125  Mean support loss:  1.009765625   Mean query loss: 1.48046875
#
# Epoch  167
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.824 0.724 0.7   0.696 0.696 0.694 0.694 0.694 0.694]
# Mean test acc: 0.76513671875  Mean support loss:  0.9775390625   Mean query loss: 1.4345703125
#
# Epoch  168
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.814 0.688 0.686 0.68  0.68  0.678 0.678 0.678 0.678]
# Mean test acc: 0.7509765625  Mean support loss:  0.8984375   Mean query loss: 1.3408203125
#
# Epoch  169
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.818 0.702 0.686 0.67  0.682 0.674 0.674 0.674 0.674]
# Mean test acc: 0.75048828125  Mean support loss:  0.94580078125   Mean query loss: 1.552734375
#
# Epoch  170
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.838 0.698 0.668 0.668 0.668 0.668 0.668 0.668 0.668]
# Mean test acc: 0.74658203125  Mean support loss:  1.017578125   Mean query loss: 1.45703125
#
# Epoch  171
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.836 0.724 0.712 0.71  0.71  0.708 0.706 0.706 0.706]
# Mean test acc: 0.7744140625  Mean support loss:  0.90234375   Mean query loss: 1.111328125
#
# Epoch  172
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.838 0.734 0.706 0.706 0.706 0.702 0.702 0.702 0.702]
# Mean test acc: 0.7724609375  Mean support loss:  0.93212890625   Mean query loss: 1.33984375
#
# Epoch  173
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.828 0.712 0.696 0.692 0.692 0.69  0.69  0.69  0.69 ]
# Mean test acc: 0.76171875  Mean support loss:  0.95458984375   Mean query loss: 1.3232421875
#
# Epoch  174
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.848 0.726 0.692 0.686 0.686 0.686 0.686 0.686 0.686]
# Mean test acc: 0.76220703125  Mean support loss:  1.0517578125   Mean query loss: 1.3291015625
#
# Epoch  175
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.824 0.688 0.674 0.674 0.674 0.674 0.672 0.672 0.672]
# Mean test acc: 0.74755859375  Mean support loss:  0.9140625   Mean query loss: 1.3896484375
#
# Epoch  176
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.822 0.712 0.682 0.68  0.682 0.682 0.682 0.682 0.682]
# Mean test acc: 0.75537109375  Mean support loss:  1.0341796875   Mean query loss: 1.4931640625
#
# Epoch  177
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.83  0.692 0.666 0.664 0.664 0.664 0.664 0.664 0.664]
# Mean test acc: 0.74267578125  Mean support loss:  0.99658203125   Mean query loss: 1.400390625
#
# Epoch  178
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.848 0.738 0.71  0.712 0.712 0.712 0.712 0.712 0.712]
# Mean test acc: 0.77880859375  Mean support loss:  0.86474609375   Mean query loss: 1.384765625
#
# Epoch  179
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.834 0.742 0.706 0.706 0.706 0.706 0.706 0.706 0.706]
# Mean test acc: 0.7744140625  Mean support loss:  0.97216796875   Mean query loss: 1.4111328125
#
# Epoch  180
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.842 0.718 0.688 0.688 0.688 0.688 0.688 0.688 0.688]
# Mean test acc: 0.76123046875  Mean support loss:  1.0244140625   Mean query loss: 1.27734375
#
# Epoch  181
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.806 0.702 0.686 0.684 0.684 0.684 0.684 0.684 0.684]
# Mean test acc: 0.75439453125  Mean support loss:  0.95556640625   Mean query loss: 1.4404296875
#
# Epoch  182
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.842 0.734 0.71  0.702 0.702 0.7   0.7   0.7   0.7  ]
# Mean test acc: 0.77197265625  Mean support loss:  1.0400390625   Mean query loss: 1.43359375
#
# Epoch  183
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.842 0.722 0.694 0.682 0.68  0.68  0.68  0.68  0.68 ]
# Mean test acc: 0.75830078125  Mean support loss:  1.0205078125   Mean query loss: 1.4814453125
#
# Epoch  184
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.818 0.69  0.65  0.648 0.648 0.648 0.648 0.648 0.648]
# Mean test acc: 0.7314453125  Mean support loss:  1.0849609375   Mean query loss: 1.8125
#
# Epoch  185
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    0.84  0.738 0.706 0.706 0.704 0.704 0.704 0.704 0.704]
# Mean test acc: 0.7734375  Mean support loss:  0.9404296875   Mean query loss: 1.2763671875
#
# Epoch  186
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.826 0.702 0.664 0.66  0.66  0.66  0.66  0.658 0.658]
# Mean test acc: 0.74072265625  Mean support loss:  0.958984375   Mean query loss: 1.5087890625
#
# Epoch  187
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    0.998 0.854 0.716 0.686 0.684 0.684 0.684 0.682 0.682 0.68 ]
# Mean test acc: 0.75927734375  Mean support loss:  1.078125   Mean query loss: 1.3388671875
#
# Epoch  188
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# ...
# Mean test acc: 0.95068359375  Mean support loss:  8.3671875   Mean query loss: 0.242919921875
#
# Epoch  133
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    1.    0.992 0.966 0.928 0.904 0.898 0.896]
# Mean test acc: 0.96240234375  Mean support loss:  9.4296875   Mean query loss: 0.2078857421875
#
# Epoch  134
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    1.    0.976 0.95  0.926 0.924 0.918 0.908]
# Mean test acc: 0.9638671875  Mean support loss:  9.34375   Mean query loss: 0.2398681640625
#
# Epoch  135
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.994 0.992 0.984 0.946 0.93  0.914 0.902 0.898]
# Mean test acc: 0.9599609375  Mean support loss:  8.734375   Mean query loss: 0.2119140625
#
# Epoch  136
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    1.    0.98  0.962 0.942 0.922 0.918 0.916]
# Mean test acc: 0.96728515625  Mean support loss:  9.2265625   Mean query loss: 0.1793212890625
#
# Epoch  137
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    1.    0.996 0.968 0.946 0.924 0.916 0.914]
# Mean test acc: 0.96923828125  Mean support loss:  9.1484375   Mean query loss: 0.1549072265625
#
# Epoch  138
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.998 0.994 0.976 0.948 0.93  0.918 0.914 0.912]
# Mean test acc: 0.962890625  Mean support loss:  9.078125   Mean query loss: 0.1864013671875
#
# Epoch  139
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.998 0.998 0.974 0.954 0.922 0.912 0.912 0.908]
# Mean test acc: 0.9619140625  Mean support loss:  9.0859375   Mean query loss: 0.241943359375
#
# Epoch  140
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.994 0.984 0.924 0.898 0.872 0.87  0.86 ]
# Mean test acc: 0.94580078125  Mean support loss:  9.453125   Mean query loss: 0.2578125
#
# Epoch  141
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    1.    0.986 0.962 0.924 0.908 0.902 0.898]
# Mean test acc: 0.9619140625  Mean support loss:  8.8984375   Mean query loss: 0.1798095703125
#
# Epoch  142
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.998 0.992 0.974 0.944 0.914 0.9   0.892 0.888]
# Mean test acc: 0.95458984375  Mean support loss:  8.4296875   Mean query loss: 0.2227783203125
#
# Epoch  143
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.99  0.966 0.934 0.906 0.89  0.886 0.884]
# Mean test acc: 0.95068359375  Mean support loss:  8.5078125   Mean query loss: 0.298095703125
#
# Epoch  144
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.996 0.97  0.956 0.938 0.92  0.902 0.894]
# Mean test acc: 0.96142578125  Mean support loss:  9.015625   Mean query loss: 0.1826171875
#
# Epoch  145
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.988 0.968 0.938 0.914 0.9   0.896 0.894]
# Mean test acc: 0.9541015625  Mean support loss:  8.5390625   Mean query loss: 0.25244140625
#
# Epoch  146
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.998 0.984 0.972 0.96  0.95  0.942 0.93 ]
# Mean test acc: 0.97607421875  Mean support loss:  8.9921875   Mean query loss: 0.08099365234375
#
# Epoch  147
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.992 0.974 0.944 0.934 0.918 0.916 0.914]
# Mean test acc: 0.962890625  Mean support loss:  8.5859375   Mean query loss: 0.20556640625
#
# Epoch  148
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    1.    0.998 0.95  0.898 0.894 0.89  0.888]
# Mean test acc: 0.9560546875  Mean support loss:  8.9765625   Mean query loss: 0.197998046875
#
# Epoch  149
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.988 0.98  0.952 0.91  0.902 0.894 0.89 ]
# Mean test acc: 0.9560546875  Mean support loss:  8.6015625   Mean query loss: 0.2060546875
#
# Epoch  150
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.998 0.998 0.986 0.962 0.95  0.914 0.898 0.896]
# Mean test acc: 0.9638671875  Mean support loss:  8.7890625   Mean query loss: 0.18505859375
#
# Epoch  151
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    1.    0.984 0.958 0.924 0.914 0.914 0.914]
# Mean test acc: 0.96435546875  Mean support loss:  8.4140625   Mean query loss: 0.1588134765625
#
# Epoch  152
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.996 0.986 0.938 0.914 0.894 0.89  0.89 ]
# Mean test acc: 0.955078125  Mean support loss:  8.890625   Mean query loss: 0.17529296875
#
# Epoch  153
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.986 0.98  0.968 0.934 0.912 0.9   0.9  ]
# Mean test acc: 0.9619140625  Mean support loss:  9.140625   Mean query loss: 0.19970703125
#
# Epoch  154
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.986 0.982 0.948 0.936 0.93  0.926 0.92 ]
# Mean test acc: 0.96630859375  Mean support loss:  9.046875   Mean query loss: 0.2364501953125
#
# Epoch  155
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.994 0.966 0.942 0.904 0.896 0.89  0.886]
# Mean test acc: 0.95263671875  Mean support loss:  8.4609375   Mean query loss: 0.2392578125
#
# Epoch  156
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.998 0.99  0.97  0.942 0.93  0.922 0.92 ]
# Mean test acc: 0.97021484375  Mean support loss:  8.78125   Mean query loss: 0.1409912109375
#
# Epoch  157
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.994 0.974 0.944 0.926 0.914 0.906 0.904]
# Mean test acc: 0.9599609375  Mean support loss:  8.9921875   Mean query loss: 0.1859130859375
#
# Epoch  158
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.992 0.962 0.942 0.93  0.918 0.908 0.902]
# Mean test acc: 0.95947265625  Mean support loss:  8.6953125   Mean query loss: 0.2142333984375
#
# Epoch  159
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.996 0.996 0.978 0.928 0.882 0.87  0.87  0.864]
# Mean test acc: 0.94384765625  Mean support loss:  8.84375   Mean query loss: 0.25
#
# Epoch  160
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.998 0.984 0.94  0.928 0.914 0.91  0.91 ]
# Mean test acc: 0.96240234375  Mean support loss:  8.734375   Mean query loss: 0.19189453125
#
# Epoch  161
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.996 0.992 0.972 0.952 0.946 0.932 0.926 0.926]
# Mean test acc: 0.96728515625  Mean support loss:  8.6328125   Mean query loss: 0.10986328125
#
# Epoch  162
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.994 0.99  0.976 0.956 0.92  0.898 0.894 0.892]
# Mean test acc: 0.95654296875  Mean support loss:  9.0703125   Mean query loss: 0.2203369140625
#
# Epoch  163
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.994 0.98  0.95  0.926 0.904 0.896 0.896]
# Mean test acc: 0.95849609375  Mean support loss:  8.6875   Mean query loss: 0.1693115234375
#
# Epoch  164
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.996 0.988 0.98  0.94  0.918 0.904 0.886 0.884]
# Mean test acc: 0.9541015625  Mean support loss:  9.484375   Mean query loss: 0.1500244140625
#
# Epoch  165
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.988 0.97  0.952 0.932 0.918 0.912 0.908]
# Mean test acc: 0.9619140625  Mean support loss:  8.7734375   Mean query loss: 0.1978759765625
#
# Epoch  166
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.996 0.976 0.94  0.922 0.902 0.896 0.892]
# Mean test acc: 0.95654296875  Mean support loss:  9.09375   Mean query loss: 0.2568359375
#
# Epoch  167
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.992 0.976 0.954 0.932 0.918 0.902 0.892]
# Mean test acc: 0.96044921875  Mean support loss:  9.265625   Mean query loss: 0.168212890625
#
# Epoch  168
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.992 0.984 0.95  0.916 0.908 0.9   0.902]
# Mean test acc: 0.95947265625  Mean support loss:  9.1015625   Mean query loss: 0.205078125
#
# Epoch  169
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    1.    0.982 0.976 0.95  0.942 0.924 0.924]
# Mean test acc: 0.97265625  Mean support loss:  8.8359375   Mean query loss: 0.10302734375
#
# Epoch  170
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.996 0.988 0.952 0.936 0.924 0.912 0.896]
# Mean test acc: 0.9638671875  Mean support loss:  9.0703125   Mean query loss: 0.13916015625
#
# Epoch  171
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.998 0.976 0.966 0.94  0.922 0.922 0.918]
# Mean test acc: 0.96728515625  Mean support loss:  9.0546875   Mean query loss: 0.1533203125
#
# Epoch  172
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.996 0.978 0.956 0.926 0.902 0.902 0.902]
# Mean test acc: 0.9599609375  Mean support loss:  9.1171875   Mean query loss: 0.185546875
#
# Epoch  173
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.996 0.996 0.97  0.952 0.908 0.884 0.88  0.88 ]
# Mean test acc: 0.95166015625  Mean support loss:  9.296875   Mean query loss: 0.193359375
#
# Epoch  174
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.996 0.986 0.976 0.958 0.93  0.904 0.904 0.9  ]
# Mean test acc: 0.95947265625  Mean support loss:  9.2109375   Mean query loss: 0.205322265625
#
# Epoch  175
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.996 0.992 0.978 0.94  0.912 0.892 0.884 0.884]
# Mean test acc: 0.95263671875  Mean support loss:  9.3203125   Mean query loss: 0.1815185546875
#
# Epoch  176
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.988 0.966 0.954 0.938 0.93  0.926 0.92 ]
# Mean test acc: 0.9658203125  Mean support loss:  8.875   Mean query loss: 0.223876953125
#
# Epoch  177
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.99  0.974 0.94  0.914 0.89  0.876 0.87 ]
# Mean test acc: 0.9501953125  Mean support loss:  9.046875   Mean query loss: 0.246337890625
#
# Epoch  178
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.992 0.972 0.958 0.914 0.9   0.894 0.894]
# Mean test acc: 0.95654296875  Mean support loss:  9.390625   Mean query loss: 0.27978515625
#
# Epoch  179
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.998 0.99  0.96  0.932 0.916 0.9   0.898 0.896]
# Mean test acc: 0.95361328125  Mean support loss:  9.046875   Mean query loss: 0.262939453125
#
# Epoch  180
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.99  0.958 0.94  0.91  0.896 0.896 0.89 ]
# Mean test acc: 0.95263671875  Mean support loss:  8.609375   Mean query loss: 0.255126953125
#
# Epoch  181
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.998 0.97  0.95  0.916 0.912 0.906 0.906]
# Mean test acc: 0.9599609375  Mean support loss:  9.1171875   Mean query loss: 0.232421875
#
# Epoch  182
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.99  0.962 0.938 0.898 0.896 0.89  0.888]
# Mean test acc: 0.951171875  Mean support loss:  9.2109375   Mean query loss: 0.25
#
# Epoch  183
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.988 0.966 0.936 0.916 0.906 0.898 0.896]
# Mean test acc: 0.955078125  Mean support loss:  8.734375   Mean query loss: 0.279296875
#
# Epoch  184
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.988 0.974 0.95  0.94  0.924 0.906 0.904]
# Mean test acc: 0.96240234375  Mean support loss:  9.59375   Mean query loss: 0.2193603515625
#
# Epoch  185
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.992 0.974 0.962 0.934 0.924 0.922 0.922]
# Mean test acc: 0.96630859375  Mean support loss:  9.28125   Mean query loss: 0.2154541015625
#
# Epoch  186
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.998 0.956 0.932 0.92  0.898 0.898 0.896]
# Mean test acc: 0.95458984375  Mean support loss:  9.4765625   Mean query loss: 0.23583984375
#
# Epoch  187
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    0.998 0.99  0.972 0.946 0.926 0.904 0.894 0.886]
# Mean test acc: 0.9560546875  Mean support loss:  8.8984375   Mean query loss: 0.30419921875
#
# Epoch  188
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    1.    0.966 0.95  0.94  0.928 0.924 0.92 ]
# Mean test acc: 0.96630859375  Mean support loss:  9.5078125   Mean query loss: 0.190673828125
#
# Epoch  189
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.994 0.97  0.952 0.936 0.926 0.916 0.908]
# Mean test acc: 0.9638671875  Mean support loss:  9.28125   Mean query loss: 0.1851806640625
#
# Epoch  190
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.992 0.966 0.93  0.91  0.886 0.88  0.876]
# Mean test acc: 0.94921875  Mean support loss:  8.9921875   Mean query loss: 0.2412109375
#
# Epoch  191
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.994 0.982 0.958 0.936 0.926 0.918 0.916]
# Mean test acc: 0.96630859375  Mean support loss:  9.1171875   Mean query loss: 0.163330078125
#
# Epoch  192
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.994 0.968 0.94  0.932 0.93  0.928 0.928]
# Mean test acc: 0.96533203125  Mean support loss:  9.0625   Mean query loss: 0.2021484375
#
# Epoch  193
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.99  0.97  0.944 0.916 0.91  0.908 0.908]
# Mean test acc: 0.958984375  Mean support loss:  9.5859375   Mean query loss: 0.2177734375
#
# Epoch  194
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.994 0.978 0.938 0.914 0.908 0.886 0.886]
# Mean test acc: 0.955078125  Mean support loss:  9.2890625   Mean query loss: 0.211669921875
#
# Epoch  195
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.99  0.964 0.948 0.934 0.916 0.912 0.912]
# Mean test acc: 0.96142578125  Mean support loss:  9.5234375   Mean query loss: 0.2083740234375
#
# Epoch  196
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.998 0.982 0.95  0.93  0.93  0.92  0.92 ]
# Mean test acc: 0.96630859375  Mean support loss:  9.2890625   Mean query loss: 0.1337890625
#
# Epoch  197
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.992 0.96  0.936 0.912 0.9   0.888 0.886]
# Mean test acc: 0.9521484375  Mean support loss:  9.6796875   Mean query loss: 0.253173828125
#
# Epoch  198
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.992 0.976 0.96  0.932 0.896 0.894 0.882]
# Mean test acc: 0.95751953125  Mean support loss:  8.9921875   Mean query loss: 0.1666259765625
#
# Epoch  199
# Training accuracies: 	 [1. 1. 1. 1. 1. 1.]
# Test accuracies: 	 [1.    1.    1.    1.    0.99  0.972 0.944 0.922 0.91  0.908 0.898]
# Mean test acc: 0.95849609375  Mean support loss:  9.3359375   Mean query loss: 0.20166015625
#
# Highest mean validation accuracy:  0.976
#
# Assessing test set....
#
# Mean test accuracy: 0.95
# MAML execution time: 0.49835698440666665 hrs

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))


print('Mean Test Accuracy over Epochs')

text_file = open('/content/mean_test_accuracy.txt', "r")
mean_accs = text_file.read().split('\n')
mean_accs = [(float(ma) * 100) for ma in mean_accs]

axes = plt.gca()
axes.set_ylim([np.int(min(mean_accs)-2), np.int(max(mean_accs)) +2])
        
plt.plot(mean_accs)
plt.xlabel('Epochs')
plt.ylabel('Mean Accuracy')
plt.title('Mean Test Accuracy over Epochs')
plt.show();
# Out:
# Mean Test Accuracy over Epochs

# %%
metrics = pd.read_csv('mean_metrics.csv')
metrics.head()

metrics[['train_loss', 'val_loss']].plot(figsize=(10,5), title='Train and Validation Loss over Epochs')

# %%
metrics[['train_accuracy', 'val_accuracy']].plot(figsize=(10,5), title='Train and Validation Accuracy over Epochs')

# %%
import matplotlib.pyplot as plt
import itertools

# modified from main.py https://github.com/zhangrong1722/CheXNet-Pytorch

def plt_roc(test_y, probas_y, plot_micro=False, plot_macro=False):
    assert isinstance(test_y, list) and isinstance(probas_y, list), 'the type of input must be list'
    skplt.metrics.plot_roc(test_y, probas_y, plot_micro=plot_micro, plot_macro=plot_macro)
    plt.savefig('roc_auc_curve.png')
    plt.show()
    plt.close()


###########################################
# Define confusion matrix and ROC visualization functions
# from https://colab.research.google.com/drive/1ISfhxFDntfOos7cOeT7swduSqzLEqyFn#scrollTo=UiKRYOWPfhJs

def plot_confusion_matrix(cm, classes=None,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues,
                          cv=10):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
   
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("\nNormalized confusion matrix")
    else:
        print('\nConfusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    if classes:
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 1.5
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.locator_params(nbins=2)

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# %%
pred_df = pd.read_csv('test_predictions_and_labels.csv')

# %%
from IPython.display import display

# Get the predicted labels for metric calculations.
#
# Since prototypical networks always sets the ground truth to 0,
# infer the predicted class label from true label and the Boolean value for 'correct'
# To do this, set hc to be -1 and sz to 1. This allows the opposite class to be selected
# for rows where correct is False by multiplying the true_label by -1
pred_df['true_label'] = pred_df.apply(lambda x: -1 if x['true_label'] == 0 else 1, axis=1)
pred_df['correct'] = pred_df.apply(lambda x: 1 if x['correct'] == True else 0, axis=1)
pred_df['prediction'] = pred_df.apply(lambda x: x['true_label']
  if x['correct'] == 1 else x['true_label'] * -1, axis=1)
pred_df.replace(-1, 0, inplace=True)
# display(pred_df.head())
# pred_df.tail()

# %%
from sklearn.metrics import confusion_matrix


pred_y = pred_df['prediction'].values
truth_y = pred_df['true_label'].values
#probas_y = [s.replace('[', '').replace(']', '').split(', ') for s in best_model_preds['probas_y'].values]
#probas_y = [[float(t[0]), float(t[1])] for t in probas_y]


confusion = confusion_matrix(pred_y, truth_y)
plot_confusion_matrix(confusion,
                      classes=['hc', 'sz'],
                      title='Confusion Matrix')
# Out:
# Confusion matrix, without normalization

# %%
pd.read_csv('metrics_summary.csv')
# Out:
#    Final Val Support Loss  ...  Test F1 Score Micro
# 0                   9.336  ...             0.949091
#
# [1 rows x 9 columns]
