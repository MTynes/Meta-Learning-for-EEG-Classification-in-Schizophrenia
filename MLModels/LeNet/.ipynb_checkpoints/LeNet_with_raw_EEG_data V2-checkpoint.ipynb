# %%
import os
raw_data_dir = ''

if  'COLAB_GPU' in os.environ:
    print('Using Google Colab. Setting up environment')
    raw_data_dir = '/content/drive/My Drive/Colab Notebooks/' 
    # !pip install mne==0.19.2
    # !pip install pyedflib==0.1.15

    print('\n \n To load files from Google Drive, account validation is required.')
    #mount to drive -- files should be located in the Colab notebooks directory
    from google.colab import drive
    drive.mount("/content/drive", force_remount=True)
else:
    if 'HOMEPATH' in os.environ:
        print('Using homepath ' + os.environ['HOMEPATH'])
    raw_data_dir = '../../Data/Raw/'
# Out:
# Using Google Colab. Setting up environment
# Requirement already satisfied: mne in /usr/local/lib/python3.6/dist-packages (0.19.2)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from mne) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from mne) (1.17.5)
# Requirement already satisfied: pyedflib in /usr/local/lib/python3.6/dist-packages (0.1.15)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from pyedflib) (1.17.5)
#
#
#  To load files from Google Drive, account validation is required.
# Mounted at /content/drive

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling1D, AveragePooling1D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

import pandas as pd
import pyedflib


import tensorflow as tf
use_gpu = tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)


import numpy as np

# mne imports
import mne
from mne import io

# Model-specific imports
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Convolution1D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense


# tools for plotting confusion matrices
from matplotlib import pyplot as plt

import random 
import math

# %%
from tensorflow.keras import layers
#https://www.tensorflow.org/guide/keras/rnn

def LSTM(samples, time_steps, nb_features, chans, nb_classes):

    model=tf.keras.Sequential()
    
    print('chans: ', chans)
    print('nb_features: ', nb_features)
    model.add(layers.LSTM(128,
                          input_shape=(chans, time_steps)
            #input_shape=(chans* nb_features, time_steps),
            ))
    

    model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
    

    model.add(Dense(nb_classes,activation='softmax'))
    
    return model



    #LSTM(samles, time_steps=20, input_size=30, chans)


    
    
from tensorflow.keras import layers
#https://www.tensorflow.org/guide/keras/rnn

def GRU_RNN(samples, time_steps, nb_features, chans, nb_classes):
    model=tf.keras.Sequential()
    
    #model.add(layers.LSTM(128,
    #         input_shape=(chans, time_steps),
    #         ))
    
    # The output of GRU will be a 3D tensor of shape (batch_size, timesteps, 256)
    model.add(layers.GRU(512, 
                         input_shape=(chans, time_steps),
                         return_sequences=True))

    model.add(layers.SimpleRNN(128))
    #model.add(layers.SimpleRNN(128))
    

    model.add(Dense(32,kernel_initializer='he_uniform',activation='relu'))
    

    model.add(Dense(nb_classes,activation='softmax'))
    
    return model  




"""def LeNet(nb_classes, Chans = 64, Samples = 128, Kernels=1,
          dropoutRate = 0.5, kernLength = 64, F1 = 8, 
          D = 2, F2 = 16, norm_rate = 0.25):"""

def LeNet(samples, time_steps, nb_features, chans, nb_classes):

    model = Sequential()

    # first set of CONV => RELU => POOL
    model.add(Convolution1D(6, 3, 3, # border_mode="same",
        #input_shape=( time_steps, chans, 50), name='conv2D_1'))
        input_shape=( chans, time_steps), name='conv2D_1'))
    model.add(Activation("relu"))
    model.add(layers.AveragePooling1D())
    #model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='maxpool_1'))

    # second set of CONV => RELU => POOL
    model.add(Convolution1D(16, 3, 3, name='conv2D_2')) #, border_mode="same"))
    model.add(Activation("relu"))
    #model.add(layers.AveragePooling1D(), name='averagepool_2')
    #model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), name='maxpool_2'))

    # set of FC => RELU layers
    model.add(Flatten())
    model.add(Dense(120))
    model.add(Activation("relu"))
    model.add(Dense(84))
    model.add(Activation("relu"))

    # softmax classifier
    model.add(Dense(nb_classes))
    model.add(Activation("softmax"))
    


    return model

# %%
ignore_list = ['s07']  #list of patient files that should be skipped
#seconds of data to include in one slice
time_window = 12

# %%
mne.set_log_level("WARNING")


# get the minimum length of the files
def get_minimum_duration(group_directory_name, patient_group_file_prefix):
    file_durations = []
    for i in range (1, 15): # reading 14 files
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        file_name = raw_data_dir +'{}/{}.edf'.format(group_directory_name, patient_id)
        f = pyedflib.EdfReader(file_name)
        file_durations.append(f.file_duration)
        f.close()
    return(min(file_durations))

# modified based on https://stackoverflow.com/a/48704557/2466781
def chunk(seq, size):
    sl = len(seq) - (len(seq)%size) #exclude values that will be out of range
    r = [pd.DataFrame(seq[pos:pos + size]) for pos in range(0, sl, size)]
    return r

# modified version of process_patient_group in older notebooks
# Uses the raw EDF files and converts to dataframe, dropping the first 150 and last 30 seconds of the shortest  file
# All other files are trimmed similarly to produce the same size
# Adapted from page 1 of https://buildmedia.readthedocs.org/media/pdf/pyedflib/latest/pyedflib.pdf
def process_patient_group(group_directory_name, patient_group_file_prefix, 
                          minimum_original_duration,
                          time_window = 20,
                          plot_channels = False,
                         channels = ['F8', 'F7', 'F4', 'F3', 'Fz']):
    meta_df = pd.DataFrame()
    meta = []
    patient_id_list = []

    for i in range (1, 15): # reading 14 files
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        patient_id_list.append(patient_id)
        
        file_name = raw_data_dir + '{}/{}.edf'.format(group_directory_name, patient_id)
        data = mne.io.read_raw_edf(file_name)
        df = data.to_data_frame()
        df2 = df[channels]
        ## based on visual inspection, drop the first 120 seconds
        df2 = df2[120: (minimum_original_duration-120)]
        f = pyedflib.EdfReader(file_name)
        f.close()
        if patient_id not in ignore_list:
            meta_df = meta_df.append(df2)
            
    batches = chunk(meta_df, time_window)

    for batch in batches:
        #display(np.asarray(batch.values).shape)
        meta.append([np.asarray(batch.values)])
           
                    
    return meta

# %%
# Retrieve patient data, using a time window determined by the shortest recording
# patient s07 is removed

minimum_duration = min(get_minimum_duration("Healthy Controls", "h"), get_minimum_duration('SZ Patients', 's'))
print('Minimum duration: ', minimum_duration)

all_channels = ['Fp2', 'F8', 'T4', 'T6', 'O2', 'Fp1', 'F7', 'T3', 'T5', 'O1', 'F4',
                'C4', 'P4', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Pz']

target_channels = ['T4', 'T6', 'O2', 'T3', 'T5', 'O1',
                   'C4', 'P4', 'C3', 'P3', 'Cz', 'Pz']

print("Healthy Controls")
hc_data = process_patient_group('Healthy Controls', 'h', minimum_duration, 
                                #channels=target_channels, 
                                channels=all_channels, 
                                time_window=time_window)
display(np.asarray(hc_data).shape)



print('Sz Patients')
sz_data = np.asarray(process_patient_group('SZ Patients', 's', minimum_duration, 
                                           channels=all_channels, 
                                           #channels=target_channels, 
                                           time_window=time_window))
display(np.asarray(sz_data).shape)


##### combine groups and create Y (labels)

X =  np.concatenate((hc_data, sz_data), axis=0)
display('Input size: ', X.shape)
y = ([0] * len(hc_data)) +( [1] * len(sz_data))
# Out:
# Minimum duration:  740
# Healthy Controls
# (583, 1, 12, 19)
# Sz Patients
# (541, 1, 12, 19)
# 'Input size: '
# (1124, 1, 12, 19)

# %%
#X[1].plot()
from IPython.display import display

import pylab as pylab

print('Input (X) shape: ' + str(X.shape))
print('Preview of data. First slice of unfiltered data')
for el in X[1][0]:
  #print(el)
  #pylab.scatter(x=range(len(el)), y=el)
  pylab.plot(el)
# Out:
# Input (X) shape: (108, 1, 125, 19)
# Preview of data. First slice of unfiltered data

# %%
# create the /tmp directory if it doesn't already exist
import os
if not os.path.exists('tmp'):
    os.makedirs('tmp')

# %%
# get a list of randomly selected sets of numbers based on a range
# the proportion of values selected for each set is determined by the ratio_array
def get_mixed_indexes_for_ml_train_test(length, ratios_array):
    input_indexes = range(0, length)
    output_indexes = []
    for ratio in ratios_array:
        selection = random.choices(input_indexes, k=math.floor(ratio * length))
        input_indexes = [i for i in input_indexes if i not in selection]
        output_indexes.append(selection)
    return output_indexes

# %%
kern_len = 5
kernels, chans, samples = 1, 19, time_window/kern_len
full_size = len(X)
train_idxs, validate_idxs, test_idxs = get_mixed_indexes_for_ml_train_test(len(X), [.70, 0.15, 0.15])



X_train      = X[train_idxs][0:,]
Y_train      = np.asarray(y)[train_idxs]
X_validate   = X[validate_idxs][0:,]
Y_validate   = np.asarray(y)[validate_idxs]
X_test       = X[test_idxs][0:,]
Y_test       = np.asarray(y)[test_idxs]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train, num_classes=2)
Y_validate   = np_utils.to_categorical(Y_validate, num_classes=2)
Y_test       = np_utils.to_categorical(Y_test, num_classes=2)


"""tw_mod = math.floor(time_window/kern_len)
X_train      = X_train.reshape(X_train.shape[0],  chans, tw_mod,   kern_len)
X_validate   = X_validate.reshape( X_validate.shape[0], chans, tw_mod, kern_len)
X_test       = X_test.reshape( X_test.shape[0], chans, tw_mod, kern_len)
print('tw_mod: ', tw_mod)"""



chans = 19
X_train      = X_train.reshape(X_train.shape[0],   chans, time_window,)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, time_window)
X_test       = X_test.reshape(X_test.shape[0], chans, time_window)



 
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')



#LSTM(samles, time_steps=20, input_size=30, chans)
#model = LSTM(samples=samples, time_steps=time_window, chans=chans, nb_features=1, nb_classes=2, )

model = LeNet(samples=samples, time_steps=time_window, chans=chans, nb_features=1, nb_classes=2 )
model.summary()

#import tensorflow 
import tensorflow.keras.optimizers
opt_adam = tensorflow.keras.optimizers.Adam(lr=0.000001, 
                                beta_1=0.99,
                                beta_2=0.999,
                                epsilon=1e-07)
sgd = tensorflow.keras.optimizers.SGD(lr=0.01)



def rmse (y_true, y_pred):

    return K.sqrt(K.mean(K.square(y_pred -y_true)))

def rmse_np (y_true, y_pred):
    y_true = y_true.astype(int)
    y_pred=y_pred.astype(int)
    print(y_pred.dtype)
    return K.sqrt(K.mean(K.square(y_pred -y_true)))

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer=opt_adam, 
              metrics=[#'mse', 'mae', 
                  'accuracy', rmse
                 ])


# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='/tmp/LSTM_checkpoint.h5', verbose=1,
                               save_best_only=True)
# Out:
# X_train shape: (786, 19, 12)
# 786 train samples
# 168 test samples
# Model: "sequential_62"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2D_1 (Conv1D)            (None, 6, 6)              222
# _________________________________________________________________
# activation_139 (Activation)  (None, 6, 6)              0
# _________________________________________________________________
# average_pooling1d_4 (Average (None, 3, 6)              0
# _________________________________________________________________
# conv2D_2 (Conv1D)            (None, 1, 16)             304
# _________________________________________________________________
# activation_140 (Activation)  (None, 1, 16)             0
# _________________________________________________________________
# flatten_26 (Flatten)         (None, 16)                0
# _________________________________________________________________
# dense_52 (Dense)             (None, 120)               2040
# _________________________________________________________________
# activation_141 (Activation)  (None, 120)               0
# _________________________________________________________________
# dense_53 (Dense)             (None, 84)                10164
# _________________________________________________________________
# activation_142 (Activation)  (None, 84)                0
# _________________________________________________________________
# dense_54 (Dense)             (None, 2)                 170
# _________________________________________________________________
# activation_143 (Activation)  (None, 2)                 0
# =================================================================
# Total params: 12,900
# Trainable params: 12,900
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow.keras.backend as K
#import tensorflow.keras.callbacks.LearningRateScheduler
#import tensorflow.keras.callbacks.LearningRateScheduler
def scheduler(epoch):
  if epoch == 700:
    K.set_value(model.optimizer.lr, 0.0000001)
  if epoch == 1000:
    K.set_value(model.optimizer.lr, 0.00000009)
  if epoch == 1200:
    K.set_value(model.optimizer.lr, 0.000000007)
 
  return K.get_value(model.optimizer.lr)


change_lr = tensorflow.keras.callbacks.LearningRateScheduler(scheduler)


fitted_model = model.fit(X_train, Y_train, batch_size = 8, epochs = 2000, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer, change_lr])
# Out:
# Train on 786 samples, validate on 168 samples
# Epoch 1/2000
#
# Epoch 00001: val_loss improved from inf to 0.75463, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 2s - loss: 0.7102 - acc: 0.5051 - rmse: 0.5044 - val_loss: 0.7546 - val_acc: 0.4762 - val_rmse: 0.5212
# Epoch 2/2000
#
# Epoch 00002: val_loss improved from 0.75463 to 0.75394, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7094 - acc: 0.5064 - rmse: 0.5038 - val_loss: 0.7539 - val_acc: 0.4762 - val_rmse: 0.5217
# Epoch 3/2000
#
# Epoch 00003: val_loss improved from 0.75394 to 0.75341, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7085 - acc: 0.5051 - rmse: 0.5046 - val_loss: 0.7534 - val_acc: 0.4762 - val_rmse: 0.5207
# Epoch 4/2000
#
# Epoch 00004: val_loss improved from 0.75341 to 0.75276, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7077 - acc: 0.5051 - rmse: 0.5037 - val_loss: 0.7528 - val_acc: 0.4762 - val_rmse: 0.5221
# Epoch 5/2000
#
# Epoch 00005: val_loss improved from 0.75276 to 0.75215, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7069 - acc: 0.5025 - rmse: 0.5037 - val_loss: 0.7522 - val_acc: 0.4762 - val_rmse: 0.5216
# Epoch 6/2000
#
# Epoch 00006: val_loss improved from 0.75215 to 0.75156, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7061 - acc: 0.5025 - rmse: 0.5037 - val_loss: 0.7516 - val_acc: 0.4762 - val_rmse: 0.5214
# Epoch 7/2000
#
# Epoch 00007: val_loss improved from 0.75156 to 0.75098, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7054 - acc: 0.5051 - rmse: 0.5039 - val_loss: 0.7510 - val_acc: 0.4762 - val_rmse: 0.5219
# Epoch 8/2000
#
# Epoch 00008: val_loss improved from 0.75098 to 0.75036, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7047 - acc: 0.5051 - rmse: 0.5045 - val_loss: 0.7504 - val_acc: 0.4762 - val_rmse: 0.5211
# Epoch 9/2000
#
# Epoch 00009: val_loss improved from 0.75036 to 0.74979, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7039 - acc: 0.5038 - rmse: 0.5021 - val_loss: 0.7498 - val_acc: 0.4762 - val_rmse: 0.5213
# Epoch 10/2000
#
# Epoch 00010: val_loss improved from 0.74979 to 0.74923, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7031 - acc: 0.5064 - rmse: 0.5019 - val_loss: 0.7492 - val_acc: 0.4762 - val_rmse: 0.5190
# Epoch 11/2000
#
# Epoch 00011: val_loss improved from 0.74923 to 0.74866, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7024 - acc: 0.5064 - rmse: 0.5033 - val_loss: 0.7487 - val_acc: 0.4762 - val_rmse: 0.5195
# Epoch 12/2000
#
# Epoch 00012: val_loss improved from 0.74866 to 0.74808, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7017 - acc: 0.5076 - rmse: 0.5012 - val_loss: 0.7481 - val_acc: 0.4762 - val_rmse: 0.5193
# Epoch 13/2000
#
# Epoch 00013: val_loss improved from 0.74808 to 0.74753, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7009 - acc: 0.5076 - rmse: 0.5015 - val_loss: 0.7475 - val_acc: 0.4762 - val_rmse: 0.5200
# Epoch 14/2000
#
# Epoch 00014: val_loss improved from 0.74753 to 0.74698, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.7002 - acc: 0.5089 - rmse: 0.5007 - val_loss: 0.7470 - val_acc: 0.4762 - val_rmse: 0.5203
# Epoch 15/2000
#
# Epoch 00015: val_loss improved from 0.74698 to 0.74649, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6995 - acc: 0.5089 - rmse: 0.4984 - val_loss: 0.7465 - val_acc: 0.4762 - val_rmse: 0.5175
# Epoch 16/2000
#
# Epoch 00016: val_loss improved from 0.74649 to 0.74597, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6987 - acc: 0.5102 - rmse: 0.5013 - val_loss: 0.7460 - val_acc: 0.4762 - val_rmse: 0.5188
# Epoch 17/2000
#
# Epoch 00017: val_loss improved from 0.74597 to 0.74545, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6980 - acc: 0.5115 - rmse: 0.5007 - val_loss: 0.7454 - val_acc: 0.4762 - val_rmse: 0.5193
# Epoch 18/2000
#
# Epoch 00018: val_loss improved from 0.74545 to 0.74492, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6974 - acc: 0.5115 - rmse: 0.4977 - val_loss: 0.7449 - val_acc: 0.4821 - val_rmse: 0.5199
# Epoch 19/2000
#
# Epoch 00019: val_loss improved from 0.74492 to 0.74443, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6967 - acc: 0.5115 - rmse: 0.4987 - val_loss: 0.7444 - val_acc: 0.4821 - val_rmse: 0.5183
# Epoch 20/2000
#
# Epoch 00020: val_loss improved from 0.74443 to 0.74399, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6960 - acc: 0.5115 - rmse: 0.5001 - val_loss: 0.7440 - val_acc: 0.4821 - val_rmse: 0.5171
# Epoch 21/2000
#
# Epoch 00021: val_loss improved from 0.74399 to 0.74350, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6954 - acc: 0.5127 - rmse: 0.4991 - val_loss: 0.7435 - val_acc: 0.4821 - val_rmse: 0.5181
# Epoch 22/2000
#
# Epoch 00022: val_loss improved from 0.74350 to 0.74307, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6947 - acc: 0.5153 - rmse: 0.4995 - val_loss: 0.7431 - val_acc: 0.4821 - val_rmse: 0.5196
# Epoch 23/2000
#
# Epoch 00023: val_loss improved from 0.74307 to 0.74252, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6941 - acc: 0.5153 - rmse: 0.4968 - val_loss: 0.7425 - val_acc: 0.4821 - val_rmse: 0.5186
# Epoch 24/2000
#
# Epoch 00024: val_loss improved from 0.74252 to 0.74208, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6934 - acc: 0.5153 - rmse: 0.4991 - val_loss: 0.7421 - val_acc: 0.4821 - val_rmse: 0.5178
# Epoch 25/2000
#
# Epoch 00025: val_loss improved from 0.74208 to 0.74166, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6928 - acc: 0.5165 - rmse: 0.4964 - val_loss: 0.7417 - val_acc: 0.4821 - val_rmse: 0.5180
# Epoch 26/2000
#
# Epoch 00026: val_loss improved from 0.74166 to 0.74124, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6922 - acc: 0.5178 - rmse: 0.4971 - val_loss: 0.7412 - val_acc: 0.4821 - val_rmse: 0.5182
# Epoch 27/2000
#
# Epoch 00027: val_loss improved from 0.74124 to 0.74078, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6916 - acc: 0.5178 - rmse: 0.4960 - val_loss: 0.7408 - val_acc: 0.4762 - val_rmse: 0.5157
# Epoch 28/2000
#
# Epoch 00028: val_loss improved from 0.74078 to 0.74035, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6909 - acc: 0.5178 - rmse: 0.4965 - val_loss: 0.7404 - val_acc: 0.4821 - val_rmse: 0.5165
# Epoch 29/2000
#
# Epoch 00029: val_loss improved from 0.74035 to 0.73995, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6903 - acc: 0.5178 - rmse: 0.4963 - val_loss: 0.7400 - val_acc: 0.4821 - val_rmse: 0.5162
# Epoch 30/2000
#
# Epoch 00030: val_loss improved from 0.73995 to 0.73957, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6897 - acc: 0.5191 - rmse: 0.4955 - val_loss: 0.7396 - val_acc: 0.4821 - val_rmse: 0.5169
# Epoch 31/2000
#
# Epoch 00031: val_loss improved from 0.73957 to 0.73911, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6891 - acc: 0.5191 - rmse: 0.4952 - val_loss: 0.7391 - val_acc: 0.4821 - val_rmse: 0.5175
# Epoch 32/2000
#
# Epoch 00032: val_loss improved from 0.73911 to 0.73865, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6885 - acc: 0.5191 - rmse: 0.4961 - val_loss: 0.7387 - val_acc: 0.4821 - val_rmse: 0.5164
# Epoch 33/2000
#
# Epoch 00033: val_loss improved from 0.73865 to 0.73827, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6879 - acc: 0.5216 - rmse: 0.4965 - val_loss: 0.7383 - val_acc: 0.4821 - val_rmse: 0.5161
# Epoch 34/2000
#
# Epoch 00034: val_loss improved from 0.73827 to 0.73785, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6874 - acc: 0.5216 - rmse: 0.4961 - val_loss: 0.7378 - val_acc: 0.4821 - val_rmse: 0.5176
# Epoch 35/2000
#
# Epoch 00035: val_loss improved from 0.73785 to 0.73747, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6868 - acc: 0.5216 - rmse: 0.4965 - val_loss: 0.7375 - val_acc: 0.4821 - val_rmse: 0.5168
# Epoch 36/2000
#
# Epoch 00036: val_loss improved from 0.73747 to 0.73707, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6862 - acc: 0.5216 - rmse: 0.4953 - val_loss: 0.7371 - val_acc: 0.4821 - val_rmse: 0.5163
# Epoch 37/2000
#
# Epoch 00037: val_loss improved from 0.73707 to 0.73664, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6857 - acc: 0.5216 - rmse: 0.4948 - val_loss: 0.7366 - val_acc: 0.4821 - val_rmse: 0.5166
# Epoch 38/2000
#
# Epoch 00038: val_loss improved from 0.73664 to 0.73625, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6851 - acc: 0.5229 - rmse: 0.4950 - val_loss: 0.7362 - val_acc: 0.4821 - val_rmse: 0.5157
# Epoch 39/2000
#
# Epoch 00039: val_loss improved from 0.73625 to 0.73592, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6845 - acc: 0.5229 - rmse: 0.4935 - val_loss: 0.7359 - val_acc: 0.4821 - val_rmse: 0.5164
# Epoch 40/2000
#
# Epoch 00040: val_loss improved from 0.73592 to 0.73556, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6840 - acc: 0.5254 - rmse: 0.4936 - val_loss: 0.7356 - val_acc: 0.4881 - val_rmse: 0.5159
# Epoch 41/2000
#
# Epoch 00041: val_loss improved from 0.73556 to 0.73516, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6835 - acc: 0.5254 - rmse: 0.4938 - val_loss: 0.7352 - val_acc: 0.4881 - val_rmse: 0.5132
# Epoch 42/2000
#
# Epoch 00042: val_loss improved from 0.73516 to 0.73482, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6829 - acc: 0.5280 - rmse: 0.4949 - val_loss: 0.7348 - val_acc: 0.4881 - val_rmse: 0.5168
# Epoch 43/2000
#
# Epoch 00043: val_loss improved from 0.73482 to 0.73450, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6824 - acc: 0.5305 - rmse: 0.4929 - val_loss: 0.7345 - val_acc: 0.4881 - val_rmse: 0.5153
# Epoch 44/2000
#
# Epoch 00044: val_loss improved from 0.73450 to 0.73405, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6819 - acc: 0.5293 - rmse: 0.4922 - val_loss: 0.7341 - val_acc: 0.4821 - val_rmse: 0.5144
# Epoch 45/2000
#
# Epoch 00045: val_loss improved from 0.73405 to 0.73370, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6814 - acc: 0.5280 - rmse: 0.4925 - val_loss: 0.7337 - val_acc: 0.4821 - val_rmse: 0.5153
# Epoch 46/2000
#
# Epoch 00046: val_loss improved from 0.73370 to 0.73339, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6808 - acc: 0.5280 - rmse: 0.4931 - val_loss: 0.7334 - val_acc: 0.4821 - val_rmse: 0.5147
# Epoch 47/2000
#
# Epoch 00047: val_loss improved from 0.73339 to 0.73309, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6803 - acc: 0.5293 - rmse: 0.4919 - val_loss: 0.7331 - val_acc: 0.4821 - val_rmse: 0.5137
# Epoch 48/2000
#
# Epoch 00048: val_loss improved from 0.73309 to 0.73283, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6799 - acc: 0.5293 - rmse: 0.4937 - val_loss: 0.7328 - val_acc: 0.4821 - val_rmse: 0.5131
# Epoch 49/2000
#
# Epoch 00049: val_loss improved from 0.73283 to 0.73246, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6794 - acc: 0.5305 - rmse: 0.4919 - val_loss: 0.7325 - val_acc: 0.4821 - val_rmse: 0.5146
# Epoch 50/2000
#
# Epoch 00050: val_loss improved from 0.73246 to 0.73210, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6789 - acc: 0.5293 - rmse: 0.4928 - val_loss: 0.7321 - val_acc: 0.4881 - val_rmse: 0.5149
# Epoch 51/2000
#
# Epoch 00051: val_loss improved from 0.73210 to 0.73177, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6784 - acc: 0.5318 - rmse: 0.4918 - val_loss: 0.7318 - val_acc: 0.4881 - val_rmse: 0.5137
# Epoch 52/2000
#
# Epoch 00052: val_loss improved from 0.73177 to 0.73144, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6779 - acc: 0.5318 - rmse: 0.4918 - val_loss: 0.7314 - val_acc: 0.4881 - val_rmse: 0.5144
# Epoch 53/2000
#
# Epoch 00053: val_loss improved from 0.73144 to 0.73117, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6774 - acc: 0.5356 - rmse: 0.4938 - val_loss: 0.7312 - val_acc: 0.4881 - val_rmse: 0.5135
# Epoch 54/2000
#
# Epoch 00054: val_loss improved from 0.73117 to 0.73071, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6769 - acc: 0.5382 - rmse: 0.4923 - val_loss: 0.7307 - val_acc: 0.4881 - val_rmse: 0.5133
# Epoch 55/2000
#
# Epoch 00055: val_loss improved from 0.73071 to 0.73036, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6765 - acc: 0.5407 - rmse: 0.4913 - val_loss: 0.7304 - val_acc: 0.4881 - val_rmse: 0.5142
# Epoch 56/2000
#
# Epoch 00056: val_loss improved from 0.73036 to 0.73000, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6760 - acc: 0.5382 - rmse: 0.4910 - val_loss: 0.7300 - val_acc: 0.4881 - val_rmse: 0.5139
# Epoch 57/2000
#
# Epoch 00057: val_loss improved from 0.73000 to 0.72970, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6755 - acc: 0.5394 - rmse: 0.4899 - val_loss: 0.7297 - val_acc: 0.4881 - val_rmse: 0.5137
# Epoch 58/2000
#
# Epoch 00058: val_loss improved from 0.72970 to 0.72940, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6751 - acc: 0.5407 - rmse: 0.4896 - val_loss: 0.7294 - val_acc: 0.4881 - val_rmse: 0.5138
# Epoch 59/2000
#
# Epoch 00059: val_loss improved from 0.72940 to 0.72910, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6746 - acc: 0.5420 - rmse: 0.4908 - val_loss: 0.7291 - val_acc: 0.4881 - val_rmse: 0.5140
# Epoch 60/2000
#
# Epoch 00060: val_loss improved from 0.72910 to 0.72880, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6742 - acc: 0.5420 - rmse: 0.4911 - val_loss: 0.7288 - val_acc: 0.4881 - val_rmse: 0.5127
# Epoch 61/2000
#
# Epoch 00061: val_loss improved from 0.72880 to 0.72850, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6737 - acc: 0.5420 - rmse: 0.4885 - val_loss: 0.7285 - val_acc: 0.4881 - val_rmse: 0.5131
# Epoch 62/2000
#
# Epoch 00062: val_loss improved from 0.72850 to 0.72824, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6733 - acc: 0.5420 - rmse: 0.4897 - val_loss: 0.7282 - val_acc: 0.4881 - val_rmse: 0.5134
# Epoch 63/2000
#
# Epoch 00063: val_loss improved from 0.72824 to 0.72788, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6729 - acc: 0.5407 - rmse: 0.4900 - val_loss: 0.7279 - val_acc: 0.4881 - val_rmse: 0.5129
# Epoch 64/2000
#
# Epoch 00064: val_loss improved from 0.72788 to 0.72759, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6724 - acc: 0.5407 - rmse: 0.4888 - val_loss: 0.7276 - val_acc: 0.4881 - val_rmse: 0.5126
# Epoch 65/2000
#
# Epoch 00065: val_loss improved from 0.72759 to 0.72743, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6720 - acc: 0.5407 - rmse: 0.4895 - val_loss: 0.7274 - val_acc: 0.4881 - val_rmse: 0.5137
# Epoch 66/2000
#
# Epoch 00066: val_loss improved from 0.72743 to 0.72710, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6716 - acc: 0.5407 - rmse: 0.4881 - val_loss: 0.7271 - val_acc: 0.4881 - val_rmse: 0.5134
# Epoch 67/2000
#
# Epoch 00067: val_loss improved from 0.72710 to 0.72686, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6711 - acc: 0.5394 - rmse: 0.4886 - val_loss: 0.7269 - val_acc: 0.4881 - val_rmse: 0.5132
# Epoch 68/2000
#
# Epoch 00068: val_loss improved from 0.72686 to 0.72661, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6707 - acc: 0.5407 - rmse: 0.4893 - val_loss: 0.7266 - val_acc: 0.4881 - val_rmse: 0.5121
# Epoch 69/2000
#
# Epoch 00069: val_loss improved from 0.72661 to 0.72632, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6703 - acc: 0.5445 - rmse: 0.4878 - val_loss: 0.7263 - val_acc: 0.4881 - val_rmse: 0.5127
# Epoch 70/2000
#
# Epoch 00070: val_loss improved from 0.72632 to 0.72610, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6699 - acc: 0.5445 - rmse: 0.4884 - val_loss: 0.7261 - val_acc: 0.4881 - val_rmse: 0.5135
# Epoch 71/2000
#
# Epoch 00071: val_loss improved from 0.72610 to 0.72585, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6695 - acc: 0.5445 - rmse: 0.4873 - val_loss: 0.7259 - val_acc: 0.4881 - val_rmse: 0.5123
# Epoch 72/2000
#
# Epoch 00072: val_loss improved from 0.72585 to 0.72563, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6691 - acc: 0.5445 - rmse: 0.4877 - val_loss: 0.7256 - val_acc: 0.4881 - val_rmse: 0.5116
# Epoch 73/2000
#
# Epoch 00073: val_loss improved from 0.72563 to 0.72530, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6687 - acc: 0.5445 - rmse: 0.4889 - val_loss: 0.7253 - val_acc: 0.4881 - val_rmse: 0.5121
# Epoch 74/2000
#
# Epoch 00074: val_loss improved from 0.72530 to 0.72506, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6683 - acc: 0.5445 - rmse: 0.4877 - val_loss: 0.7251 - val_acc: 0.4881 - val_rmse: 0.5121
# Epoch 75/2000
#
# Epoch 00075: val_loss improved from 0.72506 to 0.72485, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6679 - acc: 0.5445 - rmse: 0.4869 - val_loss: 0.7249 - val_acc: 0.4881 - val_rmse: 0.5116
# Epoch 76/2000
#
# Epoch 00076: val_loss improved from 0.72485 to 0.72457, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6675 - acc: 0.5445 - rmse: 0.4868 - val_loss: 0.7246 - val_acc: 0.4881 - val_rmse: 0.5127
# Epoch 77/2000
#
# Epoch 00077: val_loss improved from 0.72457 to 0.72433, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6671 - acc: 0.5445 - rmse: 0.4864 - val_loss: 0.7243 - val_acc: 0.4881 - val_rmse: 0.5120
# Epoch 78/2000
#
# Epoch 00078: val_loss improved from 0.72433 to 0.72408, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6667 - acc: 0.5445 - rmse: 0.4873 - val_loss: 0.7241 - val_acc: 0.4881 - val_rmse: 0.5122
# Epoch 79/2000
#
# Epoch 00079: val_loss improved from 0.72408 to 0.72392, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6663 - acc: 0.5445 - rmse: 0.4871 - val_loss: 0.7239 - val_acc: 0.4762 - val_rmse: 0.5114
# Epoch 80/2000
#
# Epoch 00080: val_loss improved from 0.72392 to 0.72368, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6659 - acc: 0.5496 - rmse: 0.4858 - val_loss: 0.7237 - val_acc: 0.4762 - val_rmse: 0.5123
# Epoch 81/2000
#
# Epoch 00081: val_loss improved from 0.72368 to 0.72337, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6656 - acc: 0.5547 - rmse: 0.4869 - val_loss: 0.7234 - val_acc: 0.4762 - val_rmse: 0.5110
# Epoch 82/2000
#
# Epoch 00082: val_loss improved from 0.72337 to 0.72313, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6652 - acc: 0.5547 - rmse: 0.4871 - val_loss: 0.7231 - val_acc: 0.4762 - val_rmse: 0.5114
# Epoch 83/2000
#
# Epoch 00083: val_loss improved from 0.72313 to 0.72292, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6648 - acc: 0.5547 - rmse: 0.4862 - val_loss: 0.7229 - val_acc: 0.4762 - val_rmse: 0.5116
# Epoch 84/2000
#
# Epoch 00084: val_loss improved from 0.72292 to 0.72273, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6645 - acc: 0.5547 - rmse: 0.4864 - val_loss: 0.7227 - val_acc: 0.4762 - val_rmse: 0.5118
# Epoch 85/2000
#
# Epoch 00085: val_loss improved from 0.72273 to 0.72248, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6641 - acc: 0.5547 - rmse: 0.4860 - val_loss: 0.7225 - val_acc: 0.4762 - val_rmse: 0.5120
# Epoch 86/2000
#
# Epoch 00086: val_loss improved from 0.72248 to 0.72224, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6637 - acc: 0.5560 - rmse: 0.4841 - val_loss: 0.7222 - val_acc: 0.4762 - val_rmse: 0.5102
# Epoch 87/2000
#
# Epoch 00087: val_loss improved from 0.72224 to 0.72197, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6634 - acc: 0.5560 - rmse: 0.4860 - val_loss: 0.7220 - val_acc: 0.4762 - val_rmse: 0.5105
# Epoch 88/2000
#
# Epoch 00088: val_loss improved from 0.72197 to 0.72182, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6630 - acc: 0.5560 - rmse: 0.4836 - val_loss: 0.7218 - val_acc: 0.4762 - val_rmse: 0.5109
# Epoch 89/2000
#
# Epoch 00089: val_loss improved from 0.72182 to 0.72160, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6627 - acc: 0.5573 - rmse: 0.4853 - val_loss: 0.7216 - val_acc: 0.4762 - val_rmse: 0.5116
# Epoch 90/2000
#
# Epoch 00090: val_loss improved from 0.72160 to 0.72137, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6623 - acc: 0.5547 - rmse: 0.4850 - val_loss: 0.7214 - val_acc: 0.4762 - val_rmse: 0.5102
# Epoch 91/2000
#
# Epoch 00091: val_loss improved from 0.72137 to 0.72110, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6620 - acc: 0.5534 - rmse: 0.4838 - val_loss: 0.7211 - val_acc: 0.4762 - val_rmse: 0.5104
# Epoch 92/2000
#
# Epoch 00092: val_loss improved from 0.72110 to 0.72090, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6616 - acc: 0.5534 - rmse: 0.4833 - val_loss: 0.7209 - val_acc: 0.4762 - val_rmse: 0.5099
# Epoch 93/2000
#
# Epoch 00093: val_loss improved from 0.72090 to 0.72075, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6613 - acc: 0.5547 - rmse: 0.4845 - val_loss: 0.7208 - val_acc: 0.4762 - val_rmse: 0.5113
# Epoch 94/2000
#
# Epoch 00094: val_loss improved from 0.72075 to 0.72054, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6609 - acc: 0.5598 - rmse: 0.4848 - val_loss: 0.7205 - val_acc: 0.4762 - val_rmse: 0.5106
# Epoch 95/2000
#
# Epoch 00095: val_loss improved from 0.72054 to 0.72040, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6606 - acc: 0.5611 - rmse: 0.4837 - val_loss: 0.7204 - val_acc: 0.4762 - val_rmse: 0.5112
# Epoch 96/2000
#
# Epoch 00096: val_loss improved from 0.72040 to 0.72017, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6603 - acc: 0.5560 - rmse: 0.4838 - val_loss: 0.7202 - val_acc: 0.4762 - val_rmse: 0.5100
# Epoch 97/2000
#
# Epoch 00097: val_loss improved from 0.72017 to 0.72001, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6600 - acc: 0.5573 - rmse: 0.4847 - val_loss: 0.7200 - val_acc: 0.4762 - val_rmse: 0.5102
# Epoch 98/2000
#
# Epoch 00098: val_loss improved from 0.72001 to 0.71980, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6596 - acc: 0.5598 - rmse: 0.4833 - val_loss: 0.7198 - val_acc: 0.4762 - val_rmse: 0.5096
# Epoch 99/2000
#
# Epoch 00099: val_loss improved from 0.71980 to 0.71959, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6593 - acc: 0.5636 - rmse: 0.4838 - val_loss: 0.7196 - val_acc: 0.4821 - val_rmse: 0.5105
# Epoch 100/2000
#
# Epoch 00100: val_loss improved from 0.71959 to 0.71945, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6590 - acc: 0.5623 - rmse: 0.4821 - val_loss: 0.7194 - val_acc: 0.4940 - val_rmse: 0.5103
# Epoch 101/2000
#
# Epoch 00101: val_loss improved from 0.71945 to 0.71925, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6587 - acc: 0.5636 - rmse: 0.4833 - val_loss: 0.7193 - val_acc: 0.4940 - val_rmse: 0.5090
# Epoch 102/2000
#
# Epoch 00102: val_loss improved from 0.71925 to 0.71904, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6584 - acc: 0.5649 - rmse: 0.4824 - val_loss: 0.7190 - val_acc: 0.4940 - val_rmse: 0.5103
# Epoch 103/2000
#
# Epoch 00103: val_loss improved from 0.71904 to 0.71889, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6581 - acc: 0.5649 - rmse: 0.4832 - val_loss: 0.7189 - val_acc: 0.4940 - val_rmse: 0.5098
# Epoch 104/2000
#
# Epoch 00104: val_loss improved from 0.71889 to 0.71871, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6577 - acc: 0.5649 - rmse: 0.4817 - val_loss: 0.7187 - val_acc: 0.4940 - val_rmse: 0.5099
# Epoch 105/2000
#
# Epoch 00105: val_loss improved from 0.71871 to 0.71858, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6574 - acc: 0.5662 - rmse: 0.4812 - val_loss: 0.7186 - val_acc: 0.4940 - val_rmse: 0.5099
# Epoch 106/2000
#
# Epoch 00106: val_loss improved from 0.71858 to 0.71842, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6571 - acc: 0.5649 - rmse: 0.4827 - val_loss: 0.7184 - val_acc: 0.4940 - val_rmse: 0.5097
# Epoch 107/2000
#
# Epoch 00107: val_loss improved from 0.71842 to 0.71827, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6568 - acc: 0.5662 - rmse: 0.4817 - val_loss: 0.7183 - val_acc: 0.4940 - val_rmse: 0.5098
# Epoch 108/2000
#
# Epoch 00108: val_loss improved from 0.71827 to 0.71810, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6565 - acc: 0.5700 - rmse: 0.4836 - val_loss: 0.7181 - val_acc: 0.4940 - val_rmse: 0.5090
# Epoch 109/2000
#
# Epoch 00109: val_loss improved from 0.71810 to 0.71791, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6562 - acc: 0.5700 - rmse: 0.4825 - val_loss: 0.7179 - val_acc: 0.4940 - val_rmse: 0.5099
# Epoch 110/2000
#
# Epoch 00110: val_loss improved from 0.71791 to 0.71772, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6559 - acc: 0.5725 - rmse: 0.4825 - val_loss: 0.7177 - val_acc: 0.4940 - val_rmse: 0.5086
# Epoch 111/2000
#
# Epoch 00111: val_loss improved from 0.71772 to 0.71754, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6556 - acc: 0.5725 - rmse: 0.4799 - val_loss: 0.7175 - val_acc: 0.5000 - val_rmse: 0.5097
# Epoch 112/2000
#
# Epoch 00112: val_loss improved from 0.71754 to 0.71733, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6553 - acc: 0.5725 - rmse: 0.4813 - val_loss: 0.7173 - val_acc: 0.5000 - val_rmse: 0.5093
# Epoch 113/2000
#
# Epoch 00113: val_loss improved from 0.71733 to 0.71716, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6550 - acc: 0.5751 - rmse: 0.4811 - val_loss: 0.7172 - val_acc: 0.5000 - val_rmse: 0.5094
# Epoch 114/2000
#
# Epoch 00114: val_loss improved from 0.71716 to 0.71704, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6547 - acc: 0.5725 - rmse: 0.4807 - val_loss: 0.7170 - val_acc: 0.5000 - val_rmse: 0.5092
# Epoch 115/2000
#
# Epoch 00115: val_loss improved from 0.71704 to 0.71695, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6544 - acc: 0.5700 - rmse: 0.4814 - val_loss: 0.7169 - val_acc: 0.5000 - val_rmse: 0.5089
# Epoch 116/2000
#
# Epoch 00116: val_loss improved from 0.71695 to 0.71678, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6541 - acc: 0.5738 - rmse: 0.4817 - val_loss: 0.7168 - val_acc: 0.5000 - val_rmse: 0.5085
# Epoch 117/2000
#
# Epoch 00117: val_loss improved from 0.71678 to 0.71661, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6538 - acc: 0.5738 - rmse: 0.4805 - val_loss: 0.7166 - val_acc: 0.5000 - val_rmse: 0.5097
# Epoch 118/2000
#
# Epoch 00118: val_loss improved from 0.71661 to 0.71644, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6535 - acc: 0.5738 - rmse: 0.4799 - val_loss: 0.7164 - val_acc: 0.5000 - val_rmse: 0.5091
# Epoch 119/2000
#
# Epoch 00119: val_loss improved from 0.71644 to 0.71628, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6532 - acc: 0.5751 - rmse: 0.4806 - val_loss: 0.7163 - val_acc: 0.5000 - val_rmse: 0.5092
# Epoch 120/2000
#
# Epoch 00120: val_loss improved from 0.71628 to 0.71612, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6530 - acc: 0.5751 - rmse: 0.4812 - val_loss: 0.7161 - val_acc: 0.5000 - val_rmse: 0.5089
# Epoch 121/2000
#
# Epoch 00121: val_loss improved from 0.71612 to 0.71599, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6527 - acc: 0.5763 - rmse: 0.4800 - val_loss: 0.7160 - val_acc: 0.5000 - val_rmse: 0.5094
# Epoch 122/2000
#
# Epoch 00122: val_loss improved from 0.71599 to 0.71590, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6524 - acc: 0.5763 - rmse: 0.4801 - val_loss: 0.7159 - val_acc: 0.5060 - val_rmse: 0.5083
# Epoch 123/2000
#
# Epoch 00123: val_loss improved from 0.71590 to 0.71576, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6521 - acc: 0.5763 - rmse: 0.4810 - val_loss: 0.7158 - val_acc: 0.5060 - val_rmse: 0.5091
# Epoch 124/2000
#
# Epoch 00124: val_loss improved from 0.71576 to 0.71563, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6518 - acc: 0.5763 - rmse: 0.4807 - val_loss: 0.7156 - val_acc: 0.5060 - val_rmse: 0.5079
# Epoch 125/2000
#
# Epoch 00125: val_loss improved from 0.71563 to 0.71553, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6515 - acc: 0.5776 - rmse: 0.4796 - val_loss: 0.7155 - val_acc: 0.5060 - val_rmse: 0.5081
# Epoch 126/2000
#
# Epoch 00126: val_loss improved from 0.71553 to 0.71539, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6513 - acc: 0.5776 - rmse: 0.4801 - val_loss: 0.7154 - val_acc: 0.5060 - val_rmse: 0.5088
# Epoch 127/2000
#
# Epoch 00127: val_loss improved from 0.71539 to 0.71521, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6510 - acc: 0.5776 - rmse: 0.4791 - val_loss: 0.7152 - val_acc: 0.5060 - val_rmse: 0.5090
# Epoch 128/2000
#
# Epoch 00128: val_loss improved from 0.71521 to 0.71510, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6507 - acc: 0.5776 - rmse: 0.4799 - val_loss: 0.7151 - val_acc: 0.5060 - val_rmse: 0.5086
# Epoch 129/2000
#
# Epoch 00129: val_loss improved from 0.71510 to 0.71493, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6505 - acc: 0.5776 - rmse: 0.4797 - val_loss: 0.7149 - val_acc: 0.5060 - val_rmse: 0.5082
# Epoch 130/2000
#
# Epoch 00130: val_loss improved from 0.71493 to 0.71481, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6502 - acc: 0.5776 - rmse: 0.4799 - val_loss: 0.7148 - val_acc: 0.5060 - val_rmse: 0.5084
# Epoch 131/2000
#
# Epoch 00131: val_loss improved from 0.71481 to 0.71471, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6499 - acc: 0.5789 - rmse: 0.4783 - val_loss: 0.7147 - val_acc: 0.5060 - val_rmse: 0.5084
# Epoch 132/2000
#
# Epoch 00132: val_loss improved from 0.71471 to 0.71452, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6496 - acc: 0.5789 - rmse: 0.4798 - val_loss: 0.7145 - val_acc: 0.4940 - val_rmse: 0.5086
# Epoch 133/2000
#
# Epoch 00133: val_loss improved from 0.71452 to 0.71437, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6494 - acc: 0.5789 - rmse: 0.4786 - val_loss: 0.7144 - val_acc: 0.5000 - val_rmse: 0.5080
# Epoch 134/2000
#
# Epoch 00134: val_loss improved from 0.71437 to 0.71432, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6491 - acc: 0.5802 - rmse: 0.4781 - val_loss: 0.7143 - val_acc: 0.5000 - val_rmse: 0.5080
# Epoch 135/2000
#
# Epoch 00135: val_loss improved from 0.71432 to 0.71413, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6489 - acc: 0.5814 - rmse: 0.4781 - val_loss: 0.7141 - val_acc: 0.5000 - val_rmse: 0.5074
# Epoch 136/2000
#
# Epoch 00136: val_loss improved from 0.71413 to 0.71402, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6486 - acc: 0.5827 - rmse: 0.4775 - val_loss: 0.7140 - val_acc: 0.5000 - val_rmse: 0.5078
# Epoch 137/2000
#
# Epoch 00137: val_loss improved from 0.71402 to 0.71391, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6483 - acc: 0.5827 - rmse: 0.4789 - val_loss: 0.7139 - val_acc: 0.5000 - val_rmse: 0.5072
# Epoch 138/2000
#
# Epoch 00138: val_loss improved from 0.71391 to 0.71380, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6481 - acc: 0.5840 - rmse: 0.4773 - val_loss: 0.7138 - val_acc: 0.5060 - val_rmse: 0.5083
# Epoch 139/2000
#
# Epoch 00139: val_loss improved from 0.71380 to 0.71369, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6478 - acc: 0.5865 - rmse: 0.4775 - val_loss: 0.7137 - val_acc: 0.5060 - val_rmse: 0.5082
# Epoch 140/2000
#
# Epoch 00140: val_loss improved from 0.71369 to 0.71359, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6475 - acc: 0.5865 - rmse: 0.4777 - val_loss: 0.7136 - val_acc: 0.5060 - val_rmse: 0.5067
# Epoch 141/2000
#
# Epoch 00141: val_loss improved from 0.71359 to 0.71345, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6473 - acc: 0.5852 - rmse: 0.4773 - val_loss: 0.7135 - val_acc: 0.5119 - val_rmse: 0.5076
# Epoch 142/2000
#
# Epoch 00142: val_loss improved from 0.71345 to 0.71340, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6470 - acc: 0.5865 - rmse: 0.4770 - val_loss: 0.7134 - val_acc: 0.5119 - val_rmse: 0.5081
# Epoch 143/2000
#
# Epoch 00143: val_loss improved from 0.71340 to 0.71328, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6468 - acc: 0.5865 - rmse: 0.4779 - val_loss: 0.7133 - val_acc: 0.5119 - val_rmse: 0.5076
# Epoch 144/2000
#
# Epoch 00144: val_loss improved from 0.71328 to 0.71317, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6465 - acc: 0.5865 - rmse: 0.4773 - val_loss: 0.7132 - val_acc: 0.5119 - val_rmse: 0.5079
# Epoch 145/2000
#
# Epoch 00145: val_loss improved from 0.71317 to 0.71306, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6463 - acc: 0.5865 - rmse: 0.4780 - val_loss: 0.7131 - val_acc: 0.5119 - val_rmse: 0.5078
# Epoch 146/2000
#
# Epoch 00146: val_loss improved from 0.71306 to 0.71291, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6460 - acc: 0.5865 - rmse: 0.4772 - val_loss: 0.7129 - val_acc: 0.5060 - val_rmse: 0.5077
# Epoch 147/2000
#
# Epoch 00147: val_loss improved from 0.71291 to 0.71277, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6458 - acc: 0.5878 - rmse: 0.4768 - val_loss: 0.7128 - val_acc: 0.5000 - val_rmse: 0.5073
# Epoch 148/2000
#
# Epoch 00148: val_loss improved from 0.71277 to 0.71266, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6455 - acc: 0.5878 - rmse: 0.4766 - val_loss: 0.7127 - val_acc: 0.5000 - val_rmse: 0.5069
# Epoch 149/2000
#
# Epoch 00149: val_loss improved from 0.71266 to 0.71260, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6453 - acc: 0.5852 - rmse: 0.4769 - val_loss: 0.7126 - val_acc: 0.5000 - val_rmse: 0.5076
# Epoch 150/2000
#
# Epoch 00150: val_loss improved from 0.71260 to 0.71249, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6450 - acc: 0.5852 - rmse: 0.4768 - val_loss: 0.7125 - val_acc: 0.5000 - val_rmse: 0.5075
# Epoch 151/2000
#
# Epoch 00151: val_loss improved from 0.71249 to 0.71241, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6448 - acc: 0.5852 - rmse: 0.4768 - val_loss: 0.7124 - val_acc: 0.5060 - val_rmse: 0.5068
# Epoch 152/2000
#
# Epoch 00152: val_loss improved from 0.71241 to 0.71229, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6445 - acc: 0.5865 - rmse: 0.4775 - val_loss: 0.7123 - val_acc: 0.5060 - val_rmse: 0.5073
# Epoch 153/2000
#
# Epoch 00153: val_loss improved from 0.71229 to 0.71219, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6443 - acc: 0.5865 - rmse: 0.4758 - val_loss: 0.7122 - val_acc: 0.5060 - val_rmse: 0.5073
# Epoch 154/2000
#
# Epoch 00154: val_loss improved from 0.71219 to 0.71211, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6441 - acc: 0.5865 - rmse: 0.4778 - val_loss: 0.7121 - val_acc: 0.5000 - val_rmse: 0.5072
# Epoch 155/2000
#
# Epoch 00155: val_loss improved from 0.71211 to 0.71194, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6438 - acc: 0.5865 - rmse: 0.4764 - val_loss: 0.7119 - val_acc: 0.5000 - val_rmse: 0.5078
# Epoch 156/2000
#
# Epoch 00156: val_loss improved from 0.71194 to 0.71186, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6436 - acc: 0.5878 - rmse: 0.4761 - val_loss: 0.7119 - val_acc: 0.5000 - val_rmse: 0.5075
# Epoch 157/2000
#
# Epoch 00157: val_loss improved from 0.71186 to 0.71175, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6433 - acc: 0.5878 - rmse: 0.4752 - val_loss: 0.7117 - val_acc: 0.5000 - val_rmse: 0.5065
# Epoch 158/2000
#
# Epoch 00158: val_loss improved from 0.71175 to 0.71165, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6431 - acc: 0.5878 - rmse: 0.4761 - val_loss: 0.7116 - val_acc: 0.4940 - val_rmse: 0.5071
# Epoch 159/2000
#
# Epoch 00159: val_loss improved from 0.71165 to 0.71148, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6429 - acc: 0.5891 - rmse: 0.4752 - val_loss: 0.7115 - val_acc: 0.4940 - val_rmse: 0.5066
# Epoch 160/2000
#
# Epoch 00160: val_loss improved from 0.71148 to 0.71142, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6426 - acc: 0.5903 - rmse: 0.4762 - val_loss: 0.7114 - val_acc: 0.4940 - val_rmse: 0.5064
# Epoch 161/2000
#
# Epoch 00161: val_loss improved from 0.71142 to 0.71135, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6424 - acc: 0.5903 - rmse: 0.4753 - val_loss: 0.7114 - val_acc: 0.4940 - val_rmse: 0.5072
# Epoch 162/2000
#
# Epoch 00162: val_loss improved from 0.71135 to 0.71126, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6421 - acc: 0.5916 - rmse: 0.4754 - val_loss: 0.7113 - val_acc: 0.4940 - val_rmse: 0.5071
# Epoch 163/2000
#
# Epoch 00163: val_loss improved from 0.71126 to 0.71113, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6419 - acc: 0.5929 - rmse: 0.4748 - val_loss: 0.7111 - val_acc: 0.4940 - val_rmse: 0.5076
# Epoch 164/2000
#
# Epoch 00164: val_loss improved from 0.71113 to 0.71096, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6417 - acc: 0.5954 - rmse: 0.4749 - val_loss: 0.7110 - val_acc: 0.4940 - val_rmse: 0.5073
# Epoch 165/2000
#
# Epoch 00165: val_loss improved from 0.71096 to 0.71092, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6414 - acc: 0.5941 - rmse: 0.4747 - val_loss: 0.7109 - val_acc: 0.5000 - val_rmse: 0.5066
# Epoch 166/2000
#
# Epoch 00166: val_loss improved from 0.71092 to 0.71080, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6412 - acc: 0.5941 - rmse: 0.4746 - val_loss: 0.7108 - val_acc: 0.5000 - val_rmse: 0.5070
# Epoch 167/2000
#
# Epoch 00167: val_loss improved from 0.71080 to 0.71067, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6410 - acc: 0.5916 - rmse: 0.4735 - val_loss: 0.7107 - val_acc: 0.5000 - val_rmse: 0.5066
# Epoch 168/2000
#
# Epoch 00168: val_loss improved from 0.71067 to 0.71055, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6407 - acc: 0.5916 - rmse: 0.4751 - val_loss: 0.7106 - val_acc: 0.5000 - val_rmse: 0.5054
# Epoch 169/2000
#
# Epoch 00169: val_loss improved from 0.71055 to 0.71050, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6405 - acc: 0.5916 - rmse: 0.4743 - val_loss: 0.7105 - val_acc: 0.5000 - val_rmse: 0.5068
# Epoch 170/2000
#
# Epoch 00170: val_loss improved from 0.71050 to 0.71041, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6403 - acc: 0.5916 - rmse: 0.4736 - val_loss: 0.7104 - val_acc: 0.5000 - val_rmse: 0.5065
# Epoch 171/2000
#
# Epoch 00171: val_loss improved from 0.71041 to 0.71033, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6401 - acc: 0.5916 - rmse: 0.4749 - val_loss: 0.7103 - val_acc: 0.5000 - val_rmse: 0.5066
# Epoch 172/2000
#
# Epoch 00172: val_loss improved from 0.71033 to 0.71024, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6398 - acc: 0.5916 - rmse: 0.4742 - val_loss: 0.7102 - val_acc: 0.5000 - val_rmse: 0.5068
# Epoch 173/2000
#
# Epoch 00173: val_loss improved from 0.71024 to 0.71013, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6396 - acc: 0.5916 - rmse: 0.4741 - val_loss: 0.7101 - val_acc: 0.5000 - val_rmse: 0.5060
# Epoch 174/2000
#
# Epoch 00174: val_loss improved from 0.71013 to 0.71009, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6394 - acc: 0.5916 - rmse: 0.4735 - val_loss: 0.7101 - val_acc: 0.5000 - val_rmse: 0.5067
# Epoch 175/2000
#
# Epoch 00175: val_loss improved from 0.71009 to 0.71001, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6392 - acc: 0.5916 - rmse: 0.4739 - val_loss: 0.7100 - val_acc: 0.5000 - val_rmse: 0.5068
# Epoch 176/2000
#
# Epoch 00176: val_loss improved from 0.71001 to 0.70993, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6390 - acc: 0.5916 - rmse: 0.4742 - val_loss: 0.7099 - val_acc: 0.5000 - val_rmse: 0.5067
# Epoch 177/2000
#
# Epoch 00177: val_loss improved from 0.70993 to 0.70985, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6387 - acc: 0.5916 - rmse: 0.4743 - val_loss: 0.7098 - val_acc: 0.5000 - val_rmse: 0.5064
# Epoch 178/2000
#
# Epoch 00178: val_loss improved from 0.70985 to 0.70979, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6385 - acc: 0.5916 - rmse: 0.4735 - val_loss: 0.7098 - val_acc: 0.5000 - val_rmse: 0.5055
# Epoch 179/2000
#
# Epoch 00179: val_loss improved from 0.70979 to 0.70969, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6383 - acc: 0.5941 - rmse: 0.4732 - val_loss: 0.7097 - val_acc: 0.5000 - val_rmse: 0.5066
# Epoch 180/2000
#
# Epoch 00180: val_loss improved from 0.70969 to 0.70960, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6381 - acc: 0.5941 - rmse: 0.4723 - val_loss: 0.7096 - val_acc: 0.5000 - val_rmse: 0.5058
# Epoch 181/2000
#
# Epoch 00181: val_loss improved from 0.70960 to 0.70954, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6378 - acc: 0.5941 - rmse: 0.4734 - val_loss: 0.7095 - val_acc: 0.5000 - val_rmse: 0.5063
# Epoch 182/2000
#
# Epoch 00182: val_loss improved from 0.70954 to 0.70948, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6376 - acc: 0.5941 - rmse: 0.4729 - val_loss: 0.7095 - val_acc: 0.5000 - val_rmse: 0.5057
# Epoch 183/2000
#
# Epoch 00183: val_loss improved from 0.70948 to 0.70940, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6374 - acc: 0.6005 - rmse: 0.4720 - val_loss: 0.7094 - val_acc: 0.5000 - val_rmse: 0.5061
# Epoch 184/2000
#
# Epoch 00184: val_loss improved from 0.70940 to 0.70937, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6372 - acc: 0.6005 - rmse: 0.4728 - val_loss: 0.7094 - val_acc: 0.5060 - val_rmse: 0.5065
# Epoch 185/2000
#
# Epoch 00185: val_loss improved from 0.70937 to 0.70928, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6370 - acc: 0.6005 - rmse: 0.4729 - val_loss: 0.7093 - val_acc: 0.5060 - val_rmse: 0.5058
# Epoch 186/2000
#
# Epoch 00186: val_loss improved from 0.70928 to 0.70923, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6368 - acc: 0.6031 - rmse: 0.4732 - val_loss: 0.7092 - val_acc: 0.5060 - val_rmse: 0.5059
# Epoch 187/2000
#
# Epoch 00187: val_loss improved from 0.70923 to 0.70920, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6366 - acc: 0.6043 - rmse: 0.4719 - val_loss: 0.7092 - val_acc: 0.5060 - val_rmse: 0.5065
# Epoch 188/2000
#
# Epoch 00188: val_loss improved from 0.70920 to 0.70910, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6363 - acc: 0.6043 - rmse: 0.4723 - val_loss: 0.7091 - val_acc: 0.5060 - val_rmse: 0.5059
# Epoch 189/2000
#
# Epoch 00189: val_loss improved from 0.70910 to 0.70901, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6361 - acc: 0.6043 - rmse: 0.4727 - val_loss: 0.7090 - val_acc: 0.5119 - val_rmse: 0.5059
# Epoch 190/2000
#
# Epoch 00190: val_loss improved from 0.70901 to 0.70900, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6359 - acc: 0.6043 - rmse: 0.4722 - val_loss: 0.7090 - val_acc: 0.5119 - val_rmse: 0.5061
# Epoch 191/2000
#
# Epoch 00191: val_loss improved from 0.70900 to 0.70895, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6357 - acc: 0.6056 - rmse: 0.4734 - val_loss: 0.7089 - val_acc: 0.5119 - val_rmse: 0.5065
# Epoch 192/2000
#
# Epoch 00192: val_loss improved from 0.70895 to 0.70887, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6355 - acc: 0.6043 - rmse: 0.4726 - val_loss: 0.7089 - val_acc: 0.5060 - val_rmse: 0.5056
# Epoch 193/2000
#
# Epoch 00193: val_loss improved from 0.70887 to 0.70876, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6352 - acc: 0.6056 - rmse: 0.4712 - val_loss: 0.7088 - val_acc: 0.5060 - val_rmse: 0.5057
# Epoch 194/2000
#
# Epoch 00194: val_loss improved from 0.70876 to 0.70865, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6350 - acc: 0.6018 - rmse: 0.4722 - val_loss: 0.7086 - val_acc: 0.5060 - val_rmse: 0.5060
# Epoch 195/2000
#
# Epoch 00195: val_loss improved from 0.70865 to 0.70856, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6348 - acc: 0.6005 - rmse: 0.4713 - val_loss: 0.7086 - val_acc: 0.5060 - val_rmse: 0.5062
# Epoch 196/2000
#
# Epoch 00196: val_loss improved from 0.70856 to 0.70848, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6346 - acc: 0.6043 - rmse: 0.4695 - val_loss: 0.7085 - val_acc: 0.5060 - val_rmse: 0.5056
# Epoch 197/2000
#
# Epoch 00197: val_loss improved from 0.70848 to 0.70842, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6344 - acc: 0.6043 - rmse: 0.4723 - val_loss: 0.7084 - val_acc: 0.5060 - val_rmse: 0.5059
# Epoch 198/2000
#
# Epoch 00198: val_loss improved from 0.70842 to 0.70833, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6342 - acc: 0.6043 - rmse: 0.4716 - val_loss: 0.7083 - val_acc: 0.5060 - val_rmse: 0.5058
# Epoch 199/2000
#
# Epoch 00199: val_loss improved from 0.70833 to 0.70825, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6340 - acc: 0.6043 - rmse: 0.4710 - val_loss: 0.7083 - val_acc: 0.5060 - val_rmse: 0.5045
# Epoch 200/2000
#
# Epoch 00200: val_loss improved from 0.70825 to 0.70816, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6338 - acc: 0.6043 - rmse: 0.4698 - val_loss: 0.7082 - val_acc: 0.5060 - val_rmse: 0.5054
# Epoch 201/2000
#
# Epoch 00201: val_loss improved from 0.70816 to 0.70805, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6336 - acc: 0.6043 - rmse: 0.4708 - val_loss: 0.7081 - val_acc: 0.5060 - val_rmse: 0.5055
# Epoch 202/2000
#
# Epoch 00202: val_loss improved from 0.70805 to 0.70805, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6334 - acc: 0.6043 - rmse: 0.4707 - val_loss: 0.7080 - val_acc: 0.5000 - val_rmse: 0.5061
# Epoch 203/2000
#
# Epoch 00203: val_loss improved from 0.70805 to 0.70796, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6331 - acc: 0.6056 - rmse: 0.4706 - val_loss: 0.7080 - val_acc: 0.4940 - val_rmse: 0.5056
# Epoch 204/2000
#
# Epoch 00204: val_loss improved from 0.70796 to 0.70787, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6329 - acc: 0.6056 - rmse: 0.4698 - val_loss: 0.7079 - val_acc: 0.5000 - val_rmse: 0.5063
# Epoch 205/2000
#
# Epoch 00205: val_loss improved from 0.70787 to 0.70781, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6327 - acc: 0.6056 - rmse: 0.4702 - val_loss: 0.7078 - val_acc: 0.5000 - val_rmse: 0.5061
# Epoch 206/2000
#
# Epoch 00206: val_loss improved from 0.70781 to 0.70777, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6325 - acc: 0.6056 - rmse: 0.4709 - val_loss: 0.7078 - val_acc: 0.4940 - val_rmse: 0.5051
# Epoch 207/2000
#
# Epoch 00207: val_loss improved from 0.70777 to 0.70769, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6323 - acc: 0.6056 - rmse: 0.4697 - val_loss: 0.7077 - val_acc: 0.4940 - val_rmse: 0.5055
# Epoch 208/2000
#
# Epoch 00208: val_loss improved from 0.70769 to 0.70764, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6321 - acc: 0.6056 - rmse: 0.4707 - val_loss: 0.7076 - val_acc: 0.4940 - val_rmse: 0.5053
# Epoch 209/2000
#
# Epoch 00209: val_loss improved from 0.70764 to 0.70760, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6319 - acc: 0.6069 - rmse: 0.4702 - val_loss: 0.7076 - val_acc: 0.5000 - val_rmse: 0.5058
# Epoch 210/2000
#
# Epoch 00210: val_loss improved from 0.70760 to 0.70750, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6317 - acc: 0.6069 - rmse: 0.4700 - val_loss: 0.7075 - val_acc: 0.5000 - val_rmse: 0.5053
# Epoch 211/2000
#
# Epoch 00211: val_loss improved from 0.70750 to 0.70742, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6315 - acc: 0.6069 - rmse: 0.4699 - val_loss: 0.7074 - val_acc: 0.5000 - val_rmse: 0.5054
# Epoch 212/2000
#
# Epoch 00212: val_loss did not improve from 0.70742
# 786/786 - 0s - loss: 0.6313 - acc: 0.6094 - rmse: 0.4693 - val_loss: 0.7074 - val_acc: 0.5000 - val_rmse: 0.5052
# Epoch 213/2000
#
# Epoch 00213: val_loss improved from 0.70742 to 0.70733, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 0s - loss: 0.6311 - acc: 0.6107 - rmse: 0.4701 - val_loss: 0.7073 - val_acc: 0.5000 - val_rmse: 0.5050
# Epoch 214/2000
#
# Epoch 00214: val_loss improved from 0.70733 to 0.70727, saving model to /tmp/LSTM_checkpoint.h5
# ...
# Epoch 1913/2000
#
# Epoch 01913: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4289 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4999
# Epoch 1914/2000
#
# Epoch 01914: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4263 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4987
# Epoch 1915/2000
#
# Epoch 01915: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4290 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5002
# Epoch 1916/2000
#
# Epoch 01916: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4287 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5002
# Epoch 1917/2000
#
# Epoch 01917: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4293 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4977
# Epoch 1918/2000
#
# Epoch 01918: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4301 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4987
# Epoch 1919/2000
#
# Epoch 01919: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4300 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4986
# Epoch 1920/2000
#
# Epoch 01920: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4294 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5009
# Epoch 1921/2000
#
# Epoch 01921: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4299 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4993
# Epoch 1922/2000
#
# Epoch 01922: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4297 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4995
# Epoch 1923/2000
#
# Epoch 01923: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4304 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4996
# Epoch 1924/2000
#
# Epoch 01924: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4277 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4988
# Epoch 1925/2000
#
# Epoch 01925: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4282 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5002
# Epoch 1926/2000
#
# Epoch 01926: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4295 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5001
# Epoch 1927/2000
#
# Epoch 01927: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4290 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4997
# Epoch 1928/2000
#
# Epoch 01928: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4291 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5010
# Epoch 1929/2000
#
# Epoch 01929: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4286 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5007
# Epoch 1930/2000
#
# Epoch 01930: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4306 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5014
# Epoch 1931/2000
#
# Epoch 01931: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4298 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5001
# Epoch 1932/2000
#
# Epoch 01932: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4290 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4995
# Epoch 1933/2000
#
# Epoch 01933: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4292 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5002
# Epoch 1934/2000
#
# Epoch 01934: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4294 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4990
# Epoch 1935/2000
#
# Epoch 01935: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4284 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5004
# Epoch 1936/2000
#
# Epoch 01936: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4296 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5000
# Epoch 1937/2000
#
# Epoch 01937: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4296 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4996
# Epoch 1938/2000
#
# Epoch 01938: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4293 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5009
# Epoch 1939/2000
#
# Epoch 01939: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4298 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5005
# Epoch 1940/2000
#
# Epoch 01940: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4285 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5011
# Epoch 1941/2000
#
# Epoch 01941: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4282 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4996
# Epoch 1942/2000
#
# Epoch 01942: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4280 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4980
# Epoch 1943/2000
#
# Epoch 01943: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4292 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4993
# Epoch 1944/2000
#
# Epoch 01944: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4290 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5004
# Epoch 1945/2000
#
# Epoch 01945: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4282 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5008
# Epoch 1946/2000
#
# Epoch 01946: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4285 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4994
# Epoch 1947/2000
#
# Epoch 01947: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4282 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5000
# Epoch 1948/2000
#
# Epoch 01948: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4283 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5010
# Epoch 1949/2000
#
# Epoch 01949: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4296 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5005
# Epoch 1950/2000
#
# Epoch 01950: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4277 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5010
# Epoch 1951/2000
#
# Epoch 01951: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4285 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5000
# Epoch 1952/2000
#
# Epoch 01952: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4293 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5012
# Epoch 1953/2000
#
# Epoch 01953: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4296 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4983
# Epoch 1954/2000
#
# Epoch 01954: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4282 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4995
# Epoch 1955/2000
#
# Epoch 01955: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4302 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5000
# Epoch 1956/2000
#
# Epoch 01956: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4286 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4992
# Epoch 1957/2000
#
# Epoch 01957: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4285 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5001
# Epoch 1958/2000
#
# Epoch 01958: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4272 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5003
# Epoch 1959/2000
#
# Epoch 01959: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4293 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4990
# Epoch 1960/2000
#
# Epoch 01960: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4275 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5000
# Epoch 1961/2000
#
# Epoch 01961: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4300 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5002
# Epoch 1962/2000
#
# Epoch 01962: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4277 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5009
# Epoch 1963/2000
#
# Epoch 01963: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4293 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5003
# Epoch 1964/2000
#
# Epoch 01964: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4297 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4994
# Epoch 1965/2000
#
# Epoch 01965: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4280 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4999
# Epoch 1966/2000
#
# Epoch 01966: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4302 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5004
# Epoch 1967/2000
#
# Epoch 01967: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4281 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4995
# Epoch 1968/2000
#
# Epoch 01968: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4290 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5006
# Epoch 1969/2000
#
# Epoch 01969: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4302 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4987
# Epoch 1970/2000
#
# Epoch 01970: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4290 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5003
# Epoch 1971/2000
#
# Epoch 01971: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4278 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4995
# Epoch 1972/2000
#
# Epoch 01972: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4279 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5000
# Epoch 1973/2000
#
# Epoch 01973: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4297 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4990
# Epoch 1974/2000
#
# Epoch 01974: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4284 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4999
# Epoch 1975/2000
#
# Epoch 01975: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4296 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5009
# Epoch 1976/2000
#
# Epoch 01976: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4275 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5007
# Epoch 1977/2000
#
# Epoch 01977: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4293 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5002
# Epoch 1978/2000
#
# Epoch 01978: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4284 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4999
# Epoch 1979/2000
#
# Epoch 01979: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4299 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4998
# Epoch 1980/2000
#
# Epoch 01980: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4277 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4999
# Epoch 1981/2000
#
# Epoch 01981: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4288 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4996
# Epoch 1982/2000
#
# Epoch 01982: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4283 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5005
# Epoch 1983/2000
#
# Epoch 01983: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4281 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5000
# Epoch 1984/2000
#
# Epoch 01984: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4293 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4997
# Epoch 1985/2000
#
# Epoch 01985: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4286 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5002
# Epoch 1986/2000
#
# Epoch 01986: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4303 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5005
# Epoch 1987/2000
#
# Epoch 01987: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4289 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4998
# Epoch 1988/2000
#
# Epoch 01988: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4281 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5001
# Epoch 1989/2000
#
# Epoch 01989: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4284 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5007
# Epoch 1990/2000
#
# Epoch 01990: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4290 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4987
# Epoch 1991/2000
#
# Epoch 01991: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4295 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4999
# Epoch 1992/2000
#
# Epoch 01992: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4286 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5003
# Epoch 1993/2000
#
# Epoch 01993: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4271 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5008
# Epoch 1994/2000
#
# Epoch 01994: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4286 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4976
# Epoch 1995/2000
#
# Epoch 01995: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4298 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5002
# Epoch 1996/2000
#
# Epoch 01996: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4294 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.4996
# Epoch 1997/2000
#
# Epoch 01997: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4292 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5018
# Epoch 1998/2000
#
# Epoch 01998: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4294 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5006
# Epoch 1999/2000
#
# Epoch 01999: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4282 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5001
# Epoch 2000/2000
#
# Epoch 02000: val_loss did not improve from 0.70045
# 786/786 - 0s - loss: 0.5513 - acc: 0.7341 - rmse: 0.4282 - val_loss: 0.7016 - val_acc: 0.5655 - val_rmse: 0.5002

# %%
# load optimal weights
model.load_weights('/tmp/LSTM_checkpoint.h5')



probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# Classification accuracy: 0.654762

# %%
# list all data in history
#print(fitted_model.history.keys())

print('Diagrammed History of Model Metrics')

# summarize history for accuracy
plt.plot(fitted_model.history['acc'])
plt.plot(fitted_model.history['val_acc'])
plt.title('Model Accuracy over Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Diagrammed History of Model Metrics

# %%
# summarize history for rmse
plt.plot(fitted_model.history['rmse'])
plt.plot(fitted_model.history['val_rmse'])
plt.title('Model RMSE over Epochs')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize loss history
plt.plot(fitted_model.history['loss'])
plt.plot(fitted_model.history['val_loss'])
plt.title('Model Loss over Epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# !pip freeze

# %%
from platform import python_version

print(python_version())
