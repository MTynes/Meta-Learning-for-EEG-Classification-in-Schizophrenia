# %%
import os
raw_data_dir = ''

if  'COLAB_GPU' in os.environ:
    print('Using Google Colab. Setting up environment')
    raw_data_dir = '/content/drive/My Drive/Colab Notebooks/' 
    # !pip install mne
    # !pip install pyedflib

    print('\n \n To load files from Google Drive, account validation is required.')
    #mount to drive -- files should be located in the Colab notebooks directory
    from google.colab import drive
    drive.mount("/content/drive", force_remount=True)
else:
    if 'HOMEPATH' in os.environ:
        print('Using homepath ' + os.environ['HOMEPATH'])
    raw_data_dir = '../../Data/Raw/'
# Out:
# Using Google Colab. Setting up environment
# Collecting mne
#   Downloading https://files.pythonhosted.org/packages/a1/7c/ad1b52a3fdd4be8f55e183f1eff7d76f48cd1bee83c5630f9c26770e032e/mne-0.19.2-py3-none-any.whl (6.4MB)
#      |████████████████████████████████| 6.4MB 3.3MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from mne) (1.17.5)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from mne) (1.4.1)
# Installing collected packages: mne
# Successfully installed mne-0.19.2
# Collecting pyedflib
#   Downloading https://files.pythonhosted.org/packages/bc/8b/47ce5a889e1f6917390ba2328b494424d018cf9c263ab59e14ac851e194f/pyEDFlib-0.1.15.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 3.3MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from pyedflib) (1.17.5)
# Building wheels for collected packages: pyedflib
#   Building wheel for pyedflib (setup.py) ... done
#   Created wheel for pyedflib: filename=pyEDFlib-0.1.15-cp36-cp36m-linux_x86_64.whl size=920110 sha256=b4f9e37c52b6913595b8b9feabad3fa9be44edfd972777b53828f1ace7c249b2
#   Stored in directory: /root/.cache/pip/wheels/57/e3/8e/ce6236e9ada08b8ff91ef922c7418dbd66f1182dfbb22f8579
# Successfully built pyedflib
# Installing collected packages: pyedflib
# Successfully installed pyedflib-0.1.15
#
#
#  To load files from Google Drive, account validation is required.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

import pandas as pd
import pyedflib


import tensorflow as tf
use_gpu = tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)


import numpy as np

# mne imports
import mne
from mne import io

# EEGNet-specific imports
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint


# tools for plotting confusion matrices
from matplotlib import pyplot as plt

import random 
import math
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from tensorflow.keras import layers
#https://www.tensorflow.org/guide/keras/rnn

def LSTM(samples, time_steps, nb_features, chans, nb_classes):

    model=tf.keras.Sequential()
    
    print('chans: ', chans)
    print('nb_features: ', nb_features)
    model.add(layers.LSTM(128,
                          input_shape=(chans, time_steps)
            #input_shape=(chans* nb_features, time_steps),
            ))
    

    model.add(Dense(16,kernel_initializer='he_uniform',activation='relu'))
    

    model.add(Dense(nb_classes,activation='softmax'))
    
    return model



    #LSTM(samles, time_steps=20, input_size=30, chans)


    
    
from tensorflow.keras import layers
#https://www.tensorflow.org/guide/keras/rnn

def GRU_RNN(samples, time_steps, nb_features, chans, nb_classes):
    model=tf.keras.Sequential()
    
    #model.add(layers.LSTM(128,
    #         input_shape=(chans, time_steps),
    #         ))
    
    # The output of GRU will be a 3D tensor of shape (batch_size, timesteps, 256)
    model.add(layers.GRU(512, 
                         input_shape=(chans, time_steps),
                         return_sequences=True))

    model.add(layers.SimpleRNN(256))
    #model.add(layers.SimpleRNN(128))
    

    model.add(Dense(32,kernel_initializer='he_uniform',activation='relu'))
    

    model.add(Dense(nb_classes,activation='softmax'))
    
    return model

# %%
ignore_list = ['s07']  #list of patient files that should be skipped
#seconds of data to include in one slice
time_window = 12

# %%
mne.set_log_level("WARNING")


# get the minimum length of the files
def get_minimum_duration(group_directory_name, patient_group_file_prefix):
    file_durations = []
    for i in range (1, 15): # reading 14 files
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        file_name = raw_data_dir +'{}/{}.edf'.format(group_directory_name, patient_id)
        f = pyedflib.EdfReader(file_name)
        file_durations.append(f.file_duration)
        f.close()
    return(min(file_durations))

# modified based on https://stackoverflow.com/a/48704557/2466781
def chunk(seq, size):
    sl = len(seq) - (len(seq)%size) #exclude values that will be out of range
    r = [pd.DataFrame(seq[pos:pos + size]) for pos in range(0, sl, size)]
    return r

# modified version of process_patient_group in older notebooks
# Uses the raw EDF files and converts to dataframe, dropping the first 150 and last 30 seconds of the shortest  file
# All other files are trimmed similarly to produce the same size
# Adapted from page 1 of https://buildmedia.readthedocs.org/media/pdf/pyedflib/latest/pyedflib.pdf
def process_patient_group(group_directory_name, patient_group_file_prefix, 
                          minimum_original_duration,
                          time_window = 20,
                          plot_channels = False,
                         channels = ['F8', 'F7', 'F4', 'F3', 'Fz']):
    meta_df = pd.DataFrame()
    meta = []
    patient_id_list = []

    for i in range (1, 15): # reading 14 files
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        patient_id_list.append(patient_id)
        
        file_name = raw_data_dir + '{}/{}.edf'.format(group_directory_name, patient_id)
        data = mne.io.read_raw_edf(file_name)
        df = data.to_data_frame()
        df2 = df[channels]
        ## based on visual inspection, drop the first 120 seconds
        df2 = df2[120: (minimum_original_duration-120)]
        f = pyedflib.EdfReader(file_name)
        f.close()
        if patient_id not in ignore_list:
            meta_df = meta_df.append(df2)
            
    batches = chunk(meta_df, time_window)

    for batch in batches:
        #display(np.asarray(batch.values).shape)
        meta.append([np.asarray(batch.values)])
           
                    
    return meta

# %%
# Retrieve patient data, using a time window determined by the shortest recording
# patient s07 is removed

minimum_duration = min(get_minimum_duration("Healthy Controls", "h"), get_minimum_duration('SZ Patients', 's'))
print('Minimum duration: ', minimum_duration)

all_channels = ['Fp2', 'F8', 'T4', 'T6', 'O2', 'Fp1', 'F7', 'T3', 'T5', 'O1', 'F4',
                'C4', 'P4', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Pz']

target_channels = ['T4', 'T6', 'O2', 'T3', 'T5', 'O1',
                   'C4', 'P4', 'C3', 'P3', 'Cz', 'Pz']

print("Healthy Controls")
hc_data = process_patient_group('Healthy Controls', 'h', minimum_duration, channels=target_channels, time_window=time_window)
display(np.asarray(hc_data).shape)


print('Sz Patients')
sz_data = np.asarray(process_patient_group('SZ Patients', 's', minimum_duration, channels=target_channels, time_window=time_window))
display(np.asarray(sz_data).shape)


##### combine groups and create Y (labels)

X =  np.concatenate((hc_data, sz_data), axis=0)
display('Input size: ', X.shape)
y = ([0] * len(hc_data)) +( [1] * len(sz_data))
# Out:
# Minimum duration:  740
# Healthy Controls
# (583, 1, 12, 12)
# Sz Patients
# (541, 1, 12, 12)
# 'Input size: '
# (1124, 1, 12, 12)

# %%
#X[1].plot()
from IPython.display import display

import pylab as pylab

print('Input (X) shape: ' + str(X.shape))
print('Preview of data. First slice of unfiltered data')
for el in X[1][0]:
  #print(el)
  #pylab.scatter(x=range(len(el)), y=el)
  pylab.plot(el)
# Out:
# Input (X) shape: (1124, 1, 12, 12)
# Preview of data. First slice of unfiltered data

# %%
# create the /tmp directory if it doesn't already exist
import os
if not os.path.exists('tmp'):
    os.makedirs('tmp')

# %%
# get a list of randomly selected sets of numbers based on a range
# the proportion of values selected for each set is determined by the ratio_array
def get_mixed_indexes_for_ml_train_test(length, ratios_array):
    input_indexes = range(0, length)
    output_indexes = []
    for ratio in ratios_array:
        selection = random.choices(input_indexes, k=math.floor(ratio * length))
        input_indexes = [i for i in input_indexes if i not in selection]
        output_indexes.append(selection)
    return output_indexes

# %%
kernels, chans, samples = 1, 12, time_window
full_size = len(X)
train_idxs, validate_idxs, test_idxs = get_mixed_indexes_for_ml_train_test(len(X), [.70, 0.15, 0.15])



X_train      = X[train_idxs][0:,]
Y_train      = np.asarray(y)[train_idxs]
X_validate   = X[validate_idxs][0:,]
Y_validate   = np.asarray(y)[validate_idxs]
X_test       = X[test_idxs][0:,]
Y_test       = np.asarray(y)[test_idxs]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train, num_classes=2)
Y_validate   = np_utils.to_categorical(Y_validate, num_classes=2)
Y_test       = np_utils.to_categorical(Y_test, num_classes=2)



X_train      = X_train.reshape(X_train.shape[0],   chans, time_window,)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, time_window)
X_test       = X_test.reshape(X_test.shape[0], chans, time_window)


 
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')



#LSTM(samles, time_steps=20, input_size=30, chans)
#model = LSTM(samples=samples, time_steps=time_window, chans=chans, nb_features=1, nb_classes=2, )

model = GRU_RNN(samples=samples, time_steps=time_window, chans=chans, nb_features=1, nb_classes=2 )
model.summary()

#import tensorflow 
import tensorflow.keras.optimizers
opt_adam = tensorflow.keras.optimizers.Adam(lr=0.000001, 
                                beta_1=0.99,
                                beta_2=0.999,
                                epsilon=1e-07)
sgd = tensorflow.keras.optimizers.SGD(lr=0.01)



def rmse (y_true, y_pred):

    return K.sqrt(K.mean(K.square(y_pred -y_true)))

def rmse_np (y_true, y_pred):
    y_true = y_true.astype(int)
    y_pred=y_pred.astype(int)
    print(y_pred.dtype)
    return K.sqrt(K.mean(K.square(y_pred -y_true)))

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer=opt_adam, 
              metrics=[#'mse', 'mae', 
                  'accuracy', rmse
                 ])


# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='/tmp/RNN_checkpoint.h5', verbose=1,
                               save_best_only=True)
# Out:
# X_train shape: (786, 12, 12)
# 786 train samples
# 168 test samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 12, 512)           806400
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 256)               196864
# _________________________________________________________________
# dense (Dense)                (None, 32)                8224
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 1,011,554
# Trainable params: 1,011,554
# Non-trainable params: 0
# _________________________________________________________________

# %%
fitted_model = model.fit(X_train, Y_train, batch_size = 32, epochs = 2000, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 786 samples, validate on 168 samples
# Epoch 1/2000
#
# Epoch 00001: val_loss improved from inf to 0.81750, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 3s - loss: 0.7947 - acc: 0.5178 - rmse: 0.5374 - val_loss: 0.8175 - val_acc: 0.5000 - val_rmse: 0.5514
# Epoch 2/2000
#
# Epoch 00002: val_loss improved from 0.81750 to 0.80966, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.7827 - acc: 0.5216 - rmse: 0.5335 - val_loss: 0.8097 - val_acc: 0.5060 - val_rmse: 0.5367
# Epoch 3/2000
#
# Epoch 00003: val_loss improved from 0.80966 to 0.80257, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.7706 - acc: 0.5267 - rmse: 0.5266 - val_loss: 0.8026 - val_acc: 0.5238 - val_rmse: 0.5253
# Epoch 4/2000
#
# Epoch 00004: val_loss improved from 0.80257 to 0.79613, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.7594 - acc: 0.5331 - rmse: 0.5232 - val_loss: 0.7961 - val_acc: 0.5238 - val_rmse: 0.5500
# Epoch 5/2000
#
# Epoch 00005: val_loss improved from 0.79613 to 0.78992, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.7494 - acc: 0.5483 - rmse: 0.5203 - val_loss: 0.7899 - val_acc: 0.5298 - val_rmse: 0.5334
# Epoch 6/2000
#
# Epoch 00006: val_loss improved from 0.78992 to 0.78439, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.7391 - acc: 0.5522 - rmse: 0.5164 - val_loss: 0.7844 - val_acc: 0.5298 - val_rmse: 0.5264
# Epoch 7/2000
#
# Epoch 00007: val_loss improved from 0.78439 to 0.77918, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.7304 - acc: 0.5573 - rmse: 0.5130 - val_loss: 0.7792 - val_acc: 0.5238 - val_rmse: 0.5360
# Epoch 8/2000
#
# Epoch 00008: val_loss improved from 0.77918 to 0.77432, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.7218 - acc: 0.5509 - rmse: 0.5097 - val_loss: 0.7743 - val_acc: 0.5060 - val_rmse: 0.5313
# Epoch 9/2000
#
# Epoch 00009: val_loss improved from 0.77432 to 0.76975, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.7133 - acc: 0.5534 - rmse: 0.5069 - val_loss: 0.7698 - val_acc: 0.5119 - val_rmse: 0.5248
# Epoch 10/2000
#
# Epoch 00010: val_loss improved from 0.76975 to 0.76537, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.7059 - acc: 0.5585 - rmse: 0.5030 - val_loss: 0.7654 - val_acc: 0.5060 - val_rmse: 0.5179
# Epoch 11/2000
#
# Epoch 00011: val_loss improved from 0.76537 to 0.76112, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6985 - acc: 0.5674 - rmse: 0.4998 - val_loss: 0.7611 - val_acc: 0.5000 - val_rmse: 0.5300
# Epoch 12/2000
#
# Epoch 00012: val_loss improved from 0.76112 to 0.75709, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6914 - acc: 0.5738 - rmse: 0.4978 - val_loss: 0.7571 - val_acc: 0.4940 - val_rmse: 0.5177
# Epoch 13/2000
#
# Epoch 00013: val_loss improved from 0.75709 to 0.75315, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6846 - acc: 0.5776 - rmse: 0.4939 - val_loss: 0.7531 - val_acc: 0.5060 - val_rmse: 0.5201
# Epoch 14/2000
#
# Epoch 00014: val_loss improved from 0.75315 to 0.74938, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6781 - acc: 0.5852 - rmse: 0.4920 - val_loss: 0.7494 - val_acc: 0.5060 - val_rmse: 0.5304
# Epoch 15/2000
#
# Epoch 00015: val_loss improved from 0.74938 to 0.74587, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6718 - acc: 0.5929 - rmse: 0.4892 - val_loss: 0.7459 - val_acc: 0.5060 - val_rmse: 0.5248
# Epoch 16/2000
#
# Epoch 00016: val_loss improved from 0.74587 to 0.74252, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6659 - acc: 0.5980 - rmse: 0.4863 - val_loss: 0.7425 - val_acc: 0.5060 - val_rmse: 0.5055
# Epoch 17/2000
#
# Epoch 00017: val_loss improved from 0.74252 to 0.73934, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6603 - acc: 0.6005 - rmse: 0.4830 - val_loss: 0.7393 - val_acc: 0.5060 - val_rmse: 0.5176
# Epoch 18/2000
#
# Epoch 00018: val_loss improved from 0.73934 to 0.73631, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6546 - acc: 0.6043 - rmse: 0.4791 - val_loss: 0.7363 - val_acc: 0.5179 - val_rmse: 0.5082
# Epoch 19/2000
#
# Epoch 00019: val_loss improved from 0.73631 to 0.73345, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6490 - acc: 0.6081 - rmse: 0.4794 - val_loss: 0.7335 - val_acc: 0.5179 - val_rmse: 0.5048
# Epoch 20/2000
#
# Epoch 00020: val_loss improved from 0.73345 to 0.73065, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6439 - acc: 0.6132 - rmse: 0.4764 - val_loss: 0.7307 - val_acc: 0.5238 - val_rmse: 0.5229
# Epoch 21/2000
#
# Epoch 00021: val_loss improved from 0.73065 to 0.72793, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6388 - acc: 0.6196 - rmse: 0.4733 - val_loss: 0.7279 - val_acc: 0.5298 - val_rmse: 0.5007
# Epoch 22/2000
#
# Epoch 00022: val_loss improved from 0.72793 to 0.72527, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6337 - acc: 0.6260 - rmse: 0.4703 - val_loss: 0.7253 - val_acc: 0.5298 - val_rmse: 0.5177
# Epoch 23/2000
#
# Epoch 00023: val_loss improved from 0.72527 to 0.72262, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6289 - acc: 0.6310 - rmse: 0.4693 - val_loss: 0.7226 - val_acc: 0.5357 - val_rmse: 0.5050
# Epoch 24/2000
#
# Epoch 00024: val_loss improved from 0.72262 to 0.71998, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6242 - acc: 0.6349 - rmse: 0.4667 - val_loss: 0.7200 - val_acc: 0.5357 - val_rmse: 0.4989
# Epoch 25/2000
#
# Epoch 00025: val_loss improved from 0.71998 to 0.71744, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6195 - acc: 0.6412 - rmse: 0.4639 - val_loss: 0.7174 - val_acc: 0.5536 - val_rmse: 0.5003
# Epoch 26/2000
#
# Epoch 00026: val_loss improved from 0.71744 to 0.71492, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6151 - acc: 0.6514 - rmse: 0.4624 - val_loss: 0.7149 - val_acc: 0.5536 - val_rmse: 0.5047
# Epoch 27/2000
#
# Epoch 00027: val_loss improved from 0.71492 to 0.71241, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6107 - acc: 0.6552 - rmse: 0.4598 - val_loss: 0.7124 - val_acc: 0.5595 - val_rmse: 0.5094
# Epoch 28/2000
#
# Epoch 00028: val_loss improved from 0.71241 to 0.71004, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6062 - acc: 0.6590 - rmse: 0.4583 - val_loss: 0.7100 - val_acc: 0.5595 - val_rmse: 0.5143
# Epoch 29/2000
#
# Epoch 00029: val_loss improved from 0.71004 to 0.70768, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.6020 - acc: 0.6667 - rmse: 0.4554 - val_loss: 0.7077 - val_acc: 0.5536 - val_rmse: 0.5044
# Epoch 30/2000
#
# Epoch 00030: val_loss improved from 0.70768 to 0.70538, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5979 - acc: 0.6692 - rmse: 0.4532 - val_loss: 0.7054 - val_acc: 0.5774 - val_rmse: 0.5116
# Epoch 31/2000
#
# Epoch 00031: val_loss improved from 0.70538 to 0.70318, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5938 - acc: 0.6768 - rmse: 0.4516 - val_loss: 0.7032 - val_acc: 0.5714 - val_rmse: 0.4943
# Epoch 32/2000
#
# Epoch 00032: val_loss improved from 0.70318 to 0.70103, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5898 - acc: 0.6832 - rmse: 0.4496 - val_loss: 0.7010 - val_acc: 0.5774 - val_rmse: 0.4952
# Epoch 33/2000
#
# Epoch 00033: val_loss improved from 0.70103 to 0.69898, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5859 - acc: 0.6832 - rmse: 0.4481 - val_loss: 0.6990 - val_acc: 0.5774 - val_rmse: 0.4987
# Epoch 34/2000
#
# Epoch 00034: val_loss improved from 0.69898 to 0.69694, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5822 - acc: 0.6845 - rmse: 0.4448 - val_loss: 0.6969 - val_acc: 0.5774 - val_rmse: 0.4879
# Epoch 35/2000
#
# Epoch 00035: val_loss improved from 0.69694 to 0.69500, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5785 - acc: 0.6858 - rmse: 0.4437 - val_loss: 0.6950 - val_acc: 0.5774 - val_rmse: 0.5146
# Epoch 36/2000
#
# Epoch 00036: val_loss improved from 0.69500 to 0.69309, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5749 - acc: 0.6934 - rmse: 0.4434 - val_loss: 0.6931 - val_acc: 0.5952 - val_rmse: 0.5034
# Epoch 37/2000
#
# Epoch 00037: val_loss improved from 0.69309 to 0.69123, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5712 - acc: 0.6997 - rmse: 0.4404 - val_loss: 0.6912 - val_acc: 0.6071 - val_rmse: 0.4965
# Epoch 38/2000
#
# Epoch 00038: val_loss improved from 0.69123 to 0.68936, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5677 - acc: 0.7087 - rmse: 0.4393 - val_loss: 0.6894 - val_acc: 0.6190 - val_rmse: 0.4873
# Epoch 39/2000
#
# Epoch 00039: val_loss improved from 0.68936 to 0.68745, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5644 - acc: 0.7087 - rmse: 0.4374 - val_loss: 0.6875 - val_acc: 0.6190 - val_rmse: 0.4899
# Epoch 40/2000
#
# Epoch 00040: val_loss improved from 0.68745 to 0.68553, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5609 - acc: 0.7074 - rmse: 0.4355 - val_loss: 0.6855 - val_acc: 0.6190 - val_rmse: 0.5015
# Epoch 41/2000
#
# Epoch 00041: val_loss improved from 0.68553 to 0.68378, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5575 - acc: 0.7074 - rmse: 0.4341 - val_loss: 0.6838 - val_acc: 0.6250 - val_rmse: 0.4905
# Epoch 42/2000
#
# Epoch 00042: val_loss improved from 0.68378 to 0.68204, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5542 - acc: 0.7112 - rmse: 0.4322 - val_loss: 0.6820 - val_acc: 0.6250 - val_rmse: 0.5012
# Epoch 43/2000
#
# Epoch 00043: val_loss improved from 0.68204 to 0.68030, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5510 - acc: 0.7137 - rmse: 0.4312 - val_loss: 0.6803 - val_acc: 0.6250 - val_rmse: 0.4984
# Epoch 44/2000
#
# Epoch 00044: val_loss improved from 0.68030 to 0.67862, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5477 - acc: 0.7201 - rmse: 0.4288 - val_loss: 0.6786 - val_acc: 0.6250 - val_rmse: 0.4926
# Epoch 45/2000
#
# Epoch 00045: val_loss improved from 0.67862 to 0.67707, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5445 - acc: 0.7226 - rmse: 0.4276 - val_loss: 0.6771 - val_acc: 0.6250 - val_rmse: 0.4883
# Epoch 46/2000
#
# Epoch 00046: val_loss improved from 0.67707 to 0.67557, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5415 - acc: 0.7239 - rmse: 0.4255 - val_loss: 0.6756 - val_acc: 0.6250 - val_rmse: 0.4834
# Epoch 47/2000
#
# Epoch 00047: val_loss improved from 0.67557 to 0.67400, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5385 - acc: 0.7316 - rmse: 0.4241 - val_loss: 0.6740 - val_acc: 0.6250 - val_rmse: 0.4871
# Epoch 48/2000
#
# Epoch 00048: val_loss improved from 0.67400 to 0.67258, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5355 - acc: 0.7303 - rmse: 0.4227 - val_loss: 0.6726 - val_acc: 0.6250 - val_rmse: 0.4800
# Epoch 49/2000
#
# Epoch 00049: val_loss improved from 0.67258 to 0.67114, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5326 - acc: 0.7303 - rmse: 0.4218 - val_loss: 0.6711 - val_acc: 0.6250 - val_rmse: 0.4723
# Epoch 50/2000
#
# Epoch 00050: val_loss improved from 0.67114 to 0.66964, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5297 - acc: 0.7316 - rmse: 0.4196 - val_loss: 0.6696 - val_acc: 0.6250 - val_rmse: 0.4869
# Epoch 51/2000
#
# Epoch 00051: val_loss improved from 0.66964 to 0.66820, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5269 - acc: 0.7366 - rmse: 0.4191 - val_loss: 0.6682 - val_acc: 0.6250 - val_rmse: 0.4812
# Epoch 52/2000
#
# Epoch 00052: val_loss improved from 0.66820 to 0.66675, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5240 - acc: 0.7379 - rmse: 0.4165 - val_loss: 0.6668 - val_acc: 0.6310 - val_rmse: 0.4864
# Epoch 53/2000
#
# Epoch 00053: val_loss improved from 0.66675 to 0.66528, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5213 - acc: 0.7392 - rmse: 0.4144 - val_loss: 0.6653 - val_acc: 0.6429 - val_rmse: 0.4874
# Epoch 54/2000
#
# Epoch 00054: val_loss improved from 0.66528 to 0.66394, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5186 - acc: 0.7430 - rmse: 0.4139 - val_loss: 0.6639 - val_acc: 0.6488 - val_rmse: 0.4818
# Epoch 55/2000
#
# Epoch 00055: val_loss improved from 0.66394 to 0.66250, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5159 - acc: 0.7455 - rmse: 0.4127 - val_loss: 0.6625 - val_acc: 0.6548 - val_rmse: 0.4813
# Epoch 56/2000
#
# Epoch 00056: val_loss improved from 0.66250 to 0.66114, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5133 - acc: 0.7468 - rmse: 0.4103 - val_loss: 0.6611 - val_acc: 0.6548 - val_rmse: 0.4873
# Epoch 57/2000
#
# Epoch 00057: val_loss improved from 0.66114 to 0.65969, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5107 - acc: 0.7494 - rmse: 0.4101 - val_loss: 0.6597 - val_acc: 0.6548 - val_rmse: 0.4912
# Epoch 58/2000
#
# Epoch 00058: val_loss improved from 0.65969 to 0.65835, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5081 - acc: 0.7506 - rmse: 0.4088 - val_loss: 0.6584 - val_acc: 0.6548 - val_rmse: 0.4795
# Epoch 59/2000
#
# Epoch 00059: val_loss improved from 0.65835 to 0.65697, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5056 - acc: 0.7545 - rmse: 0.4069 - val_loss: 0.6570 - val_acc: 0.6548 - val_rmse: 0.4757
# Epoch 60/2000
#
# Epoch 00060: val_loss improved from 0.65697 to 0.65571, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5030 - acc: 0.7608 - rmse: 0.4048 - val_loss: 0.6557 - val_acc: 0.6548 - val_rmse: 0.4627
# Epoch 61/2000
#
# Epoch 00061: val_loss improved from 0.65571 to 0.65438, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.5006 - acc: 0.7621 - rmse: 0.4032 - val_loss: 0.6544 - val_acc: 0.6548 - val_rmse: 0.4736
# Epoch 62/2000
#
# Epoch 00062: val_loss improved from 0.65438 to 0.65310, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4982 - acc: 0.7634 - rmse: 0.4032 - val_loss: 0.6531 - val_acc: 0.6548 - val_rmse: 0.4759
# Epoch 63/2000
#
# Epoch 00063: val_loss improved from 0.65310 to 0.65191, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4958 - acc: 0.7659 - rmse: 0.4014 - val_loss: 0.6519 - val_acc: 0.6548 - val_rmse: 0.4928
# Epoch 64/2000
#
# Epoch 00064: val_loss improved from 0.65191 to 0.65069, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4934 - acc: 0.7684 - rmse: 0.3993 - val_loss: 0.6507 - val_acc: 0.6667 - val_rmse: 0.4823
# Epoch 65/2000
#
# Epoch 00065: val_loss improved from 0.65069 to 0.64957, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4911 - acc: 0.7697 - rmse: 0.3981 - val_loss: 0.6496 - val_acc: 0.6667 - val_rmse: 0.4712
# Epoch 66/2000
#
# Epoch 00066: val_loss improved from 0.64957 to 0.64854, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4889 - acc: 0.7710 - rmse: 0.3968 - val_loss: 0.6485 - val_acc: 0.6667 - val_rmse: 0.4771
# Epoch 67/2000
#
# Epoch 00067: val_loss improved from 0.64854 to 0.64747, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4866 - acc: 0.7710 - rmse: 0.3967 - val_loss: 0.6475 - val_acc: 0.6667 - val_rmse: 0.4736
# Epoch 68/2000
#
# Epoch 00068: val_loss improved from 0.64747 to 0.64637, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4844 - acc: 0.7774 - rmse: 0.3937 - val_loss: 0.6464 - val_acc: 0.6726 - val_rmse: 0.4753
# Epoch 69/2000
#
# Epoch 00069: val_loss improved from 0.64637 to 0.64533, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4822 - acc: 0.7786 - rmse: 0.3941 - val_loss: 0.6453 - val_acc: 0.6726 - val_rmse: 0.4786
# Epoch 70/2000
#
# Epoch 00070: val_loss improved from 0.64533 to 0.64430, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4801 - acc: 0.7850 - rmse: 0.3916 - val_loss: 0.6443 - val_acc: 0.6726 - val_rmse: 0.4711
# Epoch 71/2000
#
# Epoch 00071: val_loss improved from 0.64430 to 0.64321, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4780 - acc: 0.7888 - rmse: 0.3924 - val_loss: 0.6432 - val_acc: 0.6786 - val_rmse: 0.4553
# Epoch 72/2000
#
# Epoch 00072: val_loss improved from 0.64321 to 0.64212, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4760 - acc: 0.7888 - rmse: 0.3904 - val_loss: 0.6421 - val_acc: 0.6786 - val_rmse: 0.4780
# Epoch 73/2000
#
# Epoch 00073: val_loss improved from 0.64212 to 0.64107, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4739 - acc: 0.7901 - rmse: 0.3901 - val_loss: 0.6411 - val_acc: 0.6845 - val_rmse: 0.4619
# Epoch 74/2000
#
# Epoch 00074: val_loss improved from 0.64107 to 0.64012, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4718 - acc: 0.7939 - rmse: 0.3893 - val_loss: 0.6401 - val_acc: 0.6845 - val_rmse: 0.4484
# Epoch 75/2000
#
# Epoch 00075: val_loss improved from 0.64012 to 0.63907, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4698 - acc: 0.7939 - rmse: 0.3879 - val_loss: 0.6391 - val_acc: 0.6845 - val_rmse: 0.4801
# Epoch 76/2000
#
# Epoch 00076: val_loss improved from 0.63907 to 0.63804, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4678 - acc: 0.7926 - rmse: 0.3869 - val_loss: 0.6380 - val_acc: 0.6905 - val_rmse: 0.4782
# Epoch 77/2000
#
# Epoch 00077: val_loss improved from 0.63804 to 0.63696, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4658 - acc: 0.7939 - rmse: 0.3855 - val_loss: 0.6370 - val_acc: 0.7083 - val_rmse: 0.4725
# Epoch 78/2000
#
# Epoch 00078: val_loss improved from 0.63696 to 0.63586, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4638 - acc: 0.7990 - rmse: 0.3849 - val_loss: 0.6359 - val_acc: 0.7083 - val_rmse: 0.4706
# Epoch 79/2000
#
# Epoch 00079: val_loss improved from 0.63586 to 0.63484, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4619 - acc: 0.8003 - rmse: 0.3823 - val_loss: 0.6348 - val_acc: 0.7083 - val_rmse: 0.4655
# Epoch 80/2000
#
# Epoch 00080: val_loss improved from 0.63484 to 0.63383, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4600 - acc: 0.8003 - rmse: 0.3806 - val_loss: 0.6338 - val_acc: 0.7083 - val_rmse: 0.4726
# Epoch 81/2000
#
# Epoch 00081: val_loss improved from 0.63383 to 0.63283, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4581 - acc: 0.8015 - rmse: 0.3796 - val_loss: 0.6328 - val_acc: 0.7024 - val_rmse: 0.4643
# Epoch 82/2000
#
# Epoch 00082: val_loss improved from 0.63283 to 0.63188, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4562 - acc: 0.8028 - rmse: 0.3792 - val_loss: 0.6319 - val_acc: 0.7024 - val_rmse: 0.4650
# Epoch 83/2000
#
# Epoch 00083: val_loss improved from 0.63188 to 0.63093, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4544 - acc: 0.8028 - rmse: 0.3793 - val_loss: 0.6309 - val_acc: 0.7024 - val_rmse: 0.4783
# Epoch 84/2000
#
# Epoch 00084: val_loss improved from 0.63093 to 0.62996, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4526 - acc: 0.8028 - rmse: 0.3775 - val_loss: 0.6300 - val_acc: 0.7024 - val_rmse: 0.4681
# Epoch 85/2000
#
# Epoch 00085: val_loss improved from 0.62996 to 0.62907, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4508 - acc: 0.8041 - rmse: 0.3756 - val_loss: 0.6291 - val_acc: 0.7024 - val_rmse: 0.4614
# Epoch 86/2000
#
# Epoch 00086: val_loss improved from 0.62907 to 0.62823, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4490 - acc: 0.8066 - rmse: 0.3759 - val_loss: 0.6282 - val_acc: 0.7024 - val_rmse: 0.4688
# Epoch 87/2000
#
# Epoch 00087: val_loss improved from 0.62823 to 0.62733, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4473 - acc: 0.8079 - rmse: 0.3735 - val_loss: 0.6273 - val_acc: 0.7024 - val_rmse: 0.4668
# Epoch 88/2000
#
# Epoch 00088: val_loss improved from 0.62733 to 0.62650, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4455 - acc: 0.8066 - rmse: 0.3725 - val_loss: 0.6265 - val_acc: 0.7024 - val_rmse: 0.4768
# Epoch 89/2000
#
# Epoch 00089: val_loss improved from 0.62650 to 0.62564, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4438 - acc: 0.8092 - rmse: 0.3731 - val_loss: 0.6256 - val_acc: 0.7024 - val_rmse: 0.4725
# Epoch 90/2000
#
# Epoch 00090: val_loss improved from 0.62564 to 0.62484, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4421 - acc: 0.8155 - rmse: 0.3730 - val_loss: 0.6248 - val_acc: 0.7024 - val_rmse: 0.4640
# Epoch 91/2000
#
# Epoch 00091: val_loss improved from 0.62484 to 0.62406, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4404 - acc: 0.8168 - rmse: 0.3720 - val_loss: 0.6241 - val_acc: 0.7024 - val_rmse: 0.4633
# Epoch 92/2000
#
# Epoch 00092: val_loss improved from 0.62406 to 0.62330, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4387 - acc: 0.8181 - rmse: 0.3704 - val_loss: 0.6233 - val_acc: 0.7024 - val_rmse: 0.4604
# Epoch 93/2000
#
# Epoch 00093: val_loss improved from 0.62330 to 0.62245, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4371 - acc: 0.8193 - rmse: 0.3693 - val_loss: 0.6224 - val_acc: 0.7024 - val_rmse: 0.4391
# Epoch 94/2000
#
# Epoch 00094: val_loss improved from 0.62245 to 0.62165, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4354 - acc: 0.8244 - rmse: 0.3696 - val_loss: 0.6216 - val_acc: 0.7024 - val_rmse: 0.4424
# Epoch 95/2000
#
# Epoch 00095: val_loss improved from 0.62165 to 0.62094, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4337 - acc: 0.8257 - rmse: 0.3664 - val_loss: 0.6209 - val_acc: 0.7083 - val_rmse: 0.4622
# Epoch 96/2000
#
# Epoch 00096: val_loss improved from 0.62094 to 0.62019, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4321 - acc: 0.8295 - rmse: 0.3665 - val_loss: 0.6202 - val_acc: 0.7083 - val_rmse: 0.4560
# Epoch 97/2000
#
# Epoch 00097: val_loss improved from 0.62019 to 0.61928, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4305 - acc: 0.8346 - rmse: 0.3659 - val_loss: 0.6193 - val_acc: 0.7083 - val_rmse: 0.4698
# Epoch 98/2000
#
# Epoch 00098: val_loss improved from 0.61928 to 0.61844, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4289 - acc: 0.8372 - rmse: 0.3648 - val_loss: 0.6184 - val_acc: 0.7083 - val_rmse: 0.4689
# Epoch 99/2000
#
# Epoch 00099: val_loss improved from 0.61844 to 0.61759, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4273 - acc: 0.8372 - rmse: 0.3642 - val_loss: 0.6176 - val_acc: 0.7083 - val_rmse: 0.4501
# Epoch 100/2000
#
# Epoch 00100: val_loss improved from 0.61759 to 0.61681, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4257 - acc: 0.8397 - rmse: 0.3623 - val_loss: 0.6168 - val_acc: 0.7083 - val_rmse: 0.4547
# Epoch 101/2000
#
# Epoch 00101: val_loss improved from 0.61681 to 0.61609, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4241 - acc: 0.8422 - rmse: 0.3628 - val_loss: 0.6161 - val_acc: 0.7083 - val_rmse: 0.4613
# Epoch 102/2000
#
# Epoch 00102: val_loss improved from 0.61609 to 0.61525, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4226 - acc: 0.8435 - rmse: 0.3590 - val_loss: 0.6153 - val_acc: 0.7083 - val_rmse: 0.4694
# Epoch 103/2000
#
# Epoch 00103: val_loss improved from 0.61525 to 0.61450, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4210 - acc: 0.8499 - rmse: 0.3592 - val_loss: 0.6145 - val_acc: 0.7083 - val_rmse: 0.4655
# Epoch 104/2000
#
# Epoch 00104: val_loss improved from 0.61450 to 0.61372, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4195 - acc: 0.8524 - rmse: 0.3591 - val_loss: 0.6137 - val_acc: 0.7083 - val_rmse: 0.4672
# Epoch 105/2000
#
# Epoch 00105: val_loss improved from 0.61372 to 0.61306, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4179 - acc: 0.8537 - rmse: 0.3577 - val_loss: 0.6131 - val_acc: 0.7083 - val_rmse: 0.4644
# Epoch 106/2000
#
# Epoch 00106: val_loss improved from 0.61306 to 0.61245, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4164 - acc: 0.8562 - rmse: 0.3576 - val_loss: 0.6124 - val_acc: 0.7083 - val_rmse: 0.4425
# Epoch 107/2000
#
# Epoch 00107: val_loss improved from 0.61245 to 0.61176, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4149 - acc: 0.8562 - rmse: 0.3548 - val_loss: 0.6118 - val_acc: 0.7083 - val_rmse: 0.4657
# Epoch 108/2000
#
# Epoch 00108: val_loss improved from 0.61176 to 0.61113, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4134 - acc: 0.8575 - rmse: 0.3559 - val_loss: 0.6111 - val_acc: 0.7083 - val_rmse: 0.4620
# Epoch 109/2000
#
# Epoch 00109: val_loss improved from 0.61113 to 0.61046, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4119 - acc: 0.8575 - rmse: 0.3549 - val_loss: 0.6105 - val_acc: 0.7083 - val_rmse: 0.4620
# Epoch 110/2000
#
# Epoch 00110: val_loss improved from 0.61046 to 0.60979, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4104 - acc: 0.8575 - rmse: 0.3533 - val_loss: 0.6098 - val_acc: 0.7083 - val_rmse: 0.4589
# Epoch 111/2000
#
# Epoch 00111: val_loss improved from 0.60979 to 0.60912, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4089 - acc: 0.8575 - rmse: 0.3523 - val_loss: 0.6091 - val_acc: 0.7083 - val_rmse: 0.4615
# Epoch 112/2000
#
# Epoch 00112: val_loss improved from 0.60912 to 0.60856, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4075 - acc: 0.8601 - rmse: 0.3526 - val_loss: 0.6086 - val_acc: 0.7083 - val_rmse: 0.4472
# Epoch 113/2000
#
# Epoch 00113: val_loss improved from 0.60856 to 0.60794, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4060 - acc: 0.8601 - rmse: 0.3508 - val_loss: 0.6079 - val_acc: 0.7083 - val_rmse: 0.4632
# Epoch 114/2000
#
# Epoch 00114: val_loss improved from 0.60794 to 0.60732, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4046 - acc: 0.8613 - rmse: 0.3506 - val_loss: 0.6073 - val_acc: 0.7083 - val_rmse: 0.4617
# Epoch 115/2000
#
# Epoch 00115: val_loss improved from 0.60732 to 0.60676, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4031 - acc: 0.8626 - rmse: 0.3500 - val_loss: 0.6068 - val_acc: 0.7083 - val_rmse: 0.4540
# Epoch 116/2000
#
# Epoch 00116: val_loss improved from 0.60676 to 0.60617, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4017 - acc: 0.8626 - rmse: 0.3505 - val_loss: 0.6062 - val_acc: 0.7083 - val_rmse: 0.4522
# Epoch 117/2000
#
# Epoch 00117: val_loss improved from 0.60617 to 0.60556, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.4002 - acc: 0.8626 - rmse: 0.3492 - val_loss: 0.6056 - val_acc: 0.7083 - val_rmse: 0.4372
# Epoch 118/2000
#
# Epoch 00118: val_loss improved from 0.60556 to 0.60499, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3988 - acc: 0.8651 - rmse: 0.3466 - val_loss: 0.6050 - val_acc: 0.7083 - val_rmse: 0.4478
# Epoch 119/2000
#
# Epoch 00119: val_loss improved from 0.60499 to 0.60445, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3974 - acc: 0.8639 - rmse: 0.3451 - val_loss: 0.6044 - val_acc: 0.7083 - val_rmse: 0.4583
# Epoch 120/2000
#
# Epoch 00120: val_loss improved from 0.60445 to 0.60390, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3960 - acc: 0.8639 - rmse: 0.3456 - val_loss: 0.6039 - val_acc: 0.7083 - val_rmse: 0.4318
# Epoch 121/2000
#
# Epoch 00121: val_loss improved from 0.60390 to 0.60335, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3946 - acc: 0.8702 - rmse: 0.3438 - val_loss: 0.6034 - val_acc: 0.7083 - val_rmse: 0.4566
# Epoch 122/2000
#
# Epoch 00122: val_loss improved from 0.60335 to 0.60286, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3932 - acc: 0.8715 - rmse: 0.3440 - val_loss: 0.6029 - val_acc: 0.7083 - val_rmse: 0.4324
# Epoch 123/2000
#
# Epoch 00123: val_loss improved from 0.60286 to 0.60236, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3918 - acc: 0.8728 - rmse: 0.3417 - val_loss: 0.6024 - val_acc: 0.7083 - val_rmse: 0.4535
# Epoch 124/2000
#
# Epoch 00124: val_loss improved from 0.60236 to 0.60187, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3904 - acc: 0.8728 - rmse: 0.3419 - val_loss: 0.6019 - val_acc: 0.7083 - val_rmse: 0.4419
# Epoch 125/2000
#
# Epoch 00125: val_loss improved from 0.60187 to 0.60133, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3890 - acc: 0.8728 - rmse: 0.3420 - val_loss: 0.6013 - val_acc: 0.7083 - val_rmse: 0.4419
# Epoch 126/2000
#
# Epoch 00126: val_loss improved from 0.60133 to 0.60082, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3877 - acc: 0.8753 - rmse: 0.3399 - val_loss: 0.6008 - val_acc: 0.7143 - val_rmse: 0.4491
# Epoch 127/2000
#
# Epoch 00127: val_loss improved from 0.60082 to 0.60028, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3863 - acc: 0.8766 - rmse: 0.3398 - val_loss: 0.6003 - val_acc: 0.7143 - val_rmse: 0.4522
# Epoch 128/2000
#
# Epoch 00128: val_loss improved from 0.60028 to 0.59972, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3849 - acc: 0.8779 - rmse: 0.3386 - val_loss: 0.5997 - val_acc: 0.7143 - val_rmse: 0.4573
# Epoch 129/2000
#
# Epoch 00129: val_loss improved from 0.59972 to 0.59919, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3836 - acc: 0.8830 - rmse: 0.3387 - val_loss: 0.5992 - val_acc: 0.7083 - val_rmse: 0.4510
# Epoch 130/2000
#
# Epoch 00130: val_loss improved from 0.59919 to 0.59871, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3823 - acc: 0.8830 - rmse: 0.3368 - val_loss: 0.5987 - val_acc: 0.7083 - val_rmse: 0.4416
# Epoch 131/2000
#
# Epoch 00131: val_loss improved from 0.59871 to 0.59816, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3809 - acc: 0.8855 - rmse: 0.3359 - val_loss: 0.5982 - val_acc: 0.7083 - val_rmse: 0.4587
# Epoch 132/2000
#
# Epoch 00132: val_loss improved from 0.59816 to 0.59767, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3796 - acc: 0.8855 - rmse: 0.3357 - val_loss: 0.5977 - val_acc: 0.7083 - val_rmse: 0.4271
# Epoch 133/2000
#
# Epoch 00133: val_loss improved from 0.59767 to 0.59711, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3783 - acc: 0.8855 - rmse: 0.3351 - val_loss: 0.5971 - val_acc: 0.7143 - val_rmse: 0.4506
# Epoch 134/2000
#
# Epoch 00134: val_loss improved from 0.59711 to 0.59659, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3770 - acc: 0.8855 - rmse: 0.3338 - val_loss: 0.5966 - val_acc: 0.7143 - val_rmse: 0.4412
# Epoch 135/2000
#
# Epoch 00135: val_loss improved from 0.59659 to 0.59616, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3757 - acc: 0.8855 - rmse: 0.3341 - val_loss: 0.5962 - val_acc: 0.7143 - val_rmse: 0.4472
# Epoch 136/2000
#
# Epoch 00136: val_loss improved from 0.59616 to 0.59572, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3744 - acc: 0.8855 - rmse: 0.3315 - val_loss: 0.5957 - val_acc: 0.7143 - val_rmse: 0.4404
# Epoch 137/2000
#
# Epoch 00137: val_loss improved from 0.59572 to 0.59518, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3731 - acc: 0.8855 - rmse: 0.3321 - val_loss: 0.5952 - val_acc: 0.7143 - val_rmse: 0.4492
# Epoch 138/2000
#
# Epoch 00138: val_loss improved from 0.59518 to 0.59472, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3718 - acc: 0.8855 - rmse: 0.3315 - val_loss: 0.5947 - val_acc: 0.7143 - val_rmse: 0.4463
# Epoch 139/2000
#
# Epoch 00139: val_loss improved from 0.59472 to 0.59425, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3706 - acc: 0.8868 - rmse: 0.3273 - val_loss: 0.5943 - val_acc: 0.7143 - val_rmse: 0.4473
# Epoch 140/2000
#
# Epoch 00140: val_loss improved from 0.59425 to 0.59372, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3693 - acc: 0.8893 - rmse: 0.3298 - val_loss: 0.5937 - val_acc: 0.7143 - val_rmse: 0.4497
# Epoch 141/2000
#
# Epoch 00141: val_loss improved from 0.59372 to 0.59333, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3680 - acc: 0.8893 - rmse: 0.3289 - val_loss: 0.5933 - val_acc: 0.7083 - val_rmse: 0.4376
# Epoch 142/2000
#
# Epoch 00142: val_loss improved from 0.59333 to 0.59293, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3668 - acc: 0.8893 - rmse: 0.3271 - val_loss: 0.5929 - val_acc: 0.7083 - val_rmse: 0.4597
# Epoch 143/2000
#
# Epoch 00143: val_loss improved from 0.59293 to 0.59247, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3655 - acc: 0.8919 - rmse: 0.3270 - val_loss: 0.5925 - val_acc: 0.7083 - val_rmse: 0.4481
# Epoch 144/2000
#
# Epoch 00144: val_loss improved from 0.59247 to 0.59198, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3643 - acc: 0.8931 - rmse: 0.3268 - val_loss: 0.5920 - val_acc: 0.7083 - val_rmse: 0.4439
# Epoch 145/2000
#
# Epoch 00145: val_loss improved from 0.59198 to 0.59158, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3630 - acc: 0.8969 - rmse: 0.3256 - val_loss: 0.5916 - val_acc: 0.7083 - val_rmse: 0.4537
# Epoch 146/2000
#
# Epoch 00146: val_loss improved from 0.59158 to 0.59108, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3618 - acc: 0.8982 - rmse: 0.3240 - val_loss: 0.5911 - val_acc: 0.7083 - val_rmse: 0.4344
# Epoch 147/2000
#
# Epoch 00147: val_loss improved from 0.59108 to 0.59062, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3606 - acc: 0.9008 - rmse: 0.3241 - val_loss: 0.5906 - val_acc: 0.7083 - val_rmse: 0.4653
# Epoch 148/2000
#
# Epoch 00148: val_loss improved from 0.59062 to 0.59025, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3594 - acc: 0.9020 - rmse: 0.3235 - val_loss: 0.5903 - val_acc: 0.7083 - val_rmse: 0.4392
# Epoch 149/2000
#
# Epoch 00149: val_loss improved from 0.59025 to 0.58995, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3581 - acc: 0.9020 - rmse: 0.3233 - val_loss: 0.5900 - val_acc: 0.7143 - val_rmse: 0.4445
# Epoch 150/2000
#
# Epoch 00150: val_loss improved from 0.58995 to 0.58955, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3569 - acc: 0.9033 - rmse: 0.3214 - val_loss: 0.5896 - val_acc: 0.7143 - val_rmse: 0.4535
# Epoch 151/2000
#
# Epoch 00151: val_loss improved from 0.58955 to 0.58916, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3557 - acc: 0.9033 - rmse: 0.3206 - val_loss: 0.5892 - val_acc: 0.7143 - val_rmse: 0.4460
# Epoch 152/2000
#
# Epoch 00152: val_loss improved from 0.58916 to 0.58884, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3545 - acc: 0.9059 - rmse: 0.3204 - val_loss: 0.5888 - val_acc: 0.7143 - val_rmse: 0.4203
# Epoch 153/2000
#
# Epoch 00153: val_loss improved from 0.58884 to 0.58844, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3534 - acc: 0.9059 - rmse: 0.3195 - val_loss: 0.5884 - val_acc: 0.7143 - val_rmse: 0.4470
# Epoch 154/2000
#
# Epoch 00154: val_loss improved from 0.58844 to 0.58804, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3522 - acc: 0.9059 - rmse: 0.3196 - val_loss: 0.5880 - val_acc: 0.7143 - val_rmse: 0.4385
# Epoch 155/2000
#
# Epoch 00155: val_loss improved from 0.58804 to 0.58760, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3510 - acc: 0.9059 - rmse: 0.3187 - val_loss: 0.5876 - val_acc: 0.7143 - val_rmse: 0.4437
# Epoch 156/2000
#
# Epoch 00156: val_loss improved from 0.58760 to 0.58725, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3499 - acc: 0.9059 - rmse: 0.3171 - val_loss: 0.5872 - val_acc: 0.7143 - val_rmse: 0.4389
# Epoch 157/2000
#
# Epoch 00157: val_loss improved from 0.58725 to 0.58688, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3487 - acc: 0.9059 - rmse: 0.3158 - val_loss: 0.5869 - val_acc: 0.7143 - val_rmse: 0.4525
# Epoch 158/2000
#
# Epoch 00158: val_loss improved from 0.58688 to 0.58647, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3475 - acc: 0.9059 - rmse: 0.3161 - val_loss: 0.5865 - val_acc: 0.7143 - val_rmse: 0.4376
# Epoch 159/2000
#
# Epoch 00159: val_loss improved from 0.58647 to 0.58612, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3464 - acc: 0.9097 - rmse: 0.3148 - val_loss: 0.5861 - val_acc: 0.7143 - val_rmse: 0.4368
# Epoch 160/2000
#
# Epoch 00160: val_loss improved from 0.58612 to 0.58570, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3452 - acc: 0.9097 - rmse: 0.3126 - val_loss: 0.5857 - val_acc: 0.7143 - val_rmse: 0.4608
# Epoch 161/2000
#
# Epoch 00161: val_loss improved from 0.58570 to 0.58535, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3441 - acc: 0.9097 - rmse: 0.3127 - val_loss: 0.5853 - val_acc: 0.7143 - val_rmse: 0.4489
# Epoch 162/2000
#
# Epoch 00162: val_loss improved from 0.58535 to 0.58500, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3429 - acc: 0.9097 - rmse: 0.3124 - val_loss: 0.5850 - val_acc: 0.7143 - val_rmse: 0.4371
# Epoch 163/2000
#
# Epoch 00163: val_loss improved from 0.58500 to 0.58464, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3418 - acc: 0.9122 - rmse: 0.3120 - val_loss: 0.5846 - val_acc: 0.7143 - val_rmse: 0.4246
# Epoch 164/2000
#
# Epoch 00164: val_loss improved from 0.58464 to 0.58427, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3407 - acc: 0.9122 - rmse: 0.3111 - val_loss: 0.5843 - val_acc: 0.7143 - val_rmse: 0.4333
# Epoch 165/2000
#
# Epoch 00165: val_loss improved from 0.58427 to 0.58400, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3396 - acc: 0.9135 - rmse: 0.3105 - val_loss: 0.5840 - val_acc: 0.7143 - val_rmse: 0.4554
# Epoch 166/2000
#
# Epoch 00166: val_loss improved from 0.58400 to 0.58367, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3385 - acc: 0.9135 - rmse: 0.3090 - val_loss: 0.5837 - val_acc: 0.7143 - val_rmse: 0.4384
# Epoch 167/2000
#
# Epoch 00167: val_loss improved from 0.58367 to 0.58341, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3374 - acc: 0.9135 - rmse: 0.3099 - val_loss: 0.5834 - val_acc: 0.7143 - val_rmse: 0.4572
# Epoch 168/2000
#
# Epoch 00168: val_loss improved from 0.58341 to 0.58312, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3362 - acc: 0.9135 - rmse: 0.3076 - val_loss: 0.5831 - val_acc: 0.7143 - val_rmse: 0.4560
# Epoch 169/2000
#
# Epoch 00169: val_loss improved from 0.58312 to 0.58285, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3352 - acc: 0.9135 - rmse: 0.3072 - val_loss: 0.5828 - val_acc: 0.7143 - val_rmse: 0.4472
# Epoch 170/2000
#
# Epoch 00170: val_loss improved from 0.58285 to 0.58255, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3340 - acc: 0.9148 - rmse: 0.3068 - val_loss: 0.5825 - val_acc: 0.7143 - val_rmse: 0.4502
# Epoch 171/2000
#
# Epoch 00171: val_loss improved from 0.58255 to 0.58221, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3329 - acc: 0.9148 - rmse: 0.3086 - val_loss: 0.5822 - val_acc: 0.7143 - val_rmse: 0.4520
# Epoch 172/2000
#
# Epoch 00172: val_loss improved from 0.58221 to 0.58196, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3318 - acc: 0.9160 - rmse: 0.3059 - val_loss: 0.5820 - val_acc: 0.7143 - val_rmse: 0.4309
# Epoch 173/2000
#
# Epoch 00173: val_loss improved from 0.58196 to 0.58172, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3307 - acc: 0.9160 - rmse: 0.3059 - val_loss: 0.5817 - val_acc: 0.7143 - val_rmse: 0.4393
# Epoch 174/2000
#
# Epoch 00174: val_loss improved from 0.58172 to 0.58151, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3296 - acc: 0.9160 - rmse: 0.3051 - val_loss: 0.5815 - val_acc: 0.7143 - val_rmse: 0.4340
# Epoch 175/2000
#
# Epoch 00175: val_loss improved from 0.58151 to 0.58121, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3286 - acc: 0.9160 - rmse: 0.3050 - val_loss: 0.5812 - val_acc: 0.7143 - val_rmse: 0.4124
# Epoch 176/2000
#
# Epoch 00176: val_loss improved from 0.58121 to 0.58094, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3275 - acc: 0.9160 - rmse: 0.3024 - val_loss: 0.5809 - val_acc: 0.7143 - val_rmse: 0.4480
# Epoch 177/2000
#
# Epoch 00177: val_loss improved from 0.58094 to 0.58066, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3264 - acc: 0.9160 - rmse: 0.3023 - val_loss: 0.5807 - val_acc: 0.7143 - val_rmse: 0.4639
# Epoch 178/2000
#
# Epoch 00178: val_loss improved from 0.58066 to 0.58045, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3254 - acc: 0.9160 - rmse: 0.3020 - val_loss: 0.5805 - val_acc: 0.7202 - val_rmse: 0.4340
# Epoch 179/2000
#
# Epoch 00179: val_loss improved from 0.58045 to 0.58012, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3243 - acc: 0.9160 - rmse: 0.3010 - val_loss: 0.5801 - val_acc: 0.7202 - val_rmse: 0.4451
# Epoch 180/2000
#
# Epoch 00180: val_loss improved from 0.58012 to 0.57982, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3232 - acc: 0.9160 - rmse: 0.3008 - val_loss: 0.5798 - val_acc: 0.7202 - val_rmse: 0.4434
# Epoch 181/2000
#
# Epoch 00181: val_loss improved from 0.57982 to 0.57956, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3222 - acc: 0.9160 - rmse: 0.3000 - val_loss: 0.5796 - val_acc: 0.7202 - val_rmse: 0.4386
# Epoch 182/2000
#
# Epoch 00182: val_loss improved from 0.57956 to 0.57933, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3212 - acc: 0.9160 - rmse: 0.2996 - val_loss: 0.5793 - val_acc: 0.7202 - val_rmse: 0.4456
# Epoch 183/2000
#
# Epoch 00183: val_loss improved from 0.57933 to 0.57911, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3201 - acc: 0.9160 - rmse: 0.2972 - val_loss: 0.5791 - val_acc: 0.7202 - val_rmse: 0.4371
# Epoch 184/2000
#
# Epoch 00184: val_loss improved from 0.57911 to 0.57881, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3191 - acc: 0.9160 - rmse: 0.2973 - val_loss: 0.5788 - val_acc: 0.7202 - val_rmse: 0.4375
# Epoch 185/2000
#
# Epoch 00185: val_loss improved from 0.57881 to 0.57848, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3180 - acc: 0.9160 - rmse: 0.2975 - val_loss: 0.5785 - val_acc: 0.7202 - val_rmse: 0.4473
# Epoch 186/2000
#
# Epoch 00186: val_loss improved from 0.57848 to 0.57823, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3170 - acc: 0.9160 - rmse: 0.2968 - val_loss: 0.5782 - val_acc: 0.7202 - val_rmse: 0.4533
# Epoch 187/2000
#
# Epoch 00187: val_loss improved from 0.57823 to 0.57786, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3160 - acc: 0.9160 - rmse: 0.2951 - val_loss: 0.5779 - val_acc: 0.7202 - val_rmse: 0.4377
# Epoch 188/2000
#
# Epoch 00188: val_loss improved from 0.57786 to 0.57753, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3150 - acc: 0.9173 - rmse: 0.2954 - val_loss: 0.5775 - val_acc: 0.7202 - val_rmse: 0.4303
# Epoch 189/2000
#
# Epoch 00189: val_loss improved from 0.57753 to 0.57723, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3140 - acc: 0.9173 - rmse: 0.2947 - val_loss: 0.5772 - val_acc: 0.7202 - val_rmse: 0.4409
# Epoch 190/2000
#
# Epoch 00190: val_loss improved from 0.57723 to 0.57696, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3129 - acc: 0.9173 - rmse: 0.2938 - val_loss: 0.5770 - val_acc: 0.7262 - val_rmse: 0.4433
# Epoch 191/2000
#
# Epoch 00191: val_loss improved from 0.57696 to 0.57663, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3120 - acc: 0.9173 - rmse: 0.2923 - val_loss: 0.5766 - val_acc: 0.7262 - val_rmse: 0.4352
# Epoch 192/2000
#
# Epoch 00192: val_loss improved from 0.57663 to 0.57635, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3109 - acc: 0.9173 - rmse: 0.2930 - val_loss: 0.5763 - val_acc: 0.7262 - val_rmse: 0.4227
# Epoch 193/2000
#
# Epoch 00193: val_loss improved from 0.57635 to 0.57612, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3100 - acc: 0.9173 - rmse: 0.2923 - val_loss: 0.5761 - val_acc: 0.7262 - val_rmse: 0.4472
# Epoch 194/2000
#
# Epoch 00194: val_loss improved from 0.57612 to 0.57576, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3090 - acc: 0.9173 - rmse: 0.2910 - val_loss: 0.5758 - val_acc: 0.7262 - val_rmse: 0.4419
# Epoch 195/2000
#
# Epoch 00195: val_loss improved from 0.57576 to 0.57546, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3080 - acc: 0.9173 - rmse: 0.2908 - val_loss: 0.5755 - val_acc: 0.7262 - val_rmse: 0.4220
# Epoch 196/2000
#
# Epoch 00196: val_loss improved from 0.57546 to 0.57519, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3070 - acc: 0.9173 - rmse: 0.2903 - val_loss: 0.5752 - val_acc: 0.7262 - val_rmse: 0.4369
# Epoch 197/2000
#
# Epoch 00197: val_loss improved from 0.57519 to 0.57494, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3060 - acc: 0.9186 - rmse: 0.2881 - val_loss: 0.5749 - val_acc: 0.7262 - val_rmse: 0.4385
# Epoch 198/2000
#
# Epoch 00198: val_loss improved from 0.57494 to 0.57474, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3051 - acc: 0.9186 - rmse: 0.2881 - val_loss: 0.5747 - val_acc: 0.7262 - val_rmse: 0.4221
# Epoch 199/2000
#
# Epoch 00199: val_loss improved from 0.57474 to 0.57458, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3041 - acc: 0.9198 - rmse: 0.2886 - val_loss: 0.5746 - val_acc: 0.7321 - val_rmse: 0.4346
# Epoch 200/2000
#
# Epoch 00200: val_loss improved from 0.57458 to 0.57444, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3032 - acc: 0.9198 - rmse: 0.2853 - val_loss: 0.5744 - val_acc: 0.7321 - val_rmse: 0.4310
# Epoch 201/2000
#
# Epoch 00201: val_loss improved from 0.57444 to 0.57426, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3022 - acc: 0.9198 - rmse: 0.2874 - val_loss: 0.5743 - val_acc: 0.7321 - val_rmse: 0.4127
# Epoch 202/2000
#
# Epoch 00202: val_loss improved from 0.57426 to 0.57401, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3012 - acc: 0.9198 - rmse: 0.2859 - val_loss: 0.5740 - val_acc: 0.7321 - val_rmse: 0.4200
# Epoch 203/2000
#
# Epoch 00203: val_loss improved from 0.57401 to 0.57391, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.3003 - acc: 0.9198 - rmse: 0.2850 - val_loss: 0.5739 - val_acc: 0.7321 - val_rmse: 0.4284
# Epoch 204/2000
#
# Epoch 00204: val_loss improved from 0.57391 to 0.57376, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.2993 - acc: 0.9198 - rmse: 0.2844 - val_loss: 0.5738 - val_acc: 0.7321 - val_rmse: 0.4053
# Epoch 205/2000
#
# Epoch 00205: val_loss improved from 0.57376 to 0.57352, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.2984 - acc: 0.9224 - rmse: 0.2849 - val_loss: 0.5735 - val_acc: 0.7321 - val_rmse: 0.4432
# Epoch 206/2000
#
# Epoch 00206: val_loss improved from 0.57352 to 0.57336, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.2975 - acc: 0.9224 - rmse: 0.2830 - val_loss: 0.5734 - val_acc: 0.7321 - val_rmse: 0.4483
# Epoch 207/2000
#
# Epoch 00207: val_loss improved from 0.57336 to 0.57315, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.2965 - acc: 0.9249 - rmse: 0.2834 - val_loss: 0.5732 - val_acc: 0.7321 - val_rmse: 0.4415
# Epoch 208/2000
#
# Epoch 00208: val_loss improved from 0.57315 to 0.57291, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.2956 - acc: 0.9262 - rmse: 0.2817 - val_loss: 0.5729 - val_acc: 0.7321 - val_rmse: 0.4498
# Epoch 209/2000
#
# Epoch 00209: val_loss improved from 0.57291 to 0.57274, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.2947 - acc: 0.9262 - rmse: 0.2814 - val_loss: 0.5727 - val_acc: 0.7321 - val_rmse: 0.4322
# Epoch 210/2000
#
# Epoch 00210: val_loss improved from 0.57274 to 0.57243, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.2938 - acc: 0.9275 - rmse: 0.2815 - val_loss: 0.5724 - val_acc: 0.7321 - val_rmse: 0.4203
# Epoch 211/2000
#
# Epoch 00211: val_loss improved from 0.57243 to 0.57223, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.2929 - acc: 0.9275 - rmse: 0.2796 - val_loss: 0.5722 - val_acc: 0.7321 - val_rmse: 0.4448
# Epoch 212/2000
#
# Epoch 00212: val_loss improved from 0.57223 to 0.57205, saving model to /tmp/LSTM_checkpoint.h5
# 786/786 - 1s - loss: 0.2919 - acc: 0.9275 - rmse: 0.2800 - val_loss: 0.5721 - val_acc: 0.7321 - val_rmse: 0.4385
# Epoch 213/2000
#
# ...
# 786/786 - 0s - loss: 1.0526e-07 - acc: 1.0000 - rmse: 2.3012e-07 - val_loss: 1.8463 - val_acc: 0.8095 - val_rmse: 0.4102
# Epoch 1917/2000
#
# Epoch 01917: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 1.0450e-07 - acc: 1.0000 - rmse: 2.4578e-07 - val_loss: 1.8493 - val_acc: 0.8095 - val_rmse: 0.4068
# Epoch 1918/2000
#
# Epoch 01918: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 1.0359e-07 - acc: 1.0000 - rmse: 2.3966e-07 - val_loss: 1.8508 - val_acc: 0.8095 - val_rmse: 0.4285
# Epoch 1919/2000
#
# Epoch 01919: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 1.0237e-07 - acc: 1.0000 - rmse: 2.3594e-07 - val_loss: 1.8517 - val_acc: 0.8095 - val_rmse: 0.4297
# Epoch 1920/2000
#
# Epoch 01920: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 1.0237e-07 - acc: 1.0000 - rmse: 2.3728e-07 - val_loss: 1.8531 - val_acc: 0.8095 - val_rmse: 0.4256
# Epoch 1921/2000
#
# Epoch 01921: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 1.0177e-07 - acc: 1.0000 - rmse: 2.3868e-07 - val_loss: 1.8545 - val_acc: 0.8095 - val_rmse: 0.4209
# Epoch 1922/2000
#
# Epoch 01922: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 1.0146e-07 - acc: 1.0000 - rmse: 2.3087e-07 - val_loss: 1.8523 - val_acc: 0.8095 - val_rmse: 0.4094
# Epoch 1923/2000
#
# Epoch 01923: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 1.0055e-07 - acc: 1.0000 - rmse: 2.3692e-07 - val_loss: 1.8525 - val_acc: 0.8095 - val_rmse: 0.4469
# Epoch 1924/2000
#
# Epoch 01924: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 1.0025e-07 - acc: 1.0000 - rmse: 2.2741e-07 - val_loss: 1.8537 - val_acc: 0.8095 - val_rmse: 0.4200
# Epoch 1925/2000
#
# Epoch 01925: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.9796e-08 - acc: 1.0000 - rmse: 2.2639e-07 - val_loss: 1.8545 - val_acc: 0.8095 - val_rmse: 0.4117
# Epoch 1926/2000
#
# Epoch 01926: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.8886e-08 - acc: 1.0000 - rmse: 2.2245e-07 - val_loss: 1.8540 - val_acc: 0.8095 - val_rmse: 0.4230
# Epoch 1927/2000
#
# Epoch 01927: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.8431e-08 - acc: 1.0000 - rmse: 2.2141e-07 - val_loss: 1.8557 - val_acc: 0.8095 - val_rmse: 0.3959
# Epoch 1928/2000
#
# Epoch 01928: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.7976e-08 - acc: 1.0000 - rmse: 2.2281e-07 - val_loss: 1.8574 - val_acc: 0.8095 - val_rmse: 0.4471
# Epoch 1929/2000
#
# Epoch 01929: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.7369e-08 - acc: 1.0000 - rmse: 2.1961e-07 - val_loss: 1.8597 - val_acc: 0.8095 - val_rmse: 0.4000
# Epoch 1930/2000
#
# Epoch 01930: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.6763e-08 - acc: 1.0000 - rmse: 2.1751e-07 - val_loss: 1.8595 - val_acc: 0.8095 - val_rmse: 0.4291
# Epoch 1931/2000
#
# Epoch 01931: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.6308e-08 - acc: 1.0000 - rmse: 2.1955e-07 - val_loss: 1.8600 - val_acc: 0.8095 - val_rmse: 0.4488
# Epoch 1932/2000
#
# Epoch 01932: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.5094e-08 - acc: 1.0000 - rmse: 2.1877e-07 - val_loss: 1.8606 - val_acc: 0.8095 - val_rmse: 0.4281
# Epoch 1933/2000
#
# Epoch 01933: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.3729e-08 - acc: 1.0000 - rmse: 2.1596e-07 - val_loss: 1.8620 - val_acc: 0.8095 - val_rmse: 0.4127
# Epoch 1934/2000
#
# Epoch 01934: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.3123e-08 - acc: 1.0000 - rmse: 2.1586e-07 - val_loss: 1.8622 - val_acc: 0.8095 - val_rmse: 0.3605
# Epoch 1935/2000
#
# Epoch 01935: val_loss did not improve from 0.51157
# 786/786 - 1s - loss: 9.2668e-08 - acc: 1.0000 - rmse: 2.1593e-07 - val_loss: 1.8659 - val_acc: 0.8095 - val_rmse: 0.4477
# Epoch 1936/2000
#
# Epoch 01936: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.2213e-08 - acc: 1.0000 - rmse: 2.1413e-07 - val_loss: 1.8708 - val_acc: 0.8095 - val_rmse: 0.4300
# Epoch 1937/2000
#
# Epoch 01937: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.2061e-08 - acc: 1.0000 - rmse: 2.0598e-07 - val_loss: 1.8739 - val_acc: 0.8095 - val_rmse: 0.4023
# Epoch 1938/2000
#
# Epoch 01938: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.1758e-08 - acc: 1.0000 - rmse: 2.0320e-07 - val_loss: 1.8738 - val_acc: 0.8095 - val_rmse: 0.4113
# Epoch 1939/2000
#
# Epoch 01939: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.1454e-08 - acc: 1.0000 - rmse: 2.0471e-07 - val_loss: 1.8746 - val_acc: 0.8095 - val_rmse: 0.4481
# Epoch 1940/2000
#
# Epoch 01940: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 9.0241e-08 - acc: 1.0000 - rmse: 2.1328e-07 - val_loss: 1.8735 - val_acc: 0.8095 - val_rmse: 0.3956
# Epoch 1941/2000
#
# Epoch 01941: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.9331e-08 - acc: 1.0000 - rmse: 2.0209e-07 - val_loss: 1.8700 - val_acc: 0.8095 - val_rmse: 0.4113
# Epoch 1942/2000
#
# Epoch 01942: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.8724e-08 - acc: 1.0000 - rmse: 2.0336e-07 - val_loss: 1.8679 - val_acc: 0.8095 - val_rmse: 0.4061
# Epoch 1943/2000
#
# Epoch 01943: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.8118e-08 - acc: 1.0000 - rmse: 2.0272e-07 - val_loss: 1.8678 - val_acc: 0.8095 - val_rmse: 0.4233
# Epoch 1944/2000
#
# Epoch 01944: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.7359e-08 - acc: 1.0000 - rmse: 1.9366e-07 - val_loss: 1.8722 - val_acc: 0.8095 - val_rmse: 0.4374
# Epoch 1945/2000
#
# Epoch 01945: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.6449e-08 - acc: 1.0000 - rmse: 1.9466e-07 - val_loss: 1.8763 - val_acc: 0.8095 - val_rmse: 0.4437
# Epoch 1946/2000
#
# Epoch 01946: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.5994e-08 - acc: 1.0000 - rmse: 1.9987e-07 - val_loss: 1.8793 - val_acc: 0.8095 - val_rmse: 0.3601
# Epoch 1947/2000
#
# Epoch 01947: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.6146e-08 - acc: 1.0000 - rmse: 2.0016e-07 - val_loss: 1.8821 - val_acc: 0.8095 - val_rmse: 0.4069
# Epoch 1948/2000
#
# Epoch 01948: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.4933e-08 - acc: 1.0000 - rmse: 1.9510e-07 - val_loss: 1.8837 - val_acc: 0.8095 - val_rmse: 0.4137
# Epoch 1949/2000
#
# Epoch 01949: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.3871e-08 - acc: 1.0000 - rmse: 1.9290e-07 - val_loss: 1.8842 - val_acc: 0.8095 - val_rmse: 0.4111
# Epoch 1950/2000
#
# Epoch 01950: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.3113e-08 - acc: 1.0000 - rmse: 1.9365e-07 - val_loss: 1.8823 - val_acc: 0.8095 - val_rmse: 0.4119
# Epoch 1951/2000
#
# Epoch 01951: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.3264e-08 - acc: 1.0000 - rmse: 1.7888e-07 - val_loss: 1.8808 - val_acc: 0.8095 - val_rmse: 0.4101
# Epoch 1952/2000
#
# Epoch 01952: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.2809e-08 - acc: 1.0000 - rmse: 1.9094e-07 - val_loss: 1.8809 - val_acc: 0.8095 - val_rmse: 0.4367
# Epoch 1953/2000
#
# Epoch 01953: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.2354e-08 - acc: 1.0000 - rmse: 1.8923e-07 - val_loss: 1.8821 - val_acc: 0.8095 - val_rmse: 0.4044
# Epoch 1954/2000
#
# Epoch 01954: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.1899e-08 - acc: 1.0000 - rmse: 1.8358e-07 - val_loss: 1.8816 - val_acc: 0.8095 - val_rmse: 0.4434
# Epoch 1955/2000
#
# Epoch 01955: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.1141e-08 - acc: 1.0000 - rmse: 1.8358e-07 - val_loss: 1.8830 - val_acc: 0.8095 - val_rmse: 0.4101
# Epoch 1956/2000
#
# Epoch 01956: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 8.0231e-08 - acc: 1.0000 - rmse: 1.8076e-07 - val_loss: 1.8853 - val_acc: 0.8095 - val_rmse: 0.3547
# Epoch 1957/2000
#
# Epoch 01957: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.9928e-08 - acc: 1.0000 - rmse: 1.8265e-07 - val_loss: 1.8873 - val_acc: 0.8095 - val_rmse: 0.3582
# Epoch 1958/2000
#
# Epoch 01958: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.9928e-08 - acc: 1.0000 - rmse: 1.8296e-07 - val_loss: 1.8883 - val_acc: 0.8095 - val_rmse: 0.4114
# Epoch 1959/2000
#
# Epoch 01959: val_loss did not improve from 0.51157
# 786/786 - 1s - loss: 7.9321e-08 - acc: 1.0000 - rmse: 1.7918e-07 - val_loss: 1.8904 - val_acc: 0.8095 - val_rmse: 0.3543
# Epoch 1960/2000
#
# Epoch 01960: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.9321e-08 - acc: 1.0000 - rmse: 1.8274e-07 - val_loss: 1.8916 - val_acc: 0.8095 - val_rmse: 0.4116
# Epoch 1961/2000
#
# Epoch 01961: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.8715e-08 - acc: 1.0000 - rmse: 1.7896e-07 - val_loss: 1.8914 - val_acc: 0.8095 - val_rmse: 0.4189
# Epoch 1962/2000
#
# Epoch 01962: val_loss did not improve from 0.51157
# 786/786 - 1s - loss: 7.8715e-08 - acc: 1.0000 - rmse: 1.7805e-07 - val_loss: 1.8925 - val_acc: 0.8095 - val_rmse: 0.4121
# Epoch 1963/2000
#
# Epoch 01963: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.8260e-08 - acc: 1.0000 - rmse: 1.7413e-07 - val_loss: 1.8922 - val_acc: 0.8095 - val_rmse: 0.3574
# Epoch 1964/2000
#
# Epoch 01964: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.7956e-08 - acc: 1.0000 - rmse: 1.8147e-07 - val_loss: 1.8914 - val_acc: 0.8095 - val_rmse: 0.3567
# Epoch 1965/2000
#
# Epoch 01965: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.7501e-08 - acc: 1.0000 - rmse: 1.7447e-07 - val_loss: 1.8905 - val_acc: 0.8095 - val_rmse: 0.4170
# Epoch 1966/2000
#
# Epoch 01966: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.6895e-08 - acc: 1.0000 - rmse: 1.7077e-07 - val_loss: 1.8921 - val_acc: 0.8095 - val_rmse: 0.4069
# Epoch 1967/2000
#
# Epoch 01967: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.6591e-08 - acc: 1.0000 - rmse: 1.7616e-07 - val_loss: 1.8925 - val_acc: 0.8095 - val_rmse: 0.4268
# Epoch 1968/2000
#
# Epoch 01968: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.5985e-08 - acc: 1.0000 - rmse: 1.7817e-07 - val_loss: 1.8976 - val_acc: 0.8095 - val_rmse: 0.3580
# Epoch 1969/2000
#
# Epoch 01969: val_loss did not improve from 0.51157
# 786/786 - 1s - loss: 7.5530e-08 - acc: 1.0000 - rmse: 1.7076e-07 - val_loss: 1.8985 - val_acc: 0.8095 - val_rmse: 0.4031
# Epoch 1970/2000
#
# Epoch 01970: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.5226e-08 - acc: 1.0000 - rmse: 1.6859e-07 - val_loss: 1.9018 - val_acc: 0.8095 - val_rmse: 0.4216
# Epoch 1971/2000
#
# Epoch 01971: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.4316e-08 - acc: 1.0000 - rmse: 1.6829e-07 - val_loss: 1.9022 - val_acc: 0.8095 - val_rmse: 0.4085
# Epoch 1972/2000
#
# Epoch 01972: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.4165e-08 - acc: 1.0000 - rmse: 1.6693e-07 - val_loss: 1.9028 - val_acc: 0.8095 - val_rmse: 0.3586
# Epoch 1973/2000
#
# Epoch 01973: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.4165e-08 - acc: 1.0000 - rmse: 1.6267e-07 - val_loss: 1.9009 - val_acc: 0.8095 - val_rmse: 0.4093
# Epoch 1974/2000
#
# Epoch 01974: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.4316e-08 - acc: 1.0000 - rmse: 1.6569e-07 - val_loss: 1.9004 - val_acc: 0.8095 - val_rmse: 0.4173
# Epoch 1975/2000
#
# Epoch 01975: val_loss did not improve from 0.51157
# 786/786 - 1s - loss: 7.3406e-08 - acc: 1.0000 - rmse: 1.6474e-07 - val_loss: 1.9006 - val_acc: 0.8095 - val_rmse: 0.4276
# Epoch 1976/2000
#
# Epoch 01976: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.2951e-08 - acc: 1.0000 - rmse: 1.6559e-07 - val_loss: 1.9021 - val_acc: 0.8095 - val_rmse: 0.4280
# Epoch 1977/2000
#
# Epoch 01977: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.2496e-08 - acc: 1.0000 - rmse: 1.6397e-07 - val_loss: 1.9022 - val_acc: 0.8095 - val_rmse: 0.4084
# Epoch 1978/2000
#
# Epoch 01978: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.2041e-08 - acc: 1.0000 - rmse: 1.6348e-07 - val_loss: 1.9032 - val_acc: 0.8095 - val_rmse: 0.4119
# Epoch 1979/2000
#
# Epoch 01979: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.1738e-08 - acc: 1.0000 - rmse: 1.6186e-07 - val_loss: 1.9057 - val_acc: 0.8095 - val_rmse: 0.4034
# Epoch 1980/2000
#
# Epoch 01980: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 7.0676e-08 - acc: 1.0000 - rmse: 1.5883e-07 - val_loss: 1.9085 - val_acc: 0.8095 - val_rmse: 0.4335
# Epoch 1981/2000
#
# Epoch 01981: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.9918e-08 - acc: 1.0000 - rmse: 1.6116e-07 - val_loss: 1.9115 - val_acc: 0.8095 - val_rmse: 0.4392
# Epoch 1982/2000
#
# Epoch 01982: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.8856e-08 - acc: 1.0000 - rmse: 1.5777e-07 - val_loss: 1.9127 - val_acc: 0.8095 - val_rmse: 0.3562
# Epoch 1983/2000
#
# Epoch 01983: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.8401e-08 - acc: 1.0000 - rmse: 1.5281e-07 - val_loss: 1.9096 - val_acc: 0.8095 - val_rmse: 0.4087
# Epoch 1984/2000
#
# Epoch 01984: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.8553e-08 - acc: 1.0000 - rmse: 1.5880e-07 - val_loss: 1.9070 - val_acc: 0.8095 - val_rmse: 0.3867
# Epoch 1985/2000
#
# Epoch 01985: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.8098e-08 - acc: 1.0000 - rmse: 1.5357e-07 - val_loss: 1.9089 - val_acc: 0.8095 - val_rmse: 0.4123
# Epoch 1986/2000
#
# Epoch 01986: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.7491e-08 - acc: 1.0000 - rmse: 1.5274e-07 - val_loss: 1.9126 - val_acc: 0.8095 - val_rmse: 0.4125
# Epoch 1987/2000
#
# Epoch 01987: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.7036e-08 - acc: 1.0000 - rmse: 1.4999e-07 - val_loss: 1.9143 - val_acc: 0.8095 - val_rmse: 0.4280
# Epoch 1988/2000
#
# Epoch 01988: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.6733e-08 - acc: 1.0000 - rmse: 1.5148e-07 - val_loss: 1.9169 - val_acc: 0.8095 - val_rmse: 0.4131
# Epoch 1989/2000
#
# Epoch 01989: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.5823e-08 - acc: 1.0000 - rmse: 1.5295e-07 - val_loss: 1.9156 - val_acc: 0.8095 - val_rmse: 0.4302
# Epoch 1990/2000
#
# Epoch 01990: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.5823e-08 - acc: 1.0000 - rmse: 1.4782e-07 - val_loss: 1.9157 - val_acc: 0.8095 - val_rmse: 0.4244
# Epoch 1991/2000
#
# Epoch 01991: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.4458e-08 - acc: 1.0000 - rmse: 1.4529e-07 - val_loss: 1.9161 - val_acc: 0.8095 - val_rmse: 0.3778
# Epoch 1992/2000
#
# Epoch 01992: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.4155e-08 - acc: 1.0000 - rmse: 1.4177e-07 - val_loss: 1.9179 - val_acc: 0.8095 - val_rmse: 0.4324
# Epoch 1993/2000
#
# Epoch 01993: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.3548e-08 - acc: 1.0000 - rmse: 1.4217e-07 - val_loss: 1.9178 - val_acc: 0.8095 - val_rmse: 0.4329
# Epoch 1994/2000
#
# Epoch 01994: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.3396e-08 - acc: 1.0000 - rmse: 1.4779e-07 - val_loss: 1.9186 - val_acc: 0.8095 - val_rmse: 0.4273
# Epoch 1995/2000
#
# Epoch 01995: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.2183e-08 - acc: 1.0000 - rmse: 1.4403e-07 - val_loss: 1.9195 - val_acc: 0.8095 - val_rmse: 0.4274
# Epoch 1996/2000
#
# Epoch 01996: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.1273e-08 - acc: 1.0000 - rmse: 1.4285e-07 - val_loss: 1.9209 - val_acc: 0.8095 - val_rmse: 0.4072
# Epoch 1997/2000
#
# Epoch 01997: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.0515e-08 - acc: 1.0000 - rmse: 1.4096e-07 - val_loss: 1.9207 - val_acc: 0.8095 - val_rmse: 0.4251
# Epoch 1998/2000
#
# Epoch 01998: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.0666e-08 - acc: 1.0000 - rmse: 1.4288e-07 - val_loss: 1.9210 - val_acc: 0.8095 - val_rmse: 0.4362
# Epoch 1999/2000
#
# Epoch 01999: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.0666e-08 - acc: 1.0000 - rmse: 1.4106e-07 - val_loss: 1.9215 - val_acc: 0.8095 - val_rmse: 0.4212
# Epoch 2000/2000
#
# Epoch 02000: val_loss did not improve from 0.51157
# 786/786 - 0s - loss: 6.0060e-08 - acc: 1.0000 - rmse: 1.3917e-07 - val_loss: 1.9255 - val_acc: 0.8095 - val_rmse: 0.4303

# %%
# load optimal weights
model.load_weights('/tmp/RNN_checkpoint.h5')



probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# Classification accuracy: 0.809524

# %%
# list all data in history
#print(fitted_model.history.keys())

print('Diagrammed History of Model Metrics')

# summarize history for accuracy
plt.plot(fitted_model.history['acc'])
plt.plot(fitted_model.history['val_acc'])
plt.title('Model Accuracy over Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Diagrammed History of Model Metrics

# %%
# summarize history for rmse
plt.plot(fitted_model.history['rmse'])
plt.plot(fitted_model.history['val_rmse'])
plt.title('Model RMSE over Epochs')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize loss history
plt.plot(fitted_model.history['loss'])
plt.plot(fitted_model.history['val_loss'])
plt.title('Model Loss over Epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# !pip freeze
# Out:
# absl-py==0.9.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.0.0
# asgiref==3.2.3
# astor==0.8.1
# astropy==4.0
# atari-py==0.2.6
# atomicwrites==1.3.0
# attrs==19.3.0
# audioread==2.1.8
# autograd==1.3
# Babel==2.8.0
# backcall==0.1.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.6.3
# bleach==3.1.0
# blis==0.2.4
# bokeh==1.4.0
# boto==2.49.0
# boto3==1.10.47
# botocore==1.13.47
# Bottleneck==1.3.1
# branca==0.3.1
# bs4==0.0.1
# bz2file==0.98
# cachetools==4.0.0
# certifi==2019.11.28
# cffi==1.13.2
# chainer==6.5.0
# chardet==3.0.4
# chart-studio==1.0.0
# Click==7.0
# cloudpickle==1.2.2
# cmake==3.12.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.2.0
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.0
# cupy-cuda101==6.5.0
# cvxopt==1.2.3
# cvxpy==1.0.25
# cycler==0.10.0
# cymem==2.0.3
# Cython==0.29.14
# daft==0.0.4
# dask==2.9.1
# dataclasses==0.7
# datascience==0.10.6
# decorator==4.4.1
# defusedxml==0.6.0
# descartes==1.1.0
# dill==0.3.1.1
# distributed==1.25.3
# Django==3.0.2
# dlib==19.18.0
# dm-sonnet==1.35
# docopt==0.6.2
# docutils==0.15.2
# dopamine-rl==1.0.5
# earthengine-api==0.1.209
# easydict==1.9
# ecos==2.0.7.post1
# editdistance==0.5.3
# en-core-web-sm==2.1.0
# entrypoints==0.3
# et-xmlfile==1.0.1
# fa2==0.3.5
# fancyimpute==0.4.3
# fastai==1.0.60
# fastcache==1.1.0
# fastdtw==0.3.4
# fastprogress==0.2.2
# fastrlock==0.4
# fbprophet==0.5
# feather-format==0.4.0
# featuretools==0.4.1
# filelock==3.0.12
# fix-yahoo-finance==0.0.22
# Flask==1.1.1
# folium==0.8.3
# fsspec==0.6.2
# future==0.16.0
# gast==0.2.2
# GDAL==2.2.2
# gdown==3.6.4
# gensim==3.6.0
# geographiclib==1.50
# geopy==1.17.0
# gevent==1.4.0
# gin-config==0.3.0
# glob2==0.7
# google==2.0.3
# google-api-core==1.15.0
# google-api-python-client==1.7.11
# google-auth==1.4.2
# google-auth-httplib2==0.0.3
# google-auth-oauthlib==0.4.1
# google-cloud-bigquery==1.21.0
# google-cloud-core==1.0.3
# google-cloud-datastore==1.8.0
# google-cloud-language==1.2.0
# google-cloud-storage==1.16.2
# google-cloud-translate==1.5.0
# google-colab==1.0.0
# google-pasta==0.1.8
# google-resumable-media==0.4.1
# googleapis-common-protos==1.6.0
# googledrivedownloader==0.4
# graph-nets==1.0.5
# graphviz==0.10.1
# greenlet==0.4.15
# grpcio==1.15.0
# gspread==3.0.1
# gspread-dataframe==3.0.3
# gunicorn==20.0.4
# gym==0.15.4
# h5py==2.8.0
# HeapDict==1.0.1
# holidays==0.9.12
# html5lib==1.0.1
# httpimport==0.5.18
# httplib2==0.11.3
# humanize==0.5.1
# hyperopt==0.1.2
# ideep4py==2.0.0.post3
# idna==2.8
# image==1.5.27
# imageio==2.4.1
# imagesize==1.2.0
# imbalanced-learn==0.4.3
# imblearn==0.0
# imgaug==0.2.9
# importlib-metadata==1.4.0
# imutils==0.5.3
# inflect==2.1.0
# intel-openmp==2020.0.133
# intervaltree==2.1.0
# ipykernel==4.6.1
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# ipywidgets==7.5.1
# itsdangerous==1.1.0
# jax==0.1.52
# jaxlib==0.1.36
# jdcal==1.4.1
# jedi==0.15.2
# jieba==0.40
# Jinja2==2.10.3
# jmespath==0.9.4
# joblib==0.14.1
# jpeg4py==0.1.4
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==5.2.0
# jupyter-core==4.6.1
# kaggle==1.5.6
# kapre==0.1.3.1
# Keras==2.2.5
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# keras-vis==0.4.1
# kfac==0.2.0
# kiwisolver==1.1.0
# knnimpute==0.1.0
# librosa==0.6.3
# lightgbm==2.2.3
# llvmlite==0.31.0
# lmdb==0.98
# lucid==0.3.8
# lunardate==0.2.0
# lxml==4.2.6
# magenta==0.3.19
# Markdown==3.1.1
# MarkupSafe==1.1.1
# matplotlib==3.1.2
# matplotlib-venn==0.11.5
# mesh-tensorflow==0.1.8
# mido==1.2.6
# mir-eval==0.5
# missingno==0.4.2
# mistune==0.8.4
# mizani==0.6.0
# mkl==2019.0
# mlxtend==0.14.0
# mne==0.19.2
# more-itertools==8.0.2
# moviepy==0.2.3.5
# mpi4py==3.0.3
# mpmath==1.1.0
# msgpack==0.5.6
# multiprocess==0.70.9
# multitasking==0.0.9
# murmurhash==1.0.2
# music21==5.5.0
# natsort==5.5.0
# nbconvert==5.6.1
# nbformat==5.0.3
# networkx==2.4
# nibabel==2.3.3
# nltk==3.2.5
# notebook==5.2.2
# np-utils==0.5.12.1
# numba==0.47.0
# numexpr==2.7.1
# numpy==1.17.5
# nvidia-ml-py3==7.352.0
# oauth2client==4.1.3
# oauthlib==3.1.0
# okgrade==0.4.3
# opencv-contrib-python==4.1.2.30
# opencv-python==4.1.2.30
# openpyxl==2.5.9
# opt-einsum==3.1.0
# osqp==0.6.1
# packaging==20.0
# palettable==3.3.0
# pandas==0.25.3
# pandas-datareader==0.7.4
# pandas-gbq==0.11.0
# pandas-profiling==1.4.1
# pandocfilters==1.4.2
# parso==0.5.2
# pathlib==1.0.1
# patsy==0.5.1
# pexpect==4.7.0
# pickleshare==0.7.5
# Pillow==6.2.2
# pip-tools==4.2.0
# plac==0.9.6
# plotly==4.4.1
# plotnine==0.6.0
# pluggy==0.7.1
# portpicker==1.2.0
# prefetch-generator==1.0.1
# preshed==2.0.1
# pretty-midi==0.2.8
# prettytable==0.7.2
# progressbar2==3.38.0
# prometheus-client==0.7.1
# promise==2.3
# prompt-toolkit==1.0.18
# protobuf==3.10.0
# psutil==5.4.8
# psycopg2==2.7.6.1
# ptyprocess==0.6.0
# py==1.8.1
# pyarrow==0.14.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.7
# pycocotools==2.0.0
# pycparser==2.19
# pydata-google-auth==0.2.1
# pydot==1.3.0
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyEDFlib==0.1.15
# pyemd==0.5.1
# pyglet==1.3.2
# Pygments==2.1.3
# pygobject==3.26.1
# pymc3==3.7
# PyMeeus==0.3.6
# pymongo==3.10.0
# pymystem3==0.2.0
# PyOpenGL==3.1.5
# pyparsing==2.4.6
# pypng==0.0.20
# pyrsistent==0.15.7
# pysndfile==1.3.8
# PySocks==1.7.1
# pystan==2.19.1.1
# pytest==3.6.4
# python-apt==1.6.4
# python-chess==0.23.11
# python-dateutil==2.6.1
# python-louvain==0.13
# python-rtmidi==1.3.1
# python-slugify==4.0.0
# python-utils==2.3.0
# pytz==2018.9
# PyWavelets==1.1.1
# PyYAML==3.13
# pyzmq==17.0.0
# qtconsole==4.6.0
# regex==2019.12.20
# requests==2.21.0
# requests-oauthlib==1.3.0
# resampy==0.2.2
# retrying==1.3.3
# rpy2==2.9.5
# rsa==4.0
# s3fs==0.4.0
# s3transfer==0.2.1
# scikit-image==0.16.2
# scikit-learn==0.22.1
# scipy==1.4.1
# screen-resolution-extra==0.0.0
# scs==2.1.1.post2
# seaborn==0.9.0
# semantic-version==2.8.4
# Send2Trash==1.5.0
# setuptools-git==1.2
# Shapely==1.6.4.post2
# simplegeneric==0.8.1
# six==1.12.0
# sklearn==0.0
# sklearn-pandas==1.8.0
# smart-open==1.9.0
# snowballstemmer==2.0.0
# sortedcontainers==2.1.0
# spacy==2.1.9
# Sphinx==1.8.5
# sphinxcontrib-websupport==1.1.2
# SQLAlchemy==1.3.12
# sqlparse==0.3.0
# srsly==1.0.1
# stable-baselines==2.2.1
# statsmodels==0.10.2
# sympy==1.1.1
# tables==3.4.4
# tabulate==0.8.6
# tblib==1.6.0
# tensor2tensor==1.14.1
# tensorboard==1.15.0
# tensorboardcolab==0.0.22
# tensorflow==1.15.0
# tensorflow-datasets==1.3.2
# tensorflow-estimator==1.15.1
# tensorflow-gan==2.0.0
# tensorflow-hub==0.7.0
# tensorflow-metadata==0.15.2
# tensorflow-privacy==0.2.2
# tensorflow-probability==0.7.0
# termcolor==1.1.0
# terminado==0.8.3
# testpath==0.4.4
# text-unidecode==1.3
# textblob==0.15.3
# textgenrnn==1.4.1
# tflearn==0.3.2
# Theano==1.0.4
# thinc==7.0.8
# toolz==0.10.0
# torch==1.3.1
# torchsummary==1.5.1
# torchtext==0.3.1
# torchvision==0.4.2
# tornado==4.5.3
# tqdm==4.28.1
# traitlets==4.3.3
# tweepy==3.6.0
# typing==3.6.6
# typing-extensions==3.6.6
# tzlocal==1.5.1
# umap-learn==0.3.10
# uritemplate==3.0.1
# urllib3==1.24.3
# vega-datasets==0.8.0
# wasabi==0.6.0
# wcwidth==0.1.8
# webencodings==0.5.1
# Werkzeug==0.16.0
# widgetsnbextension==3.5.1
# wordcloud==1.5.0
# wrapt==1.11.2
# xarray==0.14.1
# xgboost==0.90
# xkit==0.0.0
# xlrd==1.1.0
# xlwt==1.3.0
# yellowbrick==0.9.1
# zict==1.0.0
# zipp==1.0.0
# zmq==0.0.0

# %%
from platform import python_version

print(python_version())
# Out:
# 3.6.9
