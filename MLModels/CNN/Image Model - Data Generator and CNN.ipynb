# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, Conv1D, MaxPooling1D, MaxPooling2D, AveragePooling2D, AveragePooling1D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout1D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm

import pandas as pd
import numpy as np
import random 

from importlib import reload  #reload(chart_builder)

# %%
generate_images = True
raw_data_dir = ''
acc_key = 'acc'
plot_examples = False # notebook file size will increase by 30 to 60MB if set to True; size is <1MB otherwise

if  'COLAB_GPU' in os.environ :
    print('Using Google Colab. Setting up environment')
    raw_data_dir = '/content/drive/My Drive/Colab Notebooks/' 
    # !pip install mne==0.19.2
    # !pip install pyedflib==0.1.15
    print('\n \n To load files from Google Drive, account validation is required.')
    # mount to drive -- files should be located in the /Colab Notebooks directory
    from google.colab import drive
    drive.mount("/content/drive", force_remount=True)
    
    # download project utilities and data reader 
    # !svn checkout https://github.com/WinAIML/schizophrenia/trunk/ReadData
    # !svn checkout https://github.com/WinAIML/schizophrenia/trunk/MLModels/utils

elif 'KAGGLE_URL_BASE' in os.environ:
    acc_key = 'accuracy'
    print('Using Kaggle kernel. Setting up environment')
    # !pip install mne==0.19.2
    # !pip install pyedflib==0.1.15
    # !pip install chart_studio==1.0.0
    # !svn checkout https://github.com/WinAIML/schizophrenia/trunk/Data/Raw
    raw_data_dir = 'Raw/'
    
    # download project utilities and data reader 
    # !svn checkout https://github.com/WinAIML/schizophrenia/trunk/ReadData
    # !svn checkout https://github.com/WinAIML/schizophrenia/trunk/MLModels/utils Utils


else:
    # assuming that a local run will be launched only from a github project; 
    # add the utils and ReadData directories to the temporary path
    if 'HOMEPATH' in os.environ:
        print('Using homepath ' + os.environ['HOMEPATH'])
    raw_data_dir = '../../Data/Raw/'
    
    from pathlib import Path
    import sys
    sys.path.append(os.path.realpath('..'))
    path = Path(os.getcwd())
    sys.path.append(str(path.parent.parent))


#################
# import project utilities and the raw data reader
# Kaggle environment does not accept 'utils' as a file, so it must be accessed seperately
import ReadData.RawDataReader as data_reader
if 'KAGGLE_URL_BASE' in os.environ:
    import Utils.ModelBuilder as model_builder
    import Utils.ChartBuilder as chart_builder
    
else:
    import utils.ModelBuilder as model_builder
    import utils.ChartBuilder as chart_builder
# Out:
# Using homepath \Users\marit
# C:\Users\marit\Anaconda3\lib\site-packages\numba\decorators.py:146: RuntimeWarning: Caching is not available when the 'parallel' target is in use. Caching is now being disabled to allow execution to continue.
#   warnings.warn(msg, RuntimeWarning)
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# %%capture
## ^^ do not display charts
import matplotlib.pyplot as plt 

class image_data_generator(object):

    def generate_spectrogram(self, data, save_chart=True, display_chart=False, file_name='test.png'):

        x = data
        NFFT = 256 # default value #24  # the length of the windowing segments
        Fs = 14 #   sampling frequency set to number of channels
        plt.ioff()
        plt.tick_params(
            axis='x',          # changes apply to the x-axis
            which='both',      # both major and minor ticks are affected
            bottom=False,      # ticks along the bottom edge are off
            top=False,         # ticks along the top edge are off
            labelbottom=False,
            labelleft=False) # labels along the bottom edge are off

        fig = plt.figure(figsize=(30, 40))
        ax = fig.add_subplot()

        Pxx, freqs, bins, im = ax.specgram(x, NFFT=NFFT, Fs=Fs)
        # The `specgram` method returns 4 objects. They are:
        # - Pxx: the periodogram
        # - freqs: the frequency vector
        # - bins: the centers of the time bins
        # - im: the matplotlib.image.AxesImage instance representing the data in the plot

        #plt.savefig(file_name)
        fig.savefig(file_name,bbox_inches='tight', transparent="True", pad_inches=0)
        if display_chart:
            plt.show()
            plt.close()

    #flatten data from all channels; group by time
    #X: 2-d array with channels as the second axis
    def flatten_data(self, X):
        x_adj = [] 
        for t in X:
            x_adj = np.append(x_adj, t)
        return x_adj

    def generate_image_files(self, batch, batch_labels, group_name):
        distinct_batch_labels = list(set(batch_labels))
        if not os.path.exists('gen_data/'+ group_name+'/'+distinct_batch_labels[0]):
            for dbl in distinct_batch_labels:
                os.makedirs('gen_data/'+group_name+'/'+ dbl)
        for i,sample in enumerate(batch):
            data_f = self.flatten_data(sample)
            label = batch_labels[i]
            self.generate_spectrogram(data_f, save_chart=True, #ImageDataGenerator expects files to be seperated by set/group and class
                                 file_name='gen_data/{}/{}/{}_{}.png'.format(group_name, label, group_name, i))

# %%
#reload(data_reader)
ignore_list = ['s12', 's14']  # List of patient files that should be skipped
resolution_hz = 250 # Hz resolution - number of frames per second; 250Hz is the selected value for the EEG dataset
time_window = resolution_hz * 20 # Seconds of data to include in one slice;

all_channels = ['Fp2', 'F8', 'T4', 'T6', 'O2', 'Fp1', 'F7', 'T3', 'T5', 'O1', 'F4',
                'C4', 'P4', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Pz']
excluded_channels = [ 'T3', 'T5', 'T6', 'O1', 'F3', 'Fp1', 'Fp2', 'P4']#F8'

chans=len(all_channels) - len(excluded_channels)

data = data_reader.get_raw_data(raw_data_dir, resolution_hz, ignore_list, 
                                excluded_channels, time_window)
# Out:
# Minimum duration:  740
# 'Shape of raw data for healthy controls: '
# (14, 125001, 11)
# 'Shape of raw data for schizophrenic patients: '
# (12, 125001, 11)
# Selecting training  / testing / validation sets randomly from patient data
# Splitting data into time windows to improve stability of results
# (10, 125001, 11)
# (250, 5000, 11)
# Shape of X_train:  (450, 5000, 11)
# Shape of X_validate:  (100, 5000, 11)
# Shape of X_test:  (100, 5000, 11)
# Removing outliers by channel
# Selected indexes for control group:
# Training:  [4, 7, 13, 2, 9, 6, 3, 1, 0, 5]
# Testing:  [11, 10]
# Validation:  [8, 12]
#
# Selected indexes for patient group:
# Training:  [9, 5, 1, 7, 10, 0, 3, 4]
# Testing:  [2, 8]
# Validation:  [11, 6]

# %%
# The first label should be the class that was originally set to 0 before one-hot encoding was applied;
# Healthy Controls in this case
def convert_one_hot_labels_to_strings(data_array, label_1, label_2):
    label_strings = []
    for label in data_array:
        if np.array_equal(label, [1., 0.]):
            string_label = label_1
        else:
            string_label = label_2
        label_strings.append(string_label)
    return label_strings

# %%
if generate_images:
    image_generator = image_data_generator()
    str_y_train = convert_one_hot_labels_to_strings(data['Y_train'],  'Healthy_Control', 'Sz_Patient')
    image_generator.generate_image_files(data['X_train'], str_y_train, 'train')
    str_y_validate = convert_one_hot_labels_to_strings(data['Y_validate'], 'Healthy_Control', 'Sz_Patient')
    image_generator.generate_image_files(data['X_validate'], str_y_validate, 'validate')
    str_y_test = convert_one_hot_labels_to_strings(data['Y_test'], 'Healthy_Control', 'Sz_Patient')
    image_generator.generate_image_files(data['X_test'], str_y_test, 'test')
    #generate_image_files(x_test[:2], 'gen_test')
# Out:
# C:\Users\marit\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
if plot_examples:
    print ('TO DO: implement display of image files')
    #random_selection =  data_reader.get_random_participants(raw_data_dir, data, ignore_list, resolution_hz)
    #chart_builder.plot_random_participants(data, ignore_list, excluded_channels, all_channels, random_selection)

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint


# Construct a learning rate scheduler such that the lr is decreased when the loss remains unchanged after 4 epochs
# Adapted from https://towardsdatascience.com/learning-rate-schedules-and-adaptive-learning-rate-methods-for-deep-learning-2c8f433990d1
class LossHistory(tf.keras.callbacks.Callback):
    def __init__(self):
        self.losses = []
        self.lr = []
        self.last_loss_improvement = None
        self.loss_unchanged_count = 0

    def on_train_begin(self, logs={}):
        self.losses = []
        self.lr = []
        self.last_loss_improvement = 1.0
        self.loss_unchanged_count = 0

    def on_epoch_end(self, batch, logs={}):
        epoch_loss = logs.get('val_loss')
        # track if losses are being updated
        if (len(self.losses) > 1) and ((epoch_loss == self.losses[-1]) or (epoch_loss > self.last_loss_improvement)):
            self.loss_unchanged_count += 1
        else:
            self.loss_unchanged_count = 0
            self.last_loss_improvement = epoch_loss

        self.losses.append(epoch_loss)

    # Implement the lr_loss_scheduler within the class so that it can access loss_unchanged_count
    def on_epoch_begin(self, batch,
                       logs={}):
        if self.loss_unchanged_count > 3:
            self.loss_unchanged_count = 0  # reset
            current_lr = K.get_value(self.model.optimizer.lr)
            lr = current_lr - (current_lr / 2)  # decrement lr by 50% of current value
            K.set_value(self.model.optimizer.lr, lr)  # set for the model
            print('Updated learning rate to ', lr)
            # return K.get_value(self.model.optimizer.lr)

            
def rmse (y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred -y_true)))

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import math


from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Dropout, Bidirectional
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.layers import Conv2D, Conv1D, MaxPooling2D, MaxPooling1D, AveragePooling2D, AveragePooling1D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.models import Sequential



# https://theailearner.com/2019/07/06/binary-classification/
sub_dir = 'gen_data' #'oxford_flower_dataset_subset'#
batch_size = 20
img_width, img_height = 150, 150

train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(sub_dir + '/train/',target_size=(img_width,img_height),
                                                    batch_size=batch_size,class_mode='binary',interpolation='bilinear')
validation_generator = validation_datagen.flow_from_directory(sub_dir + '/validate/',target_size=(img_width,img_height),
                                                    batch_size=batch_size,class_mode='binary',interpolation='bilinear')
test_generator = test_datagen.flow_from_directory(sub_dir + '/test/',target_size=(img_width,img_height),
                                                  batch_size=batch_size,class_mode='binary',interpolation='bilinear')

from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Dropout
from tensorflow.keras.models import Sequential

def image_cnn_model(img_width, img_height):
    model = Sequential()
    model.add(Conv2D(32,(3,3),activation='relu',input_shape=(img_width,img_height,3)))
    model.add(MaxPool2D((2,2)))
    model.add(Dropout(0.5))
    model.add(Conv2D(32,(3,3),activation='relu'))
    model.add(MaxPool2D((2,2)))
    model.add(Dropout(0.5))
    #model.add(Conv2D(64,(3,3),activation='relu'))
    #model.add(MaxPool2D((2,2)))
    #model.add(Dropout(0.5))
    model.add(Conv2D(64,(3,3),activation='relu'))
    model.add(MaxPool2D((2,2)))
    model.add(Dropout(0.75))
    model.add(Flatten())
    model.add(Dense(36,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    
    return model
# Out:
# Found 450 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
import tensorflow.keras.backend as K

model = image_cnn_model(img_width, img_height)
model.summary()

def rmse (y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred -y_true)))
metrics = ['accuracy', rmse]

image_cnn_opt_adam = tf.keras.optimizers.Adam(lr=0.0007, 
                                beta_1=0.95,
                                beta_2=0.89,
                                epsilon=1e-07)

model.compile(loss='binary_crossentropy', optimizer=image_cnn_opt_adam, metrics=metrics)

filepath = 'img_cnn_weights.hdf5'

checkpoint = ModelCheckpoint(filepath, #monitor='val_acc', 
                             verbose=0, save_best_only=True, save_weights_only=True, mode='auto',period=1)

history = model.fit_generator(train_generator, steps_per_epoch=math.floor(train_generator.samples // batch_size), 
                                            epochs=100, validation_data=validation_generator,
                                            validation_steps=math.floor(validation_generator.samples // batch_size),  
                                                                        callbacks=[checkpoint])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 36, 36, 32)        0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 36)                665892
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 37
# =================================================================
# Total params: 694,569
# Trainable params: 694,569
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 5/5 [==============================] - 11s 2s/step - loss: 0.6928 - acc: 0.5000 - rmse: 0.4998
# 23/23 [==============================] - 80s 3s/step - loss: 0.8066 - acc: 0.5267 - rmse: 0.5239 - val_loss: 0.6928 - val_acc: 0.5000 - val_rmse: 0.4998
# Epoch 2/100
# 5/5 [==============================] - 12s 2s/step - loss: 0.6916 - acc: 0.5000 - rmse: 0.4992
# 23/23 [==============================] - 59s 3s/step - loss: 0.6942 - acc: 0.5556 - rmse: 0.5003 - val_loss: 0.6916 - val_acc: 0.5000 - val_rmse: 0.4992
# Epoch 3/100
# 5/5 [==============================] - 16s 3s/step - loss: 0.6918 - acc: 0.5000 - rmse: 0.4993
# 23/23 [==============================] - 86s 4s/step - loss: 0.6861 - acc: 0.5556 - rmse: 0.4964 - val_loss: 0.6918 - val_acc: 0.5000 - val_rmse: 0.4993
# Epoch 4/100
# 5/5 [==============================] - 17s 3s/step - loss: 0.6900 - acc: 0.5000 - rmse: 0.4984
# 23/23 [==============================] - 94s 4s/step - loss: 0.6851 - acc: 0.5556 - rmse: 0.4958 - val_loss: 0.6900 - val_acc: 0.5000 - val_rmse: 0.4984
# Epoch 5/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.6880 - acc: 0.5000 - rmse: 0.4974
# 23/23 [==============================] - 71s 3s/step - loss: 0.6846 - acc: 0.5556 - rmse: 0.4956 - val_loss: 0.6880 - val_acc: 0.5000 - val_rmse: 0.4974
# Epoch 6/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.6833 - acc: 0.5000 - rmse: 0.4951
# 23/23 [==============================] - 72s 3s/step - loss: 0.6716 - acc: 0.5556 - rmse: 0.4890 - val_loss: 0.6833 - val_acc: 0.5000 - val_rmse: 0.4951
# Epoch 7/100
# 5/5 [==============================] - 13s 3s/step - loss: 0.6653 - acc: 0.5000 - rmse: 0.4859
# 23/23 [==============================] - 77s 3s/step - loss: 0.6581 - acc: 0.5556 - rmse: 0.4822 - val_loss: 0.6653 - val_acc: 0.5000 - val_rmse: 0.4859
# Epoch 8/100
# 5/5 [==============================] - 14s 3s/step - loss: 0
100
# 5/5 [==============================] - 14s 3s/step - loss: 0.5491 - acc: 0.7100 - rmse: 0.4164
# 23/23 [==============================] - 76s 3s/step - loss: 0.2101 - acc: 0.9556 - rmse: 0.2292 - val_loss: 0.5491 - val_acc: 0.7100 - val_rmse: 0.4164
# Epoch 93/100
# 5/5 [==============================] - 16s 3s/step - loss: 0.5975 - acc: 0.6600 - rmse: 0.4527
# 23/23 [==============================] - 80s 3s/step - loss: 0.2072 - acc: 0.9511 - rmse: 0.2336 - val_loss: 0.5975 - val_acc: 0.6600 - val_rmse: 0.4527
# Epoch 94/100
# 5/5 [==============================] - 16s 3s/step - loss: 0.6417 - acc: 0.6700 - rmse: 0.4575
# 23/23 [==============================] - 73s 3s/step - loss: 0.2083 - acc: 0.9578 - rmse: 0.2316 - val_loss: 0.6417 - val_acc: 0.6700 - val_rmse: 0.4575
# Epoch 95/100
# 5/5 [==============================] - 13s 3s/step - loss: 0.5994 - acc: 0.7200 - rmse: 0.4465
# 23/23 [==============================] - 68s 3s/step - loss: 0.2124 - acc: 0.9556 - rmse: 0.2257 - val_loss: 0.5994 - val_acc: 0.7200 - val_rmse: 0.4465
# Epoch 96/100
# 5/5 [==============================] - 16s 3s/step - loss: 0.5929 - acc: 0.7200 - rmse: 0.4500
# 23/23 [==============================] - 72s 3s/step - loss: 0.1881 - acc: 0.9578 - rmse: 0.2170 - val_loss: 0.5929 - val_acc: 0.7200 - val_rmse: 0.4500
# Epoch 97/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.6251 - acc: 0.6800 - rmse: 0.4539
# 23/23 [==============================] - 76s 3s/step - loss: 0.1881 - acc: 0.9622 - rmse: 0.2134 - val_loss: 0.6251 - val_acc: 0.6800 - val_rmse: 0.4539
# Epoch 98/100
# 5/5 [==============================] - 15s 3s/step - loss: 0.6010 - acc: 0.6700 - rmse: 0.4428
# 23/23 [==============================] - 73s 3s/step - loss: 0.1989 - acc: 0.9556 - rmse: 0.2178 - val_loss: 0.6010 - val_acc: 0.6700 - val_rmse: 0.4428
# Epoch 99/100
# 5/5 [==============================] - 14s 3s/step - loss: 0.5728 - acc: 0.6900 - rmse: 0.4371
# 23/23 [==============================] - 77s 3s/step - loss: 0.2049 - acc: 0.9644 - rmse: 0.2173 - val_loss: 0.5728 - val_acc: 0.6900 - val_rmse: 0.4371
# Epoch 100/100
# 5/5 [==============================] - 16s 3s/step - loss: 0.5388 - acc: 0.7300 - rmse: 0.4126
# 23/23 [==============================] - 75s 3s/step - loss: 0.2419 - acc: 0.9311 - rmse: 0.2411 - val_loss: 0.5388 - val_acc: 0.7300 - val_rmse: 0.4126

# %%
#https://github.com/wtfleming/jupyter-notebooks-public/blob/master/dogs-vs-cats/dogs-vs-cats-part-2.ipynb
import matplotlib.pyplot as plt

def plot_accuracy_and_loss(history):
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, acc, 'bo', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.legend()
    plt.show()

    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()
    plt.show()
    
plot_accuracy_and_loss(history)

# %%
#https://wtfleming.github.io/2019/05/12/keras-cats-vs-dogs-part-2/
    
test_generator = test_datagen.flow_from_directory(
    sub_dir + '/test/',
    target_size=(img_width,img_height),
    batch_size=batch_size,
    class_mode='binary')

test_loss, test_acc, test_rmse = model.evaluate_generator(test_generator, steps=90)
print('Test accuracy: {0:.2f}%   | Test loss: {1:.5f} | Test RMSE: {2:.5f}'.format(test_acc * 100, test_loss, test_rmse))
# Out:
# Found 100 images belonging to 2 classes.
# Test accuracy: 68.00%   | Test loss: 0.51177 | Test RMSE: 0.41339

# %%
train_generator.samples
# Out:
# 450

# %%
# !pip freeze
# Out:
# absl-py==0.9.0
# affine==2.3.0
# aiohttp==3.6.2
# alabaster==0.7.12
# albumentations==0.4.3
# alembic==1.4.1
# allennlp==0.9.0
# altair==4.0.1
# anaconda-client==1.7.2
# anaconda-navigator==1.9.12
# anaconda-project==0.8.3
# annoy==1.16.3
# appdirs==1.4.3
# arrow==0.15.5
# arviz==0.7.0
# asn1crypto==1.3.0
# astor==0.8.1
# astroid==2.3.3
# astropy==3.2.3
# async-timeout==3.0.1
# atomicwrites==1.3.0
# attr==0.3.1
# attrs==19.3.0
# audioread==2.1.8
# aws-requests-auth==0.4.2
# Babel==2.8.0
# backcall==0.1.0
# backports.functools-lru-cache==1.6.1
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# Baker==1.3
# basemap==1.2.0
# bayesian-optimization==1.1.0
# bayespy==0.5.19
# bcolz==1.2.1
# beautifulsoup4==4.8.2
# biopython==1.76
# bitarray==1.2.1
# bkcharts==0.2
# bleach==3.1.0
# blis==0.4.1
# bokeh==1.4.0
# Boruta==0.3
# boto==2.49.0
# boto3==1.12.13
# botocore==1.15.13
# Bottleneck==1.3.2
# -e git+https://github.com/SohierDane/BigQuery_Helper@8615a7f6c1663e7f2d48aa2b32c2dbcb600a440f#egg=bq_helper
# bqplot==0.12.4
# branca==0.4.0
# brewer2mpl==1.4.1
# bs4==0.0.1
# cachetools==4.0.0
# cairocffi==1.1.0
# CairoSVG==2.4.2
# Cartopy==0.17.0
# catalogue==1.0.0
# catalyst==20.2.4
# catboost==0.22
# category-encoders==2.1.0
# certifi==2019.11.28
# cesium==0.9.12
# cffi==1.14.0
# cftime==1.1.0
# chainer==7.2.0
# chainer-chemistry==0.7.0
# chainercv==0.13.1
# chardet==3.0.4
# chart-studio==1.0.0
# cleverhans==3.0.1
# Click==7.0
# click-plugins==1.1.1
# cliff==3.0.0
# cligj==0.5.0
# cloudpickle==1.3.0
# clyent==1.2.2
# cmd2==0.8.9
# cmdstanpy==0.4.0
# cmudict==0.4.4
# colorama==0.4.3
# colorcet==2.0.2
# colorlog==4.1.0
# colorlover==0.3.0
# conda==4.8.2
# conda-build==3.18.11
# conda-package-handling==1.6.0
# conda-verify==3.4.2
# ConfigArgParse==1.0
# configparser==4.0.2
# confuse==1.0.0
# conllu==1.3.1
# contextily==1.0rc2
# contextlib2==0.6.0.post1
# convertdate==2.2.0
# conx==3.7.10
# coverage==5.0.3
# crc32c==2.0
# cryptography==2.3.1
# cssselect2==0.2.2
# cufflinks==0.17.3
# cupy-cuda101==7.2.0
# CVXcanon==0.1.1
# cvxpy==1.0.28
# cycler==0.10.0
# cymem==2.0.3
# cysignals==1.10.2
# Cython==0.29.15
# cytoolz==0.10.1
# dask==2.11.0
# dask-glm==0.2.0
# dask-ml==1.2.0
# dask-xgboost==0.1.10
# dataclasses==0.7
# datashader==0.10.0
# datashape==0.5.2
# deap==1.3.1
# decorator==4.4.1
# deepdish==0.3.6
# defusedxml==0.6.0
# Delorean==1.0.0
# Deprecated==1.2.7
# descartes==1.1.0
# dill==0.3.1.1
# dipy==1.1.1
# distributed==2.10.0
# dlib==19.19.0
# docker-pycreds==0.4.0
# docopt==0.6.2
# docutils==0.15.2
# dora==0.1
# earthengine-api==0.1.213
# ecos==2.0.7.post1
# editdistance==0.5.3
# edward==1.3.5
# eli5==0.10.1
# emoji==0.5.4
# en-core-web-lg==2.2.5
# en-core-web-sm==2.2.5
# entrypoints==0.3
# ephem==3.7.7.1
# esda==2.2.1
# essentia==2.1b6.dev184
# et-xmlfile==1.0.1
# fancyimpute==0.5.4
# fastai==1.0.60
# fastcache==1.1.0
# fasteners==0.14.1
# fastFM==0.2.11
# fastprogress==0.2.2
# fastrlock==0.4
# fasttext==0.9.1
# fbpca==1.0
# fbprophet==0.6
# feather-format==0.4.0
# featuretools==0.13.3
# filelock==3.0.12
# Fiona==1.8.13.post1
# fitter==1.2.0
# flake8==3.7.9
# flaky==3.6.1
# flashtext==2.7
# Flask==1.1.1
# Flask-Cors==3.0.8
# Flask-JSON==0.3.4
# folium==0.10.1
# fsspec==0.6.2
# ftfy==5.7
# funcsigs==1.0.2
# funcy==1.14
# fury==0.4.0
# future==0.18.2
# fuzzywuzzy==0.18.0
# gast==0.2.2
# gatspy==0.3
# gensim==3.8.1
# geographiclib==1.50
# Geohash==1.0
# geojson==2.5.0
# geopandas==0.6.3
# geoplot==0.4.0
# geopy==1.21.0
# geoviews==1.6.1
# gevent==1.4.0
# ggplot==0.11.5
# giddy==2.3.0
# gitdb==4.0.2
# GitPython==3.1.0
# glmnet-py==0.1.0b2
# glob2==0.7
# gluoncv==0.6.0
# gluonnlp==0.9.1
# gmpy2==2.0.8
# google==2.0.3
# google-api-core==1.16.0
# google-api-python-client==1.7.11
# google-auth==1.11.2
# google-auth-httplib2==0.0.3
# google-auth-oauthlib==0.4.1
# google-cloud-automl==0.10.0
# google-cloud-bigquery==1.12.1
# google-cloud-core==1.3.0
# google-cloud-storage==1.26.0
# google-pasta==0.1.8
# google-resumable-media==0.5.0
# googleapis-common-protos==1.51.0
# gplearn==0.4.1
# gpxpy==1.4.0
# gql==0.2.0
# graphql-core==1.1
# graphviz==0.8.4
# greenlet==0.4.15
# grpcio==1.27.2
# gym==0.17.0
# h2o==3.28.0.4
# h2o-client==3.28.0.4
# h5py==2.10.0
# hallucinate==0.0.1
# haversine==2.2.0
# heamy==0.0.7
# HeapDict==1.0.1
# hep-ml==0.6.0
# hmmlearn==0.2.3
# holidays==0.9.12
# holoviews==1.12.7
# hpsklearn==0.1.0
# html5lib==1.0.1
# htmlmin==0.1.12
# httplib2==0.17.0
# httplib2shim==0.0.3
# humanize==1.0.0
# hunspell==0.5.5
# husl==4.0.3
# hyperopt==0.2.3
# hypertools==0.6.2
# hypothesis==5.5.4
# ibis-framework==1.3.0
# idna==2.8
# idna-ssl==1.1.0
# imagecodecs==2020.2.18
# ImageHash==4.0
# imageio==2.6.1
# imagesize==1.2.0
# imbalanced-learn==0.6.2
# imgaug==0.2.6
# implicit==0.4.2
# importlib-metadata==1.5.0
# inequality==1.0.0
# ipykernel==5.1.1
# ipython==7.12.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# iso3166==1.0.1
# isort==4.3.21
# isoweek==1.3.3
# itsdangerous==1.1.0
# Janome==0.3.10
# jax==0.1.59
# jaxlib==0.1.38
# jdcal==1.4.1
# jedi==0.16.0
# jeepney==0.4.2
# jieba==0.42.1
# Jinja2==2.11.1
# jmespath==0.9.5
# joblib==0.14.1
# json5==0.9.1
# jsonlines==1.2.0
# jsonnet==0.15.0
# jsonpickle==1.3
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==6.1.0
# jupyter-core==4.6.1
# jupyterlab==1.2.6
# jupyterlab-server==1.0.6
# kaggle==1.5.6
# kaggle-environments==0.1.6
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# keras-rcnn==0.0.2
# keras-resnet==0.2.0
# keras-rl==0.4.2
# keras-tqdm==2.0.1
# keyring==21.1.0
# kiwisolver==1.1.0
# kmapper==1.2.0
# kmeans-smote==0.1.2
# kmodes==0.10.2
# knnimpute==0.1.0
# langdetect==1.0.7
# langid==1.1.6
# Lasagne==0.2.dev1
# lazy-object-proxy==1.4.3
# learntools==0.3.4
# leven==1.0.4
# libarchive-c==2.8
# libpysal==4.2.2
# librosa==0.7.2
# lief==0.9.0
# lightfm==1.15
# lightgbm==2.3.1
# lime==0.1.1.37
# line-profiler==3.0.2
# llvmlite==0.31.0
# lml==0.0.9
# locket==0.2.0
# LunarCalendar==0.0.9
# lxml==4.5.0
# lz4==2.1.2
# Mako==1.1.2
# mapclassify==2.2.0
# marisa-trie==0.7.5
# Markdown==3.2.1
# markovify==0.8.0
# MarkupSafe==1.1.1
# matplotlib==3.0.3
# matplotlib-venn==0.11.5
# mccabe==0.6.1
# memory-profiler==0.57.0
# mercantile==1.1.2
# mgwr==2.1.1
# missingno==0.4.2
# mistune==0.8.4
# mizani==0.6.0
# mkl-fft==1.0.12
# mkl-random==1.0.2
# mkl-service==2.0.2
# ml-metrics==0.1.4
# mlcrate==0.2.0
# mlens==0.2.3
# mlxtend==0.17.2
# mmh3==2.5.1
# mne==0.19.2
# mnist==0.2.2
# mock==4.0.1
# monotonic==1.5
# more-itertools==8.2.0
# mpld3==0.3
# mplleaflet==0.0.5
# mpmath==1.1.0
# msgpack==0.6.1
# msgpack-numpy==0.4.4.3
# multidict==4.7.5
# multipledispatch==0.6.0
# multiprocess==0.70.9
# munch==2.5.0
# murmurhash==1.0.2
# mxnet-cu101==1.6.0
# navigator-updater==0.2.1
# nbconvert==5.6.1
# nbformat==5.0.4
# nervananeon==2.6.0
# netCDF4==1.5.3
# networkx==2.4
# nibabel==3.0.1
# nilearn==0.6.2
# nltk==3.2.4
# nnabla==1.5.0
# nnabla-ext-cuda101==1.5.0
# nolearn==0.6.2.dev0
# nose==1.3.7
# notebook==5.5.0
# numba==0.48.0
# numdifftools==0.9.39
# numexpr==2.6.9
# numpy==1.18.1
# numpydoc==0.9.2
# nvidia-ml-py3==7.352.0
# oauthlib==3.1.0
# odfpy==1.4.1
# olefile==0.46
# onnx==1.6.0
# opencv-python==4.2.0.32
# openpyxl==3.0.3
# opt-einsum==3.2.0
# optuna==1.1.0
# orderedmultidict==1.0.1
# ortools==7.5.7466
# osmnx==0.10
# osqp==0.6.1
# overrides==2.8.0
# packaging==20.1
# palettable==3.3.0
# pandas==0.25.3
# pandas-datareader==0.8.1
# pandas-profiling==2.5.0
# pandas-summary==0.0.7
# pandasql==0.7.3
# pandoc==1.0.2
# pandocfilters==1.4.2
# param==1.9.3
# paramnb==2.0.4
# parsimonious==0.8.1
# parso==0.6.1
# partd==1.1.0
# path==13.1.0
# path.py==12.4.0
# pathlib2==2.3.5
# pathos==0.2.5
# pathtools==0.1.2
# patsy==0.5.1
# pbr==5.4.4
# pdf2image==1.12.1
# PDPbox==0.2.0+13.g73c6966
# pep8==1.7.1
# pexpect==4.8.0
# phik==0.9.9
# pickleshare==0.7.5
# Pillow==5.4.1
# pkginfo==1.5.0.1
# plac==0.9.6
# plotly==4.5.2
# plotly-express==0.4.1
# plotnine==0.4.0
# pluggy==0.13.1
# ply==3.11
# pointpats==2.1.0
# polyglot==16.7.4
# portalocker==1.5.2
# posix-ipc==1.0.4
# pox==0.2.7
# ppca==0.0.4
# ppft==1.6.6.1
# preprocessing==0.1.13
# preshed==3.0.2
# prettytable==0.7.2
# progressbar==2.5
# progressbar2==3.50.0
# prometheus-client==0.7.1
# promise==2.3
# prompt-toolkit==3.0.3
# pronouncing==0.2.0
# protobuf==3.11.3
# psutil==5.6.7
# ptyprocess==0.6.0
# pudb==2019.2
# py==1.8.1
# py-cpuinfo==5.0.0
# py-lz4framed==0.14.0
# py-spy==0.3.3
# py-stringmatching==0.4.1
# py-stringsimjoin==0.3.1
# pyahocorasick==1.4.0
# pyaml==19.12.0
# PyArabic==0.6.6
# pyarrow==0.16.0
# pyasn1==0.4.8
# pyasn1-modules==0.2.8
# PyAstronomy==0.14.0
# pybind11==2.4.3
# PyBrain==0.3.3
# pycairo==1.18.0
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycountry==19.8.18
# pycparser==2.19
# pycrypto==2.6.1
# pyct==0.4.6
# pycuda==2019.1.2
# pycurl==7.43.0.2
# pydash==4.7.6
# pydicom==1.4.2
# pydot==1.4.1
# pyeconometrics==1.0.2
# pyEDFlib==0.1.17
# pyemd==0.5.1
# pyexcel-io==0.5.20
# pyexcel-ods==0.5.6
# pyfasttext==0.4.6
# pyflakes==2.1.1
# pyflux==0.4.15
# pyglet==1.5.0
# Pygments==2.5.2
# pykalman==0.9.5
# pykoko==0.1.8
# pyLDAvis==2.1.2
# pylint==2.4.4
# pymagnitude==0.1.120
# pymc3==3.8
# PyMeeus==0.3.7
# pymongo==3.10.1
# Pympler==0.8
# pynvrtc==9.2
# pyocr==0.7.2
# pyodbc===4.0.0-unsupported
# PyOpenGL==3.1.5
# pyOpenSSL==19.0.0
# pypandoc==1.4
# pyparsing==2.4.6
# pyPdf==1.13
# pyperclip==1.7.0
# PyPrind==2.11.2
# pyproj==2.5.0
# pyrsistent==0.15.7
# pysal==2.2.0
# pyshp==2.1.0
# PySocks==1.7.1
# pystan==2.19.1.1
# pytagcloud==0.3.5
# pytesseract==0.3.2
# pytest==5.0.1
# pytest-arraydiff==0.3
# pytest-astropy==0.8.0
# pytest-astropy-header==0.1.2
# pytest-cov==2.8.1
# pytest-doctestplus==0.5.0
# pytest-mock==2.0.0
# pytest-openfiles==0.4.0
# pytest-pylint==0.15.0
# pytest-remotedata==0.3.2
# pytext-nlp==0.1.2
# python-dateutil==2.8.0
# python-editor==1.0.4
# python-igraph==0.7.1.post7
# python-Levenshtein==0.12.0
# python-louvain==0.13
# python-slugify==4.0.0
# python-utils==2.4.0
# pytools==2020.1
# pytorch-ignite==0.3.0
# pytorch-pretrained-bert==0.6.2
# pytorch-transformers==1.1.0
# pytz==2019.3
# PyUpSet==0.1.1.post7
# pyviz-comms==0.7.3
# PyWavelets==1.1.1
# PyYAML==5.3
# pyzmq==18.1.1
# qgrid==1.3.0
# QtAwesome==0.6.1
# qtconsole==4.6.0
# QtPy==1.9.0
# quantecon==0.4.6
# quilt3==3.1.8
# raccoon==3.0.0
# randomgen==1.16.6
# rasterio==1.1.3
# rasterstats==0.14.0
# ray==0.8.2
# redis==3.4.1
# regex==2020.2.20
# requests==2.22.0
# requests-futures==1.0.0
# requests-oauthlib==1.3.0
# resampy==0.2.2
# responses==0.10.12
# retrying==1.3.3
# revrand==0.6.5
# rf-perm-feat-import==0.1
# rgf-python==3.7.0
# rope==0.16.0
# rsa==4.0
# Rtree==0.8.3
# ruamel-yaml==0.15.87
# ruamel.yaml.clib==0.2.0
# s2sphere==0.2.5
# s3fs==0.4.0
# s3transfer==0.3.3
# sacred==0.8.1
# sacremoses==0.0.38
# safitty==1.3
# scattertext==0.0.2.59
# scikit-image==0.16.2
# scikit-learn==0.22.2.post1
# scikit-multilearn==0.2.0
# scikit-optimize==0.7.4
# scikit-plot==0.3.7
# scikit-surprise==1.1.0
# scipy==1.4.1
# scs==2.1.1.post2
# seaborn==0.10.0
# SecretStorage==3.1.2
# segregation==1.2.0
# Send2Trash==1.5.0
# sentencepiece==0.1.85
# sentry-sdk==0.14.2
# setuptools-git==1.2
# shap==0.35.0
# Shapely==1.7.0
# shortuuid==0.5.0
# simplegeneric==0.8.1
# SimpleITK==1.2.4
# simplejson==3.17.0
# singledispatch==3.4.0.3
# six==1.14.0
# sklearn==0.0
# sklearn-contrib-lightning==0.5.0
# sklearn-contrib-py-earth==0.1.0+1.gdde5f89
# sklearn-pandas==1.8.0
# smart-open==1.9.0
# smhasher==0.150.1
# smmap==3.0.1
# snowballstemmer==2.0.0
# snuggs==1.4.7
# sortedcollections==1.1.2
# sortedcontainers==2.1.0
# SoundFile==0.10.3.post1
# soupsieve==1.9.5
# spacy==2.2.3
# spaghetti==1.4.2.post2
# spectral==0.20
# speedml==0.9.3
# spglm==1.0.7
# Sphinx==2.4.0
# sphinx-rtd-theme==0.2.4
# sphinxcontrib-applehelp==1.0.1
# sphinxcontrib-devhelp==1.0.1
# sphinxcontrib-htmlhelp==1.0.2
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.2
# sphinxcontrib-serializinghtml==1.1.3
# sphinxcontrib-websupport==1.2.0
# spint==1.0.6
# splot==1.1.2
# spreg==1.1.1
# spvcm==0.3.0
# spyder==3.3.6
# spyder-kernels==0.5.2
# SQLAlchemy==1.3.13
# sqlparse==0.3.1
# squarify==0.4.3
# srsly==1.0.2
# statsmodels==0.11.0
# stemming==1.0.1
# stevedore==1.32.0
# stop-words==2018.7.23
# stopit==1.1.2
# subprocess32==3.5.4
# svgwrite==1.3.1
# sympy==1.5.1
# tables==3.5.1
# tabulate==0.8.6
# tangled-up-in-unicode==0.0.3
# tblib==1.6.0
# tensorboard==2.1.1
# tensorboardX==2.0
# tensorflow==2.1.0
# tensorflow-estimator==2.1.0
# tensorflow-hub==0.7.0
# tensorflow-probability==0.9.0
# Tensorforce==0.5.4
# tensorpack==0.9.8
# termcolor==1.1.0
# terminado==0.8.3
# terminalplot==0.3.0
# testpath==0.4.4
# text-unidecode==1.3
# textblob==0.15.3
# tflearn==0.3.2
# Theano==1.0.4+34.g473d74ea4
# thinc==7.3.1
# tifffile==2020.2.16
# tinycss2==1.0.2
# tobler==0.2.1
# tokenizers==0.5.2
# toolz==0.10.0
# torch==1.4.0
# torchaudio==0.4.0a0+719bcc7
# torchtext==0.5.0
# torchvision==0.5.0
# tornado==5.0.2
# TPOT==0.11.1
# tqdm==4.42.0
# trackml==0.1.12
# traitlets==4.3.3
# traittypes==0.2.1
# transformers==2.5.1
# trueskill==0.4.5
# tsfresh==0.14.1
# typed-ast==1.4.1
# typing==3.6.4
# typing-extensions==3.7.4.1
# tzlocal==2.0.0
# umap-learn==0.3.10
# unicodecsv==0.14.1
# Unidecode==1.1.1
# update-checker==0.16
# uritemplate==3.0.1
# urllib3==1.24.3
# urwid==2.1.0
# vecstack==0.4.0
# vega3==0.13.0
# vida==0.3
# visions==0.2.2
# visvis==1.12.2
# vowpalwabbit==8.8.1
# vtk==8.1.2
# Wand==0.5.3
# wandb==0.8.28
# wasabi==0.6.0
# watchdog==0.10.2
# watermark==2.0.2
# wavio==0.0.4
# wcwidth==0.1.8
# webencodings==0.5.1
# websocket-client==0.57.0
# Werkzeug==1.0.0
# wfdb==2.2.1
# widgetsnbextension==3.5.1
# word2number==1.1
# Wordbatch==1.4.4
# wordcloud==1.6.0
# wordsegment==1.3.1
# wrapt==1.11.2
# wurlitzer==2.0.0
# xarray==0.15.0
# xgboost==1.0.2
# xlrd==1.2.0
# XlsxWriter==1.2.7
# xlwt==1.3.0
# xmltodict==0.12.0
# xvfbwrapper==0.2.9
# xxhash==1.3.0
# yarl==1.4.2
# yellowbrick==1.1
# zict==1.0.0
# zipp==2.2.0

# %%
from platform import python_version

print(python_version())
# Out:
# 3.6.6
