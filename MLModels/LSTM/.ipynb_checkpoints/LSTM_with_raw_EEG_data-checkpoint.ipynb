# %%
import os
raw_data_dir = ''

if  'COLAB_GPU' in os.environ:
    print('Using Google Colab. Setting up environment')
    raw_data_dir = '/content/drive/My Drive/Colab Notebooks/' 
    # !pip install mne
    # !pip install pyedflib

    print('\n \n To load files from Google Drive, account validation is required.')
    #mount to drive -- files should be located in the Colab notebooks directory
    from google.colab import drive
    drive.mount("/content/drive", force_remount=True)
else:
    if 'HOMEPATH' in os.environ:
        print('Using homepath ' + os.environ['HOMEPATH'])
    raw_data_dir = '../../Data/Raw/'
# Out:
# Using homepath \Users\marit

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

import pandas as pd
import pyedflib


import tensorflow as tf
use_gpu = tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)


import numpy as np

# mne imports
import mne
from mne import io

# EEGNet-specific imports
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint


# tools for plotting confusion matrices
from matplotlib import pyplot as plt

import random 
import math
# Out:
# C:\Users\marit\Anaconda3\lib\site-packages\numba\decorators.py:146: RuntimeWarning: Caching is not available when the 'parallel' target is in use. Caching is now being disabled to allow execution to continue.
#   warnings.warn(msg, RuntimeWarning)

# %%
from tensorflow.keras import layers
#https://www.tensorflow.org/guide/keras/rnn

def LSTM(samples, time_steps, nb_features, chans, nb_classes):

    model=tf.keras.Sequential()
    
    print('chans: ', chans)
    print('nb_features: ', nb_features)
    model.add(layers.LSTM(256,
                          input_shape=(chans, time_steps)
            #input_shape=(chans* nb_features, time_steps),
            ))
    

    model.add(Dense(32,kernel_initializer='he_uniform',activation='relu'))
    

    model.add(Dense(nb_classes,activation='softmax'))
    
    return model

# %%
ignore_list = ['s07']  #list of patient files that should be skipped
#seconds of data to include in one slice
time_window = 1

# %%
mne.set_log_level("WARNING")


# get the minimum length of the files
def get_minimum_duration(group_directory_name, patient_group_file_prefix):
    file_durations = []
    for i in range (1, 15): # reading 14 files
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        file_name = raw_data_dir +'{}/{}.edf'.format(group_directory_name, patient_id)
        f = pyedflib.EdfReader(file_name)
        file_durations.append(f.file_duration)
        f.close()
    return(min(file_durations))

# modified based on https://stackoverflow.com/a/48704557/2466781
def chunk(seq, size):
    sl = len(seq) - (len(seq)%size) #exclude values that will be out of range
    r = [pd.DataFrame(seq[pos:pos + size]) for pos in range(0, sl, size)]
    return r

# modified version of process_patient_group in older notebooks
# Uses the raw EDF files and converts to dataframe, dropping the first 150 and last 30 seconds of the shortest  file
# All other files are trimmed similarly to produce the same size
# Adapted from page 1 of https://buildmedia.readthedocs.org/media/pdf/pyedflib/latest/pyedflib.pdf
def process_patient_group(group_directory_name, patient_group_file_prefix, 
                          minimum_original_duration,
                          time_window = 20,
                          plot_channels = False,
                         channels = ['F8', 'F7', 'F4', 'F3', 'Fz']):
    meta_df = pd.DataFrame()
    meta = []
    patient_id_list = []

    for i in range (1, 15): # reading 14 files
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        patient_id_list.append(patient_id)
        
        file_name = raw_data_dir + '{}/{}.edf'.format(group_directory_name, patient_id)
        data = mne.io.read_raw_edf(file_name)
        df = data.to_data_frame()
        df2 = df[channels]
        ## based on visual inspection, drop the first 150 seconds
        df2 = df2[150: (minimum_original_duration-30)]
        f = pyedflib.EdfReader(file_name)
        f.close()
        if patient_id not in ignore_list:
            meta_df = meta_df.append(df2)
            
    batches = chunk(meta_df, time_window)

    for batch in batches:
        #display(np.asarray(batch.values).shape)
        meta.append([np.asarray(batch.values)])
           
                    
    return meta

# %%
# Retrieve patient data, using a time window determined by the shortest recording
# patient s07 is removed

minimum_duration = min(get_minimum_duration("Healthy Controls", "h"), get_minimum_duration('SZ Patients', 's'))
print('Minimum duration: ', minimum_duration)

all_channels = ['Fp2', 'F8', 'T4', 'T6', 'O2', 'Fp1', 'F7', 'T3', 'T5', 'O1', 'F4',
                'C4', 'P4', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Pz']

target_channels = ['T4', 'T6', 'O2', 'T3', 'T5', 'O1',
                   'C4', 'P4', 'C3', 'P3', 'Cz', 'Pz']

print("Healthy Controls")
hc_data = process_patient_group('Healthy Controls', 'h', minimum_duration, channels=target_channels, time_window=time_window)
display(np.asarray(hc_data).shape)


print('Sz Patients')
sz_data = np.asarray(process_patient_group('SZ Patients', 's', minimum_duration, channels=target_channels, time_window=time_window))
display(np.asarray(sz_data).shape)


##### combine groups and create Y (labels)

X =  np.concatenate((hc_data, sz_data), axis=0)
display('Input size: ', X.shape)
y = ([0] * len(hc_data)) +( [1] * len(sz_data))
# Out:
# Minimum duration:  740
# Healthy Controls
# (7840, 1, 1, 12)
# Sz Patients
# (7280, 1, 1, 12)
# 'Input size: '
# (15120, 1, 1, 12)

# %%
#X[1].plot()
from IPython.display import display

import pylab as pylab

print('Input (X) shape: ' + str(X.shape))
print('Preview of data. First slice of unfiltered data')
for el in X[1][0]:
  #print(el)
  pylab.scatter(x=range(len(el)), y=el)
  #pylab.plot(el)
# Out:
# Input (X) shape: (15120, 1, 1, 12)
# Preview of data. First slice of unfiltered data

# %%
# create the /tmp directory if it doesn't already exist
import os
if not os.path.exists('tmp'):
    os.makedirs('tmp')

# %%
# get a list of randomly selected sets of numbers based on a range
# the proportion of values selected for each set is determined by the ratio_array
def get_mixed_indexes_for_ml_train_test(length, ratios_array):
    input_indexes = range(0, length)
    output_indexes = []
    for ratio in ratios_array:
        selection = random.choices(input_indexes, k=math.floor(ratio * length))
        input_indexes = [i for i in input_indexes if i not in selection]
        output_indexes.append(selection)
    return output_indexes

# %%
kernels, chans, samples = 1, 12, time_window
full_size = len(X)
train_idxs, validate_idxs, test_idxs = get_mixed_indexes_for_ml_train_test(len(X), [.70, 0.15, 0.15])



X_train      = X[train_idxs][0:,]
Y_train      = np.asarray(y)[train_idxs]
X_validate   = X[validate_idxs][0:,]
Y_validate   = np.asarray(y)[validate_idxs]
X_test       = X[test_idxs][0:,]
Y_test       = np.asarray(y)[test_idxs]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train, num_classes=2)
Y_validate   = np_utils.to_categorical(Y_validate, num_classes=2)
Y_test       = np_utils.to_categorical(Y_test, num_classes=2)



X_train      = X_train.reshape(X_train.shape[0],   chans, time_window,)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, time_window)
X_test       = X_test.reshape(X_test.shape[0], chans, time_window)


 
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')



#LSTM(samles, time_steps=20, input_size=30, chans)
model = LSTM(samples=samples, time_steps=time_steps, chans=chans, nb_features=1, nb_classes=2, )

model.summary()

#import tensorflow 
import tensorflow.keras.optimizers
opt_adam = tensorflow.keras.optimizers.Adam(lr=0.000001, 
                                beta_1=0.99,
                                beta_2=0.999,
                                epsilon=1e-07)
sgd = tensorflow.keras.optimizers.SGD(lr=0.01)



def rmse (y_true, y_pred):

    return K.sqrt(K.mean(K.square(y_pred -y_true)))

def rmse_np (y_true, y_pred):
    y_true = y_true.astype(int)
    y_pred=y_pred.astype(int)
    print(y_pred.dtype)
    return K.sqrt(K.mean(K.square(y_pred -y_true)))

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer=opt_adam, 
              metrics=[#'mse', 'mae', 
                  'accuracy', rmse
                 ])


# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='/tmp/LSTM_checkpoint.h5', verbose=1,
                               save_best_only=True)
# Out:
# X_train shape: (10584, 12, 1)
# 10584 train samples
# 2268 test samples
# chans:  12
# nb_features:  1
# WARNING:tensorflow:From C:\Users\marit\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 256)               264192
# _________________________________________________________________
# dense (Dense)                (None, 32)                8224
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 272,482
# Trainable params: 272,482
# Non-trainable params: 0
# _________________________________________________________________

# %%
fitted_model = model.fit(X_train, Y_train, batch_size = 32, epochs = 600, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer])#, class_weight = class_weights)

# load optimal weights
model.load_weights('/tmp/LSTM_checkpoint.h5')



probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy (Test set) : %f " % (acc))
# Out:
# Train on 10584 samples, validate on 2268 samples
# WARNING:tensorflow:From C:\Users\marit\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/600
#
# Epoch 00001: val_loss improved from inf to 0.70904, saving model to /tmp/LSTM_checkpoint.h5
#  - 38s - loss: 0.7189 - acc: 0.4800 - rmse: 0.5123 - val_loss: 0.7090 - val_acc: 0.4678 - val_rmse: 0.5078
# Epoch 2/600
#
# Epoch 00002: val_loss improved from 0.70904 to 0.69428, saving model to /tmp/LSTM_checkpoint.h5
#  - 35s - loss: 0.7018 - acc: 0.4796 - rmse: 0.5043 - val_loss: 0.6943 - val_acc: 0.4987 - val_rmse: 0.5005
# Epoch 3/600
#
# Epoch 00003: val_loss improved from 0.69428 to 0.68394, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.6897 - acc: 0.5269 - rmse: 0.4983 - val_loss: 0.6839 - val_acc: 0.5445 - val_rmse: 0.4953
# Epoch 4/600
#
# Epoch 00004: val_loss improved from 0.68394 to 0.67615, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.6809 - acc: 0.5617 - rmse: 0.4939 - val_loss: 0.6761 - val_acc: 0.5705 - val_rmse: 0.4914
# Epoch 5/600
#
# Epoch 00005: val_loss improved from 0.67615 to 0.66993, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.6744 - acc: 0.5728 - rmse: 0.4906 - val_loss: 0.6699 - val_acc: 0.5877 - val_rmse: 0.4884
# Epoch 6/600
#
# Epoch 00006: val_loss improved from 0.66993 to 0.66504, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.6692 - acc: 0.5798 - rmse: 0.4880 - val_loss: 0.6650 - val_acc: 0.5970 - val_rmse: 0.4860
# Epoch 7/600
#
# Epoch 00007: val_loss improved from 0.66504 to 0.66057, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.6649 - acc: 0.5875 - rmse: 0.4860 - val_loss: 0.6606 - val_acc: 0.6045 - val_rmse: 0.4838
# Epoch 8/600
#
# Epoch 00008: val_loss improved from 0.66057 to 0.65660, saving model to /tmp/LSTM_checkpoint.h5
#  - 37s - loss: 0.6612 - acc: 0.5938 - rmse: 0.4842 - val_loss: 0.6566 - val_acc: 0.6204 - val_rmse: 0.4819
# Epoch 9/600
#
# Epoch 00009: val_loss improved from 0.65660 to 0.65302, saving model to /tmp/LSTM_checkpoint.h5
#  - 34s - loss: 0.6579 - acc: 0.6036 - rmse: 0.4826 - val_loss: 0.6530 - val_acc: 0.6389 - val_rmse: 0.4801
# Epoch 10/600
#
# Epoch 00010: val_loss improved from 0.65302 to 0.64965, saving model to /tmp/LSTM_checkpoint.h5
#  - 35s - loss: 0.6549 - acc: 0.6127 - rmse: 0.4812 - val_loss: 0.6496 - val_acc: 0.6530 - val_rmse: 0.4786
# Epoch 11/600
#
# Epoch 00011: val_loss improved from 0.64965 to 0.64648, saving model to /tmp/LSTM_checkpoint.h5
#  - 38s - loss: 0.6520 - acc: 0.6256 - rmse: 0.4798 - val_loss: 0.6465 - val_acc: 0.6689 - val_rmse: 0.4770
# Epoch 12/600
#
# Epoch 00012: val_loss improved from 0.64648 to 0.64350, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.6493 - acc: 0.6390 - rmse: 0.4785 - val_loss: 0.6435 - val_acc: 0.6817 - val_rmse: 0.4756
# Epoch 13/600
#
# Epoch 00013: val_loss improved from 0.64350 to 0.64072, saving model to /tmp/LSTM_checkpoint.h5
#  - 35s - loss: 0.6469 - acc: 0.6554 - rmse: 0.4773 - val_loss: 0.6407 - val_acc: 0.6940 - val_rmse: 0.4742
# Epoch 14/600
#
# Epoch 00014: val_loss improved from 0.64072 to 0.63811, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.6446 - acc: 0.6683 - rmse: 0.4762 - val_loss: 0.6381 - val_acc: 0.7002 - val_rmse: 0.4729
# Epoch 15/600
#
# Epoch 00015: val_loss improved from 0.63811 to 0.63564, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.6425 - acc: 0.6771 - rmse: 0.4752 - val_loss: 0.6356 - val_acc: 0.7072 - val_rmse: 0.4717
# Epoch 16/600
#
# Epoch 00016: val_loss improved from 0.63564 to 0.63340, saving model to /tmp/LSTM_checkpoint.h5
#  - 34s - loss: 0.6405 - acc: 0.6825 - rmse: 0.4742 - val_loss: 0.6334 - val_acc: 0.7103 - val_rmse: 0.4706
# Epoch 17/600
#
# Epoch 00017: val_loss improved from 0.63340 to 0.63129, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.6386 - acc: 0.6882 - rmse: 0.4733 - val_loss: 0.6313 - val_acc: 0.7112 - val_rmse: 0.4696
# Epoch 18/600
#
# Epoch 00018: val_loss improved from 0.63129 to 0.62916, saving model to /tmp/LSTM_checkpoint.h5
#  - 36s - loss: 0.6368 - acc: 0.6943 - rmse: 0.4724 - val_loss: 0.6292 - val_acc: 0.7147 - val_rmse: 0.4685
# Epoch 19/600
#
# Epoch 00019: val_loss improved from 0.62916 to 0.62717, saving model to /tmp/LSTM_checkpoint.h5
#  - 35s - loss: 0.6351 - acc: 0.6984 - rmse: 0.4716 - val_loss: 0.6272 - val_acc: 0.7240 - val_rmse: 0.4675
# Epoch 20/600
#
# Epoch 00020: val_loss improved from 0.62717 to 0.62517, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.6334 - acc: 0.7011 - rmse: 0.4707 - val_loss: 0.6252 - val_acc: 0.7257 - val_rmse: 0.4664
# Epoch 21/600
#
# Epoch 00021: val_loss improved from 0.62517 to 0.62323, saving model to /tmp/LSTM_checkpoint.h5
#  - 35s - loss: 0.6318 - acc: 0.7034 - rmse: 0.4699 - val_loss: 0.6232 - val_acc: 0.7249 - val_rmse: 0.4655
# Epoch 22/600
#
# Epoch 00022: val_loss improved from 0.62323 to 0.62126, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.6302 - acc: 0.7087 - rmse: 0.4691 - val_loss: 0.6213 - val_acc: 0.7302 - val_rmse: 0.4645
# Epoch 23/600
#
# Epoch 00023: val_loss improved from 0.62126 to 0.61951, saving model to /tmp/LSTM_checkpoint.h5
#  - 37s - loss: 0.6287 - acc: 0.7091 - rmse: 0.4683 - val_loss: 0.6195 - val_acc: 0.7315 - val_rmse: 0.4635
# Epoch 24/600
#
# Epoch 00024: val_loss improved from 0.61951 to 0.61763, saving model to /tmp/LSTM_checkpoint.h5
#  - 37s - loss: 0.6272 - acc: 0.7114 - rmse: 0.4675 - val_loss: 0.6176 - val_acc: 0.7354 - val_rmse: 0.4626
# Epoch 25/600
#
# Epoch 00025: val_loss improved from 0.61763 to 0.61581, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.6257 - acc: 0.7128 - rmse: 0.4668 - val_loss: 0.6158 - val_acc: 0.7359 - val_rmse: 0.4616
# Epoch 26/600
#
# Epoch 00026: val_loss improved from 0.61581 to 0.61408, saving model to /tmp/LSTM_checkpoint.h5
#  - 34s - loss: 0.6242 - acc: 0.7130 - rmse: 0.4659 - val_loss: 0.6141 - val_acc: 0.7385 - val_rmse: 0.4608
# Epoch 27/600
#
# Epoch 00027: val_loss improved from 0.61408 to 0.61236, saving model to /tmp/LSTM_checkpoint.h5
#  - 36s - loss: 0.6228 - acc: 0.7140 - rmse: 0.4653 - val_loss: 0.6124 - val_acc: 0.7425 - val_rmse: 0.4598
# Epoch 28/600
#
# Epoch 00028: val_loss improved from 0.61236 to 0.61063, saving model to /tmp/LSTM_checkpoint.h5
#  - 36s - loss: 0.6214 - acc: 0.7148 - rmse: 0.4645 - val_loss: 0.6106 - val_acc: 0.7460 - val_rmse: 0.4588
# Epoch 29/600
#
# Epoch 00029: val_loss improved from 0.61063 to 0.60894, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.6200 - acc: 0.7159 - rmse: 0.4638 - val_loss: 0.6089 - val_acc: 0.7460 - val_rmse: 0.4581
# Epoch 30/600
#
# Epoch 00030: val_loss improved from 0.60894 to 0.60727, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.6187 - acc: 0.7172 - rmse: 0.4631 - val_loss: 0.6073 - val_acc: 0.7451 - val_rmse: 0.4573
# Epoch 31/600
#
# Epoch 00031: val_loss improved from 0.60727 to 0.60561, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.6173 - acc: 0.7166 - rmse: 0.4624 - val_loss: 0.6056 - val_acc: 0.7425 - val_rmse: 0.4564
# Epoch 32/600
#
# Epoch 00032: val_loss improved from 0.60561 to 0.60395, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.6160 - acc: 0.7175 - rmse: 0.4618 - val_loss: 0.6040 - val_acc: 0.7412 - val_rmse: 0.4555
# Epoch 33/600
#
# Epoch 00033: val_loss improved from 0.60395 to 0.60234, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.6147 - acc: 0.7174 - rmse: 0.4610 - val_loss: 0.6023 - val_acc: 0.7407 - val_rmse: 0.4547
# Epoch 34/600
#
# Epoch 00034: val_loss improved from 0.60234 to 0.60070, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.6134 - acc: 0.7174 - rmse: 0.4604 - val_loss: 0.6007 - val_acc: 0.7403 - val_rmse: 0.4537
# Epoch 35/600
#
# Epoch 00035: val_loss improved from 0.60070 to 0.59911, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.6121 - acc: 0.7171 - rmse: 0.4597 - val_loss: 0.5991 - val_acc: 0.7421 - val_rmse: 0.4530
# Epoch 36/600
#
# Epoch 00036: val_loss improved from 0.59911 to 0.59759, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.6109 - acc: 0.7177 - rmse: 0.4591 - val_loss: 0.5976 - val_acc: 0.7412 - val_rmse: 0.4521
# Epoch 37/600
#
# Epoch 00037: val_loss improved from 0.59759 to 0.59613, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.6097 - acc: 0.7185 - rmse: 0.4584 - val_loss: 0.5961 - val_acc: 0.7421 - val_rmse: 0.4514
# Epoch 38/600
#
# Epoch 00038: val_loss improved from 0.59613 to 0.59456, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.6085 - acc: 0.7194 - rmse: 0.4578 - val_loss: 0.5946 - val_acc: 0.7416 - val_rmse: 0.4505
# Epoch 39/600
#
# Epoch 00039: val_loss improved from 0.59456 to 0.59305, saving model to /tmp/LSTM_checkpoint.h5
#  - 34s - loss: 0.6073 - acc: 0.7187 - rmse: 0.4571 - val_loss: 0.5931 - val_acc: 0.7460 - val_rmse: 0.4497
# Epoch 40/600
#
# Epoch 00040: val_loss improved from 0.59305 to 0.59156, saving model to /tmp/LSTM_checkpoint.h5
#  - 37s - loss: 0.6061 - acc: 0.7188 - rmse: 0.4565 - val_loss: 0.5916 - val_acc: 0.7465 - val_rmse: 0.4491
# Epoch 41/600
#
# Epoch 00041: val_loss improved from 0.59156 to 0.59007, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.6050 - acc: 0.7185 - rmse: 0.4559 - val_loss: 0.5901 - val_acc: 0.7465 - val_rmse: 0.4483
# Epoch 42/600
#
# Epoch 00042: val_loss improved from 0.59007 to 0.58867, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.6038 - acc: 0.7194 - rmse: 0.4553 - val_loss: 0.5887 - val_acc: 0.7474 - val_rmse: 0.4473
# Epoch 43/600
#
# Epoch 00043: val_loss improved from 0.58867 to 0.58726, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.6027 - acc: 0.7197 - rmse: 0.4548 - val_loss: 0.5873 - val_acc: 0.7460 - val_rmse: 0.4468
# Epoch 44/600
#
# Epoch 00044: val_loss improved from 0.58726 to 0.58589, saving model to /tmp/LSTM_checkpoint.h5
#  - 34s - loss: 0.6016 - acc: 0.7200 - rmse: 0.4541 - val_loss: 0.5859 - val_acc: 0.7474 - val_rmse: 0.4461
# Epoch 45/600
#
# Epoch 00045: val_loss improved from 0.58589 to 0.58442, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.6005 - acc: 0.7199 - rmse: 0.4535 - val_loss: 0.5844 - val_acc: 0.7478 - val_rmse: 0.4454
# Epoch 46/600
#
# Epoch 00046: val_loss improved from 0.58442 to 0.58303, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5994 - acc: 0.7206 - rmse: 0.4530 - val_loss: 0.5830 - val_acc: 0.7460 - val_rmse: 0.4445
# Epoch 47/600
#
# Epoch 00047: val_loss improved from 0.58303 to 0.58167, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5984 - acc: 0.7207 - rmse: 0.4525 - val_loss: 0.5817 - val_acc: 0.7474 - val_rmse: 0.4435
# Epoch 48/600
#
# Epoch 00048: val_loss improved from 0.58167 to 0.58039, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5973 - acc: 0.7212 - rmse: 0.4519 - val_loss: 0.5804 - val_acc: 0.7509 - val_rmse: 0.4431
# Epoch 49/600
#
# Epoch 00049: val_loss improved from 0.58039 to 0.57903, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.5963 - acc: 0.7211 - rmse: 0.4513 - val_loss: 0.5790 - val_acc: 0.7509 - val_rmse: 0.4424
# Epoch 50/600
#
# Epoch 00050: val_loss improved from 0.57903 to 0.57776, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5953 - acc: 0.7217 - rmse: 0.4508 - val_loss: 0.5778 - val_acc: 0.7509 - val_rmse: 0.4417
# Epoch 51/600
#
# Epoch 00051: val_loss improved from 0.57776 to 0.57647, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.5943 - acc: 0.7212 - rmse: 0.4503 - val_loss: 0.5765 - val_acc: 0.7509 - val_rmse: 0.4410
# Epoch 52/600
#
# Epoch 00052: val_loss improved from 0.57647 to 0.57520, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5933 - acc: 0.7206 - rmse: 0.4497 - val_loss: 0.5752 - val_acc: 0.7509 - val_rmse: 0.4402
# Epoch 53/600
#
# Epoch 00053: val_loss improved from 0.57520 to 0.57396, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5923 - acc: 0.7195 - rmse: 0.4492 - val_loss: 0.5740 - val_acc: 0.7513 - val_rmse: 0.4396
# Epoch 54/600
#
# Epoch 00054: val_loss improved from 0.57396 to 0.57273, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5914 - acc: 0.7194 - rmse: 0.4488 - val_loss: 0.5727 - val_acc: 0.7522 - val_rmse: 0.4390
# Epoch 55/600
#
# Epoch 00055: val_loss improved from 0.57273 to 0.57151, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5904 - acc: 0.7199 - rmse: 0.4483 - val_loss: 0.5715 - val_acc: 0.7522 - val_rmse: 0.4385
# Epoch 56/600
#
# Epoch 00056: val_loss improved from 0.57151 to 0.57035, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5895 - acc: 0.7197 - rmse: 0.4478 - val_loss: 0.5703 - val_acc: 0.7496 - val_rmse: 0.4378
# Epoch 57/600
#
# Epoch 00057: val_loss improved from 0.57035 to 0.56916, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.5886 - acc: 0.7199 - rmse: 0.4472 - val_loss: 0.5692 - val_acc: 0.7509 - val_rmse: 0.4371
# Epoch 58/600
#
# Epoch 00058: val_loss improved from 0.56916 to 0.56805, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.5877 - acc: 0.7199 - rmse: 0.4469 - val_loss: 0.5681 - val_acc: 0.7478 - val_rmse: 0.4368
# Epoch 59/600
#
# Epoch 00059: val_loss improved from 0.56805 to 0.56686, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5868 - acc: 0.7194 - rmse: 0.4463 - val_loss: 0.5669 - val_acc: 0.7478 - val_rmse: 0.4359
# Epoch 60/600
#
# Epoch 00060: val_loss improved from 0.56686 to 0.56570, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5860 - acc: 0.7197 - rmse: 0.4458 - val_loss: 0.5657 - val_acc: 0.7504 - val_rmse: 0.4354
# Epoch 61/600
#
# Epoch 00061: val_loss improved from 0.56570 to 0.56459, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5851 - acc: 0.7189 - rmse: 0.4453 - val_loss: 0.5646 - val_acc: 0.7496 - val_rmse: 0.4347
# Epoch 62/600
#
# Epoch 00062: val_loss improved from 0.56459 to 0.56341, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5842 - acc: 0.7202 - rmse: 0.4450 - val_loss: 0.5634 - val_acc: 0.7504 - val_rmse: 0.4342
# Epoch 63/600
#
# Epoch 00063: val_loss improved from 0.56341 to 0.56234, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5834 - acc: 0.7202 - rmse: 0.4445 - val_loss: 0.5623 - val_acc: 0.7513 - val_rmse: 0.4336
# Epoch 64/600
#
# Epoch 00064: val_loss improved from 0.56234 to 0.56126, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5826 - acc: 0.7195 - rmse: 0.4440 - val_loss: 0.5613 - val_acc: 0.7513 - val_rmse: 0.4333
# Epoch 65/600
#
# Epoch 00065: val_loss improved from 0.56126 to 0.56031, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5817 - acc: 0.7196 - rmse: 0.4436 - val_loss: 0.5603 - val_acc: 0.7496 - val_rmse: 0.4324
# Epoch 66/600
#
# Epoch 00066: val_loss improved from 0.56031 to 0.55924, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.5810 - acc: 0.7187 - rmse: 0.4432 - val_loss: 0.5592 - val_acc: 0.7500 - val_rmse: 0.4321
# Epoch 67/600
#
# Epoch 00067: val_loss improved from 0.55924 to 0.55821, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.5802 - acc: 0.7184 - rmse: 0.4429 - val_loss: 0.5582 - val_acc: 0.7478 - val_rmse: 0.4312
# Epoch 68/600
#
# Epoch 00068: val_loss improved from 0.55821 to 0.55712, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.5794 - acc: 0.7198 - rmse: 0.4425 - val_loss: 0.5571 - val_acc: 0.7469 - val_rmse: 0.4307
# Epoch 69/600
#
# Epoch 00069: val_loss improved from 0.55712 to 0.55619, saving model to /tmp/LSTM_checkpoint.h5
#  - 26s - loss: 0.5786 - acc: 0.7192 - rmse: 0.4420 - val_loss: 0.5562 - val_acc: 0.7478 - val_rmse: 0.4304
# Epoch 70/600
#
# Epoch 00070: val_loss improved from 0.55619 to 0.55522, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5778 - acc: 0.7183 - rmse: 0.4416 - val_loss: 0.5552 - val_acc: 0.7474 - val_rmse: 0.4300
# Epoch 71/600
#
# Epoch 00071: val_loss improved from 0.55522 to 0.55422, saving model to /tmp/LSTM_checkpoint.h5
#  - 26s - loss: 0.5771 - acc: 0.7183 - rmse: 0.4411 - val_loss: 0.5542 - val_acc: 0.7478 - val_rmse: 0.4290
# Epoch 72/600
#
# Epoch 00072: val_loss improved from 0.55422 to 0.55323, saving model to /tmp/LSTM_checkpoint.h5
#  - 26s - loss: 0.5764 - acc: 0.7196 - rmse: 0.4408 - val_loss: 0.5532 - val_acc: 0.7469 - val_rmse: 0.4286
# Epoch 73/600
#
# Epoch 00073: val_loss improved from 0.55323 to 0.55243, saving model to /tmp/LSTM_checkpoint.h5
#  - 26s - loss: 0.5756 - acc: 0.7187 - rmse: 0.4405 - val_loss: 0.5524 - val_acc: 0.7478 - val_rmse: 0.4284
# Epoch 74/600
#
# Epoch 00074: val_loss improved from 0.55243 to 0.55141, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5749 - acc: 0.7194 - rmse: 0.4400 - val_loss: 0.5514 - val_acc: 0.7478 - val_rmse: 0.4279
# Epoch 75/600
#
# Epoch 00075: val_loss improved from 0.55141 to 0.55050, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5742 - acc: 0.7194 - rmse: 0.4396 - val_loss: 0.5505 - val_acc: 0.7487 - val_rmse: 0.4270
# Epoch 76/600
#
# Epoch 00076: val_loss improved from 0.55050 to 0.54953, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5735 - acc: 0.7193 - rmse: 0.4394 - val_loss: 0.5495 - val_acc: 0.7478 - val_rmse: 0.4271
# Epoch 77/600
#
# Epoch 00077: val_loss improved from 0.54953 to 0.54867, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5728 - acc: 0.7200 - rmse: 0.4392 - val_loss: 0.5487 - val_acc: 0.7469 - val_rmse: 0.4263
# Epoch 78/600
#
# Epoch 00078: val_loss improved from 0.54867 to 0.54771, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.5721 - acc: 0.7200 - rmse: 0.4386 - val_loss: 0.5477 - val_acc: 0.7474 - val_rmse: 0.4260
# Epoch 79/600
#
# Epoch 00079: val_loss improved from 0.54771 to 0.54684, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5714 - acc: 0.7191 - rmse: 0.4383 - val_loss: 0.5468 - val_acc: 0.7469 - val_rmse: 0.4252
# Epoch 80/600
#
# Epoch 00080: val_loss improved from 0.54684 to 0.54617, saving model to /tmp/LSTM_checkpoint.h5
#  - 26s - loss: 0.5707 - acc: 0.7196 - rmse: 0.4378 - val_loss: 0.5462 - val_acc: 0.7478 - val_rmse: 0.4250
# Epoch 81/600
#
# Epoch 00081: val_loss improved from 0.54617 to 0.54526, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5701 - acc: 0.7193 - rmse: 0.4376 - val_loss: 0.5453 - val_acc: 0.7460 - val_rmse: 0.4246
# Epoch 82/600
#
# Epoch 00082: val_loss improved from 0.54526 to 0.54449, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5695 - acc: 0.7202 - rmse: 0.4373 - val_loss: 0.5445 - val_acc: 0.7460 - val_rmse: 0.4243
# Epoch 83/600
#
# Epoch 00083: val_loss improved from 0.54449 to 0.54354, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5688 - acc: 0.7205 - rmse: 0.4370 - val_loss: 0.5435 - val_acc: 0.7465 - val_rmse: 0.4240
# Epoch 84/600
#
# Epoch 00084: val_loss improved from 0.54354 to 0.54273, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.5682 - acc: 0.7202 - rmse: 0.4365 - val_loss: 0.5427 - val_acc: 0.7474 - val_rmse: 0.4232
# Epoch 85/600
#
# Epoch 00085: val_loss improved from 0.54273 to 0.54194, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5676 - acc: 0.7203 - rmse: 0.4363 - val_loss: 0.5419 - val_acc: 0.7474 - val_rmse: 0.4230
# Epoch 86/600
#
# Epoch 00086: val_loss improved from 0.54194 to 0.54113, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5670 - acc: 0.7205 - rmse: 0.4361 - val_loss: 0.5411 - val_acc: 0.7474 - val_rmse: 0.4223
# Epoch 87/600
#
# Epoch 00087: val_loss improved from 0.54113 to 0.54054, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5664 - acc: 0.7199 - rmse: 0.4359 - val_loss: 0.5405 - val_acc: 0.7469 - val_rmse: 0.4222
# Epoch 88/600
#
# Epoch 00088: val_loss improved from 0.54054 to 0.53973, saving model to /tmp/LSTM_checkpoint.h5
#  - 26s - loss: 0.5658 - acc: 0.7204 - rmse: 0.4355 - val_loss: 0.5397 - val_acc: 0.7482 - val_rmse: 0.4220
# Epoch 89/600
#
# Epoch 00089: val_loss improved from 0.53973 to 0.53876, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5652 - acc: 0.7211 - rmse: 0.4353 - val_loss: 0.5388 - val_acc: 0.7491 - val_rmse: 0.4212
# Epoch 90/600
#
# Epoch 00090: val_loss improved from 0.53876 to 0.53822, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5646 - acc: 0.7207 - rmse: 0.4348 - val_loss: 0.5382 - val_acc: 0.7487 - val_rmse: 0.4213
# Epoch 91/600
#
# Epoch 00091: val_loss improved from 0.53822 to 0.53744, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5640 - acc: 0.7209 - rmse: 0.4345 - val_loss: 0.5374 - val_acc: 0.7491 - val_rmse: 0.4210
# Epoch 92/600
#
# Epoch 00092: val_loss improved from 0.53744 to 0.53680, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5635 - acc: 0.7211 - rmse: 0.4343 - val_loss: 0.5368 - val_acc: 0.7491 - val_rmse: 0.4204
# Epoch 93/600
#
# Epoch 00093: val_loss improved from 0.53680 to 0.53599, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5629 - acc: 0.7214 - rmse: 0.4342 - val_loss: 0.5360 - val_acc: 0.7491 - val_rmse: 0.4197
# Epoch 94/600
#
# Epoch 00094: val_loss improved from 0.53599 to 0.53520, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5624 - acc: 0.7221 - rmse: 0.4340 - val_loss: 0.5352 - val_acc: 0.7496 - val_rmse: 0.4188
# Epoch 95/600
#
# Epoch 00095: val_loss improved from 0.53520 to 0.53463, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5618 - acc: 0.7219 - rmse: 0.4337 - val_loss: 0.5346 - val_acc: 0.7487 - val_rmse: 0.4196
# Epoch 96/600
#
# Epoch 00096: val_loss improved from 0.53463 to 0.53393, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5613 - acc: 0.7222 - rmse: 0.4333 - val_loss: 0.5339 - val_acc: 0.7487 - val_rmse: 0.4186
# Epoch 97/600
#
# Epoch 00097: val_loss improved from 0.53393 to 0.53326, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5607 - acc: 0.7221 - rmse: 0.4330 - val_loss: 0.5333 - val_acc: 0.7487 - val_rmse: 0.4187
# Epoch 98/600
#
# Epoch 00098: val_loss improved from 0.53326 to 0.53261, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5602 - acc: 0.7221 - rmse: 0.4327 - val_loss: 0.5326 - val_acc: 0.7478 - val_rmse: 0.4186
# Epoch 99/600
#
# Epoch 00099: val_loss improved from 0.53261 to 0.53192, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5597 - acc: 0.7225 - rmse: 0.4325 - val_loss: 0.5319 - val_acc: 0.7482 - val_rmse: 0.4179
# Epoch 100/600
#
# Epoch 00100: val_loss improved from 0.53192 to 0.53122, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5592 - acc: 0.7227 - rmse: 0.4323 - val_loss: 0.5312 - val_acc: 0.7482 - val_rmse: 0.4178
# Epoch 101/600
#
# Epoch 00101: val_loss improved from 0.53122 to 0.53055, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5587 - acc: 0.7227 - rmse: 0.4319 - val_loss: 0.5306 - val_acc: 0.7487 - val_rmse: 0.4171
# Epoch 102/600
#
# Epoch 00102: val_loss improved from 0.53055 to 0.53002, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5582 - acc: 0.7223 - rmse: 0.4316 - val_loss: 0.5300 - val_acc: 0.7491 - val_rmse: 0.4171
# Epoch 103/600
#
# Epoch 00103: val_loss improved from 0.53002 to 0.52941, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5577 - acc: 0.7222 - rmse: 0.4316 - val_loss: 0.5294 - val_acc: 0.7491 - val_rmse: 0.4163
# Epoch 104/600
#
# Epoch 00104: val_loss improved from 0.52941 to 0.52881, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5573 - acc: 0.7220 - rmse: 0.4311 - val_loss: 0.5288 - val_acc: 0.7491 - val_rmse: 0.4165
# Epoch 105/600
#
# Epoch 00105: val_loss improved from 0.52881 to 0.52818, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5568 - acc: 0.7220 - rmse: 0.4312 - val_loss: 0.5282 - val_acc: 0.7491 - val_rmse: 0.4161
# Epoch 106/600
#
# Epoch 00106: val_loss improved from 0.52818 to 0.52766, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5564 - acc: 0.7226 - rmse: 0.4309 - val_loss: 0.5277 - val_acc: 0.7487 - val_rmse: 0.4159
# Epoch 107/600
#
# Epoch 00107: val_loss improved from 0.52766 to 0.52707, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5559 - acc: 0.7221 - rmse: 0.4309 - val_loss: 0.5271 - val_acc: 0.7474 - val_rmse: 0.4155
# Epoch 108/600
#
# Epoch 00108: val_loss improved from 0.52707 to 0.52641, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5555 - acc: 0.7219 - rmse: 0.4305 - val_loss: 0.5264 - val_acc: 0.7487 - val_rmse: 0.4155
# Epoch 109/600
#
# Epoch 00109: val_loss improved from 0.52641 to 0.52601, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5550 - acc: 0.7228 - rmse: 0.4302 - val_loss: 0.5260 - val_acc: 0.7500 - val_rmse: 0.4152
# Epoch 110/600
#
# Epoch 00110: val_loss improved from 0.52601 to 0.52534, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5546 - acc: 0.7221 - rmse: 0.4301 - val_loss: 0.5253 - val_acc: 0.7482 - val_rmse: 0.4148
# Epoch 111/600
#
# Epoch 00111: val_loss improved from 0.52534 to 0.52492, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5542 - acc: 0.7231 - rmse: 0.4297 - val_loss: 0.5249 - val_acc: 0.7500 - val_rmse: 0.4145
# Epoch 112/600
#
# Epoch 00112: val_loss improved from 0.52492 to 0.52441, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5538 - acc: 0.7227 - rmse: 0.4297 - val_loss: 0.5244 - val_acc: 0.7504 - val_rmse: 0.4143
# Epoch 113/600
#
# Epoch 00113: val_loss improved from 0.52441 to 0.52393, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5534 - acc: 0.7228 - rmse: 0.4297 - val_loss: 0.5239 - val_acc: 0.7504 - val_rmse: 0.4140
# Epoch 114/600
#
# Epoch 00114: val_loss improved from 0.52393 to 0.52334, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5530 - acc: 0.7232 - rmse: 0.4294 - val_loss: 0.5233 - val_acc: 0.7491 - val_rmse: 0.4135
# Epoch 115/600
#
# Epoch 00115: val_loss improved from 0.52334 to 0.52289, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5527 - acc: 0.7229 - rmse: 0.4296 - val_loss: 0.5229 - val_acc: 0.7487 - val_rmse: 0.4137
# Epoch 116/600
#
# Epoch 00116: val_loss improved from 0.52289 to 0.52239, saving model to /tmp/LSTM_checkpoint.h5
#  - 26s - loss: 0.5523 - acc: 0.7234 - rmse: 0.4292 - val_loss: 0.5224 - val_acc: 0.7487 - val_rmse: 0.4132
# Epoch 117/600
#
# Epoch 00117: val_loss improved from 0.52239 to 0.52198, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5519 - acc: 0.7233 - rmse: 0.4289 - val_loss: 0.5220 - val_acc: 0.7482 - val_rmse: 0.4131
# Epoch 118/600
#
# Epoch 00118: val_loss improved from 0.52198 to 0.52164, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.5516 - acc: 0.7222 - rmse: 0.4288 - val_loss: 0.5216 - val_acc: 0.7504 - val_rmse: 0.4130
# Epoch 119/600
#
# Epoch 00119: val_loss improved from 0.52164 to 0.52126, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5512 - acc: 0.7224 - rmse: 0.4286 - val_loss: 0.5213 - val_acc: 0.7518 - val_rmse: 0.4125
# Epoch 120/600
#
# Epoch 00120: val_loss improved from 0.52126 to 0.52061, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5509 - acc: 0.7231 - rmse: 0.4285 - val_loss: 0.5206 - val_acc: 0.7509 - val_rmse: 0.4124
# Epoch 121/600
#
# Epoch 00121: val_loss improved from 0.52061 to 0.52021, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5505 - acc: 0.7232 - rmse: 0.4282 - val_loss: 0.5202 - val_acc: 0.7496 - val_rmse: 0.4124
# Epoch 122/600
#
# Epoch 00122: val_loss improved from 0.52021 to 0.51984, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5502 - acc: 0.7224 - rmse: 0.4281 - val_loss: 0.5198 - val_acc: 0.7500 - val_rmse: 0.4122
# Epoch 123/600
#
# Epoch 00123: val_loss improved from 0.51984 to 0.51956, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5499 - acc: 0.7223 - rmse: 0.4282 - val_loss: 0.5196 - val_acc: 0.7504 - val_rmse: 0.4117
# Epoch 124/600
#
# Epoch 00124: val_loss improved from 0.51956 to 0.51905, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5496 - acc: 0.7223 - rmse: 0.4278 - val_loss: 0.5191 - val_acc: 0.7513 - val_rmse: 0.4118
# Epoch 125/600
#
# Epoch 00125: val_loss improved from 0.51905 to 0.51867, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5492 - acc: 0.7225 - rmse: 0.4278 - val_loss: 0.5187 - val_acc: 0.7513 - val_rmse: 0.4113
# Epoch 126/600
#
# Epoch 00126: val_loss improved from 0.51867 to 0.51832, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5489 - acc: 0.7223 - rmse: 0.4277 - val_loss: 0.5183 - val_acc: 0.7513 - val_rmse: 0.4115
# Epoch 127/600
#
# Epoch 00127: val_loss improved from 0.51832 to 0.51785, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5487 - acc: 0.7221 - rmse: 0.4275 - val_loss: 0.5179 - val_acc: 0.7540 - val_rmse: 0.4112
# Epoch 128/600
#
# Epoch 00128: val_loss improved from 0.51785 to 0.51755, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5484 - acc: 0.7225 - rmse: 0.4276 - val_loss: 0.5176 - val_acc: 0.7531 - val_rmse: 0.4114
# Epoch 129/600
#
# Epoch 00129: val_loss improved from 0.51755 to 0.51730, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5481 - acc: 0.7237 - rmse: 0.4271 - val_loss: 0.5173 - val_acc: 0.7526 - val_rmse: 0.4111
# Epoch 130/600
#
# Epoch 00130: val_loss improved from 0.51730 to 0.51688, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5478 - acc: 0.7226 - rmse: 0.4273 - val_loss: 0.5169 - val_acc: 0.7549 - val_rmse: 0.4111
# Epoch 131/600
#
# Epoch 00131: val_loss improved from 0.51688 to 0.51656, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5475 - acc: 0.7229 - rmse: 0.4271 - val_loss: 0.5166 - val_acc: 0.7540 - val_rmse: 0.4109
# Epoch 132/600
#
# Epoch 00132: val_loss improved from 0.51656 to 0.51630, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5473 - acc: 0.7239 - rmse: 0.4269 - val_loss: 0.5163 - val_acc: 0.7522 - val_rmse: 0.4103
# Epoch 133/600
#
# Epoch 00133: val_loss improved from 0.51630 to 0.51595, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5470 - acc: 0.7233 - rmse: 0.4265 - val_loss: 0.5160 - val_acc: 0.7535 - val_rmse: 0.4104
# Epoch 134/600
#
# Epoch 00134: val_loss improved from 0.51595 to 0.51551, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5468 - acc: 0.7241 - rmse: 0.4266 - val_loss: 0.5155 - val_acc: 0.7557 - val_rmse: 0.4102
# Epoch 135/600
#
# Epoch 00135: val_loss improved from 0.51551 to 0.51532, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5465 - acc: 0.7239 - rmse: 0.4267 - val_loss: 0.5153 - val_acc: 0.7531 - val_rmse: 0.4103
# Epoch 136/600
#
# Epoch 00136: val_loss improved from 0.51532 to 0.51507, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5462 - acc: 0.7230 - rmse: 0.4266 - val_loss: 0.5151 - val_acc: 0.7535 - val_rmse: 0.4098
# Epoch 137/600
#
# Epoch 00137: val_loss improved from 0.51507 to 0.51471, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5460 - acc: 0.7240 - rmse: 0.4263 - val_loss: 0.5147 - val_acc: 0.7549 - val_rmse: 0.4097
# Epoch 138/600
#
# Epoch 00138: val_loss improved from 0.51471 to 0.51438, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5457 - acc: 0.7246 - rmse: 0.4265 - val_loss: 0.5144 - val_acc: 0.7540 - val_rmse: 0.4097
# Epoch 139/600
#
# Epoch 00139: val_loss improved from 0.51438 to 0.51415, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5455 - acc: 0.7237 - rmse: 0.4262 - val_loss: 0.5141 - val_acc: 0.7535 - val_rmse: 0.4098
# Epoch 140/600
#
# Epoch 00140: val_loss improved from 0.51415 to 0.51381, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5453 - acc: 0.7242 - rmse: 0.4263 - val_loss: 0.5138 - val_acc: 0.7549 - val_rmse: 0.4093
# Epoch 141/600
#
# Epoch 00141: val_loss improved from 0.51381 to 0.51366, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5450 - acc: 0.7242 - rmse: 0.4258 - val_loss: 0.5137 - val_acc: 0.7531 - val_rmse: 0.4089
# Epoch 142/600
#
# Epoch 00142: val_loss improved from 0.51366 to 0.51335, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5448 - acc: 0.7247 - rmse: 0.4256 - val_loss: 0.5134 - val_acc: 0.7531 - val_rmse: 0.4090
# Epoch 143/600
#
# Epoch 00143: val_loss improved from 0.51335 to 0.51312, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5446 - acc: 0.7246 - rmse: 0.4259 - val_loss: 0.5131 - val_acc: 0.7526 - val_rmse: 0.4094
# Epoch 144/600
#
# Epoch 00144: val_loss improved from 0.51312 to 0.51286, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5443 - acc: 0.7250 - rmse: 0.4258 - val_loss: 0.5129 - val_acc: 0.7549 - val_rmse: 0.4086
# Epoch 145/600
#
# Epoch 00145: val_loss improved from 0.51286 to 0.51259, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5441 - acc: 0.7252 - rmse: 0.4256 - val_loss: 0.5126 - val_acc: 0.7544 - val_rmse: 0.4090
# Epoch 146/600
#
# Epoch 00146: val_loss improved from 0.51259 to 0.51232, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5439 - acc: 0.7253 - rmse: 0.4254 - val_loss: 0.5123 - val_acc: 0.7544 - val_rmse: 0.4086
# Epoch 147/600
#
# Epoch 00147: val_loss improved from 0.51232 to 0.51204, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5437 - acc: 0.7251 - rmse: 0.4254 - val_loss: 0.5120 - val_acc: 0.7535 - val_rmse: 0.4079
# Epoch 148/600
#
# Epoch 00148: val_loss improved from 0.51204 to 0.51198, saving model to /tmp/LSTM_checkpoint.h5
#  - 34s - loss: 0.5435 - acc: 0.7252 - rmse: 0.4254 - val_loss: 0.5120 - val_acc: 0.7557 - val_rmse: 0.4090
# Epoch 149/600
#
# Epoch 00149: val_loss improved from 0.51198 to 0.51164, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5432 - acc: 0.7257 - rmse: 0.4251 - val_loss: 0.5116 - val_acc: 0.7553 - val_rmse: 0.4087
# Epoch 150/600
#
# Epoch 00150: val_loss improved from 0.51164 to 0.51136, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5431 - acc: 0.7252 - rmse: 0.4251 - val_loss: 0.5114 - val_acc: 0.7535 - val_rmse: 0.4083
# Epoch 151/600
#
# Epoch 00151: val_loss improved from 0.51136 to 0.51120, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5428 - acc: 0.7252 - rmse: 0.4250 - val_loss: 0.5112 - val_acc: 0.7553 - val_rmse: 0.4078
# Epoch 152/600
#
# Epoch 00152: val_loss improved from 0.51120 to 0.51107, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5426 - acc: 0.7251 - rmse: 0.4248 - val_loss: 0.5111 - val_acc: 0.7549 - val_rmse: 0.4077
# Epoch 153/600
#
# Epoch 00153: val_loss improved from 0.51107 to 0.51076, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5424 - acc: 0.7262 - rmse: 0.4249 - val_loss: 0.5108 - val_acc: 0.7553 - val_rmse: 0.4080
# Epoch 154/600
#
# Epoch 00154: val_loss improved from 0.51076 to 0.51054, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.5422 - acc: 0.7263 - rmse: 0.4247 - val_loss: 0.5105 - val_acc: 0.7557 - val_rmse: 0.4075
# Epoch 155/600
#
# Epoch 00155: val_loss improved from 0.51054 to 0.51028, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.5421 - acc: 0.7260 - rmse: 0.4249 - val_loss: 0.5103 - val_acc: 0.7549 - val_rmse: 0.4080
# Epoch 156/600
#
# Epoch 00156: val_loss improved from 0.51028 to 0.51013, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5418 - acc: 0.7265 - rmse: 0.4247 - val_loss: 0.5101 - val_acc: 0.7557 - val_rmse: 0.4078
# Epoch 157/600
#
# Epoch 00157: val_loss improved from 0.51013 to 0.50990, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5416 - acc: 0.7265 - rmse: 0.4244 - val_loss: 0.5099 - val_acc: 0.7566 - val_rmse: 0.4079
# Epoch 158/600
#
# Epoch 00158: val_loss improved from 0.50990 to 0.50970, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5415 - acc: 0.7269 - rmse: 0.4243 - val_loss: 0.5097 - val_acc: 0.7566 - val_rmse: 0.4075
# Epoch 159/600
#
# Epoch 00159: val_loss improved from 0.50970 to 0.50943, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5413 - acc: 0.7259 - rmse: 0.4243 - val_loss: 0.5094 - val_acc: 0.7584 - val_rmse: 0.4073
# Epoch 160/600
#
# Epoch 00160: val_loss improved from 0.50943 to 0.50931, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5411 - acc: 0.7267 - rmse: 0.4245 - val_loss: 0.5093 - val_acc: 0.7562 - val_rmse: 0.4078
# Epoch 161/600
#
# Epoch 00161: val_loss improved from 0.50931 to 0.50917, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5409 - acc: 0.7269 - rmse: 0.4241 - val_loss: 0.5092 - val_acc: 0.7562 - val_rmse: 0.4073
# Epoch 162/600
#
# Epoch 00162: val_loss improved from 0.50917 to 0.50893, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5407 - acc: 0.7259 - rmse: 0.4241 - val_loss: 0.5089 - val_acc: 0.7562 - val_rmse: 0.4074
# Epoch 163/600
#
# Epoch 00163: val_loss improved from 0.50893 to 0.50877, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5405 - acc: 0.7262 - rmse: 0.4241 - val_loss: 0.5088 - val_acc: 0.7566 - val_rmse: 0.4072
# Epoch 164/600
#
# Epoch 00164: val_loss improved from 0.50877 to 0.50856, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5404 - acc: 0.7267 - rmse: 0.4239 - val_loss: 0.5086 - val_acc: 0.7571 - val_rmse: 0.4072
# Epoch 165/600
#
# Epoch 00165: val_loss improved from 0.50856 to 0.50844, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5402 - acc: 0.7264 - rmse: 0.4239 - val_loss: 0.5084 - val_acc: 0.7575 - val_rmse: 0.4072
# Epoch 166/600
#
# Epoch 00166: val_loss improved from 0.50844 to 0.50817, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5400 - acc: 0.7261 - rmse: 0.4241 - val_loss: 0.5082 - val_acc: 0.7588 - val_rmse: 0.4067
# Epoch 167/600
#
# Epoch 00167: val_loss improved from 0.50817 to 0.50807, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5399 - acc: 0.7264 - rmse: 0.4236 - val_loss: 0.5081 - val_acc: 0.7575 - val_rmse: 0.4071
# Epoch 168/600
#
# Epoch 00168: val_loss improved from 0.50807 to 0.50784, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5397 - acc: 0.7257 - rmse: 0.4236 - val_loss: 0.5078 - val_acc: 0.7584 - val_rmse: 0.4070
# Epoch 169/600
#
# Epoch 00169: val_loss improved from 0.50784 to 0.50778, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5395 - acc: 0.7257 - rmse: 0.4235 - val_loss: 0.5078 - val_acc: 0.7588 - val_rmse: 0.4068
# Epoch 170/600
#
# Epoch 00170: val_loss improved from 0.50778 to 0.50756, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5393 - acc: 0.7266 - rmse: 0.4237 - val_loss: 0.5076 - val_acc: 0.7579 - val_rmse: 0.4065
# Epoch 171/600
#
# Epoch 00171: val_loss improved from 0.50756 to 0.50751, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5392 - acc: 0.7266 - rmse: 0.4236 - val_loss: 0.5075 - val_acc: 0.7571 - val_rmse: 0.4069
# Epoch 172/600
#
# Epoch 00172: val_loss improved from 0.50751 to 0.50719, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5390 - acc: 0.7267 - rmse: 0.4237 - val_loss: 0.5072 - val_acc: 0.7588 - val_rmse: 0.4058
# Epoch 173/600
#
# Epoch 00173: val_loss improved from 0.50719 to 0.50712, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5388 - acc: 0.7263 - rmse: 0.4234 - val_loss: 0.5071 - val_acc: 0.7579 - val_rmse: 0.4071
# Epoch 174/600
#
# Epoch 00174: val_loss improved from 0.50712 to 0.50701, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5387 - acc: 0.7264 - rmse: 0.4232 - val_loss: 0.5070 - val_acc: 0.7579 - val_rmse: 0.4065
# Epoch 175/600
#
# Epoch 00175: val_loss improved from 0.50701 to 0.50674, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5385 - acc: 0.7265 - rmse: 0.4231 - val_loss: 0.5067 - val_acc: 0.7588 - val_rmse: 0.4063
# Epoch 176/600
#
# Epoch 00176: val_loss improved from 0.50674 to 0.50659, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5384 - acc: 0.7262 - rmse: 0.4232 - val_loss: 0.5066 - val_acc: 0.7588 - val_rmse: 0.4061
# Epoch 177/600
#
# Epoch 00177: val_loss improved from 0.50659 to 0.50648, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5382 - acc: 0.7265 - rmse: 0.4230 - val_loss: 0.5065 - val_acc: 0.7579 - val_rmse: 0.4065
# Epoch 178/600
#
# Epoch 00178: val_loss improved from 0.50648 to 0.50633, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5380 - acc: 0.7265 - rmse: 0.4232 - val_loss: 0.5063 - val_acc: 0.7579 - val_rmse: 0.4057
# Epoch 179/600
#
# Epoch 00179: val_loss improved from 0.50633 to 0.50619, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5379 - acc: 0.7263 - rmse: 0.4227 - val_loss: 0.5062 - val_acc: 0.7579 - val_rmse: 0.4056
# Epoch 180/600
#
# Epoch 00180: val_loss improved from 0.50619 to 0.50601, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5378 - acc: 0.7264 - rmse: 0.4229 - val_loss: 0.5060 - val_acc: 0.7579 - val_rmse: 0.4062
# Epoch 181/600
#
# Epoch 00181: val_loss did not improve from 0.50601
#  - 27s - loss: 0.5376 - acc: 0.7267 - rmse: 0.4224 - val_loss: 0.5060 - val_acc: 0.7579 - val_rmse: 0.4058
# Epoch 182/600
#
# Epoch 00182: val_loss improved from 0.50601 to 0.50574, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5375 - acc: 0.7273 - rmse: 0.4228 - val_loss: 0.5057 - val_acc: 0.7575 - val_rmse: 0.4052
# Epoch 183/600
#
# Epoch 00183: val_loss improved from 0.50574 to 0.50558, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5373 - acc: 0.7272 - rmse: 0.4228 - val_loss: 0.5056 - val_acc: 0.7575 - val_rmse: 0.4050
# Epoch 184/600
#
# Epoch 00184: val_loss improved from 0.50558 to 0.50551, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5372 - acc: 0.7269 - rmse: 0.4226 - val_loss: 0.5055 - val_acc: 0.7584 - val_rmse: 0.4050
# Epoch 185/600
#
# Epoch 00185: val_loss improved from 0.50551 to 0.50539, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5370 - acc: 0.7274 - rmse: 0.4226 - val_loss: 0.5054 - val_acc: 0.7579 - val_rmse: 0.4054
# Epoch 186/600
#
# Epoch 00186: val_loss improved from 0.50539 to 0.50515, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5368 - acc: 0.7273 - rmse: 0.4224 - val_loss: 0.5051 - val_acc: 0.7579 - val_rmse: 0.4054
# Epoch 187/600
#
# Epoch 00187: val_loss improved from 0.50515 to 0.50502, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5367 - acc: 0.7276 - rmse: 0.4224 - val_loss: 0.5050 - val_acc: 0.7584 - val_rmse: 0.4054
# Epoch 188/600
#
# Epoch 00188: val_loss improved from 0.50502 to 0.50497, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5366 - acc: 0.7276 - rmse: 0.4219 - val_loss: 0.5050 - val_acc: 0.7579 - val_rmse: 0.4052
# Epoch 189/600
#
# Epoch 00189: val_loss improved from 0.50497 to 0.50480, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5364 - acc: 0.7273 - rmse: 0.4224 - val_loss: 0.5048 - val_acc: 0.7579 - val_rmse: 0.4054
# Epoch 190/600
#
# Epoch 00190: val_loss improved from 0.50480 to 0.50464, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5363 - acc: 0.7279 - rmse: 0.4222 - val_loss: 0.5046 - val_acc: 0.7584 - val_rmse: 0.4054
# Epoch 191/600
#
# Epoch 00191: val_loss improved from 0.50464 to 0.50460, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5362 - acc: 0.7278 - rmse: 0.4221 - val_loss: 0.5046 - val_acc: 0.7593 - val_rmse: 0.4056
# Epoch 192/600
#
# Epoch 00192: val_loss improved from 0.50460 to 0.50437, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5360 - acc: 0.7279 - rmse: 0.4222 - val_loss: 0.5044 - val_acc: 0.7584 - val_rmse: 0.4052
# Epoch 193/600
#
# Epoch 00193: val_loss improved from 0.50437 to 0.50418, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5358 - acc: 0.7276 - rmse: 0.4221 - val_loss: 0.5042 - val_acc: 0.7588 - val_rmse: 0.4054
# Epoch 194/600
#
# Epoch 00194: val_loss improved from 0.50418 to 0.50416, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5357 - acc: 0.7285 - rmse: 0.4220 - val_loss: 0.5042 - val_acc: 0.7593 - val_rmse: 0.4056
# Epoch 195/600
#
# Epoch 00195: val_loss improved from 0.50416 to 0.50401, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5356 - acc: 0.7278 - rmse: 0.4219 - val_loss: 0.5040 - val_acc: 0.7593 - val_rmse: 0.4052
# Epoch 196/600
#
# Epoch 00196: val_loss improved from 0.50401 to 0.50388, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5354 - acc: 0.7278 - rmse: 0.4217 - val_loss: 0.5039 - val_acc: 0.7597 - val_rmse: 0.4051
# Epoch 197/600
#
# Epoch 00197: val_loss improved from 0.50388 to 0.50378, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5353 - acc: 0.7282 - rmse: 0.4220 - val_loss: 0.5038 - val_acc: 0.7588 - val_rmse: 0.4050
# Epoch 198/600
#
# Epoch 00198: val_loss improved from 0.50378 to 0.50358, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5351 - acc: 0.7278 - rmse: 0.4218 - val_loss: 0.5036 - val_acc: 0.7597 - val_rmse: 0.4049
# Epoch 199/600
#
# Epoch 00199: val_loss improved from 0.50358 to 0.50350, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5350 - acc: 0.7279 - rmse: 0.4218 - val_loss: 0.5035 - val_acc: 0.7601 - val_rmse: 0.4051
# Epoch 200/600
#
# Epoch 00200: val_loss improved from 0.50350 to 0.50338, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5348 - acc: 0.7283 - rmse: 0.4212 - val_loss: 0.5034 - val_acc: 0.7588 - val_rmse: 0.4050
# Epoch 201/600
#
# Epoch 00201: val_loss improved from 0.50338 to 0.50322, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5347 - acc: 0.7281 - rmse: 0.4217 - val_loss: 0.5032 - val_acc: 0.7593 - val_rmse: 0.4045
# Epoch 202/600
#
# Epoch 00202: val_loss improved from 0.50322 to 0.50306, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5346 - acc: 0.7270 - rmse: 0.4215 - val_loss: 0.5031 - val_acc: 0.7601 - val_rmse: 0.4040
# Epoch 203/600
#
# Epoch 00203: val_loss improved from 0.50306 to 0.50296, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.5344 - acc: 0.7278 - rmse: 0.4215 - val_loss: 0.5030 - val_acc: 0.7593 - val_rmse: 0.4047
# Epoch 204/600
#
# Epoch 00204: val_loss improved from 0.50296 to 0.50287, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5343 - acc: 0.7290 - rmse: 0.4212 - val_loss: 0.5029 - val_acc: 0.7601 - val_rmse: 0.4047
# Epoch 205/600
#
# Epoch 00205: val_loss improved from 0.50287 to 0.50275, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5342 - acc: 0.7283 - rmse: 0.4213 - val_loss: 0.5027 - val_acc: 0.7601 - val_rmse: 0.4043
# Epoch 206/600
#
# Epoch 00206: val_loss improved from 0.50275 to 0.50257, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5340 - acc: 0.7283 - rmse: 0.4213 - val_loss: 0.5026 - val_acc: 0.7597 - val_rmse: 0.4044
# Epoch 207/600
#
# Epoch 00207: val_loss improved from 0.50257 to 0.50236, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5339 - acc: 0.7280 - rmse: 0.4212 - val_loss: 0.5024 - val_acc: 0.7575 - val_rmse: 0.4046
# Epoch 208/600
#
# Epoch 00208: val_loss did not improve from 0.50236
#  - 28s - loss: 0.5338 - acc: 0.7287 - rmse: 0.4212 - val_loss: 0.5024 - val_acc: 0.7601 - val_rmse: 0.4042
# Epoch 209/600
#
# Epoch 00209: val_loss improved from 0.50236 to 0.50217, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5336 - acc: 0.7286 - rmse: 0.4210 - val_loss: 0.5022 - val_acc: 0.7579 - val_rmse: 0.4045
# Epoch 210/600
#
# Epoch 00210: val_loss improved from 0.50217 to 0.50206, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5335 - acc: 0.7282 - rmse: 0.4210 - val_loss: 0.5021 - val_acc: 0.7593 - val_rmse: 0.4038
# Epoch 211/600
#
# Epoch 00211: val_loss improved from 0.50206 to 0.50189, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5334 - acc: 0.7279 - rmse: 0.4208 - val_loss: 0.5019 - val_acc: 0.7593 - val_rmse: 0.4042
# Epoch 212/600
#
# Epoch 00212: val_loss improved from 0.50189 to 0.50188, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5333 - acc: 0.7288 - rmse: 0.4207 - val_loss: 0.5019 - val_acc: 0.7597 - val_rmse: 0.4040
# Epoch 213/600
#
# Epoch 00213: val_loss improved from 0.50188 to 0.50169, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.5331 - acc: 0.7286 - rmse: 0.4206 - val_loss: 0.5017 - val_acc: 0.7588 - val_rmse: 0.4041
# Epoch 214/600
#
# Epoch 00214: val_loss improved from 0.50169 to 0.50161, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5330 - acc: 0.7284 - rmse: 0.4207 - val_loss: 0.5016 - val_acc: 0.7588 - val_rmse: 0.4041
# Epoch 215/600
#
# Epoch 00215: val_loss improved from 0.50161 to 0.50143, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.5329 - acc: 0.7278 - rmse: 0.4207 - val_loss: 0.5014 - val_acc: 0.7579 - val_rmse: 0.4033
# Epoch 216/600
#
# Epoch 00216: val_loss did not improve from 0.50143
#  - 29s - loss: 0.5327 - acc: 0.7285 - rmse: 0.4207 - val_loss: 0.5015 - val_acc: 0.7588 - val_rmse: 0.4039
# Epoch 217/600
#
# Epoch 00217: val_loss improved from 0.50143 to 0.50131, saving model to /tmp/LSTM_checkpoint.h5
#  - 26s - loss: 0.5325 - acc: 0.7286 - rmse: 0.4207 - val_loss: 0.5013 - val_acc: 0.7588 - val_rmse: 0.4042
# Epoch 218/600
#
# Epoch 00218: val_loss improved from 0.50131 to 0.50114, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5325 - acc: 0.7287 - rmse: 0.4207 - val_loss: 0.5011 - val_acc: 0.7579 - val_rmse: 0.4041
# Epoch 219/600
#
# Epoch 00219: val_loss improved from 0.50114 to 0.50104, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.5323 - acc: 0.7287 - rmse: 0.4204 - val_loss: 0.5010 - val_acc: 0.7579 - val_rmse: 0.4037
# Epoch 220/600
#
# Epoch 00220: val_loss improved from 0.50104 to 0.50094, saving model to /tmp/LSTM_checkpoint.h5
# ...
# Epoch 521/600
#
# Epoch 00521: val_loss improved from 0.47401 to 0.47395, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4988 - acc: 0.7532 - rmse: 0.4046 - val_loss: 0.4740 - val_acc: 0.7760 - val_rmse: 0.3917
# Epoch 522/600
#
# Epoch 00522: val_loss did not improve from 0.47395
#  - 34s - loss: 0.4987 - acc: 0.7527 - rmse: 0.4043 - val_loss: 0.4740 - val_acc: 0.7756 - val_rmse: 0.3911
# Epoch 523/600
#
# Epoch 00523: val_loss improved from 0.47395 to 0.47383, saving model to /tmp/LSTM_checkpoint.h5
#  - 36s - loss: 0.4986 - acc: 0.7533 - rmse: 0.4044 - val_loss: 0.4738 - val_acc: 0.7760 - val_rmse: 0.3913
# Epoch 524/600
#
# Epoch 00524: val_loss did not improve from 0.47383
#  - 31s - loss: 0.4986 - acc: 0.7529 - rmse: 0.4045 - val_loss: 0.4739 - val_acc: 0.7756 - val_rmse: 0.3909
# Epoch 525/600
#
# Epoch 00525: val_loss improved from 0.47383 to 0.47379, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.4985 - acc: 0.7531 - rmse: 0.4042 - val_loss: 0.4738 - val_acc: 0.7756 - val_rmse: 0.3911
# Epoch 526/600
#
# Epoch 00526: val_loss improved from 0.47379 to 0.47372, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.4984 - acc: 0.7533 - rmse: 0.4047 - val_loss: 0.4737 - val_acc: 0.7760 - val_rmse: 0.3918
# Epoch 527/600
#
# Epoch 00527: val_loss improved from 0.47372 to 0.47369, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4983 - acc: 0.7532 - rmse: 0.4044 - val_loss: 0.4737 - val_acc: 0.7747 - val_rmse: 0.3912
# Epoch 528/600
#
# Epoch 00528: val_loss improved from 0.47369 to 0.47358, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4983 - acc: 0.7533 - rmse: 0.4046 - val_loss: 0.4736 - val_acc: 0.7760 - val_rmse: 0.3911
# Epoch 529/600
#
# Epoch 00529: val_loss improved from 0.47358 to 0.47350, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.4982 - acc: 0.7526 - rmse: 0.4041 - val_loss: 0.4735 - val_acc: 0.7756 - val_rmse: 0.3902
# Epoch 530/600
#
# Epoch 00530: val_loss did not improve from 0.47350
#  - 31s - loss: 0.4981 - acc: 0.7531 - rmse: 0.4043 - val_loss: 0.4735 - val_acc: 0.7747 - val_rmse: 0.3910
# Epoch 531/600
#
# Epoch 00531: val_loss improved from 0.47350 to 0.47332, saving model to /tmp/LSTM_checkpoint.h5
#  - 28s - loss: 0.4981 - acc: 0.7528 - rmse: 0.4043 - val_loss: 0.4733 - val_acc: 0.7769 - val_rmse: 0.3908
# Epoch 532/600
#
# Epoch 00532: val_loss did not improve from 0.47332
#  - 27s - loss: 0.4980 - acc: 0.7536 - rmse: 0.4040 - val_loss: 0.4735 - val_acc: 0.7720 - val_rmse: 0.3912
# Epoch 533/600
#
# Epoch 00533: val_loss did not improve from 0.47332
#  - 31s - loss: 0.4981 - acc: 0.7536 - rmse: 0.4042 - val_loss: 0.4734 - val_acc: 0.7751 - val_rmse: 0.3903
# Epoch 534/600
#
# Epoch 00534: val_loss improved from 0.47332 to 0.47331, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.4979 - acc: 0.7539 - rmse: 0.4039 - val_loss: 0.4733 - val_acc: 0.7743 - val_rmse: 0.3908
# Epoch 535/600
#
# Epoch 00535: val_loss improved from 0.47331 to 0.47325, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.4978 - acc: 0.7526 - rmse: 0.4038 - val_loss: 0.4733 - val_acc: 0.7760 - val_rmse: 0.3902
# Epoch 536/600
#
# Epoch 00536: val_loss did not improve from 0.47325
#  - 30s - loss: 0.4976 - acc: 0.7533 - rmse: 0.4037 - val_loss: 0.4733 - val_acc: 0.7720 - val_rmse: 0.3912
# Epoch 537/600
#
# Epoch 00537: val_loss improved from 0.47325 to 0.47320, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.4976 - acc: 0.7529 - rmse: 0.4039 - val_loss: 0.4732 - val_acc: 0.7729 - val_rmse: 0.3903
# Epoch 538/600
#
# Epoch 00538: val_loss improved from 0.47320 to 0.47300, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.4975 - acc: 0.7531 - rmse: 0.4038 - val_loss: 0.4730 - val_acc: 0.7769 - val_rmse: 0.3908
# Epoch 539/600
#
# Epoch 00539: val_loss did not improve from 0.47300
#  - 28s - loss: 0.4974 - acc: 0.7532 - rmse: 0.4037 - val_loss: 0.4730 - val_acc: 0.7720 - val_rmse: 0.3907
# Epoch 540/600
#
# Epoch 00540: val_loss did not improve from 0.47300
#  - 28s - loss: 0.4974 - acc: 0.7536 - rmse: 0.4039 - val_loss: 0.4730 - val_acc: 0.7725 - val_rmse: 0.3914
# Epoch 541/600
#
# Epoch 00541: val_loss improved from 0.47300 to 0.47295, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.4973 - acc: 0.7538 - rmse: 0.4037 - val_loss: 0.4730 - val_acc: 0.7738 - val_rmse: 0.3908
# Epoch 542/600
#
# Epoch 00542: val_loss improved from 0.47295 to 0.47282, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4972 - acc: 0.7540 - rmse: 0.4037 - val_loss: 0.4728 - val_acc: 0.7756 - val_rmse: 0.3912
# Epoch 543/600
#
# Epoch 00543: val_loss improved from 0.47282 to 0.47268, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4972 - acc: 0.7535 - rmse: 0.4038 - val_loss: 0.4727 - val_acc: 0.7743 - val_rmse: 0.3906
# Epoch 544/600
#
# Epoch 00544: val_loss did not improve from 0.47268
#  - 27s - loss: 0.4971 - acc: 0.7541 - rmse: 0.4036 - val_loss: 0.4729 - val_acc: 0.7716 - val_rmse: 0.3905
# Epoch 545/600
#
# Epoch 00545: val_loss did not improve from 0.47268
#  - 28s - loss: 0.4970 - acc: 0.7538 - rmse: 0.4038 - val_loss: 0.4728 - val_acc: 0.7734 - val_rmse: 0.3909
# Epoch 546/600
#
# Epoch 00546: val_loss did not improve from 0.47268
#  - 27s - loss: 0.4970 - acc: 0.7541 - rmse: 0.4036 - val_loss: 0.4727 - val_acc: 0.7738 - val_rmse: 0.3906
# Epoch 547/600
#
# Epoch 00547: val_loss improved from 0.47268 to 0.47264, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.4969 - acc: 0.7538 - rmse: 0.4037 - val_loss: 0.4726 - val_acc: 0.7747 - val_rmse: 0.3902
# Epoch 548/600
#
# Epoch 00548: val_loss improved from 0.47264 to 0.47252, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.4968 - acc: 0.7531 - rmse: 0.4037 - val_loss: 0.4725 - val_acc: 0.7734 - val_rmse: 0.3912
# Epoch 549/600
#
# Epoch 00549: val_loss did not improve from 0.47252
#  - 27s - loss: 0.4968 - acc: 0.7535 - rmse: 0.4036 - val_loss: 0.4726 - val_acc: 0.7756 - val_rmse: 0.3908
# Epoch 550/600
#
# Epoch 00550: val_loss improved from 0.47252 to 0.47246, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4967 - acc: 0.7542 - rmse: 0.4036 - val_loss: 0.4725 - val_acc: 0.7738 - val_rmse: 0.3909
# Epoch 551/600
#
# Epoch 00551: val_loss improved from 0.47246 to 0.47238, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.4966 - acc: 0.7543 - rmse: 0.4036 - val_loss: 0.4724 - val_acc: 0.7747 - val_rmse: 0.3897
# Epoch 552/600
#
# Epoch 00552: val_loss did not improve from 0.47238
#  - 28s - loss: 0.4966 - acc: 0.7546 - rmse: 0.4034 - val_loss: 0.4724 - val_acc: 0.7734 - val_rmse: 0.3906
# Epoch 553/600
#
# Epoch 00553: val_loss improved from 0.47238 to 0.47230, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.4965 - acc: 0.7544 - rmse: 0.4035 - val_loss: 0.4723 - val_acc: 0.7725 - val_rmse: 0.3901
# Epoch 554/600
#
# Epoch 00554: val_loss improved from 0.47230 to 0.47227, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.4965 - acc: 0.7538 - rmse: 0.4033 - val_loss: 0.4723 - val_acc: 0.7751 - val_rmse: 0.3902
# Epoch 555/600
#
# Epoch 00555: val_loss did not improve from 0.47227
#  - 26s - loss: 0.4964 - acc: 0.7542 - rmse: 0.4033 - val_loss: 0.4723 - val_acc: 0.7729 - val_rmse: 0.3902
# Epoch 556/600
#
# Epoch 00556: val_loss improved from 0.47227 to 0.47222, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.4963 - acc: 0.7540 - rmse: 0.4034 - val_loss: 0.4722 - val_acc: 0.7747 - val_rmse: 0.3915
# Epoch 557/600
#
# Epoch 00557: val_loss improved from 0.47222 to 0.47212, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.4962 - acc: 0.7540 - rmse: 0.4032 - val_loss: 0.4721 - val_acc: 0.7738 - val_rmse: 0.3908
# Epoch 558/600
#
# Epoch 00558: val_loss did not improve from 0.47212
#  - 30s - loss: 0.4962 - acc: 0.7545 - rmse: 0.4033 - val_loss: 0.4722 - val_acc: 0.7729 - val_rmse: 0.3905
# Epoch 559/600
#
# Epoch 00559: val_loss did not improve from 0.47212
#  - 29s - loss: 0.4962 - acc: 0.7548 - rmse: 0.4034 - val_loss: 0.4721 - val_acc: 0.7734 - val_rmse: 0.3905
# Epoch 560/600
#
# Epoch 00560: val_loss improved from 0.47212 to 0.47209, saving model to /tmp/LSTM_checkpoint.h5
#  - 36s - loss: 0.4960 - acc: 0.7551 - rmse: 0.4034 - val_loss: 0.4721 - val_acc: 0.7743 - val_rmse: 0.3906
# Epoch 561/600
#
# Epoch 00561: val_loss improved from 0.47209 to 0.47201, saving model to /tmp/LSTM_checkpoint.h5
#  - 37s - loss: 0.4959 - acc: 0.7544 - rmse: 0.4032 - val_loss: 0.4720 - val_acc: 0.7734 - val_rmse: 0.3901
# Epoch 562/600
#
# Epoch 00562: val_loss did not improve from 0.47201
#  - 32s - loss: 0.4959 - acc: 0.7545 - rmse: 0.4031 - val_loss: 0.4720 - val_acc: 0.7734 - val_rmse: 0.3902
# Epoch 563/600
#
# Epoch 00563: val_loss improved from 0.47201 to 0.47193, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.4958 - acc: 0.7546 - rmse: 0.4033 - val_loss: 0.4719 - val_acc: 0.7738 - val_rmse: 0.3906
# Epoch 564/600
#
# Epoch 00564: val_loss improved from 0.47193 to 0.47187, saving model to /tmp/LSTM_checkpoint.h5
#  - 35s - loss: 0.4957 - acc: 0.7545 - rmse: 0.4029 - val_loss: 0.4719 - val_acc: 0.7738 - val_rmse: 0.3897
# Epoch 565/600
#
# Epoch 00565: val_loss improved from 0.47187 to 0.47178, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.4957 - acc: 0.7548 - rmse: 0.4031 - val_loss: 0.4718 - val_acc: 0.7743 - val_rmse: 0.3908
# Epoch 566/600
#
# Epoch 00566: val_loss did not improve from 0.47178
#  - 31s - loss: 0.4956 - acc: 0.7543 - rmse: 0.4029 - val_loss: 0.4718 - val_acc: 0.7738 - val_rmse: 0.3905
# Epoch 567/600
#
# Epoch 00567: val_loss did not improve from 0.47178
#  - 32s - loss: 0.4956 - acc: 0.7547 - rmse: 0.4029 - val_loss: 0.4718 - val_acc: 0.7725 - val_rmse: 0.3897
# Epoch 568/600
#
# Epoch 00568: val_loss improved from 0.47178 to 0.47169, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.4955 - acc: 0.7547 - rmse: 0.4031 - val_loss: 0.4717 - val_acc: 0.7738 - val_rmse: 0.3898
# Epoch 569/600
#
# Epoch 00569: val_loss improved from 0.47169 to 0.47165, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.4955 - acc: 0.7555 - rmse: 0.4029 - val_loss: 0.4717 - val_acc: 0.7751 - val_rmse: 0.3905
# Epoch 570/600
#
# Epoch 00570: val_loss improved from 0.47165 to 0.47160, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.4953 - acc: 0.7549 - rmse: 0.4028 - val_loss: 0.4716 - val_acc: 0.7756 - val_rmse: 0.3904
# Epoch 571/600
#
# Epoch 00571: val_loss did not improve from 0.47160
#  - 30s - loss: 0.4953 - acc: 0.7549 - rmse: 0.4029 - val_loss: 0.4716 - val_acc: 0.7738 - val_rmse: 0.3903
# Epoch 572/600
#
# Epoch 00572: val_loss improved from 0.47160 to 0.47148, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.4953 - acc: 0.7548 - rmse: 0.4030 - val_loss: 0.4715 - val_acc: 0.7743 - val_rmse: 0.3905
# Epoch 573/600
#
# Epoch 00573: val_loss improved from 0.47148 to 0.47144, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.4951 - acc: 0.7550 - rmse: 0.4027 - val_loss: 0.4714 - val_acc: 0.7760 - val_rmse: 0.3904
# Epoch 574/600
#
# Epoch 00574: val_loss improved from 0.47144 to 0.47143, saving model to /tmp/LSTM_checkpoint.h5
#  - 27s - loss: 0.4951 - acc: 0.7553 - rmse: 0.4027 - val_loss: 0.4714 - val_acc: 0.7747 - val_rmse: 0.3905
# Epoch 575/600
#
# Epoch 00575: val_loss improved from 0.47143 to 0.47134, saving model to /tmp/LSTM_checkpoint.h5
#  - 29s - loss: 0.4950 - acc: 0.7554 - rmse: 0.4026 - val_loss: 0.4713 - val_acc: 0.7751 - val_rmse: 0.3905
# Epoch 576/600
#
# Epoch 00576: val_loss improved from 0.47134 to 0.47125, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.4950 - acc: 0.7552 - rmse: 0.4027 - val_loss: 0.4712 - val_acc: 0.7751 - val_rmse: 0.3905
# Epoch 577/600
#
# Epoch 00577: val_loss did not improve from 0.47125
#  - 30s - loss: 0.4949 - acc: 0.7550 - rmse: 0.4027 - val_loss: 0.4713 - val_acc: 0.7751 - val_rmse: 0.3893
# Epoch 578/600
#
# Epoch 00578: val_loss did not improve from 0.47125
#  - 30s - loss: 0.4948 - acc: 0.7550 - rmse: 0.4025 - val_loss: 0.4714 - val_acc: 0.7756 - val_rmse: 0.3902
# Epoch 579/600
#
# Epoch 00579: val_loss improved from 0.47125 to 0.47124, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.4948 - acc: 0.7553 - rmse: 0.4024 - val_loss: 0.4712 - val_acc: 0.7760 - val_rmse: 0.3898
# Epoch 580/600
#
# Epoch 00580: val_loss did not improve from 0.47124
#  - 31s - loss: 0.4947 - acc: 0.7556 - rmse: 0.4023 - val_loss: 0.4713 - val_acc: 0.7760 - val_rmse: 0.3903
# Epoch 581/600
#
# Epoch 00581: val_loss improved from 0.47124 to 0.47111, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4946 - acc: 0.7560 - rmse: 0.4025 - val_loss: 0.4711 - val_acc: 0.7756 - val_rmse: 0.3899
# Epoch 582/600
#
# Epoch 00582: val_loss did not improve from 0.47111
#  - 30s - loss: 0.4946 - acc: 0.7557 - rmse: 0.4024 - val_loss: 0.4712 - val_acc: 0.7760 - val_rmse: 0.3905
# Epoch 583/600
#
# Epoch 00583: val_loss did not improve from 0.47111
#  - 31s - loss: 0.4945 - acc: 0.7561 - rmse: 0.4024 - val_loss: 0.4712 - val_acc: 0.7756 - val_rmse: 0.3898
# Epoch 584/600
#
# Epoch 00584: val_loss improved from 0.47111 to 0.47096, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4945 - acc: 0.7561 - rmse: 0.4026 - val_loss: 0.4710 - val_acc: 0.7765 - val_rmse: 0.3902
# Epoch 585/600
#
# Epoch 00585: val_loss did not improve from 0.47096
#  - 30s - loss: 0.4945 - acc: 0.7562 - rmse: 0.4025 - val_loss: 0.4710 - val_acc: 0.7756 - val_rmse: 0.3900
# Epoch 586/600
#
# Epoch 00586: val_loss improved from 0.47096 to 0.47087, saving model to /tmp/LSTM_checkpoint.h5
#  - 32s - loss: 0.4944 - acc: 0.7560 - rmse: 0.4025 - val_loss: 0.4709 - val_acc: 0.7756 - val_rmse: 0.3904
# Epoch 587/600
#
# Epoch 00587: val_loss did not improve from 0.47087
#  - 30s - loss: 0.4943 - acc: 0.7555 - rmse: 0.4026 - val_loss: 0.4710 - val_acc: 0.7773 - val_rmse: 0.3896
# Epoch 588/600
#
# Epoch 00588: val_loss did not improve from 0.47087
#  - 29s - loss: 0.4942 - acc: 0.7568 - rmse: 0.4027 - val_loss: 0.4709 - val_acc: 0.7756 - val_rmse: 0.3900
# Epoch 589/600
#
# Epoch 00589: val_loss improved from 0.47087 to 0.47083, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4942 - acc: 0.7553 - rmse: 0.4022 - val_loss: 0.4708 - val_acc: 0.7773 - val_rmse: 0.3897
# Epoch 590/600
#
# Epoch 00590: val_loss did not improve from 0.47083
#  - 31s - loss: 0.4941 - acc: 0.7569 - rmse: 0.4023 - val_loss: 0.4709 - val_acc: 0.7778 - val_rmse: 0.3900
# Epoch 591/600
#
# Epoch 00591: val_loss improved from 0.47083 to 0.47066, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.4940 - acc: 0.7566 - rmse: 0.4023 - val_loss: 0.4707 - val_acc: 0.7743 - val_rmse: 0.3899
# Epoch 592/600
#
# Epoch 00592: val_loss did not improve from 0.47066
#  - 30s - loss: 0.4940 - acc: 0.7569 - rmse: 0.4024 - val_loss: 0.4707 - val_acc: 0.7751 - val_rmse: 0.3904
# Epoch 593/600
#
# Epoch 00593: val_loss improved from 0.47066 to 0.47056, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4939 - acc: 0.7562 - rmse: 0.4022 - val_loss: 0.4706 - val_acc: 0.7734 - val_rmse: 0.3899
# Epoch 594/600
#
# Epoch 00594: val_loss did not improve from 0.47056
#  - 30s - loss: 0.4938 - acc: 0.7560 - rmse: 0.4025 - val_loss: 0.4707 - val_acc: 0.7760 - val_rmse: 0.3897
# Epoch 595/600
#
# Epoch 00595: val_loss did not improve from 0.47056
#  - 30s - loss: 0.4938 - acc: 0.7577 - rmse: 0.4018 - val_loss: 0.4707 - val_acc: 0.7751 - val_rmse: 0.3895
# Epoch 596/600
#
# Epoch 00596: val_loss improved from 0.47056 to 0.47052, saving model to /tmp/LSTM_checkpoint.h5
#  - 31s - loss: 0.4938 - acc: 0.7566 - rmse: 0.4022 - val_loss: 0.4705 - val_acc: 0.7747 - val_rmse: 0.3903
# Epoch 597/600
#
# Epoch 00597: val_loss did not improve from 0.47052
#  - 30s - loss: 0.4937 - acc: 0.7563 - rmse: 0.4022 - val_loss: 0.4705 - val_acc: 0.7751 - val_rmse: 0.3903
# Epoch 598/600
#
# Epoch 00598: val_loss did not improve from 0.47052
#  - 30s - loss: 0.4937 - acc: 0.7582 - rmse: 0.4021 - val_loss: 0.4706 - val_acc: 0.7747 - val_rmse: 0.3901
# Epoch 599/600
#
# Epoch 00599: val_loss improved from 0.47052 to 0.47042, saving model to /tmp/LSTM_checkpoint.h5
#  - 33s - loss: 0.4936 - acc: 0.7573 - rmse: 0.4018 - val_loss: 0.4704 - val_acc: 0.7747 - val_rmse: 0.3899
# Epoch 600/600
#
# Epoch 00600: val_loss improved from 0.47042 to 0.47041, saving model to /tmp/LSTM_checkpoint.h5
#  - 30s - loss: 0.4935 - acc: 0.7577 - rmse: 0.4025 - val_loss: 0.4704 - val_acc: 0.7751 - val_rmse: 0.3892
# Classification accuracy: 0.773369

# %%
# list all data in history
#print(fitted_model.history.keys())

print('Diagrammed History of Model Metrics')

# summarize history for accuracy
plt.plot(fitted_model.history['acc'])
plt.plot(fitted_model.history['val_acc'])
plt.title('Model Accuracy over Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Diagrammed History of Model Metrics
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4d0648aed029> in <module>()
#       3
#       4 # summarize history for accuracy
# ----> 5 plt.plot(fitted_model.history['acc'])
#       6 plt.plot(fitted_model.history['val_acc'])
#       7 plt.title('Model Accuracy over Epochs')
#
# NameError: name 'plt' is not defined

# %%
# summarize history for rmse
plt.plot(fitted_model.history['rmse'])
plt.plot(fitted_model.history['val_rmse'])
plt.title('Model RMSE over Epochs')
plt.ylabel('RMSE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# summarize loss history
plt.plot(fitted_model.history['loss'])
plt.plot(fitted_model.history['val_loss'])
plt.title('Model Loss over Epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# !pip freeze
# Out:
# absl-py==0.9.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.0.0
# asgiref==3.2.3
# astor==0.8.1
# astropy==4.0
# atari-py==0.2.6
# atomicwrites==1.3.0
# attrs==19.3.0
# audioread==2.1.8
# autograd==1.3
# Babel==2.8.0
# backcall==0.1.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.6.3
# bleach==3.1.0
# blis==0.2.4
# bokeh==1.4.0
# boto==2.49.0
# boto3==1.10.47
# botocore==1.13.47
# Bottleneck==1.3.1
# branca==0.3.1
# bs4==0.0.1
# bz2file==0.98
# cachetools==4.0.0
# certifi==2019.11.28
# cffi==1.13.2
# chainer==6.5.0
# chardet==3.0.4
# chart-studio==1.0.0
# Click==7.0
# cloudpickle==1.2.2
# cmake==3.12.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.2.0
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.0
# cupy-cuda101==6.5.0
# cvxopt==1.2.3
# cvxpy==1.0.25
# cycler==0.10.0
# cymem==2.0.3
# Cython==0.29.14
# daft==0.0.4
# dask==2.9.1
# dataclasses==0.7
# datascience==0.10.6
# decorator==4.4.1
# defusedxml==0.6.0
# descartes==1.1.0
# dill==0.3.1.1
# distributed==1.25.3
# Django==3.0.2
# dlib==19.18.0
# dm-sonnet==1.35
# docopt==0.6.2
# docutils==0.15.2
# dopamine-rl==1.0.5
# earthengine-api==0.1.209
# easydict==1.9
# ecos==2.0.7.post1
# editdistance==0.5.3
# en-core-web-sm==2.1.0
# entrypoints==0.3
# et-xmlfile==1.0.1
# fa2==0.3.5
# fancyimpute==0.4.3
# fastai==1.0.60
# fastcache==1.1.0
# fastdtw==0.3.4
# fastprogress==0.2.2
# fastrlock==0.4
# fbprophet==0.5
# feather-format==0.4.0
# featuretools==0.4.1
# filelock==3.0.12
# fix-yahoo-finance==0.0.22
# Flask==1.1.1
# folium==0.8.3
# fsspec==0.6.2
# future==0.16.0
# gast==0.2.2
# GDAL==2.2.2
# gdown==3.6.4
# gensim==3.6.0
# geographiclib==1.50
# geopy==1.17.0
# gevent==1.4.0
# gin-config==0.3.0
# glob2==0.7
# google==2.0.3
# google-api-core==1.15.0
# google-api-python-client==1.7.11
# google-auth==1.4.2
# google-auth-httplib2==0.0.3
# google-auth-oauthlib==0.4.1
# google-cloud-bigquery==1.21.0
# google-cloud-core==1.0.3
# google-cloud-datastore==1.8.0
# google-cloud-language==1.2.0
# google-cloud-storage==1.16.2
# google-cloud-translate==1.5.0
# google-colab==1.0.0
# google-pasta==0.1.8
# google-resumable-media==0.4.1
# googleapis-common-protos==1.6.0
# googledrivedownloader==0.4
# graph-nets==1.0.5
# graphviz==0.10.1
# greenlet==0.4.15
# grpcio==1.15.0
# gspread==3.0.1
# gspread-dataframe==3.0.3
# gunicorn==20.0.4
# gym==0.15.4
# h5py==2.8.0
# HeapDict==1.0.1
# holidays==0.9.12
# html5lib==1.0.1
# httpimport==0.5.18
# httplib2==0.11.3
# humanize==0.5.1
# hyperopt==0.1.2
# ideep4py==2.0.0.post3
# idna==2.8
# image==1.5.27
# imageio==2.4.1
# imagesize==1.2.0
# imbalanced-learn==0.4.3
# imblearn==0.0
# imgaug==0.2.9
# importlib-metadata==1.4.0
# imutils==0.5.3
# inflect==2.1.0
# intel-openmp==2020.0.133
# intervaltree==2.1.0
# ipykernel==4.6.1
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# ipywidgets==7.5.1
# itsdangerous==1.1.0
# jax==0.1.52
# jaxlib==0.1.36
# jdcal==1.4.1
# jedi==0.15.2
# jieba==0.40
# Jinja2==2.10.3
# jmespath==0.9.4
# joblib==0.14.1
# jpeg4py==0.1.4
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==5.2.0
# jupyter-core==4.6.1
# kaggle==1.5.6
# kapre==0.1.3.1
# Keras==2.2.5
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# keras-vis==0.4.1
# kfac==0.2.0
# kiwisolver==1.1.0
# knnimpute==0.1.0
# librosa==0.6.3
# lightgbm==2.2.3
# llvmlite==0.31.0
# lmdb==0.98
# lucid==0.3.8
# lunardate==0.2.0
# lxml==4.2.6
# magenta==0.3.19
# Markdown==3.1.1
# MarkupSafe==1.1.1
# matplotlib==3.1.2
# matplotlib-venn==0.11.5
# mesh-tensorflow==0.1.8
# mido==1.2.6
# mir-eval==0.5
# missingno==0.4.2
# mistune==0.8.4
# mizani==0.6.0
# mkl==2019.0
# mlxtend==0.14.0
# mne==0.19.2
# more-itertools==8.0.2
# moviepy==0.2.3.5
# mpi4py==3.0.3
# mpmath==1.1.0
# msgpack==0.5.6
# multiprocess==0.70.9
# multitasking==0.0.9
# murmurhash==1.0.2
# music21==5.5.0
# natsort==5.5.0
# nbconvert==5.6.1
# nbformat==5.0.3
# networkx==2.4
# nibabel==2.3.3
# nltk==3.2.5
# notebook==5.2.2
# np-utils==0.5.12.1
# numba==0.47.0
# numexpr==2.7.1
# numpy==1.17.5
# nvidia-ml-py3==7.352.0
# oauth2client==4.1.3
# oauthlib==3.1.0
# okgrade==0.4.3
# opencv-contrib-python==4.1.2.30
# opencv-python==4.1.2.30
# openpyxl==2.5.9
# opt-einsum==3.1.0
# osqp==0.6.1
# packaging==20.0
# palettable==3.3.0
# pandas==0.25.3
# pandas-datareader==0.7.4
# pandas-gbq==0.11.0
# pandas-profiling==1.4.1
# pandocfilters==1.4.2
# parso==0.5.2
# pathlib==1.0.1
# patsy==0.5.1
# pexpect==4.7.0
# pickleshare==0.7.5
# Pillow==6.2.2
# pip-tools==4.2.0
# plac==0.9.6
# plotly==4.4.1
# plotnine==0.6.0
# pluggy==0.7.1
# portpicker==1.2.0
# prefetch-generator==1.0.1
# preshed==2.0.1
# pretty-midi==0.2.8
# prettytable==0.7.2
# progressbar2==3.38.0
# prometheus-client==0.7.1
# promise==2.3
# prompt-toolkit==1.0.18
# protobuf==3.10.0
# psutil==5.4.8
# psycopg2==2.7.6.1
# ptyprocess==0.6.0
# py==1.8.1
# pyarrow==0.14.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.7
# pycocotools==2.0.0
# pycparser==2.19
# pydata-google-auth==0.2.1
# pydot==1.3.0
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyEDFlib==0.1.15
# pyemd==0.5.1
# pyglet==1.3.2
# Pygments==2.1.3
# pygobject==3.26.1
# pymc3==3.7
# PyMeeus==0.3.6
# pymongo==3.10.0
# pymystem3==0.2.0
# PyOpenGL==3.1.5
# pyparsing==2.4.6
# pypng==0.0.20
# pyrsistent==0.15.7
# pysndfile==1.3.8
# PySocks==1.7.1
# pystan==2.19.1.1
# pytest==3.6.4
# python-apt==1.6.4
# python-chess==0.23.11
# python-dateutil==2.6.1
# python-louvain==0.13
# python-rtmidi==1.3.1
# python-slugify==4.0.0
# python-utils==2.3.0
# pytz==2018.9
# PyWavelets==1.1.1
# PyYAML==3.13
# pyzmq==17.0.0
# qtconsole==4.6.0
# regex==2019.12.20
# requests==2.21.0
# requests-oauthlib==1.3.0
# resampy==0.2.2
# retrying==1.3.3
# rpy2==2.9.5
# rsa==4.0
# s3fs==0.4.0
# s3transfer==0.2.1
# scikit-image==0.16.2
# scikit-learn==0.22.1
# scipy==1.4.1
# screen-resolution-extra==0.0.0
# scs==2.1.1.post2
# seaborn==0.9.0
# semantic-version==2.8.4
# Send2Trash==1.5.0
# setuptools-git==1.2
# Shapely==1.6.4.post2
# simplegeneric==0.8.1
# six==1.12.0
# sklearn==0.0
# sklearn-pandas==1.8.0
# smart-open==1.9.0
# snowballstemmer==2.0.0
# sortedcontainers==2.1.0
# spacy==2.1.9
# Sphinx==1.8.5
# sphinxcontrib-websupport==1.1.2
# SQLAlchemy==1.3.12
# sqlparse==0.3.0
# srsly==1.0.1
# stable-baselines==2.2.1
# statsmodels==0.10.2
# sympy==1.1.1
# tables==3.4.4
# tabulate==0.8.6
# tblib==1.6.0
# tensor2tensor==1.14.1
# tensorboard==1.15.0
# tensorboardcolab==0.0.22
# tensorflow==1.15.0
# tensorflow-datasets==1.3.2
# tensorflow-estimator==1.15.1
# tensorflow-gan==2.0.0
# tensorflow-hub==0.7.0
# tensorflow-metadata==0.15.2
# tensorflow-privacy==0.2.2
# tensorflow-probability==0.7.0
# termcolor==1.1.0
# terminado==0.8.3
# testpath==0.4.4
# text-unidecode==1.3
# textblob==0.15.3
# textgenrnn==1.4.1
# tflearn==0.3.2
# Theano==1.0.4
# thinc==7.0.8
# toolz==0.10.0
# torch==1.3.1
# torchsummary==1.5.1
# torchtext==0.3.1
# torchvision==0.4.2
# tornado==4.5.3
# tqdm==4.28.1
# traitlets==4.3.3
# tweepy==3.6.0
# typing==3.6.6
# typing-extensions==3.6.6
# tzlocal==1.5.1
# umap-learn==0.3.10
# uritemplate==3.0.1
# urllib3==1.24.3
# vega-datasets==0.8.0
# wasabi==0.6.0
# wcwidth==0.1.8
# webencodings==0.5.1
# Werkzeug==0.16.0
# widgetsnbextension==3.5.1
# wordcloud==1.5.0
# wrapt==1.11.2
# xarray==0.14.1
# xgboost==0.90
# xkit==0.0.0
# xlrd==1.1.0
# xlwt==1.3.0
# yellowbrick==0.9.1
# zict==1.0.0
# zipp==0.6.0
# zmq==0.0.0

# %%
from platform import python_version

print(python_version())
# Out:
# 3.6.9
