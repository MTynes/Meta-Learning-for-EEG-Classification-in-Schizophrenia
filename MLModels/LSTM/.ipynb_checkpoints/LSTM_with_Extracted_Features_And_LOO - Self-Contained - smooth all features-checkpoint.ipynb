# %%
import os
raw_data_dir = ''

if  'COLAB_GPU' in os.environ:
    print('Using Google Colab. Setting up environment')
    raw_data_dir = '/content/drive/My Drive/Colab Notebooks/' 
    # !pip install mne
    # !pip install pyedflib

    print('\n \n To load files from Google Drive, account validation is required.')
    #mount to drive -- files should be located in the Colab notebooks directory
    from google.colab import drive
    drive.mount("/content/drive", force_remount=True)
else:
    if 'HOMEPATH' in os.environ:
        print('Using homepath ' + os.environ['HOMEPATH'])
    raw_data_dir = '../../Data/Raw/'
# Out:
# Using homepath \Users\marit

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

import pandas as pd
import pyedflib


import tensorflow as tf
use_gpu = tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)


import numpy as np

# mne imports
import mne
from mne import io

from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint


# tools for plotting confusion matrices
from matplotlib import pyplot as plt

import random 
import math
# Out:
# C:\Users\marit\Anaconda3\lib\site-packages\numba\decorators.py:146: RuntimeWarning: Caching is not available when the 'parallel' target is in use. Caching is now being disabled to allow execution to continue.
#   warnings.warn(msg, RuntimeWarning)

# %%
#### Get all raw data

from IPython.display import Markdown, display

# edf libraries
import pyedflib
import mne

#pca dependencies
from sklearn import decomposition

ignore_list = ['s07']  #list of patient files that should be skipped
sample_size = 20

import pyedflib
mne.set_log_level("WARNING")

# get the minimum length of the files
def get_minimum_duration(group_directory_name, patient_group_file_prefix):
    file_durations = []
    for i in range (1, 15): # reading 14 files
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        file_name = raw_data_dir + '{}/{}.edf'.format(group_directory_name, patient_id)
        f = pyedflib.EdfReader(file_name)
        file_durations.append(f.file_duration)
        f.close()
    return(min(file_durations))






    
    
def process_patient_group_all_data(group_directory_name, patient_group_file_prefix, 
                          minimum_original_duration, 
                          plot_channels = False):
    meta = []
    patient_id_list = []
    for i in range (1, 15): # reading 14 files
        patient_df = []
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        patient_id_list.append(patient_id)
        
        file_name = raw_data_dir + '{}/{}.edf'.format(group_directory_name, patient_id)
        data = mne.io.read_raw_edf(file_name)
        df = data.to_data_frame()
        ## drop the first 120 seconds and last 120 seconds
        df2 = df[120: (minimum_original_duration-120)]
        if patient_id not in ignore_list:
            meta.append(np.asarray(df2))
           
                    
    return meta



#
all_channels = ['Fp2', 'F8', 'T4', 'T6', 'O2', 'Fp1', 'F7', 'T3', 'T5', 'O1', 'F4',
                'C4', 'P4', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Pz']
#target_channels = ['T4', 'T6', 'O2', 'T3', 'T5', 'O1',
#                   'C4', 'P4', 'C3', 'P3', 'Cz', 'Pz']

minimum_duration = min(get_minimum_duration("Healthy Controls", "h"), get_minimum_duration('SZ Patients', 's'))
print('Retrieving raw data....')
print('Minimum file duration: {} seconds'.format( minimum_duration))
print("Healthy Controls:")
hc_data_all = np.asarray(process_patient_group_all_data('Healthy Controls', 'h', minimum_duration), dtype=np.float32)
print(np.asarray(hc_data_all).shape)


print('Sz Patients:')
sz_data_all = np.asarray(process_patient_group_all_data('SZ Patients', 's', minimum_duration), dtype=np.float32)
print(np.asarray(sz_data_all).shape)




###
# Out:
# Retrieving raw data....
# Minimum file duration: 740 seconds
# Healthy Controls:
# (14, 500, 19)
# Sz Patients:
# (13, 500, 19)

# %%
def select_denoised_data(patient_data):
    all_entries = []
    for entry in patient_data:
        all_features.append(entry)
        
    
    pca_denoise = decomposition.PCA(n_components=12)
    pca_denoise.fit(all_entries.transpose())
    denoised_data = pca_denoise.components_
    all_features.append(np.asarray(denoised_data)) 
        
    return all_features
    

sample_size = minimum_duration #use entire window
#send all channels and all patient data; s07 is still skipped
hc_data_all_denoised_selected = select_denoised_data(hc_data_all)
sz_data_all_denoised_selected = select_denoised_data(sz_data_all)

print('Shape of denoised data (extracted components) :')
print(np.asarray(hc_data_all_denoised_selected).shape)
print(np.asarray(sz_data_all_denoised_selected).shape)
# Out:
# Shape of denoised data (extracted components) :
# (14, 12, 500)
# (13, 12, 500)

# %%
def select_denoised_data(patient_data, num_components=12):
    pds = np.asarray(patient_data).shape
    print(pds)
    all_entries = patient_data.reshape(pds[0] * pds[1], pds[2])
    
    print(np.asarray(all_entries).shape)
        
    #print(np.asarray(all_entries).shape)
    pca = decomposition.PCA(n_components=num_components)
    pca.fit(all_entries.transpose())
    denoised_data = pca.components_
    #print('denoised data shape: ', denoised_data.shape)
    all_features = []
    all_features = denoised_data.reshape(pds[0], pds[1], num_components)
    #for i in range(patient_data):
    #    all_features.append(np.asarray(denoised_data)) 
    
    return all_features
    

sample_size = minimum_duration #use entire window
#send all channels and all patient data; s07 is still skipped
#hc_data_all_denoised_selected = select_denoised_data(hc_data_all)
#sz_data_all_denoised_selected = select_denoised_data(sz_data_all)
combined_raw_data = np.concatenate((hc_data_all, sz_data_all), axis=0)
denoised_data = select_denoised_data(combined_raw_data)


print('Shape of denoised data (extracted components) :')
print(np.asarray(denoised_data).shape)
#print(np.asarray(sz_data_all_denoised_selected).shape)
# Out:
# (27, 500, 19)
# (13500, 19)
# Shape of denoised data (extracted components) :
# (27, 500, 12)

# %%
#setup the network
from tensorflow.keras import layers
#https://www.tensorflow.org/guide/keras/rnn

def LSTM(samples, time_steps, nb_features, chans, nb_classes):

    model=tf.keras.Sequential()
    
    model.add(layers.LSTM(256,
                          input_shape=(chans, time_steps)
            #input_shape=(chans* nb_features, time_steps),
            ))

    model.add(Dense(32,kernel_initializer='he_uniform',activation='relu'))

    model.add(Dense(nb_classes,activation='softmax'))
    
    return model

# %%
X =  denoised_data #np.concatenate((hc_data_all_denoised_selected, sz_data_all_denoised_selected), axis=0)
print('Input size: ', X.shape)
y = ([0] * len(hc_data_all)) +( [1] * len(sz_data_all))
# Out:
# Input size:  (27, 500, 12)

# %%
#X[1].plot()
from IPython.display import display

import pylab as pylab
plt.figure(figsize=(20,10))

print('Input (X) shape: ' + str(X.shape))
print('Preview of data. First sample of extracted and cleaned data ', X[0].shape )
for el in X[0]:
    #print(el)
    #pylab.scatter(x=range(len(el)), y=el)
    pylab.plot(el)
# Out:
# Input (X) shape: (27, 500, 12)
# Preview of data. First sample of extracted and cleaned data  (500, 12)

# %%
#### Create the /tmp directory if it doesn't already exist
import os
if not os.path.exists('tmp'):
    os.makedirs('tmp')

# %%
#### Implement Leave One Out

log_train_accuracy = []
log_validation_accuracy = []
log_train_rmse = []
log_validation_rmse = []
log_train_loss = []
log_validation_loss = []

full_train_accuracy = []
full_validation_accuracy = []
full_train_rmse = []
full_validation_rmse = []
full_train_loss = []
full_validation_loss = []

for i, entry in enumerate(X):
    X_validate = X[i]
    X_train = np.delete(X, i, axis=0)
    Y_validate = np.asarray([y[i]])
    Y_train = np.delete(y, i, axis=0)
    
    time_steps = 500 #sample_size #seconds of data to include in one slice

    kernels, chans, samples = 1, 12, time_steps
    full_size = len(X)

    # convert labels to one-hot encodings.
    Y_train      = np_utils.to_categorical(Y_train, num_classes=2)
    Y_validate   = np_utils.to_categorical(Y_validate, num_classes=2)
    #Y_test       = np_utils.to_categorical(Y_test, num_classes=2)


    print(X_train.shape)
    X_train      = X_train.reshape(X_train.shape[0],   chans, time_steps,)
    X_validate   = X_validate.reshape(1, chans, time_steps)
    #X_test       = X_test.reshape(X_test.shape[0], chans, time_steps)


    print('X_train shape:', X_train.shape)
    print(X_train.shape[0], 'train samples')


    model = LSTM(samples=samples, time_steps=time_steps, chans=chans, nb_features=1, nb_classes=2, )
    model.summary()

    #import tensorflow 
    import tensorflow.keras.optimizers
    opt_adam = tensorflow.keras.optimizers.Adam(lr=0.000001, 
                                    beta_1=0.99,
                                    beta_2=0.999,
                                    epsilon=1e-07)
    sgd = tensorflow.keras.optimizers.SGD(lr=0.01)



    def rmse (y_true, y_pred):

        return K.sqrt(K.mean(K.square(y_pred -y_true)))

    def rmse_np (y_true, y_pred):
        y_true = y_true.astype(int)
        y_pred=y_pred.astype(int)
        print(y_pred.dtype)
        return K.sqrt(K.mean(K.square(y_pred -y_true)))

    # compile the model and set the optimizers
    model.compile(loss='categorical_crossentropy', optimizer=opt_adam, 
                  metrics=[#'mse', 'mae', 
                      'accuracy', rmse
                     ])


    # count number of parameters in the model
    numParams    = model.count_params()    

    # set a valid path for your system to record model checkpoints
    checkpointer = ModelCheckpoint(filepath='/tmp/LSTM_checkpoint.h5', verbose=1,
                                   save_best_only=True)
    
    fitted_model = model.fit(X_train, Y_train, batch_size = 32, epochs = 300, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer])#, class_weight = class_weights)


    log_train_accuracy.append(fitted_model.history['acc'][-1])
    log_validation_accuracy.append(fitted_model.history['val_acc'][-1])
    log_train_rmse.append(fitted_model.history['rmse'][-1])
    log_validation_rmse.append(fitted_model.history['val_rmse'][-1])
    log_train_loss.append(fitted_model.history['loss'][-1])
    log_validation_loss.append(fitted_model.history['val_loss'][-1])
    
    full_train_accuracy.append(fitted_model.history['acc'])
    full_validation_accuracy.append(fitted_model.history['val_acc'])
    full_train_rmse.append(fitted_model.history['rmse'])
    full_validation_rmse.append(fitted_model.history['val_rmse'])
    full_train_loss.append(fitted_model.history['loss'])
    full_validation_loss.append(fitted_model.history['val_loss'])
# Out:
# (26, 500, 12)
# X_train shape: (26, 12, 500)
# 26 train samples
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_27 (LSTM)               (None, 256)               775168
# _________________________________________________________________
# dense_54 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dense_55 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 783,458
# Trainable params: 783,458
# Non-trainable params: 0
# _________________________________________________________________
# Train on 26 samples, validate on 1 samples
# Epoch 1/300
#
# Epoch 00001: val_loss improved from inf to 0.69363, saving model to /tmp/LSTM_checkpoint.h5
#  - 24s - loss: 0.6925 - acc: 0.7308 - rmse: 0.4997 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 2/300
#
# Epoch 00002: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6925 - acc: 0.7308 - rmse: 0.4997 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 3/300
#
# Epoch 00003: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6925 - acc: 0.7308 - rmse: 0.4997 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 4/300
#
# Epoch 00004: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6925 - acc: 0.7308 - rmse: 0.4997 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 5/300
#
# Epoch 00005: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6925 - acc: 0.7308 - rmse: 0.4997 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 6/300
#
# Epoch 00006: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6925 - acc: 0.7308 - rmse: 0.4997 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 7/300
#
# Epoch 00007: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6925 - acc: 0.7308 - rmse: 0.4997 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 8/300
#
# Epoch 00008: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4997 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 9/300
#
# Epoch 00009: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 10/300
#
# Epoch 00010: val_loss did not improve from 0.69363
#  - 2s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 11/300
#
# Epoch 00011: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 12/300
#
# Epoch 00012: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 13/300
#
# Epoch 00013: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 14/300
#
# Epoch 00014: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 15/300
#
# Epoch 00015: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 16/300
#
# Epoch 00016: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 17/300
#
# Epoch 00017: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 18/300
#
# Epoch 00018: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 19/300
#
# Epoch 00019: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 20/300
#
# Epoch 00020: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 21/300
#
# Epoch 00021: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 22/300
#
# Epoch 00022: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6924 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 23/300
#
# Epoch 00023: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 24/300
#
# Epoch 00024: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 25/300
#
# Epoch 00025: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 26/300
#
# Epoch 00026: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 27/300
#
# Epoch 00027: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 28/300
#
# Epoch 00028: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 29/300
#
# Epoch 00029: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 30/300
#
# Epoch 00030: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 31/300
#
# Epoch 00031: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 32/300
#
# Epoch 00032: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 33/300
#
# Epoch 00033: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 34/300
#
# Epoch 00034: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 35/300
#
# Epoch 00035: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 36/300
#
# Epoch 00036: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 37/300
#
# Epoch 00037: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6923 - acc: 0.7308 - rmse: 0.4996 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 38/300
#
# Epoch 00038: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 39/300
#
# Epoch 00039: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 40/300
#
# Epoch 00040: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 41/300
#
# Epoch 00041: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 42/300
#
# Epoch 00042: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 43/300
#
# Epoch 00043: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 44/300
#
# Epoch 00044: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 45/300
#
# Epoch 00045: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 46/300
#
# Epoch 00046: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 47/300
#
# Epoch 00047: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 48/300
#
# Epoch 00048: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 49/300
#
# Epoch 00049: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 50/300
#
# Epoch 00050: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 51/300
#
# Epoch 00051: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 52/300
#
# Epoch 00052: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6922 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 53/300
#
# Epoch 00053: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 54/300
#
# Epoch 00054: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 55/300
#
# Epoch 00055: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 56/300
#
# Epoch 00056: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 57/300
#
# Epoch 00057: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 58/300
#
# Epoch 00058: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 59/300
#
# Epoch 00059: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 60/300
#
# Epoch 00060: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 61/300
#
# Epoch 00061: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 62/300
#
# Epoch 00062: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 63/300
#
# Epoch 00063: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 64/300
#
# Epoch 00064: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 65/300
#
# Epoch 00065: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 66/300
#
# Epoch 00066: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 67/300
#
# Epoch 00067: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 68/300
#
# Epoch 00068: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6921 - acc: 0.7308 - rmse: 0.4995 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 69/300
#
# Epoch 00069: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6920 - acc: 0.7308 - rmse: 0.4994 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 70/300
#
# Epoch 00070: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6920 - acc: 0.7308 - rmse: 0.4994 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 71/300
#
# Epoch 00071: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6920 - acc: 0.7308 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 72/300
#
# Epoch 00072: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6920 - acc: 0.7308 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 73/300
#
# Epoch 00073: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6920 - acc: 0.7308 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 74/300
#
# Epoch 00074: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6920 - acc: 0.7308 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 75/300
#
# Epoch 00075: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6920 - acc: 0.7308 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 76/300
#
# Epoch 00076: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6920 - acc: 0.7308 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 77/300
#
# Epoch 00077: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6920 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 78/300
#
# Epoch 00078: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6920 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 79/300
#
# Epoch 00079: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6920 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 80/300
#
# Epoch 00080: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6920 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 81/300
#
# Epoch 00081: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6920 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 82/300
#
# Epoch 00082: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6920 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 83/300
#
# Epoch 00083: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6920 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 84/300
#
# Epoch 00084: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 85/300
#
# Epoch 00085: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 86/300
#
# Epoch 00086: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 87/300
#
# Epoch 00087: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 88/300
#
# Epoch 00088: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 89/300
#
# Epoch 00089: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 90/300
#
# Epoch 00090: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 91/300
#
# Epoch 00091: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 92/300
#
# Epoch 00092: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 93/300
#
# Epoch 00093: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 94/300
#
# Epoch 00094: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 95/300
#
# Epoch 00095: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 96/300
#
# Epoch 00096: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 97/300
#
# Epoch 00097: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 98/300
#
# Epoch 00098: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 99/300
#
# Epoch 00099: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6919 - acc: 0.7692 - rmse: 0.4994 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 100/300
#
# Epoch 00100: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 101/300
#
# Epoch 00101: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6938 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 102/300
#
# Epoch 00102: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 103/300
#
# Epoch 00103: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 104/300
#
# Epoch 00104: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 105/300
#
# Epoch 00105: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 106/300
#
# Epoch 00106: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 107/300
#
# Epoch 00107: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 108/300
#
# Epoch 00108: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 109/300
#
# Epoch 00109: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 110/300
#
# Epoch 00110: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 111/300
#
# Epoch 00111: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 112/300
#
# Epoch 00112: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 113/300
#
# Epoch 00113: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 114/300
#
# Epoch 00114: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 115/300
#
# Epoch 00115: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6918 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 116/300
#
# Epoch 00116: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 117/300
#
# Epoch 00117: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 118/300
#
# Epoch 00118: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 119/300
#
# Epoch 00119: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 120/300
#
# Epoch 00120: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 121/300
#
# Epoch 00121: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 122/300
#
# Epoch 00122: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 123/300
#
# Epoch 00123: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 124/300
#
# Epoch 00124: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 125/300
#
# Epoch 00125: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 126/300
#
# Epoch 00126: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 127/300
#
# Epoch 00127: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 128/300
#
# Epoch 00128: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 129/300
#
# Epoch 00129: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6939 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 130/300
#
# Epoch 00130: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 131/300
#
# Epoch 00131: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6917 - acc: 0.7692 - rmse: 0.4993 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 132/300
#
# Epoch 00132: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 133/300
#
# Epoch 00133: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 134/300
#
# Epoch 00134: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 135/300
#
# Epoch 00135: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 136/300
#
# Epoch 00136: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 137/300
#
# Epoch 00137: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 138/300
#
# Epoch 00138: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 139/300
#
# Epoch 00139: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 140/300
#
# Epoch 00140: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 141/300
#
# Epoch 00141: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 142/300
#
# Epoch 00142: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 143/300
#
# Epoch 00143: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 144/300
#
# Epoch 00144: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 145/300
#
# Epoch 00145: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 146/300
#
# Epoch 00146: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 147/300
#
# Epoch 00147: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6916 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 148/300
#
# Epoch 00148: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 149/300
#
# Epoch 00149: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 150/300
#
# Epoch 00150: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 151/300
#
# Epoch 00151: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 152/300
#
# Epoch 00152: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 153/300
#
# Epoch 00153: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 154/300
#
# Epoch 00154: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 155/300
#
# Epoch 00155: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 156/300
#
# Epoch 00156: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 157/300
#
# Epoch 00157: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 158/300
#
# Epoch 00158: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 159/300
#
# Epoch 00159: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 160/300
#
# Epoch 00160: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 161/300
#
# Epoch 00161: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 162/300
#
# Epoch 00162: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 163/300
#
# Epoch 00163: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6915 - acc: 0.7692 - rmse: 0.4992 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 164/300
#
# Epoch 00164: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 165/300
#
# Epoch 00165: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 166/300
#
# Epoch 00166: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 167/300
#
# Epoch 00167: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 168/300
#
# Epoch 00168: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 169/300
#
# Epoch 00169: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 170/300
#
# Epoch 00170: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 171/300
#
# Epoch 00171: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 172/300
#
# Epoch 00172: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 173/300
#
# Epoch 00173: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 174/300
#
# Epoch 00174: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 175/300
#
# Epoch 00175: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 176/300
#
# Epoch 00176: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 177/300
#
# Epoch 00177: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 178/300
#
# Epoch 00178: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.7692 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 179/300
#
# Epoch 00179: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6914 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 180/300
#
# Epoch 00180: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 181/300
#
# Epoch 00181: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 182/300
#
# Epoch 00182: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 183/300
#
# Epoch 00183: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 184/300
#
# Epoch 00184: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 185/300
#
# Epoch 00185: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 186/300
#
# Epoch 00186: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 187/300
#
# Epoch 00187: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 188/300
#
# Epoch 00188: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5004
# Epoch 189/300
#
# Epoch 00189: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 190/300
#
# Epoch 00190: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6940 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 191/300
#
# Epoch 00191: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 192/300
#
# Epoch 00192: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 193/300
#
# Epoch 00193: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 194/300
#
# Epoch 00194: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 195/300
#
# Epoch 00195: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6913 - acc: 0.8077 - rmse: 0.4991 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 196/300
#
# Epoch 00196: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 197/300
#
# Epoch 00197: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 198/300
#
# Epoch 00198: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 199/300
#
# Epoch 00199: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 200/300
#
# Epoch 00200: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 201/300
#
# Epoch 00201: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 202/300
#
# Epoch 00202: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 203/300
#
# Epoch 00203: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 204/300
#
# Epoch 00204: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 205/300
#
# Epoch 00205: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 206/300
#
# Epoch 00206: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 207/300
#
# Epoch 00207: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 208/300
#
# Epoch 00208: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 209/300
#
# Epoch 00209: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 210/300
#
# Epoch 00210: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 211/300
#
# Epoch 00211: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6912 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 212/300
#
# Epoch 00212: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 213/300
#
# Epoch 00213: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 214/300
#
# Epoch 00214: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 215/300
#
# Epoch 00215: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 216/300
#
# Epoch 00216: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 217/300
#
# Epoch 00217: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 218/300
#
# Epoch 00218: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 219/300
#
# Epoch 00219: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 220/300
#
# Epoch 00220: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 221/300
#
# Epoch 00221: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 222/300
#
# Epoch 00222: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 223/300
#
# Epoch 00223: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6911 - acc: 0.8077 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 224/300
#
# Epoch 00224: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6911 - acc: 0.8462 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 225/300
#
# Epoch 00225: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6911 - acc: 0.8462 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 226/300
#
# Epoch 00226: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6911 - acc: 0.8462 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 227/300
#
# Epoch 00227: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6911 - acc: 0.8462 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 228/300
#
# Epoch 00228: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6911 - acc: 0.8462 - rmse: 0.4990 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 229/300
#
# Epoch 00229: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 230/300
#
# Epoch 00230: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 231/300
#
# Epoch 00231: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 232/300
#
# Epoch 00232: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 233/300
#
# Epoch 00233: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 234/300
#
# Epoch 00234: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 235/300
#
# Epoch 00235: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 236/300
#
# Epoch 00236: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 237/300
#
# Epoch 00237: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 238/300
#
# Epoch 00238: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 239/300
#
# Epoch 00239: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 240/300
#
# Epoch 00240: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 241/300
#
# Epoch 00241: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 242/300
#
# Epoch 00242: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 243/300
#
# Epoch 00243: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 244/300
#
# Epoch 00244: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 245/300
#
# Epoch 00245: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6910 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 246/300
#
# Epoch 00246: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 247/300
#
# Epoch 00247: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 248/300
#
# Epoch 00248: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 249/300
#
# Epoch 00249: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 250/300
#
# Epoch 00250: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 251/300
#
# Epoch 00251: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 252/300
#
# Epoch 00252: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 253/300
#
# Epoch 00253: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 254/300
#
# Epoch 00254: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 255/300
#
# Epoch 00255: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 256/300
#
# Epoch 00256: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 257/300
#
# Epoch 00257: val_loss did not improve from 0.69363
#  - 1s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 258/300
#
# Epoch 00258: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 259/300
#
# Epoch 00259: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 260/300
#
# Epoch 00260: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 261/300
#
# Epoch 00261: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 262/300
#
# Epoch 00262: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6909 - acc: 0.8462 - rmse: 0.4989 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 263/300
#
# Epoch 00263: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6908 - acc: 0.8462 - rmse: 0.4988 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 264/300
#
# Epoch 00264: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6908 - acc: 0.8462 - rmse: 0.4988 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 265/300
#
# Epoch 00265: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6908 - acc: 0.8462 - rmse: 0.4988 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 266/300
#
# Epoch 00266: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6908 - acc: 0.8462 - rmse: 0.4988 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 267/300
#
# Epoch 00267: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6908 - acc: 0.8462 - rmse: 0.4988 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 268/300
#
# Epoch 00268: val_loss did not improve from 0.69363
#  - 0s - loss: 0.6908 - acc: 0.8462 - rmse: 0.4988 - val_loss: 0.6941 - val_acc: 0.0000e+00 - val_rmse: 0.5005
# Epoch 269/300
#
# ...
# Epoch 216/300
#
# Epoch 00216: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 217/300
#
# Epoch 00217: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 218/300
#
# Epoch 00218: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 219/300
#
# Epoch 00219: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 220/300
#
# Epoch 00220: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 221/300
#
# Epoch 00221: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 222/300
#
# Epoch 00222: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 223/300
#
# Epoch 00223: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 224/300
#
# Epoch 00224: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 225/300
#
# Epoch 00225: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 226/300
#
# Epoch 00226: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 227/300
#
# Epoch 00227: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 228/300
#
# Epoch 00228: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 229/300
#
# Epoch 00229: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6917 - acc: 0.6538 - rmse: 0.4993 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 230/300
#
# Epoch 00230: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 231/300
#
# Epoch 00231: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 232/300
#
# Epoch 00232: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 233/300
#
# Epoch 00233: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 234/300
#
# Epoch 00234: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 235/300
#
# Epoch 00235: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 236/300
#
# Epoch 00236: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 237/300
#
# Epoch 00237: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 238/300
#
# Epoch 00238: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 239/300
#
# Epoch 00239: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 240/300
#
# Epoch 00240: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 241/300
#
# Epoch 00241: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 242/300
#
# Epoch 00242: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6935 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 243/300
#
# Epoch 00243: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 244/300
#
# Epoch 00244: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 245/300
#
# Epoch 00245: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 246/300
#
# Epoch 00246: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 247/300
#
# Epoch 00247: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6916 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 248/300
#
# Epoch 00248: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 249/300
#
# Epoch 00249: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 250/300
#
# Epoch 00250: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 251/300
#
# Epoch 00251: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 252/300
#
# Epoch 00252: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 253/300
#
# Epoch 00253: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 254/300
#
# Epoch 00254: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 255/300
#
# Epoch 00255: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 256/300
#
# Epoch 00256: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 257/300
#
# Epoch 00257: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 258/300
#
# Epoch 00258: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 259/300
#
# Epoch 00259: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 260/300
#
# Epoch 00260: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 261/300
#
# Epoch 00261: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 262/300
#
# Epoch 00262: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 263/300
#
# Epoch 00263: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 264/300
#
# Epoch 00264: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 265/300
#
# Epoch 00265: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6915 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 266/300
#
# Epoch 00266: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4992 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 267/300
#
# Epoch 00267: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 268/300
#
# Epoch 00268: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 269/300
#
# Epoch 00269: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 270/300
#
# Epoch 00270: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 271/300
#
# Epoch 00271: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 272/300
#
# Epoch 00272: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 273/300
#
# Epoch 00273: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 274/300
#
# Epoch 00274: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 275/300
#
# Epoch 00275: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 276/300
#
# Epoch 00276: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6538 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 277/300
#
# Epoch 00277: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 278/300
#
# Epoch 00278: val_loss did not improve from 0.69320
#  - 1s - loss: 0.6914 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 279/300
#
# Epoch 00279: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 280/300
#
# Epoch 00280: val_loss did not improve from 0.69320
#  - 1s - loss: 0.6914 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 281/300
#
# Epoch 00281: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 282/300
#
# Epoch 00282: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 283/300
#
# Epoch 00283: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 284/300
#
# Epoch 00284: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6914 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 285/300
#
# Epoch 00285: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 286/300
#
# Epoch 00286: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 287/300
#
# Epoch 00287: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5002
# Epoch 288/300
#
# Epoch 00288: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6936 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 289/300
#
# Epoch 00289: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 290/300
#
# Epoch 00290: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 291/300
#
# Epoch 00291: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 292/300
#
# Epoch 00292: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 293/300
#
# Epoch 00293: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 294/300
#
# Epoch 00294: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 295/300
#
# Epoch 00295: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 296/300
#
# Epoch 00296: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 297/300
#
# Epoch 00297: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 298/300
#
# Epoch 00298: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 299/300
#
# Epoch 00299: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# Epoch 300/300
#
# Epoch 00300: val_loss did not improve from 0.69320
#  - 0s - loss: 0.6913 - acc: 0.6923 - rmse: 0.4991 - val_loss: 0.6937 - val_acc: 0.0000e+00 - val_rmse: 0.5003
# (26, 500, 12)
# X_train shape: (26, 12, 500)
# 26 train samples
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_31 (LSTM)               (None, 256)               775168
# _________________________________________________________________
# dense_62 (Dense)             (None, 32)                8224
# _________________________________________________________________
# dense_63 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 783,458
# Trainable params: 783,458
# Non-trainable params: 0
# _________________________________________________________________
# Train on 26 samples, validate on 1 samples
# Epoch 1/300
#
# Epoch 00001: val_loss improved from inf to 0.69465, saving model to /tmp/LSTM_checkpoint.h5

# %%
print('Mean of Metrics for All Iterations \n')
print('Train Accuracy: {0:.2f}% '.format(np.mean(log_train_accuracy) * 100))
print('Validation Accuracy: {0:.2f}% '.format(np.mean(log_validation_accuracy) * 100))
print('Train RMSE: {0:.2f} '.format(np.mean(log_train_rmse)))
print('Validation RMSE: {0:.2f} '.format(np.mean(log_validation_rmse)))
print('Train Loss: {0:.2f} '.format(np.mean(log_train_loss)))
print('Validation Loss: {0:.2f} '.format(np.mean(log_validation_loss)))
# Out:
# Mean of Metrics for All Iterations
#
# Train Accuracy: 72.51%
# Validation Accuracy: 51.85%
# Train RMSE: 0.50
# Validation RMSE: 0.50
# Train Loss: 0.69
# Validation Loss: 0.69

# %%
# list all data in history
# print(fitted_model.history.keys())

print('Diagrammed History of Model Metrics')

plt.figure(figsize=(14,6))
plt.plot(log_validation_accuracy)
plt.plot(log_train_accuracy)
plt.title('Final Train & Validation Accuracy for Each Batch')
plt.ylabel('Accuracy')
plt.xlabel('Batch')
plt.legend(['Validation', 'Train'], loc='upper left')
plt.show()
# Out:
# Diagrammed History of Model Metrics

# %%
# summarize rmse
plt.figure(figsize=(14,6))
plt.plot(log_validation_rmse)
plt.plot(log_train_rmse)
plt.title('Final Train & Validation RMSE for Each Batch')
plt.ylabel('RMSE')
plt.xlabel('Batch')
plt.legend(['Validation', 'Train'], loc='upper left')
plt.show()

# %%
# summarize loss 
plt.figure(figsize=(14,6))
plt.plot(log_validation_loss)
plt.plot(log_train_loss)
plt.title('Final Train & Validation Loss for Each Batch')
plt.ylabel('Loss')
plt.xlabel('Batch')
plt.legend(['Validation', 'Train'], loc='upper left')
plt.show()

# %%
# !pip freeze
# Out:
# absl-py==0.7.1
# alabaster==0.7.12
# altgraph==0.16.1
# anaconda-client==1.7.2
# anaconda-navigator==1.9.6
# anaconda-project==0.8.2
# asn1crypto==0.24.0
# astor==0.8.0
# astroid==2.1.0
# astropy==3.1
# atomicwrites==1.2.1
# attrs==18.2.0
# Babel==2.6.0
# backcall==0.1.0
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.6.0
# bitarray==0.8.3
# bkcharts==0.2
# blaze==0.11.3
# bleach==3.0.2
# blis==0.2.4
# bokeh==1.0.2
# boto==2.49.0
# boto3==1.9.169
# botocore==1.12.169
# Bottleneck==1.2.1
# cachetools==3.1.1
# certifi==2018.11.29
# cffi==1.11.5
# chardet==3.0.4
# Click==7.0
# cloudpickle==0.6.1
# clyent==1.2.2
# colorama==0.4.1
# colorlover==0.3.0
# comtypes==1.1.7
# conda==4.5.12
# conda-build==3.17.6
# conda-verify==3.1.1
# contextlib2==0.5.5
# cryptography==2.4.2
# cufflinks==0.15
# cycler==0.10.0
# cymem==2.0.2
# Cython==0.29.2
# cytoolz==0.9.0.1
# dask==1.0.0
# datashape==0.5.4
# decorator==4.3.0
# defusedxml==0.5.0
# distributed==1.25.1
# docutils==0.14
# entrypoints==0.2.3
# et-xmlfile==1.0.1
# fastcache==1.0.2
# filelock==3.0.10
# Flask==1.0.2
# Flask-Cors==3.0.7
# future==0.17.1
# gast==0.2.2
# genderdecoder==0.3
# gensim==3.7.3
# gevent==1.3.7
# glob2==0.6
# google-auth==1.8.2
# google-auth-oauthlib==0.4.1
# google-pasta==0.1.8
# graphviz==0.13.2
# greenlet==0.4.15
# grpcio==1.21.1
# h5py==2.8.0
# heapdict==1.0.0
# html2text==2018.1.9
# html5lib==1.0.1
# idna==2.8
# imageio==2.4.1
# imagesize==1.1.0
# importlib-metadata==0.6
# inflection==0.3.1
# ipykernel==5.1.0
# ipython==7.2.0
# ipython-genutils==0.2.0
# ipywidgets==7.4.2
# isort==4.3.4
# itsdangerous==1.1.0
# jdcal==1.4
# jedi==0.13.2
# Jinja2==2.10
# jmespath==0.9.4
# joblib==0.14.1
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.2.4
# jupyter-console==6.0.0
# jupyter-core==4.4.0
# jupyterlab==0.35.3
# jupyterlab-server==0.2.0
# Keras==2.2.4
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.0.9
# keyring==17.0.0
# kiwisolver==1.0.1
# lazy-object-proxy==1.3.1
# libarchive-c==2.8
# llvmlite==0.26.0
# locket==0.2.0
# lxml==4.2.5
# Markdown==3.0.1
# MarkupSafe==1.1.0
# matplotlib==3.0.2
# mccabe==0.6.1
# menuinst==1.4.14
# mistune==0.8.4
# mkl-fft==1.0.6
# mkl-random==1.0.2
# mlxtend==0.17.0
# mne==0.19.2
# mock==3.0.5
# more-itertools==4.3.0
# mpmath==1.1.0
# msgpack==0.5.6
# multipledispatch==0.6.0
# murmurhash==1.0.2
# navigator-updater==0.2.1
# nbconvert==5.4.0
# nbformat==4.4.0
# ndg-httpsclient==0.5.1
# networkx==2.2
# nltk==3.4.1
# nose==1.3.7
# notebook==5.7.4
# numba==0.41.0
# numexpr==2.6.8
# numpy==1.16.5
# numpydoc==0.8.0
# oauthlib==3.1.0
# odo==0.5.1
# olefile==0.46
# openpyxl==2.5.12
# opt-einsum==3.1.0
# packaging==18.0
# pandas==0.25.3
# pandocfilters==1.4.2
# parso==0.3.1
# partd==0.3.9
# path.py==11.5.0
# pathlib2==2.3.3
# patsy==0.5.1
# pefile==2019.4.18
# pep8==1.7.1
# pickleshare==0.7.5
# Pillow==5.3.0
# pkginfo==1.4.2
# plac==0.9.6
# plotly==3.10.0
# pluggy==0.8.0
# ply==3.11
# preshed==2.0.1
# prometheus-client==0.5.0
# prompt-toolkit==2.0.7
# protobuf==3.7.1
# psutil==5.4.8
# pupygrib==0.5.0
# py==1.7.0
# pyargus==1.0.post3
# pyasn1==0.4.7
# pyasn1-modules==0.2.7
# pycodestyle==2.4.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pycurl==7.43.0.2
# pydot==1.4.1
# pyEDFlib==0.1.15
# pyflakes==2.0.0
# Pygments==2.3.1
# PyInstaller==4.0.dev0+1eadfa55f2
# pylint==2.2.2
# pymssql==2.1.4
# PyMySQL==0.9.3
# pyodbc==4.0.25
# pyOpenSSL==18.0.0
# pyparsing==2.3.0
# Pyphen==0.9.5
# pyproj==2.4.2.post1
# pyriemann==0.2.5
# PySocks==1.6.8
# pytest==4.0.2
# pytest-arraydiff==0.3
# pytest-astropy==0.5.0
# pytest-doctestplus==0.2.0
# pytest-openfiles==0.3.1
# pytest-remotedata==0.3.1
# python-dateutil==2.7.5
# pytz==2018.7
# PyWavelets==1.0.1
# pywin32==223
# pywin32-ctypes==0.2.0
# pywinpty==0.5.5
# PyYAML==3.13
# pyzmq==17.1.2
# QtAwesome==0.5.3
# qtconsole==4.4.3
# QtPy==1.5.2
# Quandl==3.4.8
# repoze.lru==0.7
# requests==2.21.0
# requests-oauthlib==1.3.0
# retrying==1.3.3
# rope==0.11.0
# rsa==4.0
# ruamel-yaml==0.15.46
# s3transfer==0.2.1
# scikit-image==0.14.1
# scikit-learn==0.22.1
# scipy==1.4.1
# seaborn==0.9.0
# Send2Trash==1.5.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.12.0
# smart-open==1.8.4
# snowballstemmer==1.2.1
# sortedcollections==1.0.1
# sortedcontainers==2.1.0
# spacy==2.1.4
# Sphinx==1.8.2
# sphinxcontrib-websupport==1.1.0
# spyder==3.3.2
# spyder-kernels==0.3.0
# SQLAlchemy==1.2.15
# srsly==0.0.5
# statsmodels==0.9.0
# style==1.1.0
# sympy==1.3
# tables==3.4.4
# tblib==1.3.2
# tensorboard==1.13.1
# tensorflow==1.13.1
# tensorflow-estimator==1.13.0
# termcolor==1.1.0
# terminado==0.8.1
# testpath==0.4.2
# textblob==0.15.3
# textstat==0.5.6
# thinc==7.0.4
# toolz==0.9.0
# tornado==5.1.1
# tqdm==4.28.1
# traitlets==4.3.2
# unicodecsv==0.14.1
# update==0.0.1
# urllib3==1.24.1
# wasabi==0.2.2
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.14.1
# widgetsnbextension==3.4.2
# win-inet-pton==1.0.1
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt==1.11.2
# xlrd==1.2.0
# XlsxWriter==1.1.2
# xlwings==0.15.1
# xlwt==1.3.0
# zict==0.1.3

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.1
