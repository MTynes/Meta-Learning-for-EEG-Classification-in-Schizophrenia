# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Permute, Dropout
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import SeparableConv2D, DepthwiseConv2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import SpatialDropout2D
from tensorflow.keras.regularizers import l1_l2
from tensorflow.keras.layers import Input, Flatten
from tensorflow.keras.constraints import max_norm
from tensorflow.keras import backend as K

import pandas as pd


import tensorflow as tf
use_gpu = tf.test.is_gpu_available(
    cuda_only=False,
    min_cuda_compute_capability=None
)

#!pip install pyriemann

import numpy as np

# mne imports
import mne
from mne import io
#from mne.datasets import sample

# EEGNet-specific imports
#from EEGModels import EEGNet
from tensorflow.keras import utils as np_utils
from tensorflow.keras.callbacks import ModelCheckpoint


# tools for plotting confusion matrices
from matplotlib import pyplot as plt

import random 
import math


"""
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense"""
# Out:
# C:\Users\marit\Anaconda3\lib\site-packages\numba\decorators.py:146: RuntimeWarning: Caching is not available when the 'parallel' target is in use. Caching is now being disabled to allow execution to continue.
#   warnings.warn(msg, RuntimeWarning)
# '\nfrom keras.models import Sequential\nfrom keras.layers.convolutional import Convolution2D\nfrom keras.layers.convolutional import MaxPooling2D\nfrom keras.layers.core import Activation\nfrom keras.layers.core import Flatten\nfrom keras.layers.core import Dense'

# %%
# !pip install mne
# !pip install pyedflib
# Out:
# Requirement already satisfied: mne in /usr/local/lib/python3.6/dist-packages (0.19.2)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from mne) (1.4.1)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from mne) (1.17.5)
# Requirement already satisfied: pyedflib in /usr/local/lib/python3.6/dist-packages (0.1.15)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from pyedflib) (1.17.5)
# Requirement already satisfied: zipfile36 in /usr/local/lib/python3.6/dist-packages (0.1.3)

# %%
#import zipfile36 as zipfile
#with zipfile.ZipFile("Healthy Controls.zip", 'r') as zip_ref:
#    zip_ref.extractall("SZ Patients")

# %%
from google.colab import drive
#drive.mount('/content/drive')
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras import layers
#https://www.tensorflow.org/guide/keras/rnn

def LSTM(samples, time_steps, nb_features, chans, nb_classes):

    model=tf.keras.Sequential()
    
    print('chans: ', chans)
    print('nb_features: ', nb_features)
    model.add(layers.LSTM(128,
                          input_shape=(chans, time_steps)
            #input_shape=(chans* nb_features, time_steps),
            ))
    
    
    # Add a LSTM layer with 128 internal units.
    #model.add(layers.LSTM(128))



    model.add(Dense(32,kernel_initializer='he_uniform',activation='relu'))
    

    model.add(Dense(nb_classes,activation='softmax'))
    
    return model

# %%
ignore_list = ['s07']  #list of patient files that should be skipped
sample_size = 2

#file_test = pd.read_csv("/content/drive/My Drive/Colab Notebooks/Healthy Controls/h01.edf")

# %%
import pyedflib
mne.set_log_level("WARNING")

parent_dir = '../../Data/Raw/'

# get the minimum length of the files
def get_minimum_duration(group_directory_name, patient_group_file_prefix):
    file_durations = []
    for i in range (1, 15): # reading 14 files
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        file_name = parent_dir +'{}/{}.edf'.format(group_directory_name, patient_id)
        print(file_name)
        f = pyedflib.EdfReader(file_name)
        file_durations.append(f.file_duration)
        f.close()
    return(min(file_durations))

# modified based on https://stackoverflow.com/a/48704557/2466781
def chunk(seq, size):
    sl = len(seq) - (len(seq)%size) #exclude values that will be out of range
    r = [pd.DataFrame(seq[pos:pos + size]) for pos in range(0, sl, size)]
    return r

# modified version of process_patient_group in older notebooks
# Uses the raw EDF files and converts to dataframe, dropping the first 150 and last 30 seconds of the shortest  file
# All other files are trimmed similarly to produce the same size
# Adapted from page 1 of https://buildmedia.readthedocs.org/media/pdf/pyedflib/latest/pyedflib.pdf
def process_patient_group(group_directory_name, patient_group_file_prefix, 
                          minimum_original_duration, 
                          plot_channels = False,
                         channels = ['F8', 'F7', 'F4', 'F3', 'Fz']):
    meta_df = pd.DataFrame()
    meta = []
    patient_id_list = []

    for i in range (1, 15): # reading 14 files
        patient_id = "{}{:02d}".format(patient_group_file_prefix, i)
        patient_id_list.append(patient_id)
        
        file_name = parent_dir + '{}/{}.edf'.format(group_directory_name, patient_id)
        data = mne.io.read_raw_edf(file_name)
        df = data.to_data_frame()
        df2 = df[channels]
        ## based on visual inspection, drop the first 150 seconds
        df2 = df2[150: (minimum_original_duration-30)]
        f = pyedflib.EdfReader(file_name)
        f.close()
        if patient_id not in ignore_list:
            meta_df = meta_df.append(df2)
            
    batches = chunk(meta_df, sample_size)

    for batch in batches:
        #display(np.asarray(batch.values).shape)
        meta.append([np.asarray(batch.values)])
           
                    
    return meta

# %%
# Retrieve patient data, using a time window determined by the shortest recording
# patient s07 is removed

minimum_duration = min(get_minimum_duration("Healthy Controls", "h"), get_minimum_duration('SZ Patients', 's'))
print('minimum duration: ', minimum_duration)


target_channels = ['T4', 'T6', 'O2', 'T3', 'T5', 'O1',
                   'C4', 'P4', 'C3', 'P3', 'Cz', 'Pz']

print("Healthy Controls")
hc_data = process_patient_group('Healthy Controls', 'h', minimum_duration, channels=target_channels)
display(np.asarray(hc_data).shape)


print('Sz Patients')
sz_data = np.asarray(process_patient_group('SZ Patients', 's', minimum_duration, channels=target_channels))
display(np.asarray(sz_data).shape)


##### combine groups and create Y (labels)

X =  np.concatenate((hc_data, sz_data), axis=0)
display('input size: ', X.shape)
y = ([0] * len(hc_data)) +( [1] * len(sz_data))
# Out:
# ../../Data/Raw/Healthy Controls/h01.edf
# ../../Data/Raw/Healthy Controls/h02.edf
# ../../Data/Raw/Healthy Controls/h03.edf
# ../../Data/Raw/Healthy Controls/h04.edf
# ../../Data/Raw/Healthy Controls/h05.edf
# ../../Data/Raw/Healthy Controls/h06.edf
# ../../Data/Raw/Healthy Controls/h07.edf
# ../../Data/Raw/Healthy Controls/h08.edf
# ../../Data/Raw/Healthy Controls/h09.edf
# ../../Data/Raw/Healthy Controls/h10.edf
# ../../Data/Raw/Healthy Controls/h11.edf
# ../../Data/Raw/Healthy Controls/h12.edf
# ../../Data/Raw/Healthy Controls/h13.edf
# ../../Data/Raw/Healthy Controls/h14.edf
# ../../Data/Raw/SZ Patients/s01.edf
# ../../Data/Raw/SZ Patients/s02.edf
# ../../Data/Raw/SZ Patients/s03.edf
# ../../Data/Raw/SZ Patients/s04.edf
# ../../Data/Raw/SZ Patients/s05.edf
# ../../Data/Raw/SZ Patients/s06.edf
# ../../Data/Raw/SZ Patients/s07.edf
# ../../Data/Raw/SZ Patients/s08.edf
# ../../Data/Raw/SZ Patients/s09.edf
# ../../Data/Raw/SZ Patients/s10.edf
# ../../Data/Raw/SZ Patients/s11.edf
# ../../Data/Raw/SZ Patients/s12.edf
# ../../Data/Raw/SZ Patients/s13.edf
# ../../Data/Raw/SZ Patients/s14.edf
# minimum duration:  740
# Healthy Controls
# (3920, 1, 2, 12)
# Sz Patients
# (3640, 1, 2, 12)
# 'input size: '
# (7560, 1, 2, 12)

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
# create the /tmp directory if it doesn't already exist
import os
if not os.path.exists('tmp'):
    os.makedirs('tmp')

# %%
# get a list of randomly selected sets of numbers based on a range
# the proportion of values selected for each set is determined by the ratio_array
def get_mixed_indexes_for_ml_train_test(length, ratios_array):
    input_indexes = range(0, length)
    output_indexes = []
    for ratio in ratios_array:
        selection = random.choices(input_indexes, k=math.floor(ratio * length))
        input_indexes = [i for i in input_indexes if i not in selection]
        output_indexes.append(selection)
    return output_indexes

# %%
## TODO - auto mkdir if not exist for TF output : /tmp

# adapted from https://github.com/vlawhern/arl-eegmodels/blob/master/examples/ERP.py

##################### Process, filter and epoch the data ######################
#data_path = sample.data_path()



# Set parameters and read data
"""raw_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw.fif'
event_fname = data_path + '/MEG/sample/sample_audvis_filt-0-40_raw-eve.fif'
tmin, tmax = -0., 1
event_id = dict(aud_l=1, aud_r=2, vis_l=3, vis_r=4)

# Setup for reading the raw data
raw = io.Raw(raw_fname, preload=True, verbose=False)
raw.filter(2, None, method='iir')  # replace baselining with high-pass
events = mne.read_events(event_fname)

raw.info['bads'] = ['MEG 2443']  # set bad channels
picks = mne.pick_types(raw.info, meg=False, eeg=True, stim=False, eog=False,
                       exclude='bads')
display(raw)
# Read epochs
epochs = mne.Epochs(raw, events, event_id, tmin, tmax, proj=False,
                    picks=picks, baseline=None, preload=True, verbose=False)
labels = epochs.events[:, -1]
"""


kernels, chans, samples = 1, 12, sample_size
full_size = len(X)
train_idxs, validate_idxs, test_idxs = get_mixed_indexes_for_ml_train_test(len(X), [.70, 0.15, 0.15])



X_train      = X[train_idxs][0:,]
Y_train      = np.asarray(y)[train_idxs]
X_validate   = X[validate_idxs][0:,]
Y_validate   = np.asarray(y)[validate_idxs]
X_test       = X[test_idxs][0:,]
Y_test       = np.asarray(y)[test_idxs]

############################# EEGNet portion ##################################

# convert labels to one-hot encodings.
Y_train      = np_utils.to_categorical(Y_train, num_classes=2)
Y_validate   = np_utils.to_categorical(Y_validate, num_classes=2)
Y_test       = np_utils.to_categorical(Y_test, num_classes=2)


time_steps = 2

X_train      = X_train.reshape(X_train.shape[0],   chans, time_steps,)
X_validate   = X_validate.reshape(X_validate.shape[0], chans, time_steps)
X_test       = X_test.reshape(X_test.shape[0], chans, time_steps)


 
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# configure the EEGNet-8,2,16 model with kernel length of 32 samples (other 
# model configurations may do better, but this is a good starting point)
#model = EEGNet_CPU(nb_classes = 2, Chans = chans, Samples = samples, #
#               dropoutRate = 0.5, kernLength = 32, F1 = 64, D = 2, F2 = 32, 
#               dropoutType = 'Dropout')


#LSTM(samles, time_steps=20, input_size=30, chans)
model = LSTM(samples=samples, time_steps=time_steps, chans=chans, nb_features=1, nb_classes=2, )
adam = tf.keras.optimizers.Adam(lr=0.000005, 
                                    beta_1=0.99,
    beta_2=0.999,
    epsilon=1e-07,)
#cnn_model.compile(optimizer=adam,
#                loss='binary_crossentropy',
#                metrics=['accuracy'])

# compile the model and set the optimizers
model.compile(loss='categorical_crossentropy', optimizer=adam, 
              metrics = ['accuracy'])

# count number of parameters in the model
numParams    = model.count_params()    

# set a valid path for your system to record model checkpoints
checkpointer = ModelCheckpoint(filepath='/tmp/LSTM_checkpoint.h5', verbose=1,
                               save_best_only=True)

###############################################################################
# if the classification task was imbalanced (significantly more trials in one
# class versus the others) you can assign a weight to each class during 
# optimization to balance it out. This data is approximately balanced so we 
# don't need to do this, but is shown here for illustration/completeness. 
###############################################################################
# Out:
# X_train shape: (5292, 12, 2)
# 5292 train samples
# 1134 test samples
# chans:  12
# nb_features:  1
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# the syntax is {class_1:weight_1, class_2:weight_2,...}. Here just setting
# the weights all to be 1
class_weights = {0:1, 1:1, 2:1, 3:1}

################################################################################
# fit the model. Due to very small sample sizes this can get
# pretty noisy run-to-run, but most runs should be comparable to xDAWN + 
# Riemannian geometry classification (below)
################################################################################
fittedModel = model.fit(X_train, Y_train, batch_size = 32, epochs = 600, 
                        verbose = 2, validation_data=(X_validate, Y_validate),
                        callbacks=[checkpointer])#, class_weight = class_weights)

# load optimal weights
model.load_weights('/tmp/LSTM_checkpoint.h5')

###############################################################################
# can alternatively used the weights provided in the repo. If so it should get
# you 93% accuracy. Change the WEIGHTS_PATH variable to wherever it is on your
# system.
###############################################################################

# WEIGHTS_PATH = /path/to/EEGNet-8-2-weights.h5 
# model.load_weights(WEIGHTS_PATH)

###############################################################################
# make prediction on test set.
###############################################################################

probs       = model.predict(X_test)
preds       = probs.argmax(axis = -1)  
acc         = np.mean(preds == Y_test.argmax(axis=-1))
print("Classification accuracy: %f " % (acc))
# Out:
# Train on 5292 samples, validate on 1134 samples
# Epoch 1/600
#
# Epoch 00001: val_loss improved from 0.63807 to 0.63168, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6394 - acc: 0.6852 - val_loss: 0.6317 - val_acc: 0.7046
# Epoch 2/600
#
# Epoch 00002: val_loss improved from 0.63168 to 0.62837, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6361 - acc: 0.6893 - val_loss: 0.6284 - val_acc: 0.7090
# Epoch 3/600
#
# Epoch 00003: val_loss improved from 0.62837 to 0.62518, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6329 - acc: 0.6939 - val_loss: 0.6252 - val_acc: 0.7152
# Epoch 4/600
#
# Epoch 00004: val_loss improved from 0.62518 to 0.62198, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6297 - acc: 0.6992 - val_loss: 0.6220 - val_acc: 0.7187
# Epoch 5/600
#
# Epoch 00005: val_loss improved from 0.62198 to 0.61896, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.6265 - acc: 0.6997 - val_loss: 0.6190 - val_acc: 0.7152
# Epoch 6/600
#
# Epoch 00006: val_loss improved from 0.61896 to 0.61591, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6235 - acc: 0.7016 - val_loss: 0.6159 - val_acc: 0.7205
# Epoch 7/600
#
# Epoch 00007: val_loss improved from 0.61591 to 0.61320, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6205 - acc: 0.7050 - val_loss: 0.6132 - val_acc: 0.7284
# Epoch 8/600
#
# Epoch 00008: val_loss improved from 0.61320 to 0.61046, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6176 - acc: 0.7077 - val_loss: 0.6105 - val_acc: 0.7249
# Epoch 9/600
#
# Epoch 00009: val_loss improved from 0.61046 to 0.60771, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6147 - acc: 0.7086 - val_loss: 0.6077 - val_acc: 0.7205
# Epoch 10/600
#
# Epoch 00010: val_loss improved from 0.60771 to 0.60499, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6120 - acc: 0.7133 - val_loss: 0.6050 - val_acc: 0.7231
# Epoch 11/600
#
# Epoch 00011: val_loss improved from 0.60499 to 0.60254, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6093 - acc: 0.7130 - val_loss: 0.6025 - val_acc: 0.7222
# Epoch 12/600
#
# Epoch 00012: val_loss improved from 0.60254 to 0.60050, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6066 - acc: 0.7128 - val_loss: 0.6005 - val_acc: 0.7231
# Epoch 13/600
#
# Epoch 00013: val_loss improved from 0.60050 to 0.59790, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6040 - acc: 0.7137 - val_loss: 0.5979 - val_acc: 0.7231
# Epoch 14/600
#
# Epoch 00014: val_loss improved from 0.59790 to 0.59563, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.6014 - acc: 0.7177 - val_loss: 0.5956 - val_acc: 0.7231
# Epoch 15/600
#
# Epoch 00015: val_loss improved from 0.59563 to 0.59338, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5989 - acc: 0.7184 - val_loss: 0.5934 - val_acc: 0.7222
# Epoch 16/600
#
# Epoch 00016: val_loss improved from 0.59338 to 0.59107, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5965 - acc: 0.7205 - val_loss: 0.5911 - val_acc: 0.7293
# Epoch 17/600
#
# Epoch 00017: val_loss improved from 0.59107 to 0.58887, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5941 - acc: 0.7234 - val_loss: 0.5889 - val_acc: 0.7293
# Epoch 18/600
#
# Epoch 00018: val_loss improved from 0.58887 to 0.58684, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5918 - acc: 0.7237 - val_loss: 0.5868 - val_acc: 0.7328
# Epoch 19/600
#
# Epoch 00019: val_loss improved from 0.58684 to 0.58470, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5895 - acc: 0.7252 - val_loss: 0.5847 - val_acc: 0.7354
# Epoch 20/600
#
# Epoch 00020: val_loss improved from 0.58470 to 0.58269, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5872 - acc: 0.7271 - val_loss: 0.5827 - val_acc: 0.7310
# Epoch 21/600
#
# Epoch 00021: val_loss improved from 0.58269 to 0.58075, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5849 - acc: 0.7283 - val_loss: 0.5808 - val_acc: 0.7302
# Epoch 22/600
#
# Epoch 00022: val_loss improved from 0.58075 to 0.57871, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5827 - acc: 0.7296 - val_loss: 0.5787 - val_acc: 0.7284
# Epoch 23/600
#
# Epoch 00023: val_loss improved from 0.57871 to 0.57685, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5806 - acc: 0.7309 - val_loss: 0.5768 - val_acc: 0.7302
# Epoch 24/600
#
# Epoch 00024: val_loss improved from 0.57685 to 0.57508, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5785 - acc: 0.7309 - val_loss: 0.5751 - val_acc: 0.7319
# Epoch 25/600
#
# Epoch 00025: val_loss improved from 0.57508 to 0.57296, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5764 - acc: 0.7313 - val_loss: 0.5730 - val_acc: 0.7363
# Epoch 26/600
#
# Epoch 00026: val_loss improved from 0.57296 to 0.57140, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5742 - acc: 0.7322 - val_loss: 0.5714 - val_acc: 0.7337
# Epoch 27/600
#
# Epoch 00027: val_loss improved from 0.57140 to 0.56963, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5722 - acc: 0.7328 - val_loss: 0.5696 - val_acc: 0.7328
# Epoch 28/600
#
# Epoch 00028: val_loss improved from 0.56963 to 0.56802, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5702 - acc: 0.7345 - val_loss: 0.5680 - val_acc: 0.7337
# Epoch 29/600
#
# Epoch 00029: val_loss improved from 0.56802 to 0.56603, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5683 - acc: 0.7368 - val_loss: 0.5660 - val_acc: 0.7372
# Epoch 30/600
#
# Epoch 00030: val_loss improved from 0.56603 to 0.56465, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5664 - acc: 0.7358 - val_loss: 0.5647 - val_acc: 0.7337
# Epoch 31/600
#
# Epoch 00031: val_loss improved from 0.56465 to 0.56327, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5645 - acc: 0.7362 - val_loss: 0.5633 - val_acc: 0.7363
# Epoch 32/600
#
# Epoch 00032: val_loss improved from 0.56327 to 0.56146, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5629 - acc: 0.7364 - val_loss: 0.5615 - val_acc: 0.7337
# Epoch 33/600
#
# Epoch 00033: val_loss improved from 0.56146 to 0.55996, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5610 - acc: 0.7364 - val_loss: 0.5600 - val_acc: 0.7399
# Epoch 34/600
#
# Epoch 00034: val_loss improved from 0.55996 to 0.55839, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5593 - acc: 0.7362 - val_loss: 0.5584 - val_acc: 0.7381
# Epoch 35/600
#
# Epoch 00035: val_loss improved from 0.55839 to 0.55694, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5577 - acc: 0.7377 - val_loss: 0.5569 - val_acc: 0.7399
# Epoch 36/600
#
# Epoch 00036: val_loss improved from 0.55694 to 0.55576, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5560 - acc: 0.7389 - val_loss: 0.5558 - val_acc: 0.7407
# Epoch 37/600
#
# Epoch 00037: val_loss improved from 0.55576 to 0.55427, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5545 - acc: 0.7387 - val_loss: 0.5543 - val_acc: 0.7407
# Epoch 38/600
#
# Epoch 00038: val_loss improved from 0.55427 to 0.55295, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5529 - acc: 0.7404 - val_loss: 0.5530 - val_acc: 0.7407
# Epoch 39/600
#
# Epoch 00039: val_loss improved from 0.55295 to 0.55195, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.5514 - acc: 0.7404 - val_loss: 0.5520 - val_acc: 0.7425
# Epoch 40/600
#
# Epoch 00040: val_loss improved from 0.55195 to 0.55047, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5500 - acc: 0.7417 - val_loss: 0.5505 - val_acc: 0.7469
# Epoch 41/600
#
# Epoch 00041: val_loss improved from 0.55047 to 0.54953, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5486 - acc: 0.7406 - val_loss: 0.5495 - val_acc: 0.7451
# Epoch 42/600
#
# Epoch 00042: val_loss improved from 0.54953 to 0.54816, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5471 - acc: 0.7424 - val_loss: 0.5482 - val_acc: 0.7478
# Epoch 43/600
#
# Epoch 00043: val_loss improved from 0.54816 to 0.54717, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5458 - acc: 0.7434 - val_loss: 0.5472 - val_acc: 0.7478
# Epoch 44/600
#
# Epoch 00044: val_loss improved from 0.54717 to 0.54592, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5445 - acc: 0.7455 - val_loss: 0.5459 - val_acc: 0.7487
# Epoch 45/600
#
# Epoch 00045: val_loss improved from 0.54592 to 0.54462, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5432 - acc: 0.7466 - val_loss: 0.5446 - val_acc: 0.7487
# Epoch 46/600
#
# Epoch 00046: val_loss improved from 0.54462 to 0.54382, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5420 - acc: 0.7472 - val_loss: 0.5438 - val_acc: 0.7478
# Epoch 47/600
#
# Epoch 00047: val_loss improved from 0.54382 to 0.54284, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5407 - acc: 0.7477 - val_loss: 0.5428 - val_acc: 0.7478
# Epoch 48/600
#
# Epoch 00048: val_loss improved from 0.54284 to 0.54180, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5395 - acc: 0.7475 - val_loss: 0.5418 - val_acc: 0.7487
# Epoch 49/600
#
# Epoch 00049: val_loss improved from 0.54180 to 0.54069, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.5383 - acc: 0.7477 - val_loss: 0.5407 - val_acc: 0.7487
# Epoch 50/600
#
# Epoch 00050: val_loss improved from 0.54069 to 0.53981, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.5372 - acc: 0.7481 - val_loss: 0.5398 - val_acc: 0.7496
# Epoch 51/600
#
# Epoch 00051: val_loss improved from 0.53981 to 0.53902, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5361 - acc: 0.7481 - val_loss: 0.5390 - val_acc: 0.7496
# Epoch 52/600
#
# Epoch 00052: val_loss improved from 0.53902 to 0.53831, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5351 - acc: 0.7477 - val_loss: 0.5383 - val_acc: 0.7496
# Epoch 53/600
#
# Epoch 00053: val_loss improved from 0.53831 to 0.53720, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5340 - acc: 0.7481 - val_loss: 0.5372 - val_acc: 0.7496
# Epoch 54/600
#
# Epoch 00054: val_loss improved from 0.53720 to 0.53629, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5330 - acc: 0.7498 - val_loss: 0.5363 - val_acc: 0.7513
# Epoch 55/600
#
# Epoch 00055: val_loss improved from 0.53629 to 0.53560, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5320 - acc: 0.7502 - val_loss: 0.5356 - val_acc: 0.7504
# Epoch 56/600
#
# Epoch 00056: val_loss improved from 0.53560 to 0.53489, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5309 - acc: 0.7509 - val_loss: 0.5349 - val_acc: 0.7531
# Epoch 57/600
#
# Epoch 00057: val_loss improved from 0.53489 to 0.53411, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5299 - acc: 0.7530 - val_loss: 0.5341 - val_acc: 0.7549
# Epoch 58/600
#
# Epoch 00058: val_loss improved from 0.53411 to 0.53306, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5290 - acc: 0.7528 - val_loss: 0.5331 - val_acc: 0.7566
# Epoch 59/600
#
# Epoch 00059: val_loss improved from 0.53306 to 0.53262, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5280 - acc: 0.7530 - val_loss: 0.5326 - val_acc: 0.7575
# Epoch 60/600
#
# Epoch 00060: val_loss improved from 0.53262 to 0.53166, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5271 - acc: 0.7536 - val_loss: 0.5317 - val_acc: 0.7575
# Epoch 61/600
#
# Epoch 00061: val_loss improved from 0.53166 to 0.53127, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5262 - acc: 0.7545 - val_loss: 0.5313 - val_acc: 0.7584
# Epoch 62/600
#
# Epoch 00062: val_loss improved from 0.53127 to 0.53042, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5253 - acc: 0.7538 - val_loss: 0.5304 - val_acc: 0.7593
# Epoch 63/600
#
# Epoch 00063: val_loss improved from 0.53042 to 0.52988, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5245 - acc: 0.7557 - val_loss: 0.5299 - val_acc: 0.7593
# Epoch 64/600
#
# Epoch 00064: val_loss improved from 0.52988 to 0.52911, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5236 - acc: 0.7557 - val_loss: 0.5291 - val_acc: 0.7601
# Epoch 65/600
#
# Epoch 00065: val_loss improved from 0.52911 to 0.52852, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5227 - acc: 0.7560 - val_loss: 0.5285 - val_acc: 0.7610
# Epoch 66/600
#
# Epoch 00066: val_loss improved from 0.52852 to 0.52778, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5219 - acc: 0.7551 - val_loss: 0.5278 - val_acc: 0.7610
# Epoch 67/600
#
# Epoch 00067: val_loss improved from 0.52778 to 0.52715, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5211 - acc: 0.7553 - val_loss: 0.5271 - val_acc: 0.7610
# Epoch 68/600
#
# Epoch 00068: val_loss improved from 0.52715 to 0.52668, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5203 - acc: 0.7557 - val_loss: 0.5267 - val_acc: 0.7628
# Epoch 69/600
#
# Epoch 00069: val_loss improved from 0.52668 to 0.52599, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5196 - acc: 0.7572 - val_loss: 0.5260 - val_acc: 0.7637
# Epoch 70/600
#
# Epoch 00070: val_loss improved from 0.52599 to 0.52553, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5188 - acc: 0.7583 - val_loss: 0.5255 - val_acc: 0.7628
# Epoch 71/600
#
# Epoch 00071: val_loss improved from 0.52553 to 0.52501, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5181 - acc: 0.7566 - val_loss: 0.5250 - val_acc: 0.7610
# Epoch 72/600
#
# Epoch 00072: val_loss improved from 0.52501 to 0.52437, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5173 - acc: 0.7585 - val_loss: 0.5244 - val_acc: 0.7646
# Epoch 73/600
#
# Epoch 00073: val_loss improved from 0.52437 to 0.52413, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5166 - acc: 0.7585 - val_loss: 0.5241 - val_acc: 0.7646
# Epoch 74/600
#
# Epoch 00074: val_loss improved from 0.52413 to 0.52367, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.5159 - acc: 0.7576 - val_loss: 0.5237 - val_acc: 0.7628
# Epoch 75/600
#
# Epoch 00075: val_loss improved from 0.52367 to 0.52287, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5152 - acc: 0.7583 - val_loss: 0.5229 - val_acc: 0.7654
# Epoch 76/600
#
# Epoch 00076: val_loss improved from 0.52287 to 0.52241, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5145 - acc: 0.7593 - val_loss: 0.5224 - val_acc: 0.7646
# Epoch 77/600
#
# Epoch 00077: val_loss improved from 0.52241 to 0.52198, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5138 - acc: 0.7585 - val_loss: 0.5220 - val_acc: 0.7628
# Epoch 78/600
#
# Epoch 00078: val_loss improved from 0.52198 to 0.52147, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5132 - acc: 0.7606 - val_loss: 0.5215 - val_acc: 0.7619
# Epoch 79/600
#
# Epoch 00079: val_loss improved from 0.52147 to 0.52113, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5126 - acc: 0.7611 - val_loss: 0.5211 - val_acc: 0.7619
# Epoch 80/600
#
# Epoch 00080: val_loss improved from 0.52113 to 0.52092, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5119 - acc: 0.7611 - val_loss: 0.5209 - val_acc: 0.7637
# Epoch 81/600
#
# Epoch 00081: val_loss improved from 0.52092 to 0.52059, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5113 - acc: 0.7611 - val_loss: 0.5206 - val_acc: 0.7637
# Epoch 82/600
#
# Epoch 00082: val_loss improved from 0.52059 to 0.51966, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5107 - acc: 0.7606 - val_loss: 0.5197 - val_acc: 0.7619
# Epoch 83/600
#
# Epoch 00083: val_loss improved from 0.51966 to 0.51934, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5101 - acc: 0.7602 - val_loss: 0.5193 - val_acc: 0.7619
# Epoch 84/600
#
# Epoch 00084: val_loss improved from 0.51934 to 0.51876, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5095 - acc: 0.7619 - val_loss: 0.5188 - val_acc: 0.7637
# Epoch 85/600
#
# Epoch 00085: val_loss improved from 0.51876 to 0.51871, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5089 - acc: 0.7627 - val_loss: 0.5187 - val_acc: 0.7619
# Epoch 86/600
#
# Epoch 00086: val_loss improved from 0.51871 to 0.51834, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5084 - acc: 0.7630 - val_loss: 0.5183 - val_acc: 0.7610
# Epoch 87/600
#
# Epoch 00087: val_loss improved from 0.51834 to 0.51799, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5079 - acc: 0.7623 - val_loss: 0.5180 - val_acc: 0.7610
# Epoch 88/600
#
# Epoch 00088: val_loss improved from 0.51799 to 0.51746, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5073 - acc: 0.7625 - val_loss: 0.5175 - val_acc: 0.7610
# Epoch 89/600
#
# Epoch 00089: val_loss did not improve from 0.51746
# 5292/5292 - 4s - loss: 0.5068 - acc: 0.7632 - val_loss: 0.5175 - val_acc: 0.7610
# Epoch 90/600
#
# Epoch 00090: val_loss improved from 0.51746 to 0.51720, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5062 - acc: 0.7630 - val_loss: 0.5172 - val_acc: 0.7610
# Epoch 91/600
#
# Epoch 00091: val_loss improved from 0.51720 to 0.51664, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5058 - acc: 0.7627 - val_loss: 0.5166 - val_acc: 0.7593
# Epoch 92/600
#
# Epoch 00092: val_loss improved from 0.51664 to 0.51608, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5053 - acc: 0.7632 - val_loss: 0.5161 - val_acc: 0.7601
# Epoch 93/600
#
# Epoch 00093: val_loss did not improve from 0.51608
# 5292/5292 - 4s - loss: 0.5048 - acc: 0.7627 - val_loss: 0.5162 - val_acc: 0.7584
# Epoch 94/600
#
# Epoch 00094: val_loss improved from 0.51608 to 0.51588, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5043 - acc: 0.7634 - val_loss: 0.5159 - val_acc: 0.7593
# Epoch 95/600
#
# Epoch 00095: val_loss improved from 0.51588 to 0.51567, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5038 - acc: 0.7627 - val_loss: 0.5157 - val_acc: 0.7584
# Epoch 96/600
#
# Epoch 00096: val_loss improved from 0.51567 to 0.51564, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5034 - acc: 0.7627 - val_loss: 0.5156 - val_acc: 0.7584
# Epoch 97/600
#
# Epoch 00097: val_loss improved from 0.51564 to 0.51516, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5029 - acc: 0.7630 - val_loss: 0.5152 - val_acc: 0.7593
# Epoch 98/600
#
# Epoch 00098: val_loss improved from 0.51516 to 0.51484, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5025 - acc: 0.7638 - val_loss: 0.5148 - val_acc: 0.7584
# Epoch 99/600
#
# Epoch 00099: val_loss improved from 0.51484 to 0.51450, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5020 - acc: 0.7632 - val_loss: 0.5145 - val_acc: 0.7601
# Epoch 100/600
#
# Epoch 00100: val_loss improved from 0.51450 to 0.51441, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5016 - acc: 0.7634 - val_loss: 0.5144 - val_acc: 0.7610
# Epoch 101/600
#
# Epoch 00101: val_loss improved from 0.51441 to 0.51405, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5011 - acc: 0.7636 - val_loss: 0.5140 - val_acc: 0.7601
# Epoch 102/600
#
# Epoch 00102: val_loss improved from 0.51405 to 0.51362, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5008 - acc: 0.7640 - val_loss: 0.5136 - val_acc: 0.7601
# Epoch 103/600
#
# Epoch 00103: val_loss improved from 0.51362 to 0.51350, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.5003 - acc: 0.7636 - val_loss: 0.5135 - val_acc: 0.7601
# Epoch 104/600
#
# Epoch 00104: val_loss did not improve from 0.51350
# 5292/5292 - 4s - loss: 0.4998 - acc: 0.7638 - val_loss: 0.5135 - val_acc: 0.7593
# Epoch 105/600
#
# Epoch 00105: val_loss improved from 0.51350 to 0.51335, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4995 - acc: 0.7640 - val_loss: 0.5133 - val_acc: 0.7601
# Epoch 106/600
#
# Epoch 00106: val_loss improved from 0.51335 to 0.51293, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4991 - acc: 0.7634 - val_loss: 0.5129 - val_acc: 0.7593
# Epoch 107/600
#
# Epoch 00107: val_loss improved from 0.51293 to 0.51273, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4987 - acc: 0.7632 - val_loss: 0.5127 - val_acc: 0.7601
# Epoch 108/600
#
# Epoch 00108: val_loss improved from 0.51273 to 0.51266, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4983 - acc: 0.7632 - val_loss: 0.5127 - val_acc: 0.7601
# Epoch 109/600
#
# Epoch 00109: val_loss improved from 0.51266 to 0.51253, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4979 - acc: 0.7636 - val_loss: 0.5125 - val_acc: 0.7593
# Epoch 110/600
#
# Epoch 00110: val_loss improved from 0.51253 to 0.51245, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4976 - acc: 0.7638 - val_loss: 0.5125 - val_acc: 0.7610
# Epoch 111/600
#
# Epoch 00111: val_loss improved from 0.51245 to 0.51182, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4971 - acc: 0.7640 - val_loss: 0.5118 - val_acc: 0.7610
# Epoch 112/600
#
# Epoch 00112: val_loss improved from 0.51182 to 0.51181, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4968 - acc: 0.7642 - val_loss: 0.5118 - val_acc: 0.7610
# Epoch 113/600
#
# Epoch 00113: val_loss improved from 0.51181 to 0.51176, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4964 - acc: 0.7647 - val_loss: 0.5118 - val_acc: 0.7628
# Epoch 114/600
#
# Epoch 00114: val_loss improved from 0.51176 to 0.51134, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4961 - acc: 0.7644 - val_loss: 0.5113 - val_acc: 0.7628
# Epoch 115/600
#
# Epoch 00115: val_loss improved from 0.51134 to 0.51132, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4957 - acc: 0.7642 - val_loss: 0.5113 - val_acc: 0.7628
# Epoch 116/600
#
# Epoch 00116: val_loss did not improve from 0.51132
# 5292/5292 - 4s - loss: 0.4953 - acc: 0.7653 - val_loss: 0.5114 - val_acc: 0.7628
# Epoch 117/600
#
# Epoch 00117: val_loss improved from 0.51132 to 0.51115, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4950 - acc: 0.7657 - val_loss: 0.5112 - val_acc: 0.7628
# Epoch 118/600
#
# Epoch 00118: val_loss improved from 0.51115 to 0.51103, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4946 - acc: 0.7657 - val_loss: 0.5110 - val_acc: 0.7628
# Epoch 119/600
#
# Epoch 00119: val_loss improved from 0.51103 to 0.51088, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4944 - acc: 0.7649 - val_loss: 0.5109 - val_acc: 0.7628
# Epoch 120/600
#
# Epoch 00120: val_loss did not improve from 0.51088
# 5292/5292 - 4s - loss: 0.4940 - acc: 0.7672 - val_loss: 0.5109 - val_acc: 0.7628
# Epoch 121/600
#
# Epoch 00121: val_loss improved from 0.51088 to 0.51043, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4936 - acc: 0.7663 - val_loss: 0.5104 - val_acc: 0.7628
# Epoch 122/600
#
# Epoch 00122: val_loss improved from 0.51043 to 0.51021, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4933 - acc: 0.7661 - val_loss: 0.5102 - val_acc: 0.7628
# Epoch 123/600
#
# Epoch 00123: val_loss did not improve from 0.51021
# 5292/5292 - 4s - loss: 0.4930 - acc: 0.7666 - val_loss: 0.5105 - val_acc: 0.7619
# Epoch 124/600
#
# Epoch 00124: val_loss improved from 0.51021 to 0.50965, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4928 - acc: 0.7659 - val_loss: 0.5097 - val_acc: 0.7628
# Epoch 125/600
#
# Epoch 00125: val_loss did not improve from 0.50965
# 5292/5292 - 4s - loss: 0.4923 - acc: 0.7672 - val_loss: 0.5102 - val_acc: 0.7601
# Epoch 126/600
#
# Epoch 00126: val_loss did not improve from 0.50965
# 5292/5292 - 5s - loss: 0.4921 - acc: 0.7687 - val_loss: 0.5103 - val_acc: 0.7584
# Epoch 127/600
#
# Epoch 00127: val_loss did not improve from 0.50965
# 5292/5292 - 4s - loss: 0.4918 - acc: 0.7685 - val_loss: 0.5097 - val_acc: 0.7619
# Epoch 128/600
#
# Epoch 00128: val_loss did not improve from 0.50965
# 5292/5292 - 4s - loss: 0.4916 - acc: 0.7668 - val_loss: 0.5097 - val_acc: 0.7610
# Epoch 129/600
#
# Epoch 00129: val_loss improved from 0.50965 to 0.50958, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4914 - acc: 0.7683 - val_loss: 0.5096 - val_acc: 0.7610
# Epoch 130/600
#
# Epoch 00130: val_loss improved from 0.50958 to 0.50938, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4908 - acc: 0.7687 - val_loss: 0.5094 - val_acc: 0.7593
# Epoch 131/600
#
# Epoch 00131: val_loss did not improve from 0.50938
# 5292/5292 - 4s - loss: 0.4905 - acc: 0.7683 - val_loss: 0.5094 - val_acc: 0.7593
# Epoch 132/600
#
# Epoch 00132: val_loss improved from 0.50938 to 0.50923, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4903 - acc: 0.7672 - val_loss: 0.5092 - val_acc: 0.7610
# Epoch 133/600
#
# Epoch 00133: val_loss did not improve from 0.50923
# 5292/5292 - 4s - loss: 0.4900 - acc: 0.7680 - val_loss: 0.5093 - val_acc: 0.7601
# Epoch 134/600
#
# Epoch 00134: val_loss improved from 0.50923 to 0.50888, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4897 - acc: 0.7691 - val_loss: 0.5089 - val_acc: 0.7619
# Epoch 135/600
#
# Epoch 00135: val_loss improved from 0.50888 to 0.50866, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4894 - acc: 0.7687 - val_loss: 0.5087 - val_acc: 0.7628
# Epoch 136/600
#
# Epoch 00136: val_loss improved from 0.50866 to 0.50865, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4891 - acc: 0.7681 - val_loss: 0.5087 - val_acc: 0.7619
# Epoch 137/600
#
# Epoch 00137: val_loss improved from 0.50865 to 0.50840, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4888 - acc: 0.7687 - val_loss: 0.5084 - val_acc: 0.7619
# Epoch 138/600
#
# Epoch 00138: val_loss improved from 0.50840 to 0.50787, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4886 - acc: 0.7685 - val_loss: 0.5079 - val_acc: 0.7628
# Epoch 139/600
#
# Epoch 00139: val_loss did not improve from 0.50787
# 5292/5292 - 4s - loss: 0.4884 - acc: 0.7680 - val_loss: 0.5081 - val_acc: 0.7619
# Epoch 140/600
#
# Epoch 00140: val_loss did not improve from 0.50787
# 5292/5292 - 4s - loss: 0.4880 - acc: 0.7687 - val_loss: 0.5084 - val_acc: 0.7610
# Epoch 141/600
#
# Epoch 00141: val_loss improved from 0.50787 to 0.50775, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4878 - acc: 0.7697 - val_loss: 0.5077 - val_acc: 0.7637
# Epoch 142/600
#
# Epoch 00142: val_loss did not improve from 0.50775
# 5292/5292 - 4s - loss: 0.4875 - acc: 0.7697 - val_loss: 0.5079 - val_acc: 0.7637
# Epoch 143/600
#
# Epoch 00143: val_loss improved from 0.50775 to 0.50771, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4871 - acc: 0.7704 - val_loss: 0.5077 - val_acc: 0.7601
# Epoch 144/600
#
# Epoch 00144: val_loss improved from 0.50771 to 0.50764, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.4869 - acc: 0.7700 - val_loss: 0.5076 - val_acc: 0.7601
# Epoch 145/600
#
# Epoch 00145: val_loss did not improve from 0.50764
# 5292/5292 - 4s - loss: 0.4867 - acc: 0.7706 - val_loss: 0.5080 - val_acc: 0.7610
# Epoch 146/600
#
# Epoch 00146: val_loss improved from 0.50764 to 0.50721, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4865 - acc: 0.7700 - val_loss: 0.5072 - val_acc: 0.7601
# Epoch 147/600
#
# Epoch 00147: val_loss improved from 0.50721 to 0.50706, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4861 - acc: 0.7698 - val_loss: 0.5071 - val_acc: 0.7646
# Epoch 148/600
#
# Epoch 00148: val_loss did not improve from 0.50706
# 5292/5292 - 4s - loss: 0.4858 - acc: 0.7704 - val_loss: 0.5076 - val_acc: 0.7610
# Epoch 149/600
#
# Epoch 00149: val_loss did not improve from 0.50706
# 5292/5292 - 4s - loss: 0.4855 - acc: 0.7710 - val_loss: 0.5074 - val_acc: 0.7628
# Epoch 150/600
#
# Epoch 00150: val_loss did not improve from 0.50706
# 5292/5292 - 4s - loss: 0.4853 - acc: 0.7708 - val_loss: 0.5073 - val_acc: 0.7601
# Epoch 151/600
#
# Epoch 00151: val_loss improved from 0.50706 to 0.50678, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4850 - acc: 0.7708 - val_loss: 0.5068 - val_acc: 0.7637
# Epoch 152/600
#
# Epoch 00152: val_loss improved from 0.50678 to 0.50672, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4848 - acc: 0.7710 - val_loss: 0.5067 - val_acc: 0.7628
# Epoch 153/600
#
# Epoch 00153: val_loss improved from 0.50672 to 0.50650, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4845 - acc: 0.7710 - val_loss: 0.5065 - val_acc: 0.7628
# Epoch 154/600
#
# Epoch 00154: val_loss did not improve from 0.50650
# 5292/5292 - 4s - loss: 0.4842 - acc: 0.7717 - val_loss: 0.5067 - val_acc: 0.7628
# Epoch 155/600
#
# Epoch 00155: val_loss did not improve from 0.50650
# 5292/5292 - 4s - loss: 0.4840 - acc: 0.7721 - val_loss: 0.5066 - val_acc: 0.7628
# Epoch 156/600
#
# Epoch 00156: val_loss improved from 0.50650 to 0.50631, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4838 - acc: 0.7732 - val_loss: 0.5063 - val_acc: 0.7619
# Epoch 157/600
#
# Epoch 00157: val_loss improved from 0.50631 to 0.50608, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4834 - acc: 0.7725 - val_loss: 0.5061 - val_acc: 0.7637
# Epoch 158/600
#
# Epoch 00158: val_loss improved from 0.50608 to 0.50607, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4832 - acc: 0.7717 - val_loss: 0.5061 - val_acc: 0.7637
# Epoch 159/600
#
# Epoch 00159: val_loss improved from 0.50607 to 0.50582, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4830 - acc: 0.7721 - val_loss: 0.5058 - val_acc: 0.7619
# Epoch 160/600
#
# Epoch 00160: val_loss did not improve from 0.50582
# 5292/5292 - 4s - loss: 0.4827 - acc: 0.7727 - val_loss: 0.5061 - val_acc: 0.7601
# Epoch 161/600
#
# Epoch 00161: val_loss did not improve from 0.50582
# 5292/5292 - 4s - loss: 0.4824 - acc: 0.7725 - val_loss: 0.5061 - val_acc: 0.7601
# Epoch 162/600
#
# Epoch 00162: val_loss improved from 0.50582 to 0.50533, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4822 - acc: 0.7723 - val_loss: 0.5053 - val_acc: 0.7619
# Epoch 163/600
#
# Epoch 00163: val_loss did not improve from 0.50533
# 5292/5292 - 4s - loss: 0.4819 - acc: 0.7721 - val_loss: 0.5054 - val_acc: 0.7610
# Epoch 164/600
#
# Epoch 00164: val_loss did not improve from 0.50533
# 5292/5292 - 4s - loss: 0.4818 - acc: 0.7727 - val_loss: 0.5055 - val_acc: 0.7610
# Epoch 165/600
#
# Epoch 00165: val_loss improved from 0.50533 to 0.50524, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4815 - acc: 0.7729 - val_loss: 0.5052 - val_acc: 0.7619
# Epoch 166/600
#
# Epoch 00166: val_loss did not improve from 0.50524
# 5292/5292 - 4s - loss: 0.4812 - acc: 0.7729 - val_loss: 0.5055 - val_acc: 0.7601
# Epoch 167/600
#
# Epoch 00167: val_loss improved from 0.50524 to 0.50504, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4809 - acc: 0.7725 - val_loss: 0.5050 - val_acc: 0.7601
# Epoch 168/600
#
# Epoch 00168: val_loss improved from 0.50504 to 0.50487, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4807 - acc: 0.7723 - val_loss: 0.5049 - val_acc: 0.7619
# Epoch 169/600
#
# Epoch 00169: val_loss did not improve from 0.50487
# 5292/5292 - 4s - loss: 0.4804 - acc: 0.7734 - val_loss: 0.5050 - val_acc: 0.7601
# Epoch 170/600
#
# Epoch 00170: val_loss improved from 0.50487 to 0.50450, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4801 - acc: 0.7731 - val_loss: 0.5045 - val_acc: 0.7619
# Epoch 171/600
#
# Epoch 00171: val_loss improved from 0.50450 to 0.50437, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4800 - acc: 0.7731 - val_loss: 0.5044 - val_acc: 0.7593
# Epoch 172/600
#
# Epoch 00172: val_loss improved from 0.50437 to 0.50431, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4797 - acc: 0.7732 - val_loss: 0.5043 - val_acc: 0.7619
# Epoch 173/600
#
# Epoch 00173: val_loss did not improve from 0.50431
# 5292/5292 - 4s - loss: 0.4795 - acc: 0.7729 - val_loss: 0.5048 - val_acc: 0.7593
# Epoch 174/600
#
# Epoch 00174: val_loss did not improve from 0.50431
# 5292/5292 - 4s - loss: 0.4791 - acc: 0.7734 - val_loss: 0.5045 - val_acc: 0.7584
# Epoch 175/600
#
# Epoch 00175: val_loss did not improve from 0.50431
# 5292/5292 - 4s - loss: 0.4789 - acc: 0.7736 - val_loss: 0.5048 - val_acc: 0.7601
# Epoch 176/600
#
# Epoch 00176: val_loss improved from 0.50431 to 0.50382, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4787 - acc: 0.7738 - val_loss: 0.5038 - val_acc: 0.7593
# Epoch 177/600
#
# Epoch 00177: val_loss did not improve from 0.50382
# 5292/5292 - 4s - loss: 0.4784 - acc: 0.7738 - val_loss: 0.5041 - val_acc: 0.7593
# Epoch 178/600
#
# Epoch 00178: val_loss improved from 0.50382 to 0.50369, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4782 - acc: 0.7740 - val_loss: 0.5037 - val_acc: 0.7584
# Epoch 179/600
#
# Epoch 00179: val_loss did not improve from 0.50369
# 5292/5292 - 4s - loss: 0.4780 - acc: 0.7736 - val_loss: 0.5039 - val_acc: 0.7601
# Epoch 180/600
#
# Epoch 00180: val_loss improved from 0.50369 to 0.50364, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4777 - acc: 0.7738 - val_loss: 0.5036 - val_acc: 0.7584
# Epoch 181/600
#
# Epoch 00181: val_loss improved from 0.50364 to 0.50347, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4774 - acc: 0.7736 - val_loss: 0.5035 - val_acc: 0.7584
# Epoch 182/600
#
# Epoch 00182: val_loss did not improve from 0.50347
# 5292/5292 - 4s - loss: 0.4772 - acc: 0.7738 - val_loss: 0.5035 - val_acc: 0.7575
# Epoch 183/600
#
# Epoch 00183: val_loss did not improve from 0.50347
# 5292/5292 - 4s - loss: 0.4769 - acc: 0.7740 - val_loss: 0.5035 - val_acc: 0.7575
# Epoch 184/600
#
# Epoch 00184: val_loss did not improve from 0.50347
# 5292/5292 - 4s - loss: 0.4767 - acc: 0.7744 - val_loss: 0.5035 - val_acc: 0.7566
# Epoch 185/600
#
# Epoch 00185: val_loss improved from 0.50347 to 0.50269, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4765 - acc: 0.7740 - val_loss: 0.5027 - val_acc: 0.7610
# Epoch 186/600
#
# Epoch 00186: val_loss did not improve from 0.50269
# 5292/5292 - 4s - loss: 0.4763 - acc: 0.7742 - val_loss: 0.5030 - val_acc: 0.7584
# Epoch 187/600
#
# Epoch 00187: val_loss did not improve from 0.50269
# 5292/5292 - 4s - loss: 0.4760 - acc: 0.7753 - val_loss: 0.5031 - val_acc: 0.7593
# Epoch 188/600
#
# Epoch 00188: val_loss improved from 0.50269 to 0.50259, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4757 - acc: 0.7748 - val_loss: 0.5026 - val_acc: 0.7575
# Epoch 189/600
#
# Epoch 00189: val_loss did not improve from 0.50259
# 5292/5292 - 4s - loss: 0.4755 - acc: 0.7751 - val_loss: 0.5028 - val_acc: 0.7575
# Epoch 190/600
#
# Epoch 00190: val_loss improved from 0.50259 to 0.50231, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.4752 - acc: 0.7742 - val_loss: 0.5023 - val_acc: 0.7593
# Epoch 191/600
#
# Epoch 00191: val_loss did not improve from 0.50231
# 5292/5292 - 5s - loss: 0.4750 - acc: 0.7744 - val_loss: 0.5024 - val_acc: 0.7584
# Epoch 192/600
#
# Epoch 00192: val_loss did not improve from 0.50231
# 5292/5292 - 4s - loss: 0.4748 - acc: 0.7748 - val_loss: 0.5024 - val_acc: 0.7584
# Epoch 193/600
#
# Epoch 00193: val_loss improved from 0.50231 to 0.50200, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4745 - acc: 0.7749 - val_loss: 0.5020 - val_acc: 0.7593
# Epoch 194/600
#
# Epoch 00194: val_loss improved from 0.50200 to 0.50194, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4743 - acc: 0.7757 - val_loss: 0.5019 - val_acc: 0.7584
# Epoch 195/600
#
# Epoch 00195: val_loss improved from 0.50194 to 0.50189, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4741 - acc: 0.7755 - val_loss: 0.5019 - val_acc: 0.7601
# Epoch 196/600
#
# Epoch 00196: val_loss improved from 0.50189 to 0.50184, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4738 - acc: 0.7757 - val_loss: 0.5018 - val_acc: 0.7593
# Epoch 197/600
#
# Epoch 00197: val_loss improved from 0.50184 to 0.50152, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4735 - acc: 0.7763 - val_loss: 0.5015 - val_acc: 0.7619
# Epoch 198/600
#
# Epoch 00198: val_loss did not improve from 0.50152
# 5292/5292 - 4s - loss: 0.4734 - acc: 0.7763 - val_loss: 0.5015 - val_acc: 0.7593
# Epoch 199/600
#
# Epoch 00199: val_loss did not improve from 0.50152
# 5292/5292 - 4s - loss: 0.4732 - acc: 0.7765 - val_loss: 0.5016 - val_acc: 0.7610
# Epoch 200/600
#
# Epoch 00200: val_loss improved from 0.50152 to 0.50109, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4729 - acc: 0.7766 - val_loss: 0.5011 - val_acc: 0.7593
# Epoch 201/600
#
# Epoch 00201: val_loss did not improve from 0.50109
# 5292/5292 - 4s - loss: 0.4726 - acc: 0.7765 - val_loss: 0.5012 - val_acc: 0.7601
# Epoch 202/600
#
# Epoch 00202: val_loss improved from 0.50109 to 0.50085, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4724 - acc: 0.7763 - val_loss: 0.5009 - val_acc: 0.7593
# Epoch 203/600
#
# Epoch 00203: val_loss improved from 0.50085 to 0.50075, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4722 - acc: 0.7765 - val_loss: 0.5007 - val_acc: 0.7593
# Epoch 204/600
#
# Epoch 00204: val_loss did not improve from 0.50075
# 5292/5292 - 4s - loss: 0.4721 - acc: 0.7763 - val_loss: 0.5008 - val_acc: 0.7584
# Epoch 205/600
#
# Epoch 00205: val_loss did not improve from 0.50075
# 5292/5292 - 4s - loss: 0.4717 - acc: 0.7778 - val_loss: 0.5009 - val_acc: 0.7584
# Epoch 206/600
#
# Epoch 00206: val_loss did not improve from 0.50075
# 5292/5292 - 4s - loss: 0.4715 - acc: 0.7778 - val_loss: 0.5010 - val_acc: 0.7593
# Epoch 207/600
#
# Epoch 00207: val_loss improved from 0.50075 to 0.50060, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4713 - acc: 0.7780 - val_loss: 0.5006 - val_acc: 0.7610
# Epoch 208/600
#
# Epoch 00208: val_loss improved from 0.50060 to 0.50024, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4710 - acc: 0.7774 - val_loss: 0.5002 - val_acc: 0.7584
# Epoch 209/600
#
# Epoch 00209: val_loss improved from 0.50024 to 0.49991, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4708 - acc: 0.7778 - val_loss: 0.4999 - val_acc: 0.7575
# Epoch 210/600
#
# Epoch 00210: val_loss did not improve from 0.49991
# 5292/5292 - 4s - loss: 0.4706 - acc: 0.7780 - val_loss: 0.5004 - val_acc: 0.7584
# Epoch 211/600
#
# Epoch 00211: val_loss did not improve from 0.49991
# 5292/5292 - 4s - loss: 0.4703 - acc: 0.7780 - val_loss: 0.5005 - val_acc: 0.7584
# Epoch 212/600
#
# Epoch 00212: val_loss improved from 0.49991 to 0.49983, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4701 - acc: 0.7785 - val_loss: 0.4998 - val_acc: 0.7601
# Epoch 213/600
#
# Epoch 00213: val_loss did not improve from 0.49983
# 5292/5292 - 5s - loss: 0.4698 - acc: 0.7797 - val_loss: 0.5000 - val_acc: 0.7584
# Epoch 214/600
#
# Epoch 00214: val_loss improved from 0.49983 to 0.49970, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4696 - acc: 0.7797 - val_loss: 0.4997 - val_acc: 0.7584
# Epoch 215/600
#
# Epoch 00215: val_loss improved from 0.49970 to 0.49954, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4694 - acc: 0.7793 - val_loss: 0.4995 - val_acc: 0.7601
# Epoch 216/600
#
# Epoch 00216: val_loss improved from 0.49954 to 0.49921, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4692 - acc: 0.7783 - val_loss: 0.4992 - val_acc: 0.7646
# Epoch 217/600
#
# Epoch 00217: val_loss improved from 0.49921 to 0.49913, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4689 - acc: 0.7785 - val_loss: 0.4991 - val_acc: 0.7619
# Epoch 218/600
#
# Epoch 00218: val_loss did not improve from 0.49913
# 5292/5292 - 4s - loss: 0.4687 - acc: 0.7799 - val_loss: 0.4993 - val_acc: 0.7601
# Epoch 219/600
#
# Epoch 00219: val_loss did not improve from 0.49913
# 5292/5292 - 4s - loss: 0.4684 - acc: 0.7800 - val_loss: 0.4992 - val_acc: 0.7610
# Epoch 220/600
#
# Epoch 00220: val_loss improved from 0.49913 to 0.49884, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4681 - acc: 0.7791 - val_loss: 0.4988 - val_acc: 0.7628
# Epoch 221/600
#
# Epoch 00221: val_loss improved from 0.49884 to 0.49882, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4680 - acc: 0.7783 - val_loss: 0.4988 - val_acc: 0.7619
# Epoch 222/600
#
# Epoch 00222: val_loss improved from 0.49882 to 0.49860, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4677 - acc: 0.7797 - val_loss: 0.4986 - val_acc: 0.7628
# Epoch 223/600
#
# Epoch 00223: val_loss improved from 0.49860 to 0.49829, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4676 - acc: 0.7797 - val_loss: 0.4983 - val_acc: 0.7619
# Epoch 224/600
#
# Epoch 00224: val_loss did not improve from 0.49829
# 5292/5292 - 4s - loss: 0.4673 - acc: 0.7793 - val_loss: 0.4985 - val_acc: 0.7610
# Epoch 225/600
#
# Epoch 00225: val_loss did not improve from 0.49829
# 5292/5292 - 4s - loss: 0.4670 - acc: 0.7806 - val_loss: 0.4988 - val_acc: 0.7610
# Epoch 226/600
#
# Epoch 00226: val_loss did not improve from 0.49829
# 5292/5292 - 4s - loss: 0.4669 - acc: 0.7812 - val_loss: 0.4985 - val_acc: 0.7628
# Epoch 227/600
#
# Epoch 00227: val_loss did not improve from 0.49829
# 5292/5292 - 4s - loss: 0.4667 - acc: 0.7808 - val_loss: 0.4985 - val_acc: 0.7601
# Epoch 228/600
#
# Epoch 00228: val_loss improved from 0.49829 to 0.49755, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4664 - acc: 0.7810 - val_loss: 0.4975 - val_acc: 0.7637
# Epoch 229/600
#
# Epoch 00229: val_loss did not improve from 0.49755
# 5292/5292 - 4s - loss: 0.4662 - acc: 0.7823 - val_loss: 0.4978 - val_acc: 0.7628
# Epoch 230/600
#
# Epoch 00230: val_loss did not improve from 0.49755
# 5292/5292 - 4s - loss: 0.4659 - acc: 0.7827 - val_loss: 0.4976 - val_acc: 0.7610
# Epoch 231/600
#
# Epoch 00231: val_loss did not improve from 0.49755
# 5292/5292 - 4s - loss: 0.4657 - acc: 0.7817 - val_loss: 0.4977 - val_acc: 0.7593
# Epoch 232/600
#
# Epoch 00232: val_loss improved from 0.49755 to 0.49740, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4654 - acc: 0.7833 - val_loss: 0.4974 - val_acc: 0.7601
# Epoch 233/600
#
# Epoch 00233: val_loss improved from 0.49740 to 0.49668, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4653 - acc: 0.7829 - val_loss: 0.4967 - val_acc: 0.7628
# Epoch 234/600
#
# Epoch 00234: val_loss did not improve from 0.49668
# 5292/5292 - 4s - loss: 0.4652 - acc: 0.7831 - val_loss: 0.4976 - val_acc: 0.7575
# Epoch 235/600
#
# Epoch 00235: val_loss did not improve from 0.49668
# 5292/5292 - 4s - loss: 0.4650 - acc: 0.7823 - val_loss: 0.4973 - val_acc: 0.7637
# Epoch 236/600
#
# Epoch 00236: val_loss did not improve from 0.49668
# 5292/5292 - 4s - loss: 0.4646 - acc: 0.7840 - val_loss: 0.4969 - val_acc: 0.7610
# Epoch 237/600
#
# Epoch 00237: val_loss did not improve from 0.49668
# 5292/5292 - 4s - loss: 0.4643 - acc: 0.7840 - val_loss: 0.4969 - val_acc: 0.7601
# Epoch 238/600
#
# Epoch 00238: val_loss improved from 0.49668 to 0.49631, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4641 - acc: 0.7840 - val_loss: 0.4963 - val_acc: 0.7637
# Epoch 239/600
#
# Epoch 00239: val_loss did not improve from 0.49631
# 5292/5292 - 4s - loss: 0.4639 - acc: 0.7838 - val_loss: 0.4967 - val_acc: 0.7593
# Epoch 240/600
#
# Epoch 00240: val_loss did not improve from 0.49631
# 5292/5292 - 4s - loss: 0.4636 - acc: 0.7842 - val_loss: 0.4964 - val_acc: 0.7619
# Epoch 241/600
#
# Epoch 00241: val_loss improved from 0.49631 to 0.49621, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4634 - acc: 0.7846 - val_loss: 0.4962 - val_acc: 0.7619
# Epoch 242/600
#
# Epoch 00242: val_loss improved from 0.49621 to 0.49581, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4632 - acc: 0.7857 - val_loss: 0.4958 - val_acc: 0.7628
# Epoch 243/600
#
# Epoch 00243: val_loss did not improve from 0.49581
# 5292/5292 - 4s - loss: 0.4629 - acc: 0.7855 - val_loss: 0.4961 - val_acc: 0.7593
# Epoch 244/600
#
# Epoch 00244: val_loss did not improve from 0.49581
# 5292/5292 - 4s - loss: 0.4628 - acc: 0.7868 - val_loss: 0.4964 - val_acc: 0.7593
# Epoch 245/600
#
# Epoch 00245: val_loss improved from 0.49581 to 0.49564, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4625 - acc: 0.7863 - val_loss: 0.4956 - val_acc: 0.7601
# Epoch 246/600
#
# Epoch 00246: val_loss improved from 0.49564 to 0.49555, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4623 - acc: 0.7865 - val_loss: 0.4956 - val_acc: 0.7584
# Epoch 247/600
#
# Epoch 00247: val_loss improved from 0.49555 to 0.49524, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4621 - acc: 0.7867 - val_loss: 0.4952 - val_acc: 0.7610
# Epoch 248/600
#
# Epoch 00248: val_loss did not improve from 0.49524
# 5292/5292 - 4s - loss: 0.4618 - acc: 0.7859 - val_loss: 0.4954 - val_acc: 0.7601
# Epoch 249/600
#
# Epoch 00249: val_loss improved from 0.49524 to 0.49491, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4617 - acc: 0.7872 - val_loss: 0.4949 - val_acc: 0.7628
# Epoch 250/600
#
# Epoch 00250: val_loss did not improve from 0.49491
# 5292/5292 - 4s - loss: 0.4614 - acc: 0.7876 - val_loss: 0.4951 - val_acc: 0.7584
# Epoch 251/600
#
# Epoch 00251: val_loss did not improve from 0.49491
# 5292/5292 - 4s - loss: 0.4612 - acc: 0.7868 - val_loss: 0.4949 - val_acc: 0.7593
# Epoch 252/600
#
# Epoch 00252: val_loss improved from 0.49491 to 0.49468, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4610 - acc: 0.7880 - val_loss: 0.4947 - val_acc: 0.7584
# Epoch 253/600
#
# Epoch 00253: val_loss did not improve from 0.49468
# 5292/5292 - 4s - loss: 0.4608 - acc: 0.7870 - val_loss: 0.4948 - val_acc: 0.7584
# Epoch 254/600
#
# Epoch 00254: val_loss improved from 0.49468 to 0.49408, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4605 - acc: 0.7874 - val_loss: 0.4941 - val_acc: 0.7610
# Epoch 255/600
#
# Epoch 00255: val_loss did not improve from 0.49408
# 5292/5292 - 4s - loss: 0.4603 - acc: 0.7882 - val_loss: 0.4941 - val_acc: 0.7619
# Epoch 256/600
#
# Epoch 00256: val_loss did not improve from 0.49408
# 5292/5292 - 4s - loss: 0.4601 - acc: 0.7885 - val_loss: 0.4944 - val_acc: 0.7575
# Epoch 257/600
#
# Epoch 00257: val_loss improved from 0.49408 to 0.49358, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4599 - acc: 0.7895 - val_loss: 0.4936 - val_acc: 0.7593
# Epoch 258/600
#
# Epoch 00258: val_loss did not improve from 0.49358
# 5292/5292 - 4s - loss: 0.4597 - acc: 0.7889 - val_loss: 0.4940 - val_acc: 0.7584
# Epoch 259/600
#
# Epoch 00259: val_loss improved from 0.49358 to 0.49346, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4595 - acc: 0.7901 - val_loss: 0.4935 - val_acc: 0.7610
# Epoch 260/600
#
# Epoch 00260: val_loss did not improve from 0.49346
# 5292/5292 - 4s - loss: 0.4593 - acc: 0.7902 - val_loss: 0.4940 - val_acc: 0.7566
# Epoch 261/600
#
# Epoch 00261: val_loss improved from 0.49346 to 0.49346, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.4591 - acc: 0.7897 - val_loss: 0.4935 - val_acc: 0.7575
# Epoch 262/600
#
# Epoch 00262: val_loss improved from 0.49346 to 0.49324, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4588 - acc: 0.7897 - val_loss: 0.4932 - val_acc: 0.7584
# Epoch 263/600
#
# Epoch 00263: val_loss did not improve from 0.49324
# 5292/5292 - 4s - loss: 0.4586 - acc: 0.7897 - val_loss: 0.4934 - val_acc: 0.7584
# Epoch 264/600
#
# Epoch 00264: val_loss did not improve from 0.49324
# 5292/5292 - 4s - loss: 0.4584 - acc: 0.7901 - val_loss: 0.4934 - val_acc: 0.7575
# Epoch 265/600
#
# Epoch 00265: val_loss improved from 0.49324 to 0.49299, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.4582 - acc: 0.7897 - val_loss: 0.4930 - val_acc: 0.7584
# Epoch 266/600
#
# Epoch 00266: val_loss improved from 0.49299 to 0.49293, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4580 - acc: 0.7893 - val_loss: 0.4929 - val_acc: 0.7584
# Epoch 267/600
#
# Epoch 00267: val_loss improved from 0.49293 to 0.49270, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4578 - acc: 0.7899 - val_loss: 0.4927 - val_acc: 0.7593
# Epoch 268/600
#
# Epoch 00268: val_loss improved from 0.49270 to 0.49253, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4576 - acc: 0.7904 - val_loss: 0.4925 - val_acc: 0.7610
# Epoch 269/600
#
# ...
#
# Epoch 00501: val_loss did not improve from 0.47052
# 5292/5292 - 4s - loss: 0.4167 - acc: 0.8095 - val_loss: 0.4711 - val_acc: 0.7707
# Epoch 502/600
#
# Epoch 00502: val_loss did not improve from 0.47052
# 5292/5292 - 4s - loss: 0.4166 - acc: 0.8088 - val_loss: 0.4711 - val_acc: 0.7734
# Epoch 503/600
#
# Epoch 00503: val_loss improved from 0.47052 to 0.47047, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4163 - acc: 0.8086 - val_loss: 0.4705 - val_acc: 0.7716
# Epoch 504/600
#
# Epoch 00504: val_loss did not improve from 0.47047
# 5292/5292 - 4s - loss: 0.4161 - acc: 0.8101 - val_loss: 0.4709 - val_acc: 0.7681
# Epoch 505/600
#
# Epoch 00505: val_loss improved from 0.47047 to 0.46988, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4159 - acc: 0.8095 - val_loss: 0.4699 - val_acc: 0.7716
# Epoch 506/600
#
# Epoch 00506: val_loss did not improve from 0.46988
# 5292/5292 - 4s - loss: 0.4158 - acc: 0.8088 - val_loss: 0.4711 - val_acc: 0.7698
# Epoch 507/600
#
# Epoch 00507: val_loss did not improve from 0.46988
# 5292/5292 - 4s - loss: 0.4157 - acc: 0.8093 - val_loss: 0.4706 - val_acc: 0.7707
# Epoch 508/600
#
# Epoch 00508: val_loss did not improve from 0.46988
# 5292/5292 - 4s - loss: 0.4155 - acc: 0.8090 - val_loss: 0.4700 - val_acc: 0.7716
# Epoch 509/600
#
# Epoch 00509: val_loss did not improve from 0.46988
# 5292/5292 - 4s - loss: 0.4153 - acc: 0.8097 - val_loss: 0.4705 - val_acc: 0.7707
# Epoch 510/600
#
# Epoch 00510: val_loss did not improve from 0.46988
# 5292/5292 - 4s - loss: 0.4151 - acc: 0.8105 - val_loss: 0.4705 - val_acc: 0.7698
# Epoch 511/600
#
# Epoch 00511: val_loss did not improve from 0.46988
# 5292/5292 - 4s - loss: 0.4150 - acc: 0.8103 - val_loss: 0.4700 - val_acc: 0.7716
# Epoch 512/600
#
# Epoch 00512: val_loss improved from 0.46988 to 0.46982, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4149 - acc: 0.8097 - val_loss: 0.4698 - val_acc: 0.7725
# Epoch 513/600
#
# Epoch 00513: val_loss did not improve from 0.46982
# 5292/5292 - 4s - loss: 0.4147 - acc: 0.8103 - val_loss: 0.4703 - val_acc: 0.7681
# Epoch 514/600
#
# Epoch 00514: val_loss did not improve from 0.46982
# 5292/5292 - 4s - loss: 0.4145 - acc: 0.8105 - val_loss: 0.4705 - val_acc: 0.7725
# Epoch 515/600
#
# Epoch 00515: val_loss did not improve from 0.46982
# 5292/5292 - 4s - loss: 0.4143 - acc: 0.8112 - val_loss: 0.4700 - val_acc: 0.7734
# Epoch 516/600
#
# Epoch 00516: val_loss improved from 0.46982 to 0.46950, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4143 - acc: 0.8108 - val_loss: 0.4695 - val_acc: 0.7725
# Epoch 517/600
#
# Epoch 00517: val_loss did not improve from 0.46950
# 5292/5292 - 4s - loss: 0.4140 - acc: 0.8112 - val_loss: 0.4699 - val_acc: 0.7698
# Epoch 518/600
#
# Epoch 00518: val_loss did not improve from 0.46950
# 5292/5292 - 4s - loss: 0.4140 - acc: 0.8103 - val_loss: 0.4699 - val_acc: 0.7716
# Epoch 519/600
#
# Epoch 00519: val_loss did not improve from 0.46950
# 5292/5292 - 4s - loss: 0.4138 - acc: 0.8118 - val_loss: 0.4697 - val_acc: 0.7716
# Epoch 520/600
#
# Epoch 00520: val_loss did not improve from 0.46950
# 5292/5292 - 4s - loss: 0.4135 - acc: 0.8112 - val_loss: 0.4696 - val_acc: 0.7698
# Epoch 521/600
#
# Epoch 00521: val_loss did not improve from 0.46950
# 5292/5292 - 4s - loss: 0.4134 - acc: 0.8116 - val_loss: 0.4697 - val_acc: 0.7716
# Epoch 522/600
#
# Epoch 00522: val_loss improved from 0.46950 to 0.46934, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4133 - acc: 0.8105 - val_loss: 0.4693 - val_acc: 0.7716
# Epoch 523/600
#
# Epoch 00523: val_loss did not improve from 0.46934
# 5292/5292 - 4s - loss: 0.4130 - acc: 0.8114 - val_loss: 0.4695 - val_acc: 0.7725
# Epoch 524/600
#
# Epoch 00524: val_loss did not improve from 0.46934
# 5292/5292 - 4s - loss: 0.4129 - acc: 0.8112 - val_loss: 0.4694 - val_acc: 0.7725
# Epoch 525/600
#
# Epoch 00525: val_loss did not improve from 0.46934
# 5292/5292 - 4s - loss: 0.4130 - acc: 0.8118 - val_loss: 0.4696 - val_acc: 0.7681
# Epoch 526/600
#
# Epoch 00526: val_loss improved from 0.46934 to 0.46923, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4125 - acc: 0.8114 - val_loss: 0.4692 - val_acc: 0.7716
# Epoch 527/600
#
# Epoch 00527: val_loss did not improve from 0.46923
# 5292/5292 - 4s - loss: 0.4125 - acc: 0.8118 - val_loss: 0.4702 - val_acc: 0.7716
# Epoch 528/600
#
# Epoch 00528: val_loss improved from 0.46923 to 0.46885, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4123 - acc: 0.8101 - val_loss: 0.4689 - val_acc: 0.7751
# Epoch 529/600
#
# Epoch 00529: val_loss improved from 0.46885 to 0.46880, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4120 - acc: 0.8118 - val_loss: 0.4688 - val_acc: 0.7725
# Epoch 530/600
#
# Epoch 00530: val_loss did not improve from 0.46880
# 5292/5292 - 4s - loss: 0.4122 - acc: 0.8120 - val_loss: 0.4689 - val_acc: 0.7734
# Epoch 531/600
#
# Epoch 00531: val_loss did not improve from 0.46880
# 5292/5292 - 4s - loss: 0.4117 - acc: 0.8120 - val_loss: 0.4696 - val_acc: 0.7725
# Epoch 532/600
#
# Epoch 00532: val_loss improved from 0.46880 to 0.46863, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4119 - acc: 0.8120 - val_loss: 0.4686 - val_acc: 0.7734
# Epoch 533/600
#
# Epoch 00533: val_loss did not improve from 0.46863
# 5292/5292 - 4s - loss: 0.4115 - acc: 0.8124 - val_loss: 0.4688 - val_acc: 0.7751
# Epoch 534/600
#
# Epoch 00534: val_loss did not improve from 0.46863
# 5292/5292 - 4s - loss: 0.4114 - acc: 0.8125 - val_loss: 0.4696 - val_acc: 0.7707
# Epoch 535/600
#
# Epoch 00535: val_loss did not improve from 0.46863
# 5292/5292 - 4s - loss: 0.4111 - acc: 0.8124 - val_loss: 0.4687 - val_acc: 0.7743
# Epoch 536/600
#
# Epoch 00536: val_loss improved from 0.46863 to 0.46838, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4112 - acc: 0.8129 - val_loss: 0.4684 - val_acc: 0.7751
# Epoch 537/600
#
# Epoch 00537: val_loss did not improve from 0.46838
# 5292/5292 - 4s - loss: 0.4111 - acc: 0.8133 - val_loss: 0.4690 - val_acc: 0.7734
# Epoch 538/600
#
# Epoch 00538: val_loss improved from 0.46838 to 0.46803, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4108 - acc: 0.8125 - val_loss: 0.4680 - val_acc: 0.7743
# Epoch 539/600
#
# Epoch 00539: val_loss did not improve from 0.46803
# 5292/5292 - 4s - loss: 0.4107 - acc: 0.8131 - val_loss: 0.4691 - val_acc: 0.7743
# Epoch 540/600
#
# Epoch 00540: val_loss did not improve from 0.46803
# 5292/5292 - 4s - loss: 0.4104 - acc: 0.8125 - val_loss: 0.4687 - val_acc: 0.7734
# Epoch 541/600
#
# Epoch 00541: val_loss improved from 0.46803 to 0.46790, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4102 - acc: 0.8135 - val_loss: 0.4679 - val_acc: 0.7751
# Epoch 542/600
#
# Epoch 00542: val_loss did not improve from 0.46790
# 5292/5292 - 4s - loss: 0.4101 - acc: 0.8139 - val_loss: 0.4683 - val_acc: 0.7743
# Epoch 543/600
#
# Epoch 00543: val_loss did not improve from 0.46790
# 5292/5292 - 4s - loss: 0.4099 - acc: 0.8135 - val_loss: 0.4686 - val_acc: 0.7734
# Epoch 544/600
#
# Epoch 00544: val_loss did not improve from 0.46790
# 5292/5292 - 4s - loss: 0.4099 - acc: 0.8137 - val_loss: 0.4689 - val_acc: 0.7751
# Epoch 545/600
#
# Epoch 00545: val_loss improved from 0.46790 to 0.46760, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 5s - loss: 0.4098 - acc: 0.8141 - val_loss: 0.4676 - val_acc: 0.7760
# Epoch 546/600
#
# Epoch 00546: val_loss did not improve from 0.46760
# 5292/5292 - 5s - loss: 0.4094 - acc: 0.8139 - val_loss: 0.4681 - val_acc: 0.7734
# Epoch 547/600
#
# Epoch 00547: val_loss did not improve from 0.46760
# 5292/5292 - 4s - loss: 0.4094 - acc: 0.8142 - val_loss: 0.4681 - val_acc: 0.7743
# Epoch 548/600
#
# Epoch 00548: val_loss did not improve from 0.46760
# 5292/5292 - 4s - loss: 0.4092 - acc: 0.8146 - val_loss: 0.4687 - val_acc: 0.7725
# Epoch 549/600
#
# Epoch 00549: val_loss did not improve from 0.46760
# 5292/5292 - 4s - loss: 0.4092 - acc: 0.8142 - val_loss: 0.4677 - val_acc: 0.7743
# Epoch 550/600
#
# Epoch 00550: val_loss did not improve from 0.46760
# 5292/5292 - 4s - loss: 0.4089 - acc: 0.8141 - val_loss: 0.4687 - val_acc: 0.7734
# Epoch 551/600
#
# Epoch 00551: val_loss did not improve from 0.46760
# 5292/5292 - 4s - loss: 0.4086 - acc: 0.8141 - val_loss: 0.4678 - val_acc: 0.7734
# Epoch 552/600
#
# Epoch 00552: val_loss did not improve from 0.46760
# 5292/5292 - 4s - loss: 0.4085 - acc: 0.8148 - val_loss: 0.4676 - val_acc: 0.7743
# Epoch 553/600
#
# Epoch 00553: val_loss did not improve from 0.46760
# 5292/5292 - 4s - loss: 0.4085 - acc: 0.8142 - val_loss: 0.4685 - val_acc: 0.7760
# Epoch 554/600
#
# Epoch 00554: val_loss improved from 0.46760 to 0.46693, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4083 - acc: 0.8148 - val_loss: 0.4669 - val_acc: 0.7760
# Epoch 555/600
#
# Epoch 00555: val_loss did not improve from 0.46693
# 5292/5292 - 4s - loss: 0.4080 - acc: 0.8139 - val_loss: 0.4678 - val_acc: 0.7743
# Epoch 556/600
#
# Epoch 00556: val_loss did not improve from 0.46693
# 5292/5292 - 4s - loss: 0.4079 - acc: 0.8150 - val_loss: 0.4678 - val_acc: 0.7751
# Epoch 557/600
#
# Epoch 00557: val_loss did not improve from 0.46693
# 5292/5292 - 4s - loss: 0.4077 - acc: 0.8148 - val_loss: 0.4677 - val_acc: 0.7760
# Epoch 558/600
#
# Epoch 00558: val_loss did not improve from 0.46693
# 5292/5292 - 4s - loss: 0.4076 - acc: 0.8141 - val_loss: 0.4674 - val_acc: 0.7760
# Epoch 559/600
#
# Epoch 00559: val_loss did not improve from 0.46693
# 5292/5292 - 4s - loss: 0.4074 - acc: 0.8146 - val_loss: 0.4673 - val_acc: 0.7743
# Epoch 560/600
#
# Epoch 00560: val_loss did not improve from 0.46693
# 5292/5292 - 4s - loss: 0.4073 - acc: 0.8148 - val_loss: 0.4673 - val_acc: 0.7743
# Epoch 561/600
#
# Epoch 00561: val_loss did not improve from 0.46693
# 5292/5292 - 4s - loss: 0.4071 - acc: 0.8139 - val_loss: 0.4679 - val_acc: 0.7734
# Epoch 562/600
#
# Epoch 00562: val_loss did not improve from 0.46693
# 5292/5292 - 4s - loss: 0.4069 - acc: 0.8148 - val_loss: 0.4678 - val_acc: 0.7760
# Epoch 563/600
#
# Epoch 00563: val_loss improved from 0.46693 to 0.46664, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4069 - acc: 0.8148 - val_loss: 0.4666 - val_acc: 0.7787
# Epoch 564/600
#
# Epoch 00564: val_loss did not improve from 0.46664
# 5292/5292 - 4s - loss: 0.4066 - acc: 0.8150 - val_loss: 0.4676 - val_acc: 0.7760
# Epoch 565/600
#
# Epoch 00565: val_loss did not improve from 0.46664
# 5292/5292 - 4s - loss: 0.4064 - acc: 0.8144 - val_loss: 0.4672 - val_acc: 0.7743
# Epoch 566/600
#
# Epoch 00566: val_loss did not improve from 0.46664
# 5292/5292 - 4s - loss: 0.4063 - acc: 0.8150 - val_loss: 0.4670 - val_acc: 0.7778
# Epoch 567/600
#
# Epoch 00567: val_loss did not improve from 0.46664
# 5292/5292 - 4s - loss: 0.4061 - acc: 0.8156 - val_loss: 0.4670 - val_acc: 0.7778
# Epoch 568/600
#
# Epoch 00568: val_loss did not improve from 0.46664
# 5292/5292 - 4s - loss: 0.4060 - acc: 0.8152 - val_loss: 0.4676 - val_acc: 0.7778
# Epoch 569/600
#
# Epoch 00569: val_loss improved from 0.46664 to 0.46644, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4059 - acc: 0.8146 - val_loss: 0.4664 - val_acc: 0.7795
# Epoch 570/600
#
# Epoch 00570: val_loss did not improve from 0.46644
# 5292/5292 - 4s - loss: 0.4057 - acc: 0.8154 - val_loss: 0.4669 - val_acc: 0.7769
# Epoch 571/600
#
# Epoch 00571: val_loss did not improve from 0.46644
# 5292/5292 - 4s - loss: 0.4056 - acc: 0.8152 - val_loss: 0.4671 - val_acc: 0.7787
# Epoch 572/600
#
# Epoch 00572: val_loss did not improve from 0.46644
# 5292/5292 - 4s - loss: 0.4055 - acc: 0.8175 - val_loss: 0.4679 - val_acc: 0.7760
# Epoch 573/600
#
# Epoch 00573: val_loss did not improve from 0.46644
# 5292/5292 - 4s - loss: 0.4052 - acc: 0.8158 - val_loss: 0.4666 - val_acc: 0.7760
# Epoch 574/600
#
# Epoch 00574: val_loss did not improve from 0.46644
# 5292/5292 - 4s - loss: 0.4051 - acc: 0.8154 - val_loss: 0.4668 - val_acc: 0.7787
# Epoch 575/600
#
# Epoch 00575: val_loss did not improve from 0.46644
# 5292/5292 - 4s - loss: 0.4049 - acc: 0.8156 - val_loss: 0.4667 - val_acc: 0.7795
# Epoch 576/600
#
# Epoch 00576: val_loss did not improve from 0.46644
# 5292/5292 - 4s - loss: 0.4051 - acc: 0.8165 - val_loss: 0.4674 - val_acc: 0.7804
# Epoch 577/600
#
# Epoch 00577: val_loss improved from 0.46644 to 0.46638, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4047 - acc: 0.8156 - val_loss: 0.4664 - val_acc: 0.7769
# Epoch 578/600
#
# Epoch 00578: val_loss did not improve from 0.46638
# 5292/5292 - 4s - loss: 0.4045 - acc: 0.8154 - val_loss: 0.4667 - val_acc: 0.7795
# Epoch 579/600
#
# Epoch 00579: val_loss did not improve from 0.46638
# 5292/5292 - 4s - loss: 0.4045 - acc: 0.8152 - val_loss: 0.4672 - val_acc: 0.7795
# Epoch 580/600
#
# Epoch 00580: val_loss improved from 0.46638 to 0.46532, saving model to /tmp/LSTM_checkpoint.h5
# 5292/5292 - 4s - loss: 0.4042 - acc: 0.8159 - val_loss: 0.4653 - val_acc: 0.7804
# Epoch 581/600
#
# Epoch 00581: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4042 - acc: 0.8154 - val_loss: 0.4667 - val_acc: 0.7795
# Epoch 582/600
#
# Epoch 00582: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4040 - acc: 0.8152 - val_loss: 0.4662 - val_acc: 0.7778
# Epoch 583/600
#
# Epoch 00583: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4036 - acc: 0.8165 - val_loss: 0.4666 - val_acc: 0.7778
# Epoch 584/600
#
# Epoch 00584: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4037 - acc: 0.8161 - val_loss: 0.4665 - val_acc: 0.7787
# Epoch 585/600
#
# Epoch 00585: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4034 - acc: 0.8163 - val_loss: 0.4667 - val_acc: 0.7778
# Epoch 586/600
#
# Epoch 00586: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4034 - acc: 0.8165 - val_loss: 0.4660 - val_acc: 0.7778
# Epoch 587/600
#
# Epoch 00587: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4034 - acc: 0.8163 - val_loss: 0.4668 - val_acc: 0.7795
# Epoch 588/600
#
# Epoch 00588: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4029 - acc: 0.8167 - val_loss: 0.4661 - val_acc: 0.7787
# Epoch 589/600
#
# Epoch 00589: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4027 - acc: 0.8163 - val_loss: 0.4664 - val_acc: 0.7813
# Epoch 590/600
#
# Epoch 00590: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4027 - acc: 0.8163 - val_loss: 0.4662 - val_acc: 0.7795
# Epoch 591/600
#
# Epoch 00591: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4025 - acc: 0.8161 - val_loss: 0.4660 - val_acc: 0.7813
# Epoch 592/600
#
# Epoch 00592: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4025 - acc: 0.8169 - val_loss: 0.4664 - val_acc: 0.7778
# Epoch 593/600
#
# Epoch 00593: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4021 - acc: 0.8165 - val_loss: 0.4661 - val_acc: 0.7769
# Epoch 594/600
#
# Epoch 00594: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4020 - acc: 0.8167 - val_loss: 0.4658 - val_acc: 0.7813
# Epoch 595/600
#
# Epoch 00595: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4019 - acc: 0.8167 - val_loss: 0.4666 - val_acc: 0.7840
# Epoch 596/600
#
# Epoch 00596: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4018 - acc: 0.8173 - val_loss: 0.4654 - val_acc: 0.7822
# Epoch 597/600
#
# Epoch 00597: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4016 - acc: 0.8171 - val_loss: 0.4665 - val_acc: 0.7822
# Epoch 598/600
#
# Epoch 00598: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4014 - acc: 0.8175 - val_loss: 0.4657 - val_acc: 0.7769
# Epoch 599/600
#
# Epoch 00599: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4013 - acc: 0.8169 - val_loss: 0.4659 - val_acc: 0.7795
# Epoch 600/600
#
# Epoch 00600: val_loss did not improve from 0.46532
# 5292/5292 - 4s - loss: 0.4012 - acc: 0.8159 - val_loss: 0.4660 - val_acc: 0.7831
# Classification accuracy: 0.771605
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-755e02e7b128> in <module>()
#      40
#      41 # set up sklearn pipeline
# ---> 42 clf = make_pipeline(XdawnCovariances(n_components),
#      43                     TangentSpace(metric='riemann'),
#      44                     LogisticRegression())
#
# NameError: name 'make_pipeline' is not defined

# %%
# !pip freeze
# Out:
# absl-py==0.9.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.0.0
# asgiref==3.2.3
# astor==0.8.1
# astropy==4.0
# atari-py==0.2.6
# atomicwrites==1.3.0
# attrs==19.3.0
# audioread==2.1.8
# autograd==1.3
# Babel==2.8.0
# backcall==0.1.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# beautifulsoup4==4.6.3
# bleach==3.1.0
# blis==0.2.4
# bokeh==1.4.0
# boto==2.49.0
# boto3==1.10.47
# botocore==1.13.47
# Bottleneck==1.3.1
# branca==0.3.1
# bs4==0.0.1
# bz2file==0.98
# cachetools==4.0.0
# certifi==2019.11.28
# cffi==1.13.2
# chainer==6.5.0
# chardet==3.0.4
# chart-studio==1.0.0
# Click==7.0
# cloudpickle==1.2.2
# cmake==3.12.0
# colorlover==0.3.0
# community==1.0.0b1
# contextlib2==0.5.5
# convertdate==2.2.0
# coverage==3.7.1
# coveralls==0.5
# crcmod==1.7
# cufflinks==0.17.0
# cvxopt==1.2.3
# cvxpy==1.0.25
# cycler==0.10.0
# cymem==2.0.3
# Cython==0.29.14
# daft==0.0.4
# dask==2.9.1
# dataclasses==0.7
# datascience==0.10.6
# decorator==4.4.1
# defusedxml==0.6.0
# descartes==1.1.0
# dill==0.3.1.1
# distributed==1.25.3
# Django==3.0.2
# dlib==19.18.0
# dm-sonnet==1.35
# docopt==0.6.2
# docutils==0.15.2
# dopamine-rl==1.0.5
# earthengine-api==0.1.209
# easydict==1.9
# ecos==2.0.7.post1
# editdistance==0.5.3
# en-core-web-sm==2.1.0
# entrypoints==0.3
# et-xmlfile==1.0.1
# fa2==0.3.5
# fancyimpute==0.4.3
# fastai==1.0.60
# fastcache==1.1.0
# fastdtw==0.3.4
# fastprogress==0.2.2
# fastrlock==0.4
# fbprophet==0.5
# feather-format==0.4.0
# featuretools==0.4.1
# filelock==3.0.12
# fix-yahoo-finance==0.0.22
# Flask==1.1.1
# folium==0.8.3
# fsspec==0.6.2
# future==0.16.0
# gast==0.2.2
# GDAL==2.2.2
# gdown==3.6.4
# gensim==3.6.0
# geographiclib==1.50
# geopy==1.17.0
# gevent==1.4.0
# gin-config==0.3.0
# glob2==0.7
# google==2.0.3
# google-api-core==1.15.0
# google-api-python-client==1.7.11
# google-auth==1.4.2
# google-auth-httplib2==0.0.3
# google-auth-oauthlib==0.4.1
# google-cloud-bigquery==1.21.0
# google-cloud-core==1.0.3
# google-cloud-datastore==1.8.0
# google-cloud-language==1.2.0
# google-cloud-storage==1.16.2
# google-cloud-translate==1.5.0
# google-colab==1.0.0
# google-pasta==0.1.8
# google-resumable-media==0.4.1
# googleapis-common-protos==1.6.0
# googledrivedownloader==0.4
# graph-nets==1.0.5
# graphviz==0.10.1
# greenlet==0.4.15
# grpcio==1.15.0
# gspread==3.0.1
# gspread-dataframe==3.0.3
# gunicorn==20.0.4
# gym==0.15.4
# h5py==2.8.0
# HeapDict==1.0.1
# holidays==0.9.12
# html5lib==1.0.1
# httpimport==0.5.18
# httplib2==0.11.3
# humanize==0.5.1
# hyperopt==0.1.2
# ideep4py==2.0.0.post3
# idna==2.8
# image==1.5.27
# imageio==2.4.1
# imagesize==1.2.0
# imbalanced-learn==0.4.3
# imblearn==0.0
# imgaug==0.2.9
# importlib-metadata==1.4.0
# imutils==0.5.3
# inflect==2.1.0
# intel-openmp==2020.0.133
# intervaltree==2.1.0
# ipykernel==4.6.1
# ipython==5.5.0
# ipython-genutils==0.2.0
# ipython-sql==0.3.9
# ipywidgets==7.5.1
# itsdangerous==1.1.0
# jax==0.1.52
# jaxlib==0.1.36
# jdcal==1.4.1
# jedi==0.15.2
# jieba==0.40
# Jinja2==2.10.3
# jmespath==0.9.4
# joblib==0.14.1
# jpeg4py==0.1.4
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==5.2.0
# jupyter-core==4.6.1
# kaggle==1.5.6
# kapre==0.1.3.1
# Keras==2.2.5
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# keras-vis==0.4.1
# kfac==0.2.0
# kiwisolver==1.1.0
# knnimpute==0.1.0
# librosa==0.6.3
# lightgbm==2.2.3
# llvmlite==0.31.0
# lmdb==0.98
# lucid==0.3.8
# lunardate==0.2.0
# lxml==4.2.6
# magenta==0.3.19
# Markdown==3.1.1
# MarkupSafe==1.1.1
# matplotlib==3.1.2
# matplotlib-venn==0.11.5
# mesh-tensorflow==0.1.8
# mido==1.2.6
# mir-eval==0.5
# missingno==0.4.2
# mistune==0.8.4
# mizani==0.6.0
# mkl==2019.0
# mlxtend==0.14.0
# mne==0.19.2
# more-itertools==8.0.2
# moviepy==0.2.3.5
# mpi4py==3.0.3
# mpmath==1.1.0
# msgpack==0.5.6
# multiprocess==0.70.9
# multitasking==0.0.9
# murmurhash==1.0.2
# music21==5.5.0
# natsort==5.5.0
# nbconvert==5.6.1
# nbformat==5.0.3
# networkx==2.4
# nibabel==2.3.3
# nltk==3.2.5
# notebook==5.2.2
# np-utils==0.5.12.1
# numba==0.47.0
# numexpr==2.7.1
# numpy==1.17.5
# nvidia-ml-py3==7.352.0
# oauth2client==4.1.3
# oauthlib==3.1.0
# okgrade==0.4.3
# opencv-contrib-python==4.1.2.30
# opencv-python==4.1.2.30
# openpyxl==2.5.9
# opt-einsum==3.1.0
# osqp==0.6.1
# packaging==20.0
# palettable==3.3.0
# pandas==0.25.3
# pandas-datareader==0.7.4
# pandas-gbq==0.11.0
# pandas-profiling==1.4.1
# pandocfilters==1.4.2
# parso==0.5.2
# pathlib==1.0.1
# patsy==0.5.1
# pexpect==4.7.0
# pickleshare==0.7.5
# Pillow==6.2.2
# pip-tools==4.2.0
# plac==0.9.6
# plotly==4.4.1
# plotnine==0.6.0
# pluggy==0.7.1
# portpicker==1.2.0
# prefetch-generator==1.0.1
# preshed==2.0.1
# pretty-midi==0.2.8
# prettytable==0.7.2
# progressbar2==3.38.0
# prometheus-client==0.7.1
# promise==2.3
# prompt-toolkit==1.0.18
# protobuf==3.10.0
# psutil==5.4.8
# psycopg2==2.7.6.1
# ptyprocess==0.6.0
# py==1.8.1
# pyarrow==0.14.1
# pyasn1==0.4.8
# pyasn1-modules==0.2.7
# pycocotools==2.0.0
# pycparser==2.19
# pydata-google-auth==0.2.1
# pydot==1.3.0
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# pyEDFlib==0.1.15
# pyemd==0.5.1
# pyglet==1.3.2
# Pygments==2.1.3
# pygobject==3.26.1
# pymc3==3.7
# PyMeeus==0.3.6
# pymongo==3.10.0
# pymystem3==0.2.0
# PyOpenGL==3.1.5
# pyparsing==2.4.6
# pypng==0.0.20
# pyrsistent==0.15.7
# pysndfile==1.3.8
# PySocks==1.7.1
# pystan==2.19.1.1
# pytest==3.6.4
# python-apt==1.6.4
# python-chess==0.23.11
# python-dateutil==2.6.1
# python-louvain==0.13
# python-rtmidi==1.3.1
# python-slugify==4.0.0
# python-utils==2.3.0
# pytz==2018.9
# PyWavelets==1.1.1
# PyYAML==3.13
# pyzmq==17.0.0
# qtconsole==4.6.0
# regex==2019.12.20
# requests==2.21.0
# requests-oauthlib==1.3.0
# resampy==0.2.2
# retrying==1.3.3
# rpy2==2.9.5
# rsa==4.0
# s3fs==0.4.0
# s3transfer==0.2.1
# scikit-image==0.16.2
# scikit-learn==0.22.1
# scipy==1.4.1
# screen-resolution-extra==0.0.0
# scs==2.1.1.post2
# seaborn==0.9.0
# semantic-version==2.8.4
# Send2Trash==1.5.0
# setuptools-git==1.2
# Shapely==1.6.4.post2
# simplegeneric==0.8.1
# six==1.12.0
# sklearn==0.0
# sklearn-pandas==1.8.0
# smart-open==1.9.0
# snowballstemmer==2.0.0
# sortedcontainers==2.1.0
# spacy==2.1.9
# Sphinx==1.8.5
# sphinxcontrib-websupport==1.1.2
# SQLAlchemy==1.3.12
# sqlparse==0.3.0
# srsly==1.0.1
# stable-baselines==2.2.1
# statsmodels==0.10.2
# sympy==1.1.1
# tables==3.4.4
# tabulate==0.8.6
# tblib==1.6.0
# tensor2tensor==1.14.1
# tensorboard==1.15.0
# tensorboardcolab==0.0.22
# tensorflow==1.15.0
# tensorflow-datasets==1.3.2
# tensorflow-estimator==1.15.1
# tensorflow-gan==2.0.0
# tensorflow-hub==0.7.0
# tensorflow-metadata==0.15.2
# tensorflow-privacy==0.2.2
# tensorflow-probability==0.7.0
# termcolor==1.1.0
# terminado==0.8.3
# testpath==0.4.4
# text-unidecode==1.3
# textblob==0.15.3
# textgenrnn==1.4.1
# tflearn==0.3.2
# Theano==1.0.4
# thinc==7.0.8
# toolz==0.10.0
# torch==1.3.1
# torchsummary==1.5.1
# torchtext==0.3.1
# torchvision==0.4.2
# tornado==4.5.3
# tqdm==4.28.1
# traitlets==4.3.3
# tweepy==3.6.0
# typing==3.6.6
# typing-extensions==3.6.6
# tzlocal==1.5.1
# umap-learn==0.3.10
# uritemplate==3.0.1
# urllib3==1.24.3
# vega-datasets==0.8.0
# wasabi==0.6.0
# wcwidth==0.1.8
# webencodings==0.5.1
# Werkzeug==0.16.0
# widgetsnbextension==3.5.1
# wordcloud==1.5.0
# wrapt==1.11.2
# xarray==0.14.1
# xgboost==0.90
# xkit==0.0.0
# xlrd==1.1.0
# xlwt==1.3.0
# yellowbrick==0.9.1
# zict==1.0.0
# zipfile36==0.1.3
# zipp==0.6.0
# zmq==0.0.0

# %%
from platform import python_version

print(python_version())
# Out:
# 3.6.9
